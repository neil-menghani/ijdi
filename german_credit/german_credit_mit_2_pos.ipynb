# %%
import sys
sys.path.insert(1, './scripts')

from scan import *
from prep import *
import pandas as pd, numpy as np

# Read recipe inputs
german_prep_df = pd.read_csv("datasets/german_credit_prep.csv")
german_prep_df
# Out:
#      Unnamed: 0  under_25     sex            job housing   savings  checking  \
# 0             0     False    Male  Multiple Jobs     Own       NaN    Little
# 1             1      True  Female  Multiple Jobs     Own    Little  Moderate
# 2             2     False    Male          1 Job     Own    Little       NaN
# 3             3     False    Male  Multiple Jobs    Free    Little    Little
# 4             4     False    Male  Multiple Jobs    Free    Little    Little
# ..          ...       ...     ...            ...     ...       ...       ...
# 995         995     False  Female          1 Job     Own    Little       NaN
# 996         996     False    Male  Multiple Jobs     Own    Little    Little
# 997         997     False    Male  Multiple Jobs     Own    Little       NaN
# 998         998      True    Male  Multiple Jobs    Free    Little    Little
# 999         999     False    Male  Multiple Jobs     Own  Moderate  Moderate
#
#     credit_amt   duration              purpose  outcomes  proba_lr  proba_rf
# 0     Moderate      Short             Radio/TV         0  0.114175  0.046250
# 1         High  Very Long             Radio/TV         1  0.612611  0.803333
# 2     Moderate   Moderate            Education         0  0.154985  0.092917
# 3         High       Long  Furniture/Equipment         0  0.545431  0.141350
# 4         High       Long                  Car         1  0.574045  0.213719
# ..         ...        ...                  ...       ...       ...       ...
# 995   Moderate   Moderate  Furniture/Equipment         0  0.136923  0.122083
# 996       High       Long                  Car         0  0.517829  0.687929
# 997        Low   Moderate             Radio/TV         0  0.135555  0.010000
# 998   Moderate       Long             Radio/TV         1  0.550995  0.829405
# 999       High       Long                  Car         0  0.397940  0.248544
#
# [1000 rows x 13 columns]

# %% [markdown]
# Select only covariates to prepare for simulating probabilities and outcomes.

# %%
german_mit_df = german_prep_df
german_mit_df
# Out:
#      Unnamed: 0  under_25     sex            job housing   savings  checking  \
# 0             0     False    Male  Multiple Jobs     Own       NaN    Little
# 1             1      True  Female  Multiple Jobs     Own    Little  Moderate
# 2             2     False    Male          1 Job     Own    Little       NaN
# 3             3     False    Male  Multiple Jobs    Free    Little    Little
# 4             4     False    Male  Multiple Jobs    Free    Little    Little
# ..          ...       ...     ...            ...     ...       ...       ...
# 995         995     False  Female          1 Job     Own    Little       NaN
# 996         996     False    Male  Multiple Jobs     Own    Little    Little
# 997         997     False    Male  Multiple Jobs     Own    Little       NaN
# 998         998      True    Male  Multiple Jobs    Free    Little    Little
# 999         999     False    Male  Multiple Jobs     Own  Moderate  Moderate
#
#     credit_amt   duration              purpose  outcomes  proba_lr  proba_rf
# 0     Moderate      Short             Radio/TV         0  0.114175  0.046250
# 1         High  Very Long             Radio/TV         1  0.612611  0.803333
# 2     Moderate   Moderate            Education         0  0.154985  0.092917
# 3         High       Long  Furniture/Equipment         0  0.545431  0.141350
# 4         High       Long                  Car         1  0.574045  0.213719
# ..         ...        ...                  ...       ...       ...       ...
# 995   Moderate   Moderate  Furniture/Equipment         0  0.136923  0.122083
# 996       High       Long                  Car         0  0.517829  0.687929
# 997        Low   Moderate             Radio/TV         0  0.135555  0.010000
# 998   Moderate       Long             Radio/TV         1  0.550995  0.829405
# 999       High       Long                  Car         0  0.397940  0.248544
#
# [1000 rows x 13 columns]

# %%
# specify probability and outcomes columns
PROBA_CONFUSION_COL = 'proba_lr'
PROBA_IJDI_COL = 'proba_rf'
OUTCOMES_COL = 'outcomes'
FEATURES = ['under_25', 'sex', 'job', 'housing', 'savings', 'checking',
            'credit_amt', 'duration', 'purpose']
THRESHOLD = 0.5
LAMBDA_PARAM = 1
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# %%
# # filter for only negative outcomes
# negatives_df = german_mit_df.loc[german_mit_df[OUTCOMES_COL] == 0]

# # scan with positive direction
# current_subset, current_score = run_ijdi_scan(negatives_df, FEATURES, PROBA_CONFUSION_COL, PROBA_IJDI_COL, OUTCOMES_COL,
#                                               THRESHOLD, LAMBDA_PARAM)
# # summarize_scan(negatives_df, FEATURES, PROBA_COL, OUTCOMES_COL, current_subset, include='all')\
# current_subset, current_score

# %% [markdown]
# ### Implement Mitigation Approach 2

# %% [markdown]
# Set lambda vales to test.

# %%
lambda_vals = [0, 0.3, 1, 3, 10]
# n_iters = 1

# specify parameters for generating metrics and IJDI scan
proba_confusion_col = 'proba_lr'
proba_ijdi_col = 'proba_rf'
outcomes_col = 'outcomes'
features = ['under_25', 'sex', 'job', 'housing', 'savings', 'checking',
            'credit_amt', 'duration', 'purpose']
threshold = 'threshold'

# define stopping criteria
stop_limit = 0
max_iters = 5


pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(100)

# %%
sim_data = []

# %% [markdown]
# Implement approach for Positives

# %%
# filter for negative or positive outcomes
positives_df = german_mit_df.loc[german_mit_df[outcomes_col] == 1]

for lambda_param in lambda_vals: # run IJDI scan for various lambda values

    print("Lambda =", lambda_param)

    i = 0
    ijdi_present = True
    # set initial threshold
    positives_df['threshold'] = 0.5

    while ijdi_present and i <= 20:

        i += 1
        print("Iteration", i)

        # Run Negative or Positive IJDI Scan. Make sure to pass in copy because data may be modified by the function!
        current_subset, current_score = run_ijdi_scan(positives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                      threshold, lambda_param, constant_threshold=False, verbose=True)

        print("Score for Positives IJDI-Scan:", current_score)

        # append data
        row = [lambda_param, i, current_score, 'positive']
        sim_data.append(row)

        print(row)

        if current_score > stop_limit:

            # correct IJDI by setting new threshold for subset
            positives_df['threshold'] = correct_ijdi_subset(positives_df.copy(deep=True), features,
                                                            proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                            threshold, lambda_param, current_subset)
            print(positives_df['threshold'])

        else:
            ijdi_present = False

        print("\n----------------------------------------------------\n")
# Out:
# Lambda = 0
# Iteration 1
# Subset found on iteration 1 of 10 with score 31.531333329465813 :
# {'purpose': ['Business', 'Car', 'Domestic appliances', 'Education', 'Repairs', 'Vacation/Others'], 'savings': ['Little', 'Moderate'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long']}
# Best score is now 31.531333329465813
# Subset found on iteration 2 of 10 with score 37.90588600604126 :
# {'savings': ['Little'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'housing': ['Free', 'Rent']}
# Best score is now 37.90588600604126
# Subset found on iteration 3 of 10 with score 37.90588600604126 :
# {'duration': ['Long', 'Very Long'], 'savings': ['Little'], 'checking': ['Little', 'Moderate'], 'housing': ['Free', 'Rent']}
# Current score of 37.90588600604126 does not beat best score of 37.90588600604126
# Subset found on iteration 4 of 10 with score 37.90588600604126 :
# {'housing': ['Free', 'Rent'], 'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate'], 'savings': ['Little']}
# Current score of 37.90588600604126 does not beat best score of 37.90588600604126
# Subset found on iteration 5 of 10 with score 37.90588600604126 :
# {'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate'], 'savings': ['Little'], 'housing': ['Free', 'Rent']}
# Current score of 37.90588600604126 does not beat best score of 37.90588600604126
# Subset found on iteration 6 of 10 with score 37.90588600604126 :
# {'checking': ['Little', 'Moderate'], 'housing': ['Free', 'Rent'], 'duration': ['Long', 'Very Long'], 'savings': ['Little']}
# Current score of 37.90588600604126 does not beat best score of 37.90588600604126
# Subset found on iteration 7 of 10 with score 31.531333329465813 :
# {'purpose': ['Business', 'Car', 'Domestic appliances', 'Education', 'Repairs', 'Vacation/Others'], 'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate'], 'savings': ['Little', 'Moderate']}
# Current score of 31.531333329465813 does not beat best score of 37.90588600604126
# Subset found on iteration 8 of 10 with score 26.306602296956044 :
# {'purpose': ['Business', 'Car', 'Domestic appliances', 'Education'], 'job': ['Multiple Jobs', 'None'], 'savings': ['Little'], 'checking': ['Little'], 'duration': ['Long', 'Very Long']}
# Current score of 26.306602296956044 does not beat best score of 37.90588600604126
# Subset found on iteration 9 of 10 with score 31.531333329465813 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Education', 'Repairs', 'Vacation/Others'], 'checking': ['Little', 'Moderate']}
# Current score of 31.531333329465813 does not beat best score of 37.90588600604126
# Subset found on iteration 10 of 10 with score 37.90588600604126 :
# {'duration': ['Long', 'Very Long'], 'savings': ['Little'], 'checking': ['Little', 'Moderate'], 'housing': ['Free', 'Rent']}
# Current score of 37.90588600604126 does not beat best score of 37.90588600604126
# Required time =  39.04208445549011 seconds
# Found positive subset for ijdi scan:
# {'savings': ['Little'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'housing': ['Free', 'Rent']}
# Score: 37.90588600604126
# First Iteration
# Average p_delta: 0.13646717341150294
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 4    0.213719  0.213719  0.720745   0.720745 -0.507026                  0.39
# 11   0.950000  0.950000  0.720745   0.720745  0.229255                  0.39
# 18   0.940000  0.940000  0.720745   0.720745  0.219255                  0.39
# 44   0.900000  0.900000  0.720745   0.720745  0.179255                  0.39
# 54   0.753333  0.753333  0.720745   0.720745  0.032588                  0.39
# 59   0.910000  0.910000  0.720745   0.720745  0.189255                  0.39
# 62   0.905000  0.905000  0.720745   0.720745  0.184255                  0.39
# 95   0.940000  0.940000  0.720745   0.720745  0.219255                  0.39
# 242  0.920000  0.920000  0.720745   0.720745  0.199255                  0.39
# 291  0.435833  0.435833  0.720745   0.720745 -0.284912                  0.39
# 334  0.860000  0.860000  0.720745   0.720745  0.139255                  0.39
# 359  0.871667  0.871667  0.720745   0.720745  0.150922                  0.39
# 375  0.954000  0.954000  0.720745   0.720745  0.233255                  0.39
# 378  0.920000  0.920000  0.720745   0.720745  0.199255                  0.39
# 466  0.802500  0.802500  0.720745   0.720745  0.081755                  0.39
# 491  0.740000  0.740000  0.720745   0.720745  0.019255                  0.39
# 504  0.970000  0.970000  0.720745   0.720745  0.249255                  0.39
# 522  0.880000  0.880000  0.720745   0.720745  0.159255                  0.39
# 528  0.848071  0.848071  0.720745   0.720745  0.127326                  0.39
# 538  0.990000  0.990000  0.720745   0.720745  0.269255                  0.39
# 545  0.511667  0.511667  0.720745   0.720745 -0.209078                  0.39
# 561  0.930000  0.930000  0.720745   0.720745  0.209255                  0.39
# 570  0.910000  0.910000  0.720745   0.720745  0.189255                  0.39
# 583  0.795000  0.795000  0.720745   0.720745  0.074255                  0.39
# 593  0.900000  0.900000  0.720745   0.720745  0.179255                  0.39
# 596  0.970000  0.970000  0.720745   0.720745  0.249255                  0.39
# 602  0.731667  0.731667  0.720745   0.720745  0.010922                  0.39
# 701  0.990000  0.990000  0.720745   0.720745  0.269255                  0.39
# 728  0.910000  0.910000  0.720745   0.720745  0.189255                  0.39
# 731  0.930000  0.930000  0.720745   0.720745  0.209255                  0.39
# 736  0.885000  0.885000  0.720745   0.720745  0.164255                  0.39
# 788  0.930000  0.930000  0.720745   0.720745  0.209255                  0.39
# 814  0.990000  0.990000  0.720745   0.720745  0.269255                  0.39
# 832  0.855000  0.855000  0.720745   0.720745  0.134255                  0.39
# 914  0.831167  0.831167  0.720745   0.720745  0.110422                  0.39
# 919  0.879961  0.879961  0.720745   0.720745  0.159216                  0.39
# 927  0.910000  0.910000  0.720745   0.720745  0.189255                  0.39
# 938  0.930000  0.930000  0.720745   0.720745  0.209255                  0.39
# 972  0.862714  0.862714  0.720745   0.720745  0.141969                  0.39
# 973  0.960000  0.960000  0.720745   0.720745  0.239255                  0.39
# 998  0.829405  0.829405  0.720745   0.720745  0.108660                  0.39
#
#      p_hat_raw  p_hat
# 4         0.39   0.39
# 11        0.39   0.39
# 18        0.39   0.39
# 44        0.39   0.39
# 54        0.39   0.39
# 59        0.39   0.39
# 62        0.39   0.39
# 95        0.39   0.39
# 242       0.39   0.39
# 291       0.39   0.39
# 334       0.39   0.39
# 359       0.39   0.39
# 375       0.39   0.39
# 378       0.39   0.39
# 466       0.39   0.39
# 491       0.39   0.39
# 504       0.39   0.39
# 522       0.39   0.39
# 528       0.39   0.39
# 538       0.39   0.39
# 545       0.39   0.39
# 561       0.39   0.39
# 570       0.39   0.39
# 583       0.39   0.39
# 593       0.39   0.39
# 596       0.39   0.39
# 602       0.39   0.39
# 701       0.39   0.39
# 728       0.39   0.39
# 731       0.39   0.39
# 736       0.39   0.39
# 788       0.39   0.39
# 814       0.39   0.39
# 832       0.39   0.39
# 914       0.39   0.39
# 919       0.39   0.39
# 927       0.39   0.39
# 938       0.39   0.39
# 972       0.39   0.39
# 973       0.39   0.39
# 998       0.39   0.39
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 37.90588600604126
# [0, 1, 37.90588600604126, 'positive']
# Target positive rate for subset: 0.29343629343629346
# New threshold for subset: 0.7379955549534358
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.737996
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.500000
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 11.93239596935416 :
# {'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Education'], 'under_25': [True], 'housing': ['Free', 'Own']}
# Best score is now 11.93239596935416
# Subset found on iteration 2 of 10 with score 22.426757591440175 :
# {'purpose': ['Business', 'Car', 'Domestic appliances', 'Education', 'Repairs', 'Vacation/Others'], 'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little', 'Moderate'], 'housing': ['Own', 'Rent'], 'checking': ['Little', 'Moderate'], 'credit_amt': ['High', 'Low', 'Very High']}
# Best score is now 22.426757591440175
# Subset found on iteration 3 of 10 with score 16.330206708202525 :
# {'savings': ['Little', 'Moderate'], 'credit_amt': ['High', 'Low', 'Very High'], 'under_25': [True], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Education']}
# Current score of 16.330206708202525 does not beat best score of 22.426757591440175
# Subset found on iteration 4 of 10 with score 17.90657975494449 :
# {'purpose': ['Business', 'Domestic appliances', 'Education', 'Repairs'], 'credit_amt': ['High', 'Low', 'Very High'], 'checking': ['Little']}
# Current score of 17.90657975494449 does not beat best score of 22.426757591440175
# Subset found on iteration 5 of 10 with score 11.93239596935416 :
# {'under_25': [True], 'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Education'], 'housing': ['Free', 'Own']}
# Current score of 11.93239596935416 does not beat best score of 22.426757591440175
# Subset found on iteration 6 of 10 with score 23.094611084688083 :
# {'purpose': ['Business', 'Car', 'Domestic appliances', 'Education', 'Furniture/Equipment', 'Repairs', 'Vacation/Others'], 'credit_amt': ['Low', 'Very High'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long']}
# Best score is now 23.094611084688083
# Subset found on iteration 7 of 10 with score 0.937871907728751 :
# {'purpose': ['Repairs'], 'job': ['1 Job'], 'housing': ['Own']}
# Current score of 0.937871907728751 does not beat best score of 23.094611084688083
# Subset found on iteration 8 of 10 with score 23.094611084688083 :
# {'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long'], 'credit_amt': ['Low', 'Very High'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Education', 'Furniture/Equipment', 'Repairs', 'Vacation/Others']}
# Current score of 23.094611084688083 does not beat best score of 23.094611084688083
# Subset found on iteration 9 of 10 with score 17.90657975494449 :
# {'checking': ['Little'], 'purpose': ['Business', 'Domestic appliances', 'Education', 'Repairs'], 'credit_amt': ['High', 'Low', 'Very High']}
# Current score of 17.90657975494449 does not beat best score of 23.094611084688083
# Subset found on iteration 10 of 10 with score 5.889359538643757 :
# {'savings': ['Moderate'], 'under_25': [True], 'sex': ['Female']}
# Current score of 5.889359538643757 does not beat best score of 23.094611084688083
# Required time =  38.92254161834717 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Car', 'Domestic appliances', 'Education', 'Furniture/Equipment', 'Repairs', 'Vacation/Others'], 'credit_amt': ['Low', 'Very High'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long']}
# Score: 23.094611084688083
# First Iteration
# Average p_delta: 0.1176123680155825
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 18   0.940000  0.940000  0.720745   0.720745  0.219255                  0.29
# 63   0.880000  0.880000  0.720745   0.720745  0.159255                  0.29
# 87   0.730000  0.730000  0.720745   0.720745  0.009255                  0.29
# 95   0.940000  0.940000  0.720745   0.720745  0.219255                  0.29
# 105  0.980000  0.980000  0.720745   0.720745  0.259255                  0.29
# 127  0.827500  0.827500  0.720745   0.720745  0.106755                  0.29
# 170  0.943500  0.943500  0.720745   0.720745  0.222755                  0.29
# 184  0.822214  0.822214  0.720745   0.720745  0.101469                  0.29
# 197  0.755000  0.755000  0.720745   0.720745  0.034255                  0.29
# 203  0.822500  0.822500  0.720745   0.720745  0.101755                  0.29
# 240  0.833333  0.833333  0.720745   0.720745  0.112588                  0.29
# 274  0.760000  0.760000  0.720745   0.720745  0.039255                  0.29
# 313  0.642190  0.642190  0.720745   0.720745 -0.078555                  0.29
# 374  0.870000  0.870000  0.720745   0.720745  0.149255                  0.29
# 378  0.920000  0.920000  0.720745   0.720745  0.199255                  0.29
# 381  0.910000  0.910000  0.720745   0.720745  0.189255                  0.29
# 431  0.980000  0.980000  0.720745   0.720745  0.259255                  0.29
# 510  0.765298  0.765298  0.720745   0.720745  0.044553                  0.29
# 563  0.825000  0.825000  0.720745   0.720745  0.104255                  0.29
# 610  0.780000  0.780000  0.720745   0.720745  0.059255                  0.29
# 640  0.838000  0.838000  0.720745   0.720745  0.117255                  0.29
# 649  0.720000  0.720000  0.720745   0.720745 -0.000745                  0.29
# 656  0.642190  0.642190  0.720745   0.720745 -0.078555                  0.29
# 661  0.740000  0.740000  0.720745   0.720745  0.019255                  0.29
# 714  0.840000  0.840000  0.720745   0.720745  0.119255                  0.29
# 736  0.885000  0.885000  0.720745   0.720745  0.164255                  0.29
# 751  0.846190  0.846190  0.720745   0.720745  0.125445                  0.29
# 759  0.765298  0.765298  0.720745   0.720745  0.044553                  0.29
# 783  0.838000  0.838000  0.720745   0.720745  0.117255                  0.29
# 832  0.855000  0.855000  0.720745   0.720745  0.134255                  0.29
# 885  0.906000  0.906000  0.720745   0.720745  0.185255                  0.29
# 887  0.920000  0.920000  0.720745   0.720745  0.199255                  0.29
# 915  0.945000  0.945000  0.720745   0.720745  0.224255                  0.29
# 925  0.765298  0.765298  0.720745   0.720745  0.044553                  0.29
# 927  0.910000  0.910000  0.720745   0.720745  0.189255                  0.29
#
#      p_hat_raw  p_hat
# 18        0.29   0.29
# 63        0.29   0.29
# 87        0.29   0.29
# 95        0.29   0.29
# 105       0.29   0.29
# 127       0.29   0.29
# 170       0.29   0.29
# 184       0.29   0.29
# 197       0.29   0.29
# 203       0.29   0.29
# 240       0.29   0.29
# 274       0.29   0.29
# 313       0.29   0.29
# 374       0.29   0.29
# 378       0.29   0.29
# 381       0.29   0.29
# 431       0.29   0.29
# 510       0.29   0.29
# 563       0.29   0.29
# 610       0.29   0.29
# 640       0.29   0.29
# 649       0.29   0.29
# 656       0.29   0.29
# 661       0.29   0.29
# 714       0.29   0.29
# 736       0.29   0.29
# 751       0.29   0.29
# 759       0.29   0.29
# 783       0.29   0.29
# 832       0.29   0.29
# 885       0.29   0.29
# 887       0.29   0.29
# 915       0.29   0.29
# 925       0.29   0.29
# 927       0.29   0.29
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 23.094611084688083
# [0, 2, 23.094611084688083, 'positive']
# Target positive rate for subset: 0.21509433962264152
# New threshold for subset: 0.7821482320625971
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.737996
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.500000
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 14.693915893824832 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV'], 'duration': ['Very Long'], 'sex': ['Female']}
# Best score is now 14.693915893824832
# Subset found on iteration 2 of 10 with score 20.511482251354728 :
# {'checking': ['Little', 'Moderate'], 'housing': ['Own', 'Rent'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Furniture/Equipment'], 'duration': ['Very Long']}
# Best score is now 20.511482251354728
# Subset found on iteration 3 of 10 with score 19.816006407463977 :
# {'job': ['Multiple Jobs'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Education'], 'savings': ['Little', 'Moderate'], 'housing': ['Own', 'Rent'], 'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate']}
# Current score of 19.816006407463977 does not beat best score of 20.511482251354728
# Subset found on iteration 4 of 10 with score 20.511482251354728 :
# {'housing': ['Own', 'Rent'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Furniture/Equipment'], 'duration': ['Very Long'], 'checking': ['Little', 'Moderate']}
# Current score of 20.511482251354728 does not beat best score of 20.511482251354728
# Subset found on iteration 5 of 10 with score 19.164335970547995 :
# {'savings': ['Little'], 'duration': ['Long', 'Moderate', 'Very Long'], 'credit_amt': ['High', 'Moderate', 'Very High'], 'job': ['Multiple Jobs'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Education'], 'checking': ['Little'], 'housing': ['Own', 'Rent']}
# Current score of 19.164335970547995 does not beat best score of 20.511482251354728
# Subset found on iteration 6 of 10 with score 15.723307483207316 :
# {'housing': ['Free', 'Rent'], 'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV', 'Repairs'], 'duration': ['Moderate', 'Very Long'], 'checking': ['Little'], 'sex': ['Female']}
# Current score of 15.723307483207316 does not beat best score of 20.511482251354728
# Subset found on iteration 7 of 10 with score 20.511482251354728 :
# {'housing': ['Own', 'Rent'], 'duration': ['Very Long'], 'checking': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Furniture/Equipment']}
# Current score of 20.511482251354728 does not beat best score of 20.511482251354728
# Subset found on iteration 8 of 10 with score 13.993716208424432 :
# {'savings': ['Little', 'Moderate'], 'housing': ['Own', 'Rent'], 'sex': ['Female'], 'checking': ['Little', 'Moderate'], 'credit_amt': ['High', 'Moderate', 'Very High'], 'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'job': ['Multiple Jobs'], 'duration': ['Long', 'Moderate', 'Very Long']}
# Current score of 13.993716208424432 does not beat best score of 20.511482251354728
# Subset found on iteration 9 of 10 with score 5.917566357529931 :
# {'credit_amt': ['Very High'], 'purpose': ['Business']}
# Current score of 5.917566357529931 does not beat best score of 20.511482251354728
# Subset found on iteration 10 of 10 with score 11.087151937276053 :
# {'credit_amt': ['High', 'Moderate', 'Very High'], 'under_25': [True], 'duration': ['Moderate', 'Very Long'], 'checking': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Furniture/Equipment']}
# Current score of 11.087151937276053 does not beat best score of 20.511482251354728
# Required time =  42.15210151672363 seconds
# Found positive subset for ijdi scan:
# {'checking': ['Little', 'Moderate'], 'housing': ['Own', 'Rent'], 'purpose': ['Business', 'Car', 'Domestic appliances', 'Furniture/Equipment'], 'duration': ['Very Long']}
# Score: 20.511482251354728
# First Iteration
# Average p_delta: 0.17750580077330103
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 11   0.950000  0.950000  0.720745   0.720745  0.229255              0.216667
# 29   0.838000  0.838000  0.720745   0.720745  0.117255              0.216667
# 63   0.880000  0.880000  0.720745   0.720745  0.159255              0.216667
# 95   0.940000  0.940000  0.720745   0.720745  0.219255              0.216667
# 295  0.960000  0.960000  0.720745   0.720745  0.239255              0.216667
# 332  0.800000  0.800000  0.720745   0.720745  0.079255              0.216667
# 375  0.954000  0.954000  0.720745   0.720745  0.233255              0.216667
# 444  0.960000  0.960000  0.720745   0.720745  0.239255              0.216667
# 706  0.838667  0.838667  0.720745   0.720745  0.117922              0.216667
# 714  0.840000  0.840000  0.720745   0.720745  0.119255              0.216667
# 728  0.910000  0.910000  0.720745   0.720745  0.189255              0.216667
# 813  0.824846  0.824846  0.720745   0.720745  0.104101              0.216667
# 887  0.920000  0.920000  0.720745   0.720745  0.199255              0.216667
# 973  0.960000  0.960000  0.720745   0.720745  0.239255              0.216667
#
#      p_hat_raw     p_hat
# 11    0.216667  0.216667
# 29    0.216667  0.216667
# 63    0.216667  0.216667
# 95    0.216667  0.216667
# 295   0.216667  0.216667
# 332   0.216667  0.216667
# 375   0.216667  0.216667
# 444   0.216667  0.216667
# 706   0.216667  0.216667
# 714   0.216667  0.216667
# 728   0.216667  0.216667
# 813   0.216667  0.216667
# 887   0.216667  0.216667
# 973   0.216667  0.216667
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 20.511482251354728
# [0, 3, 20.511482251354728, 'positive']
# Target positive rate for subset: 0.17832167832167833
# New threshold for subset: 0.8212489204916923
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.821249
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.500000
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 14.733144852920734 :
# {'credit_amt': ['High', 'Moderate'], 'housing': ['Rent'], 'duration': ['Moderate'], 'purpose': ['Car', 'Furniture/Equipment'], 'checking': ['Little']}
# Best score is now 14.733144852920734
# Subset found on iteration 2 of 10 with score 17.302495160261643 :
# {'duration': ['Long', 'Moderate'], 'credit_amt': ['High', 'Moderate', 'Very High'], 'checking': ['Little'], 'purpose': ['Business', 'Car', 'Education'], 'housing': ['Own', 'Rent'], 'job': ['Multiple Jobs']}
# Best score is now 17.302495160261643
# Subset found on iteration 3 of 10 with score 17.302495160261643 :
# {'duration': ['Long', 'Moderate'], 'purpose': ['Business', 'Car', 'Education'], 'credit_amt': ['High', 'Moderate', 'Very High'], 'job': ['Multiple Jobs'], 'checking': ['Little'], 'housing': ['Own', 'Rent']}
# Current score of 17.302495160261643 does not beat best score of 17.302495160261643
# Subset found on iteration 4 of 10 with score 6.659175490186992 :
# {'credit_amt': ['Very High'], 'housing': ['Rent']}
# Current score of 6.659175490186992 does not beat best score of 17.302495160261643
# Subset found on iteration 5 of 10 with score 10.220356509232708 :
# {'savings': ['Little'], 'checking': ['Little'], 'sex': ['Female']}
# Current score of 10.220356509232708 does not beat best score of 17.302495160261643
# Subset found on iteration 6 of 10 with score 10.220356509232708 :
# {'checking': ['Little'], 'sex': ['Female'], 'savings': ['Little']}
# Current score of 10.220356509232708 does not beat best score of 17.302495160261643
# Subset found on iteration 7 of 10 with score 4.744381617640242 :
# {'credit_amt': ['Very High'], 'under_25': [True], 'job': ['1 Job', 'Multiple Jobs']}
# Current score of 4.744381617640242 does not beat best score of 17.302495160261643
# Subset found on iteration 8 of 10 with score 14.433144852920734 :
# {'duration': ['Moderate', 'Very Long'], 'checking': ['Little'], 'purpose': ['Car', 'Furniture/Equipment', 'Radio/TV', 'Repairs'], 'housing': ['Free', 'Rent'], 'sex': ['Female']}
# Current score of 14.433144852920734 does not beat best score of 17.302495160261643
# Subset found on iteration 9 of 10 with score 4.944381617640242 :
# {'job': ['1 Job'], 'duration': ['Very Long']}
# Current score of 4.944381617640242 does not beat best score of 17.302495160261643
# Subset found on iteration 10 of 10 with score 19.777526470560968 :
# {'purpose': ['Business', 'Car', 'Education'], 'savings': ['Little'], 'job': ['Multiple Jobs'], 'housing': ['Own'], 'checking': ['Little'], 'duration': ['Long']}
# Best score is now 19.777526470560968
# Required time =  32.74663472175598 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Car', 'Education'], 'savings': ['Little'], 'job': ['Multiple Jobs'], 'housing': ['Own'], 'checking': ['Little'], 'duration': ['Long']}
# Score: 19.777526470560968
# First Iteration
# Average p_delta: 0.06416514837014857
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 131  0.979848  0.979848  0.720745   0.720745  0.259103                  0.18
# 212  0.738356  0.738356  0.720745   0.720745  0.017611                  0.18
# 446  0.768333  0.768333  0.720745   0.720745  0.047588                  0.18
# 454  0.687929  0.687929  0.720745   0.720745 -0.032817                  0.18
# 500  0.727500  0.727500  0.720745   0.720745  0.006755                  0.18
# 652  0.306680  0.306680  0.720745   0.720745 -0.414065                  0.18
# 771  0.920000  0.920000  0.720745   0.720745  0.199255                  0.18
# 789  0.979848  0.979848  0.720745   0.720745  0.259103                  0.18
# 805  0.915000  0.915000  0.720745   0.720745  0.194255                  0.18
# 812  0.915000  0.915000  0.720745   0.720745  0.194255                  0.18
# 951  0.792500  0.792500  0.720745   0.720745  0.071755                  0.18
# 983  0.687929  0.687929  0.720745   0.720745 -0.032817                  0.18
#
#      p_hat_raw  p_hat
# 131       0.18   0.18
# 212       0.18   0.18
# 446       0.18   0.18
# 454       0.18   0.18
# 500       0.18   0.18
# 652       0.18   0.18
# 771       0.18   0.18
# 789       0.18   0.18
# 805       0.18   0.18
# 812       0.18   0.18
# 951       0.18   0.18
# 983       0.18   0.18
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 19.777526470560968
# [0, 4, 19.777526470560968, 'positive']
# Target positive rate for subset: 0.14583333333333334
# New threshold for subset: 0.6136301150902534
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.821249
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.613630
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 5
# Subset found on iteration 1 of 10 with score 12.40635961571825 :
# {'purpose': ['Car', 'Furniture/Equipment', 'Radio/TV', 'Repairs'], 'savings': ['Little'], 'duration': ['Long', 'Moderate', 'Very Long'], 'sex': ['Female'], 'checking': ['Little', 'Moderate']}
# Best score is now 12.40635961571825
# Subset found on iteration 2 of 10 with score 3.2391740451460946 :
# {'housing': ['Own'], 'under_25': [True], 'sex': ['Female'], 'credit_amt': ['Low'], 'purpose': ['Education', 'Radio/TV']}
# Current score of 3.2391740451460946 does not beat best score of 12.40635961571825
# Subset found on iteration 3 of 10 with score 12.011374839547667 :
# {'checking': ['Little', 'Moderate'], 'purpose': ['Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'job': ['Multiple Jobs'], 'sex': ['Female'], 'duration': ['Long', 'Moderate', 'Very Long'], 'credit_amt': ['High', 'Moderate', 'Very High'], 'savings': ['Little']}
# Current score of 12.011374839547667 does not beat best score of 12.40635961571825
# Subset found on iteration 4 of 10 with score 14.15669618058438 :
# {'purpose': ['Car', 'Furniture/Equipment', 'Repairs'], 'credit_amt': ['Moderate', 'Very High'], 'housing': ['Free', 'Rent'], 'checking': ['Little'], 'job': ['Multiple Jobs', 'None'], 'duration': ['Moderate', 'Very Long']}
# Best score is now 14.15669618058438
# Subset found on iteration 5 of 10 with score 3.539174045146095 :
# {'checking': ['Little'], 'purpose': ['Education'], 'duration': ['Short']}
# Current score of 3.539174045146095 does not beat best score of 14.15669618058438
# Subset found on iteration 6 of 10 with score 5.358761067719142 :
# {'job': ['1 Job', 'Multiple Jobs'], 'under_25': [True], 'credit_amt': ['Very High']}
# Current score of 5.358761067719142 does not beat best score of 14.15669618058438
# Subset found on iteration 7 of 10 with score 5.358761067719142 :
# {'savings': ['Little', 'Moderate'], 'credit_amt': ['Very High'], 'under_25': [True]}
# Current score of 5.358761067719142 does not beat best score of 14.15669618058438
# Subset found on iteration 8 of 10 with score 16.176283203157418 :
# {'duration': ['Moderate', 'Short', 'Very Long'], 'checking': ['Little'], 'purpose': ['Car', 'Education', 'Furniture/Equipment', 'Repairs'], 'housing': ['Free', 'Rent'], 'sex': ['Female']}
# Best score is now 16.176283203157418
# Subset found on iteration 9 of 10 with score 7.37834809029219 :
# {'duration': ['Very Long'], 'savings': ['Little'], 'under_25': [True]}
# Current score of 7.37834809029219 does not beat best score of 16.176283203157418
# Subset found on iteration 10 of 10 with score 1.5195870225730475 :
# {'credit_amt': ['High'], 'under_25': [False], 'duration': ['Very Long'], 'savings': ['Moderate']}
# Current score of 1.5195870225730475 does not beat best score of 16.176283203157418
# Required time =  32.64547061920166 seconds
# Found positive subset for ijdi scan:
# {'duration': ['Moderate', 'Short', 'Very Long'], 'checking': ['Little'], 'purpose': ['Car', 'Education', 'Furniture/Equipment', 'Repairs'], 'housing': ['Free', 'Rent'], 'sex': ['Female']}
# Score: 16.176283203157418
# First Iteration
# Average p_delta: 0.018732277999778217
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 44   0.900000  0.900000  0.720745   0.720745  0.179255              0.146667
# 155  0.597956  0.597956  0.720745   0.720745 -0.122789              0.146667
# 429  0.860000  0.860000  0.720745   0.720745  0.139255              0.146667
# 475  0.790000  0.790000  0.720745   0.720745  0.069255              0.146667
# 585  0.597956  0.597956  0.720745   0.720745 -0.122789              0.146667
# 711  0.855000  0.855000  0.720745   0.720745  0.134255              0.146667
# 761  0.597956  0.597956  0.720745   0.720745 -0.122789              0.146667
# 826  0.940000  0.940000  0.720745   0.720745  0.219255              0.146667
# 831  0.516429  0.516429  0.720745   0.720745 -0.204317              0.146667
#
#      p_hat_raw     p_hat
# 44    0.146667  0.146667
# 155   0.146667  0.146667
# 429   0.146667  0.146667
# 475   0.146667  0.146667
# 585   0.146667  0.146667
# 711   0.146667  0.146667
# 761   0.146667  0.146667
# 826   0.146667  0.146667
# 831   0.146667  0.146667
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 16.176283203157418
# [0, 5, 16.176283203157418, 'positive']
# Target positive rate for subset: 0.12027491408934708
# New threshold for subset: 0.6536277086000816
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.821249
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.613630
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 6
# Subset found on iteration 1 of 10 with score 7.781024811574585 :
# {'credit_amt': ['High', 'Very High'], 'purpose': ['Business', 'Car'], 'under_25': [True], 'housing': ['Free', 'Rent']}
# Best score is now 7.781024811574585
# Subset found on iteration 2 of 10 with score 6.527490499605953 :
# {'job': ['1 Job', 'Multiple Jobs'], 'housing': ['Rent'], 'purpose': ['Business', 'Car'], 'checking': ['Little', 'Moderate'], 'credit_amt': ['High', 'Moderate', 'Very High']}
# Current score of 6.527490499605953 does not beat best score of 7.781024811574585
# Subset found on iteration 3 of 10 with score 7.881024811574585 :
# {'purpose': ['Car'], 'checking': ['Little'], 'job': ['Multiple Jobs'], 'under_25': [False], 'credit_amt': ['Moderate'], 'housing': ['Rent']}
# Best score is now 7.881024811574585
# Subset found on iteration 4 of 10 with score 3.6405124057872924 :
# {'purpose': ['Education', 'Radio/TV'], 'under_25': [True], 'credit_amt': ['Low'], 'savings': ['Little'], 'housing': ['Own']}
# Current score of 3.6405124057872924 does not beat best score of 7.881024811574585
# Subset found on iteration 5 of 10 with score 7.364321093030062 :
# {'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Radio/TV'], 'duration': ['Very Long']}
# Current score of 7.364321093030062 does not beat best score of 7.881024811574585
# Subset found on iteration 6 of 10 with score 5.960768608680942 :
# {'credit_amt': ['High', 'Very High'], 'savings': ['Moderate'], 'job': ['1 Job']}
# Current score of 5.960768608680942 does not beat best score of 7.881024811574585
# Subset found on iteration 7 of 10 with score 5.960768608680942 :
# {'housing': ['Free', 'Rent'], 'duration': ['Very Long'], 'under_25': [True]}
# Current score of 5.960768608680942 does not beat best score of 7.881024811574585
# Subset found on iteration 8 of 10 with score 3.8405124057872926 :
# {'purpose': ['Business'], 'duration': ['Long', 'Very Long'], 'savings': ['Moderate']}
# Current score of 3.8405124057872926 does not beat best score of 7.881024811574585
# Subset found on iteration 9 of 10 with score 6.160768608680942 :
# {'job': ['1 Job'], 'duration': ['Very Long']}
# Current score of 6.160768608680942 does not beat best score of 7.881024811574585
# Subset found on iteration 10 of 10 with score 6.527490499605953 :
# {'credit_amt': ['High', 'Moderate', 'Very High'], 'job': ['1 Job', 'Multiple Jobs'], 'checking': ['Little', 'Moderate'], 'housing': ['Rent'], 'purpose': ['Business', 'Car']}
# Current score of 6.527490499605953 does not beat best score of 7.881024811574585
# Required time =  25.71898651123047 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Car'], 'checking': ['Little'], 'job': ['Multiple Jobs'], 'under_25': [False], 'credit_amt': ['Moderate'], 'housing': ['Rent']}
# Score: 7.881024811574585
# First Iteration
# Average p_delta: 0.06915171041921075
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 755  0.649794  0.649794  0.720745   0.720745 -0.070951                  0.12
# 775  0.649794  0.649794  0.720745   0.720745 -0.070951                  0.12
# 850  0.930000  0.930000  0.720745   0.720745  0.209255                  0.12
# 900  0.930000  0.930000  0.720745   0.720745  0.209255                  0.12
#
#      p_hat_raw  p_hat
# 755       0.12   0.12
# 775       0.12   0.12
# 850       0.12   0.12
# 900       0.12   0.12
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 7.881024811574585
# [0, 6, 7.881024811574585, 'positive']
# Target positive rate for subset: 0.10810810810810811
# New threshold for subset: 0.5260174073386454
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.821249
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.613630
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 7
# Subset found on iteration 1 of 10 with score 6.314114590674633 :
# {'housing': ['Free', 'Rent'], 'under_25': [True], 'duration': ['Very Long']}
# Best score is now 6.314114590674633
# Subset found on iteration 2 of 10 with score 6.514114590674633 :
# {'job': ['1 Job'], 'duration': ['Very Long']}
# Best score is now 6.514114590674633
# Subset found on iteration 3 of 10 with score 8.752152787566178 :
# {'credit_amt': ['Very High'], 'housing': ['Rent']}
# Best score is now 8.752152787566178
# Subset found on iteration 4 of 10 with score 6.0518339341734935 :
# {'housing': ['Free', 'Rent'], 'purpose': ['Business', 'Car'], 'duration': ['Very Long'], 'savings': ['Little', 'Moderate']}
# Current score of 6.0518339341734935 does not beat best score of 8.752152787566178
# Subset found on iteration 5 of 10 with score 4.076076393783088 :
# {'duration': ['Long', 'Very Long'], 'purpose': ['Business'], 'savings': ['Moderate']}
# Current score of 4.076076393783088 does not beat best score of 8.752152787566178
# Subset found on iteration 6 of 10 with score 10.390190984457721 :
# {'savings': ['Little', 'Moderate'], 'purpose': ['Car', 'Furniture/Equipment'], 'duration': ['Long'], 'checking': ['Moderate'], 'sex': ['Female'], 'job': ['Multiple Jobs']}
# Best score is now 10.390190984457721
# Subset found on iteration 7 of 10 with score 8.752152787566178 :
# {'housing': ['Rent'], 'credit_amt': ['Very High']}
# Current score of 8.752152787566178 does not beat best score of 10.390190984457721
# Subset found on iteration 8 of 10 with score 8.752152787566178 :
# {'credit_amt': ['Very High'], 'housing': ['Rent']}
# Current score of 8.752152787566178 does not beat best score of 10.390190984457721
# Subset found on iteration 9 of 10 with score 1.8380381968915445 :
# {'housing': ['Free'], 'sex': ['Male'], 'job': ['1 Job'], 'savings': ['Moderate']}
# Current score of 1.8380381968915445 does not beat best score of 10.390190984457721
# Subset found on iteration 10 of 10 with score 10.690190984457722 :
# {'housing': ['Own'], 'credit_amt': ['Moderate'], 'savings': ['Little'], 'duration': ['Long'], 'sex': ['Female']}
# Best score is now 10.690190984457722
# Required time =  22.223740577697754 seconds
# Found positive subset for ijdi scan:
# {'housing': ['Own'], 'credit_amt': ['Moderate'], 'savings': ['Little'], 'duration': ['Long'], 'sex': ['Female']}
# Score: 10.690190984457722
# First Iteration
# Average p_delta: 0.03452155168905193
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 172  0.788333  0.788333  0.720745   0.720745  0.067588              0.106667
# 252  0.836667  0.836667  0.720745   0.720745  0.115922              0.106667
# 446  0.768333  0.768333  0.720745   0.720745  0.047588              0.106667
# 634  0.844167  0.844167  0.720745   0.720745  0.123422              0.106667
# 862  0.538833  0.538833  0.720745   0.720745 -0.181912              0.106667
#
#      p_hat_raw     p_hat
# 172   0.106667  0.106667
# 252   0.106667  0.106667
# 446   0.106667  0.106667
# 634   0.106667  0.106667
# 862   0.106667  0.106667
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 10.690190984457722
# [0, 7, 10.690190984457722, 'positive']
# Target positive rate for subset: 0.09152542372881356
# New threshold for subset: 0.6078577021710824
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.821249
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.613630
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 8
# Subset found on iteration 1 of 10 with score 6.314704750727398 :
# {'credit_amt': ['High', 'Very High'], 'checking': ['Moderate'], 'sex': ['Female'], 'savings': ['Little', 'Moderate'], 'duration': ['Long'], 'housing': ['Rent']}
# Best score is now 6.314704750727398
# Subset found on iteration 2 of 10 with score 9.28627300096986 :
# {'housing': ['Rent'], 'credit_amt': ['Very High']}
# Best score is now 9.28627300096986
# Subset found on iteration 3 of 10 with score 9.186273000969859 :
# {'savings': ['Little'], 'duration': ['Very Long'], 'under_25': [True]}
# Current score of 9.186273000969859 does not beat best score of 9.28627300096986
# Subset found on iteration 4 of 10 with score 6.714704750727398 :
# {'job': ['1 Job', 'Multiple Jobs'], 'under_25': [True], 'credit_amt': ['Very High']}
# Current score of 6.714704750727398 does not beat best score of 9.28627300096986
# Subset found on iteration 5 of 10 with score 3.233056046885238 :
# {'credit_amt': ['Low', 'Moderate'], 'sex': ['Female'], 'duration': ['Moderate'], 'job': ['1 Job', 'Multiple Jobs'], 'savings': ['Little'], 'purpose': ['Car', 'Radio/TV'], 'checking': ['Little', 'Moderate']}
# Current score of 3.233056046885238 does not beat best score of 9.28627300096986
# Subset found on iteration 6 of 10 with score 4.14313650048493 :
# {'sex': ['Female'], 'checking': ['Moderate'], 'duration': ['Long'], 'purpose': ['Business', 'Furniture/Equipment'], 'housing': ['Rent']}
# Current score of 4.14313650048493 does not beat best score of 9.28627300096986
# Subset found on iteration 7 of 10 with score 9.28627300096986 :
# {'credit_amt': ['Very High'], 'housing': ['Rent']}
# Current score of 9.28627300096986 does not beat best score of 9.28627300096986
# Subset found on iteration 8 of 10 with score 1.971568250242465 :
# {'under_25': [True], 'job': ['1 Job'], 'duration': ['Moderate'], 'purpose': ['Radio/TV']}
# Current score of 1.971568250242465 does not beat best score of 9.28627300096986
# Subset found on iteration 9 of 10 with score 2.531593832437759 :
# {'savings': ['Little'], 'duration': ['Moderate'], 'under_25': [True], 'job': ['1 Job']}
# Current score of 2.531593832437759 does not beat best score of 9.28627300096986
# Subset found on iteration 10 of 10 with score 6.714704750727398 :
# {'job': ['1 Job', 'Multiple Jobs'], 'credit_amt': ['Very High'], 'under_25': [True]}
# Current score of 6.714704750727398 does not beat best score of 9.28627300096986
# Required time =  24.590646266937256 seconds
# Found positive subset for ijdi scan:
# {'housing': ['Rent'], 'credit_amt': ['Very High']}
# Score: 9.28627300096986
# First Iteration
# Average p_delta: 0.13175488502238525
# Average p_censor: 0.0
#      proba_rf  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 95      0.940  0.940  0.720745   0.720745  0.219255              0.093333
# 333     0.730  0.730  0.720745   0.720745  0.009255              0.093333
# 736     0.885  0.885  0.720745   0.720745  0.164255              0.093333
# 832     0.855  0.855  0.720745   0.720745  0.134255              0.093333
#
#      p_hat_raw     p_hat
# 95    0.093333  0.093333
# 333   0.093333  0.093333
# 736   0.093333  0.093333
# 832   0.093333  0.093333
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 9.28627300096986
# [0, 8, 9.28627300096986, 'positive']
# Target positive rate for subset: 0.08108108108108109
# New threshold for subset: 0.846997010684475
# 1      0.500000
# 4      0.737996
# 9      0.500000
# 10     0.500000
# 11     0.821249
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.613630
# 998    0.737996
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 9
# Subset found on iteration 1 of 10 with score 4.469791299697 :
# {'purpose': ['Car'], 'duration': ['Long', 'Very Long'], 'sex': ['Female'], 'housing': ['Free']}
# Best score is now 4.469791299697
# Subset found on iteration 2 of 10 with score 6.8546869495455045 :
# {'credit_amt': ['High', 'Low'], 'under_25': [True], 'checking': ['Little'], 'duration': ['Short', 'Very Long']}
# Best score is now 6.8546869495455045
# Subset found on iteration 3 of 10 with score 4.569791299697 :
# {'savings': ['Moderate'], 'credit_amt': ['High'], 'sex': ['Female'], 'housing': ['Rent']}
# Current score of 4.569791299697 does not beat best score of 6.8546869495455045
# Subset found on iteration 4 of 10 with score 8.279084241565839 :
# {'savings': ['Little', 'Moderate'], 'checking': ['Little', 'Moderate'], 'job': ['1 Job', 'Multiple Jobs'], 'sex': ['Female'], 'housing': ['Own', 'Rent'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'credit_amt': ['High', 'Low']}
# Best score is now 8.279084241565839
# Subset found on iteration 5 of 10 with score 8.279084241565839 :
# {'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'checking': ['Little', 'Moderate'], 'sex': ['Female'], 'credit_amt': ['High', 'Low'], 'housing': ['Own', 'Rent'], 'job': ['1 Job', 'Multiple Jobs']}
# Current score of 8.279084241565839 does not beat best score of 8.279084241565839
# Subset found on iteration 6 of 10 with score 9.434040009315176 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Very Long'], 'checking': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Radio/TV']}
# Best score is now 9.434040009315176
# Subset found on iteration 7 of 10 with score 6.393061474645033 :
# {'purpose': ['Business', 'Education', 'Radio/TV'], 'job': ['1 Job', 'Multiple Jobs'], 'savings': ['Little'], 'checking': ['Little'], 'sex': ['Female'], 'credit_amt': ['High', 'Low']}
# Current score of 6.393061474645033 does not beat best score of 9.434040009315176
# Subset found on iteration 8 of 10 with score 6.993061474645033 :
# {'duration': ['Very Long'], 'checking': ['Little'], 'purpose': ['Car', 'Radio/TV']}
# Current score of 6.993061474645033 does not beat best score of 9.434040009315176
# Subset found on iteration 9 of 10 with score 4.669791299697001 :
# {'housing': ['Free'], 'credit_amt': ['High'], 'job': ['1 Job']}
# Current score of 4.669791299697001 does not beat best score of 9.434040009315176
# Subset found on iteration 10 of 10 with score 6.8546869495455045 :
# {'housing': ['Own'], 'checking': ['Little'], 'duration': ['Short', 'Very Long'], 'purpose': ['Education', 'Radio/TV']}
# Current score of 6.8546869495455045 does not beat best score of 9.434040009315176
# Required time =  24.724254369735718 seconds
# Found positive subset for ijdi scan:
# {'savings': ['Little', 'Moderate'], 'duration': ['Very Long'], 'checking': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Radio/TV']}
# Score: 9.434040009315176
# First Iteration
# Average p_delta: 0.16395778357310992
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1    0.803333  0.803333  0.720745   0.720745  0.082588              0.083333
# 11   0.950000  0.950000  0.720745   0.720745  0.229255              0.083333
# 29   0.838000  0.838000  0.720745   0.720745  0.117255              0.083333
# 44   0.900000  0.900000  0.720745   0.720745  0.179255              0.083333
# 63   0.880000  0.880000  0.720745   0.720745  0.159255              0.083333
# 95   0.940000  0.940000  0.720745   0.720745  0.219255              0.083333
# 191  0.660000  0.660000  0.720745   0.720745 -0.060745              0.083333
# 242  0.920000  0.920000  0.720745   0.720745  0.199255              0.083333
# 273  0.774167  0.774167  0.720745   0.720745  0.053422              0.083333
# 332  0.800000  0.800000  0.720745   0.720745  0.079255              0.083333
# 375  0.954000  0.954000  0.720745   0.720745  0.233255              0.083333
# 538  0.990000  0.990000  0.720745   0.720745  0.269255              0.083333
# 552  0.900000  0.900000  0.720745   0.720745  0.179255              0.083333
# 569  0.860000  0.860000  0.720745   0.720745  0.139255              0.083333
# 677  0.820000  0.820000  0.720745   0.720745  0.099255              0.083333
# 701  0.990000  0.990000  0.720745   0.720745  0.269255              0.083333
# 706  0.838667  0.838667  0.720745   0.720745  0.117922              0.083333
# 714  0.840000  0.840000  0.720745   0.720745  0.119255              0.083333
# 728  0.910000  0.910000  0.720745   0.720745  0.189255              0.083333
# 814  0.990000  0.990000  0.720745   0.720745  0.269255              0.083333
# 887  0.920000  0.920000  0.720745   0.720745  0.199255              0.083333
# 927  0.910000  0.910000  0.720745   0.720745  0.189255              0.083333
# 973  0.960000  0.960000  0.720745   0.720745  0.239255              0.083333
#
#      p_hat_raw     p_hat
# 1     0.083333  0.083333
# 11    0.083333  0.083333
# 29    0.083333  0.083333
# 44    0.083333  0.083333
# 63    0.083333  0.083333
# 95    0.083333  0.083333
# 191   0.083333  0.083333
# 242   0.083333  0.083333
# 273   0.083333  0.083333
# 332   0.083333  0.083333
# 375   0.083333  0.083333
# 538   0.083333  0.083333
# 552   0.083333  0.083333
# 569   0.083333  0.083333
# 677   0.083333  0.083333
# 701   0.083333  0.083333
# 706   0.083333  0.083333
# 714   0.083333  0.083333
# 728   0.083333  0.083333
# 814   0.083333  0.083333
# 887   0.083333  0.083333
# 927   0.083333  0.083333
# 973   0.083333  0.083333
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 9.434040009315176
# [0, 9, 9.434040009315176, 'positive']
# Target positive rate for subset: 0.05415162454873646
# New threshold for subset: 0.8485131106868696
# ...
# Subset found on iteration 2 of 10 with score 14.784106659852249 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV', 'Vacation/Others'], 'duration': ['Very Long'], 'savings': ['Little', 'Moderate']}
# Best score is now 14.784106659852249
# Subset found on iteration 3 of 10 with score 14.784106659852249 :
# {'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV', 'Vacation/Others'], 'duration': ['Very Long']}
# Current score of 14.784106659852249 does not beat best score of 14.784106659852249
# Subset found on iteration 4 of 10 with score 9.884371391177023 :
# {'duration': ['Long', 'Very Long'], 'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Car'], 'credit_amt': ['Very High']}
# Current score of 9.884371391177023 does not beat best score of 14.784106659852249
# Subset found on iteration 5 of 10 with score 18.62926802355678 :
# {'housing': ['Free', 'Rent'], 'savings': ['Little'], 'duration': ['Moderate', 'Very Long'], 'sex': ['Female'], 'checking': ['Little']}
# Best score is now 18.62926802355678
# Subset found on iteration 6 of 10 with score 14.784106659852249 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV', 'Vacation/Others'], 'savings': ['Little', 'Moderate'], 'duration': ['Very Long']}
# Current score of 14.784106659852249 does not beat best score of 18.62926802355678
# Subset found on iteration 7 of 10 with score 7.791295651078661 :
# {'credit_amt': ['High', 'Very High'], 'sex': ['Female'], 'savings': ['Moderate']}
# Current score of 7.791295651078661 does not beat best score of 18.62926802355678
# Subset found on iteration 8 of 10 with score 8.054570044723375 :
# {'purpose': ['Business', 'Car', 'Vacation/Others'], 'duration': ['Long', 'Very Long'], 'savings': ['Moderate']}
# Current score of 8.054570044723375 does not beat best score of 18.62926802355678
# WARNING SCORE HAS DECREASED from 11.483973232028333 to 10.977001054039393
# Subset found on iteration 9 of 10 with score 11.077001054039393 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV'], 'checking': ['Little', 'Moderate'], 'sex': ['Female'], 'duration': ['Long', 'Moderate', 'Very Long'], 'job': ['Multiple Jobs'], 'housing': ['Rent'], 'credit_amt': ['High', 'Moderate', 'Very High']}
# Current score of 11.077001054039393 does not beat best score of 18.62926802355678
# Subset found on iteration 10 of 10 with score 11.521809920727087 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV', 'Vacation/Others'], 'credit_amt': ['High', 'Moderate', 'Very High'], 'savings': ['Little', 'Moderate'], 'job': ['Multiple Jobs'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long'], 'sex': ['Female']}
# Current score of 11.521809920727087 does not beat best score of 18.62926802355678
# Required time =  33.434916734695435 seconds
# Found positive subset for ijdi scan:
# {'housing': ['Free', 'Rent'], 'savings': ['Little'], 'duration': ['Moderate', 'Very Long'], 'sex': ['Female'], 'checking': ['Little']}
# Score: 18.62926802355678
# First Iteration
# Average p_delta: 0.024736388367524956
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 11   0.950000  0.950000  0.720745   0.720745  0.229255              0.173333
# 44   0.900000  0.900000  0.720745   0.720745  0.179255              0.173333
# 155  0.597956  0.597956  0.720745   0.720745 -0.122789              0.173333
# 375  0.954000  0.954000  0.720745   0.720745  0.233255              0.173333
# 429  0.860000  0.860000  0.720745   0.720745  0.139255              0.173333
# 475  0.790000  0.790000  0.720745   0.720745  0.069255              0.173333
# 585  0.597956  0.597956  0.720745   0.720745 -0.122789              0.173333
# 727  0.496000  0.496000  0.720745   0.720745 -0.224745              0.173333
# 761  0.597956  0.597956  0.720745   0.720745 -0.122789              0.173333
# 826  0.940000  0.940000  0.720745   0.720745  0.219255              0.173333
# 831  0.516429  0.516429  0.720745   0.720745 -0.204317              0.173333
#
#      p_hat_raw     p_hat
# 11    0.242110  0.242110
# 44    0.227110  0.227110
# 155   0.136497  0.136497
# 375   0.243310  0.243310
# 429   0.215110  0.215110
# 475   0.194110  0.194110
# 585   0.136497  0.136497
# 727   0.105910  0.105910
# 761   0.136497  0.136497
# 826   0.239110  0.239110
# 831   0.112038  0.112038
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 18.62926802355678
# [0.3, 4, 18.62926802355678, 'positive']
# Target positive rate for subset: 0.1495718856507863
# New threshold for subset: 0.7771522033544417
# 1      0.500000
# 4      0.717155
# 9      0.500000
# 10     0.500000
# 11     0.777152
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.500000
# 983    0.737996
# 998    0.717155
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 5
# Subset found on iteration 1 of 10 with score 6.3698613528190124 :
# {'sex': ['Female'], 'housing': ['Rent'], 'purpose': ['Business']}
# Best score is now 6.3698613528190124
# Subset found on iteration 2 of 10 with score 16.651785721956855 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV'], 'savings': ['Little', 'Moderate'], 'duration': ['Very Long'], 'housing': ['Own', 'Rent']}
# Best score is now 16.651785721956855
# Subset found on iteration 3 of 10 with score 10.855315351160105 :
# {'duration': ['Very Long'], 'checking': ['Little', 'Moderate'], 'purpose': ['Business', 'Vacation/Others'], 'housing': ['Free', 'Rent']}
# Current score of 10.855315351160105 does not beat best score of 16.651785721956855
# Subset found on iteration 4 of 10 with score 16.651785721956855 :
# {'savings': ['Little', 'Moderate'], 'housing': ['Own', 'Rent'], 'duration': ['Very Long'], 'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV']}
# Current score of 16.651785721956855 does not beat best score of 16.651785721956855
# Subset found on iteration 5 of 10 with score 16.305285613004315 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment'], 'checking': ['Moderate'], 'duration': ['Very Long']}
# Current score of 16.305285613004315 does not beat best score of 16.651785721956855
# Subset found on iteration 6 of 10 with score 8.63533987319858 :
# {'savings': ['Moderate'], 'sex': ['Female'], 'credit_amt': ['High', 'Very High']}
# Current score of 8.63533987319858 does not beat best score of 16.651785721956855
# Subset found on iteration 7 of 10 with score 12.536778625063945 :
# {'housing': ['Own', 'Rent'], 'duration': ['Very Long'], 'sex': ['Female'], 'credit_amt': ['High']}
# Current score of 12.536778625063945 does not beat best score of 16.651785721956855
# Subset found on iteration 8 of 10 with score 9.240337114179283 :
# {'duration': ['Long', 'Very Long'], 'sex': ['Female'], 'housing': ['Rent'], 'credit_amt': ['High', 'Very High'], 'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Car']}
# Current score of 9.240337114179283 does not beat best score of 16.651785721956855
# Subset found on iteration 9 of 10 with score 6.630305776165019 :
# {'credit_amt': ['Very High'], 'housing': ['Rent']}
# Current score of 6.630305776165019 does not beat best score of 16.651785721956855
# Subset found on iteration 10 of 10 with score 16.305285613004315 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment'], 'duration': ['Very Long'], 'checking': ['Moderate']}
# Current score of 16.305285613004315 does not beat best score of 16.651785721956855
# Required time =  32.54372525215149 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV'], 'savings': ['Little', 'Moderate'], 'duration': ['Very Long'], 'housing': ['Own', 'Rent']}
# Score: 16.651785721956855
# First Iteration
# Average p_delta: 0.1523298850223853
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1    0.803333  0.803333  0.720745   0.720745  0.082588              0.143333
# 11   0.950000  0.950000  0.720745   0.720745  0.229255              0.143333
# 29   0.838000  0.838000  0.720745   0.720745  0.117255              0.143333
# 63   0.880000  0.880000  0.720745   0.720745  0.159255              0.143333
# 95   0.940000  0.940000  0.720745   0.720745  0.219255              0.143333
# 273  0.774167  0.774167  0.720745   0.720745  0.053422              0.143333
# 295  0.960000  0.960000  0.720745   0.720745  0.239255              0.143333
# 332  0.800000  0.800000  0.720745   0.720745  0.079255              0.143333
# 333  0.730000  0.730000  0.720745   0.720745  0.009255              0.143333
# 375  0.954000  0.954000  0.720745   0.720745  0.233255              0.143333
# 444  0.960000  0.960000  0.720745   0.720745  0.239255              0.143333
# 552  0.900000  0.900000  0.720745   0.720745  0.179255              0.143333
# 569  0.860000  0.860000  0.720745   0.720745  0.139255              0.143333
# 677  0.820000  0.820000  0.720745   0.720745  0.099255              0.143333
# 706  0.838667  0.838667  0.720745   0.720745  0.117922              0.143333
# 714  0.840000  0.840000  0.720745   0.720745  0.119255              0.143333
# 728  0.910000  0.910000  0.720745   0.720745  0.189255              0.143333
# 887  0.920000  0.920000  0.720745   0.720745  0.199255              0.143333
# 973  0.960000  0.960000  0.720745   0.720745  0.239255              0.143333
# 981  0.823333  0.823333  0.720745   0.720745  0.102588              0.143333
#
#      p_hat_raw    p_hat
# 1      0.16811  0.16811
# 11     0.21211  0.21211
# 29     0.17851  0.17851
# 63     0.19111  0.19111
# 95     0.20911  0.20911
# 273    0.15936  0.15936
# 295    0.21511  0.21511
# 332    0.16711  0.16711
# 333    0.14611  0.14611
# 375    0.21331  0.21331
# 444    0.21511  0.21511
# 552    0.19711  0.19711
# 569    0.18511  0.18511
# 677    0.17311  0.17311
# 706    0.17871  0.17871
# 714    0.17911  0.17911
# 728    0.20011  0.20011
# 887    0.20311  0.20311
# 973    0.21511  0.21511
# 981    0.17411  0.17411
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 16.651785721956855
# [0.3, 5, 16.651785721956855, 'positive']
# Target positive rate for subset: 0.14539174875719518
# New threshold for subset: 0.8126226883279
# 1      0.812623
# 4      0.717155
# 9      0.500000
# 10     0.500000
# 11     0.812623
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.812623
# 983    0.737996
# 998    0.717155
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 6
# Subset found on iteration 1 of 10 with score 7.326163345573083 :
# {'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little'], 'credit_amt': ['Moderate', 'Very High'], 'job': ['1 Job', 'Multiple Jobs'], 'purpose': ['Business', 'Car', 'Furniture/Equipment']}
# Best score is now 7.326163345573083
# Subset found on iteration 2 of 10 with score 4.539096662259749 :
# {'credit_amt': ['High'], 'savings': ['Moderate'], 'purpose': ['Business']}
# Current score of 4.539096662259749 does not beat best score of 7.326163345573083
# Subset found on iteration 3 of 10 with score 1.6534975949483328 :
# {'checking': ['Little'], 'credit_amt': ['Low'], 'duration': ['Short']}
# Current score of 1.6534975949483328 does not beat best score of 7.326163345573083
# Subset found on iteration 4 of 10 with score 9.878709269346924 :
# {'housing': ['Rent'], 'purpose': ['Business', 'Car'], 'under_25': [False], 'job': ['Multiple Jobs'], 'checking': ['Little'], 'credit_amt': ['Moderate', 'Very High']}
# Best score is now 9.878709269346924
# Subset found on iteration 5 of 10 with score 3.1724193192749013 :
# {'checking': ['Little', 'Moderate'], 'housing': ['Free', 'Rent'], 'duration': ['Moderate', 'Very Long'], 'credit_amt': ['High', 'Moderate', 'Very High'], 'sex': ['Male'], 'purpose': ['Business', 'Car'], 'savings': ['Little', 'Moderate']}
# Current score of 3.1724193192749013 does not beat best score of 9.878709269346924
# Subset found on iteration 6 of 10 with score 6.700621343742045 :
# {'purpose': ['Business', 'Car', 'Education'], 'duration': ['Short', 'Very Long'], 'savings': ['Little'], 'under_25': [True]}
# Current score of 6.700621343742045 does not beat best score of 9.878709269346924
# Subset found on iteration 7 of 10 with score 3.0874718673904438 :
# {'job': ['Multiple Jobs'], 'under_25': [True], 'housing': ['Own'], 'credit_amt': ['Low', 'Very High'], 'duration': ['Short', 'Very Long']}
# Current score of 3.0874718673904438 does not beat best score of 9.878709269346924
# Subset found on iteration 8 of 10 with score 9.878709269346924 :
# {'credit_amt': ['Moderate', 'Very High'], 'job': ['Multiple Jobs'], 'checking': ['Little'], 'under_25': [False], 'housing': ['Rent'], 'purpose': ['Business', 'Car']}
# Current score of 9.878709269346924 does not beat best score of 9.878709269346924
# Subset found on iteration 9 of 10 with score 2.0353421061426955 :
# {'job': ['1 Job'], 'purpose': ['Business'], 'sex': ['Female']}
# Current score of 2.0353421061426955 does not beat best score of 9.878709269346924
# Subset found on iteration 10 of 10 with score 6.15391271068491 :
# {'savings': ['Little'], 'housing': ['Free', 'Rent'], 'duration': ['Long', 'Very Long'], 'credit_amt': ['Very High']}
# Current score of 6.15391271068491 does not beat best score of 9.878709269346924
# Required time =  31.41056776046753 seconds
# Found positive subset for ijdi scan:
# {'housing': ['Rent'], 'purpose': ['Business', 'Car'], 'under_25': [False], 'job': ['Multiple Jobs'], 'checking': ['Little'], 'credit_amt': ['Moderate', 'Very High']}
# Score: 9.878709269346924
# First Iteration
# Average p_delta: 0.08217234533984566
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 755  0.649794  0.649794  0.720745   0.720745 -0.070951                   0.1
# 775  0.649794  0.649794  0.720745   0.720745 -0.070951                   0.1
# 832  0.855000  0.855000  0.720745   0.720745  0.134255                   0.1
# 850  0.930000  0.930000  0.720745   0.720745  0.209255                   0.1
# 900  0.930000  0.930000  0.720745   0.720745  0.209255                   0.1
#
#      p_hat_raw     p_hat
# 755   0.078715  0.078715
# 775   0.078715  0.078715
# 832   0.140276  0.140276
# 850   0.162776  0.162776
# 900   0.162776  0.162776
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 9.878709269346924
# [0.3, 6, 9.878709269346924, 'positive']
# Target positive rate for subset: 0.10981529179859696
# New threshold for subset: 0.6909677903378924
# 1      0.812623
# 4      0.717155
# 9      0.500000
# 10     0.500000
# 11     0.812623
#          ...
# 979    0.500000
# 980    0.500000
# 981    0.812623
# 983    0.737996
# 998    0.717155
# Name: threshold, Length: 300, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 7
# Subset found on iteration 1 of 10 with score 3.593183561473218 :
# {'purpose': ['Education', 'Vacation/Others'], 'job': ['Multiple Jobs'], 'sex': ['Female'], 'housing': ['Free']}
# Best score is now 3.593183561473218
# Subset found on iteration 2 of 10 with score 3.616624544084062 :
# {'under_25': [True], 'job': ['Multiple Jobs'], 'credit_amt': ['Very High']}
# Best score is now 3.616624544084062
# Subset found on iteration 3 of 10 with score 9.472484254726535 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Long'], 'checking': ['Moderate'], 'sex': ['Female'], 'job': ['Multiple Jobs'], 'purpose': ['Car', 'Furniture/Equipment']}
# Best score is now 9.472484254726535
# Subset found on iteration 4 of 10 with score 3.616624544084062 :
# {'under_25': [True], 'job': ['Multiple Jobs'], 'credit_amt': ['Very High']}
# Current score of 3.616624544084062 does not beat best score of 9.472484254726535
# Subset found on iteration 5 of 10 with score 4.665317401995818 :
# {'housing': ['Free', 'Rent'], 'credit_amt': ['High'], 'purpose': ['Business'], 'job': ['1 Job']}
# Current score of 4.665317401995818 does not beat best score of 9.472484254726535

# %%
columns = ['lambda', 'iteration', 'score', 'scan_type']
mit_result_df = pd.DataFrame(sim_data, columns=columns)
mit_result_df

# %%
# Write recipe outputs
german_df.to_csv("datasets/german_credit_mit_2_neg.csv")
