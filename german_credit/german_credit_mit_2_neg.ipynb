# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
import pandas as pd, numpy as np

os.chdir('../') # cd back to parent dir
home_dir = "german_credit/" # set home dir for reading and storing data

# Read recipe inputs
german_mit_df = pd.read_csv(home_dir + "datasets/german_credit_prep.csv")
german_mit_df
# Out:
#      Unnamed: 0  under_25     sex            job housing   savings  checking  \
# 0             0     False    Male  Multiple Jobs     Own       NaN    Little
# 1             1      True  Female  Multiple Jobs     Own    Little  Moderate
# 2             2     False    Male          1 Job     Own    Little       NaN
# 3             3     False    Male  Multiple Jobs    Free    Little    Little
# 4             4     False    Male  Multiple Jobs    Free    Little    Little
# ..          ...       ...     ...            ...     ...       ...       ...
# 995         995     False  Female          1 Job     Own    Little       NaN
# 996         996     False    Male  Multiple Jobs     Own    Little    Little
# 997         997     False    Male  Multiple Jobs     Own    Little       NaN
# 998         998      True    Male  Multiple Jobs    Free    Little    Little
# 999         999     False    Male  Multiple Jobs     Own  Moderate  Moderate
#
#     credit_amt   duration              purpose  outcomes  proba_lr  proba_rf
# 0     Moderate      Short             Radio/TV         0  0.114175  0.046250
# 1         High  Very Long             Radio/TV         1  0.612611  0.803333
# 2     Moderate   Moderate            Education         0  0.154985  0.092917
# 3         High       Long  Furniture/Equipment         0  0.545431  0.141350
# 4         High       Long                  Car         1  0.574045  0.213719
# ..         ...        ...                  ...       ...       ...       ...
# 995   Moderate   Moderate  Furniture/Equipment         0  0.136923  0.122083
# 996       High       Long                  Car         0  0.517829  0.687929
# 997        Low   Moderate             Radio/TV         0  0.135555  0.010000
# 998   Moderate       Long             Radio/TV         1  0.550995  0.829405
# 999       High       Long                  Car         0  0.397940  0.248544
#
# [1000 rows x 13 columns]

# %% [markdown]
# Test running negative IJDI-Scan once.

# %%
# specify probability and outcomes columns
PROBA_CONFUSION_COL = 'proba_lr'
PROBA_IJDI_COL = 'proba_rf'
OUTCOMES_COL = 'outcomes'
FEATURES = ['under_25', 'sex', 'job', 'housing', 'savings', 'checking',
            'credit_amt', 'duration', 'purpose']
THRESHOLD = 0.5
LAMBDA_PARAM = 1
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# %%
# filter for only negative outcomes
negatives_df = german_mit_df.loc[german_mit_df[OUTCOMES_COL] == 0]

# scan with positive direction
current_subset, current_score = run_ijdi_scan(negatives_df, FEATURES, PROBA_CONFUSION_COL, PROBA_IJDI_COL, OUTCOMES_COL,
                                              THRESHOLD, LAMBDA_PARAM)
# summarize_scan(negatives_df, FEATURES, PROBA_COL, OUTCOMES_COL, current_subset, include='all')\
current_subset, current_score
# Out:
# Subset found on iteration 1 of 10 with score 17.960085766444614 :
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment'], 'credit_amt': ['High', 'Low'], 'checking': ['Little', 'Rich'], 'savings': ['Little', 'Moderate'], 'under_25': [True]}
# Best score is now 17.960085766444614
# Subset found on iteration 2 of 10 with score 17.535162728465302 :
# {'housing': ['Free', 'Rent'], 'checking': ['Little', 'Moderate'], 'credit_amt': ['Low', 'Moderate'], 'purpose': ['Business', 'Furniture/Equipment'], 'duration': ['Moderate'], 'savings': ['Little', 'Moderate']}
# Current score of 17.535162728465302 does not beat best score of 17.960085766444614
# WARNING SCORE HAS DECREASED from 6.731122626898757 to 6.659355077442537
# Subset found on iteration 3 of 10 with score 17.960085766444614 :
# {'under_25': [True], 'checking': ['Little', 'Rich'], 'savings': ['Little', 'Moderate'], 'credit_amt': ['High', 'Low'], 'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment']}
# Current score of 17.960085766444614 does not beat best score of 17.960085766444614
# Subset found on iteration 4 of 10 with score 18.247526213389627 :
# {'housing': ['Free', 'Rent'], 'duration': ['Long', 'Moderate'], 'under_25': [True], 'savings': ['Little', 'Moderate'], 'credit_amt': ['High', 'Low']}
# Best score is now 18.247526213389627
# Subset found on iteration 5 of 10 with score 29.207385349210547 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'checking': ['Little'], 'purpose': ['Business', 'Car', 'Education', 'Repairs']}
# Best score is now 29.207385349210547
# Subset found on iteration 6 of 10 with score 9.297003667369802 :
# {'duration': ['Very Long'], 'checking': ['Little', 'Moderate'], 'purpose': ['Business', 'Car'], 'housing': ['Own']}
# Current score of 9.297003667369802 does not beat best score of 29.207385349210547
# Subset found on iteration 7 of 10 with score 27.277982350103606 :
# {'purpose': ['Car', 'Education', 'Furniture/Equipment'], 'savings': ['Little'], 'housing': ['Free', 'Rent'], 'checking': ['Little', 'Rich'], 'sex': ['Female']}
# Current score of 27.277982350103606 does not beat best score of 29.207385349210547
# WARNING SCORE HAS DECREASED from 28.946661794777402 to 25.697038160460387
# Subset found on iteration 8 of 10 with score 26.597038160460386 :
# {'savings': ['Little'], 'checking': ['Little'], 'housing': ['Free', 'Rent'], 'sex': ['Female']}
# Current score of 26.597038160460386 does not beat best score of 29.207385349210547
# Subset found on iteration 9 of 10 with score 26.515124554917918 :
# {'sex': ['Female'], 'housing': ['Free', 'Rent'], 'duration': ['Moderate'], 'checking': ['Little']}
# Current score of 26.515124554917918 does not beat best score of 29.207385349210547
# Subset found on iteration 10 of 10 with score 16.636256905843418 :
# {'savings': ['Little', 'Moderate'], 'credit_amt': ['High', 'Low'], 'under_25': [True], 'checking': ['Little']}
# Current score of 16.636256905843418 does not beat best score of 29.207385349210547
# Required time =  34.00617218017578 seconds
# Found positive subset for ijdi scan:
# {'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'checking': ['Little'], 'purpose': ['Business', 'Car', 'Education', 'Repairs']}
# Score: 29.207385349210547
# First Iteration
# Average p_delta: 0.14983682115503538
# Average p_censor: 0.0
# Subset does not violate p_delta or p_censor conditions!
# ({'savings': ['Little', 'Moderate'],
#   'duration': ['Long', 'Very Long'],
#   'checking': ['Little'],
#   'purpose': ['Business', 'Car', 'Education', 'Repairs']},
#  29.207385349210547)

# %% [markdown]
# ### Implement Mitigation Approach 2

# %% [markdown]
# Set lambda vales to test.

# %%
lambda_vals = [0, 0.3, 1, 3, 10]

# specify parameters for generating metrics and IJDI scan
proba_confusion_col = 'proba_lr'
proba_ijdi_col = 'proba_rf'
outcomes_col = 'outcomes'
features = ['under_25', 'sex', 'job', 'housing', 'savings', 'checking',
            'credit_amt', 'duration', 'purpose']
threshold = 'threshold'

# define stopping criteria
stop_limit = 0
max_iters = 3

pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(100)

# %%
sim_data = []

# %% [markdown]
# Implement approach for negatives

# %%
# filter for negative or positive outcomes
negatives_df = german_mit_df.loc[german_mit_df[outcomes_col] == 0]

for lambda_param in lambda_vals: # run IJDI scan for various lambda values

    print("Lambda =", lambda_param)

    i = 0
    ijdi_present = True
    # set initial threshold
    negatives_df['threshold'] = 0.5

    while ijdi_present and i <= max_iters:

        i += 1
        print("Iteration", i)

        # Run Negative or Positive IJDI Scan. Make sure to pass in copy because data may be modified by the function!
        current_subset, current_score = run_ijdi_scan(negatives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                      threshold, lambda_param, constant_threshold=False, verbose=True)

        print("Score for Negative IJDI-Scan:", current_score)

        # append data
        row = [lambda_param, i, current_score, 'negative']
        sim_data.append(row)

        print(row)

        if current_score > stop_limit:

            # correct IJDI by setting new threshold for subset
            negatives_df['threshold'] = correct_ijdi_subset(negatives_df.copy(deep=True), features,
                                                            proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                            threshold, lambda_param, current_subset)
            print(negatives_df['threshold'])

        else:
            ijdi_present = False

        print("\n----------------------------------------------------\n")
# Out:
# Lambda = 0
# Iteration 1
# Subset found on iteration 1 of 10 with score 47.03018853370144 :
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'duration': ['Long', 'Moderate', 'Very Long'], 'job': ['1 Job', 'Multiple Jobs'], 'checking': ['Little', 'Moderate'], 'savings': ['Little', 'Moderate'], 'housing': ['Free', 'Rent']}
# Best score is now 47.03018853370144
# Subset found on iteration 2 of 10 with score 53.50569210408128 :
# {'checking': ['Little'], 'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long']}
# Best score is now 53.50569210408128
# Subset found on iteration 3 of 10 with score 46.86065186046361 :
# {'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate'], 'savings': ['Little', 'Moderate']}
# Current score of 46.86065186046361 does not beat best score of 53.50569210408128
# Subset found on iteration 4 of 10 with score 47.03018853370144 :
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'job': ['1 Job', 'Multiple Jobs'], 'housing': ['Free', 'Rent'], 'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little', 'Moderate'], 'checking': ['Little', 'Moderate']}
# Current score of 47.03018853370144 does not beat best score of 53.50569210408128
# Subset found on iteration 5 of 10 with score 53.50569210408128 :
# {'checking': ['Little'], 'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little', 'Moderate']}
# Current score of 53.50569210408128 does not beat best score of 53.50569210408128
# Subset found on iteration 6 of 10 with score 53.50569210408128 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long'], 'checking': ['Little']}
# Current score of 53.50569210408128 does not beat best score of 53.50569210408128
# Subset found on iteration 7 of 10 with score 53.50569210408128 :
# {'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little', 'Moderate'], 'checking': ['Little']}
# Current score of 53.50569210408128 does not beat best score of 53.50569210408128
# Subset found on iteration 8 of 10 with score 53.50569210408128 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long'], 'checking': ['Little']}
# Current score of 53.50569210408128 does not beat best score of 53.50569210408128
# Subset found on iteration 9 of 10 with score 47.9278361438245 :
# {'housing': ['Free', 'Rent'], 'checking': ['Little'], 'purpose': ['Car', 'Education', 'Furniture/Equipment'], 'duration': ['Long', 'Moderate', 'Very Long']}
# Current score of 47.9278361438245 does not beat best score of 53.50569210408128
# Subset found on iteration 10 of 10 with score 53.50569210408128 :
# {'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little', 'Moderate'], 'checking': ['Little']}
# Current score of 53.50569210408128 does not beat best score of 53.50569210408128
# Required time =  47.68316388130188 seconds
# Found positive subset for ijdi scan:
# {'checking': ['Little'], 'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long']}
# Score: 53.50569210408128
# First Iteration
# Average p_delta: 0.1821458826743242
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3    0.141350  0.141350  0.120261   0.120261  0.021089                   0.1
# 14   0.159667  0.159667  0.120261   0.120261  0.039406                   0.1
# 31   0.388119  0.388119  0.120261   0.120261  0.267858                   0.1
# 43   0.158000  0.158000  0.120261   0.120261  0.037739                   0.1
# 75   0.234841  0.234841  0.120261   0.120261  0.114580                   0.1
# ..        ...       ...       ...        ...       ...                   ...
# 954  0.172222  0.172222  0.120261   0.120261  0.051961                   0.1
# 985  0.025000  0.025000  0.120261   0.120261 -0.095261                   0.1
# 988  0.213719  0.213719  0.120261   0.120261  0.093458                   0.1
# 993  0.388119  0.388119  0.120261   0.120261  0.267858                   0.1
# 996  0.687929  0.687929  0.120261   0.120261  0.567668                   0.1
#
#      p_hat_raw  p_hat
# 3          0.1    0.1
# 14         0.1    0.1
# 31         0.1    0.1
# 43         0.1    0.1
# 75         0.1    0.1
# ..         ...    ...
# 954        0.1    0.1
# 985        0.1    0.1
# 988        0.1    0.1
# 993        0.1    0.1
# 996        0.1    0.1
#
# [88 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 53.50569210408128
# [0, 1, 53.50569210408128, 'negative']
# Target positive rate for subset: 0.03594771241830065
# New threshold for subset: 0.7200295497384207
# 0      0.50000
# 2      0.50000
# 3      0.72003
# 5      0.50000
# 6      0.50000
#         ...
# 994    0.50000
# 995    0.50000
# 996    0.72003
# 997    0.50000
# 999    0.50000
# Name: threshold, Length: 700, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 15.864789371404976 :
# {'housing': ['Rent'], 'purpose': ['Business', 'Education'], 'credit_amt': ['High', 'Low', 'Very High']}
# Best score is now 15.864789371404976
# Subset found on iteration 2 of 10 with score 20.715546589055695 :
# {'purpose': ['Business', 'Education'], 'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'checking': ['Moderate']}
# Best score is now 20.715546589055695
# Subset found on iteration 3 of 10 with score 27.776997412932474 :
# {'purpose': ['Business', 'Car', 'Education'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long']}
# Best score is now 27.776997412932474
# Subset found on iteration 4 of 10 with score 19.074575513233057 :
# {'checking': ['Little', 'Moderate', 'Rich'], 'purpose': ['Business', 'Education'], 'credit_amt': ['High', 'Low', 'Very High'], 'housing': ['Free', 'Rent']}
# Current score of 19.074575513233057 does not beat best score of 27.776997412932474
# Subset found on iteration 5 of 10 with score 27.776997412932474 :
# {'purpose': ['Business', 'Car', 'Education'], 'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate']}
# Current score of 27.776997412932474 does not beat best score of 27.776997412932474
# Subset found on iteration 6 of 10 with score 15.824938778243768 :
# {'purpose': ['Car', 'Education', 'Radio/TV'], 'under_25': [True], 'checking': ['Little', 'Moderate', 'Rich'], 'sex': ['Female'], 'housing': ['Free', 'Rent'], 'job': ['Multiple Jobs']}
# Current score of 15.824938778243768 does not beat best score of 27.776997412932474
# Subset found on iteration 7 of 10 with score 2.7929578742809955 :
# {'credit_amt': ['Moderate'], 'housing': ['Own'], 'duration': ['Long'], 'purpose': ['Education'], 'sex': ['Male']}
# Current score of 2.7929578742809955 does not beat best score of 27.776997412932474
# Subset found on iteration 8 of 10 with score 27.776997412932474 :
# {'purpose': ['Business', 'Car', 'Education'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long']}
# Current score of 27.776997412932474 does not beat best score of 27.776997412932474
# Subset found on iteration 9 of 10 with score 27.776997412932474 :
# {'purpose': ['Business', 'Car', 'Education'], 'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate']}
# Current score of 27.776997412932474 does not beat best score of 27.776997412932474
# Subset found on iteration 10 of 10 with score 21.950705119966962 :
# {'sex': ['Female'], 'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little', 'Moderate', 'Quite rich'], 'purpose': ['Business', 'Car', 'Education'], 'checking': ['Moderate']}
# Current score of 21.950705119966962 does not beat best score of 27.776997412932474
# Required time =  33.06753396987915 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Car', 'Education'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long']}
# Score: 27.776997412932474
# First Iteration
# Average p_delta: 0.11931444151447393
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 7    0.435833  0.435833  0.120261   0.120261  0.315572              0.037143
# 17   0.230000  0.230000  0.120261   0.120261  0.109739              0.037143
# 43   0.158000  0.158000  0.120261   0.120261  0.037739              0.037143
# 51   0.454715  0.454715  0.120261   0.120261  0.334454              0.037143
# 73   0.240000  0.240000  0.120261   0.120261  0.119739              0.037143
# 130  0.180000  0.180000  0.120261   0.120261  0.059739              0.037143
# 145  0.130833  0.130833  0.120261   0.120261  0.010572              0.037143
# 153  0.150000  0.150000  0.120261   0.120261  0.029739              0.037143
# 154  0.216667  0.216667  0.120261   0.120261  0.096406              0.037143
# 158  0.248544  0.248544  0.120261   0.120261  0.128283              0.037143
# 198  0.090000  0.090000  0.120261   0.120261 -0.030261              0.037143
# 205  0.278167  0.278167  0.120261   0.120261  0.157906              0.037143
# 208  0.250000  0.250000  0.120261   0.120261  0.129739              0.037143
# 272  0.280000  0.280000  0.120261   0.120261  0.159739              0.037143
# 284  0.248544  0.248544  0.120261   0.120261  0.128283              0.037143
# 285  0.303333  0.303333  0.120261   0.120261  0.183072              0.037143
# 286  0.270000  0.270000  0.120261   0.120261  0.149739              0.037143
# 292  0.160567  0.160567  0.120261   0.120261  0.040307              0.037143
# 322  0.511667  0.511667  0.120261   0.120261  0.391406              0.037143
# 330  0.213719  0.213719  0.120261   0.120261  0.093458              0.037143
# 340  0.181667  0.181667  0.120261   0.120261  0.061406              0.037143
# 392  0.213719  0.213719  0.120261   0.120261  0.093458              0.037143
# 395  0.290000  0.290000  0.120261   0.120261  0.169739              0.037143
# 465  0.306680  0.306680  0.120261   0.120261  0.186419              0.037143
# 481  0.479000  0.479000  0.120261   0.120261  0.358739              0.037143
# 501  0.213719  0.213719  0.120261   0.120261  0.093458              0.037143
# 525  0.454715  0.454715  0.120261   0.120261  0.334454              0.037143
# 530  0.193333  0.193333  0.120261   0.120261  0.073072              0.037143
# 560  0.228810  0.228810  0.120261   0.120261  0.108549              0.037143
# 564  0.065333  0.065333  0.120261   0.120261 -0.054928              0.037143
# 591  0.186667  0.186667  0.120261   0.120261  0.066406              0.037143
# 613  0.320000  0.320000  0.120261   0.120261  0.199739              0.037143
# 615  0.163333  0.163333  0.120261   0.120261  0.043072              0.037143
# 650  0.350000  0.350000  0.120261   0.120261  0.229739              0.037143
# 658  0.211000  0.211000  0.120261   0.120261  0.090739              0.037143
# 684  0.109000  0.109000  0.120261   0.120261 -0.011261              0.037143
# 687  0.089524  0.089524  0.120261   0.120261 -0.030737              0.037143
# 703  0.081667  0.081667  0.120261   0.120261 -0.038594              0.037143
# 704  0.230000  0.230000  0.120261   0.120261  0.109739              0.037143
# 740  0.127500  0.127500  0.120261   0.120261  0.007239              0.037143
# 770  0.649794  0.649794  0.120261   0.120261  0.529533              0.037143
# 808  0.145762  0.145762  0.120261   0.120261  0.025501              0.037143
# 815  0.220833  0.220833  0.120261   0.120261  0.100572              0.037143
# 829  0.121667  0.121667  0.120261   0.120261  0.001406              0.037143
# 838  0.306680  0.306680  0.120261   0.120261  0.186419              0.037143
# 872  0.090000  0.090000  0.120261   0.120261 -0.030261              0.037143
# 882  0.048333  0.048333  0.120261   0.120261 -0.071928              0.037143
# 886  0.055000  0.055000  0.120261   0.120261 -0.065261              0.037143
# 890  0.214167  0.214167  0.120261   0.120261  0.093906              0.037143
# 893  0.454715  0.454715  0.120261   0.120261  0.334454              0.037143
# 907  0.073250  0.073250  0.120261   0.120261 -0.047011              0.037143
# 945  0.100000  0.100000  0.120261   0.120261 -0.020261              0.037143
# 988  0.213719  0.213719  0.120261   0.120261  0.093458              0.037143
# 996  0.687929  0.687929  0.120261   0.120261  0.567668              0.037143
# 999  0.248544  0.248544  0.120261   0.120261  0.128283              0.037143
#
#      p_hat_raw     p_hat
# 7     0.037143  0.037143
# 17    0.037143  0.037143
# 43    0.037143  0.037143
# 51    0.037143  0.037143
# 73    0.037143  0.037143
# 130   0.037143  0.037143
# 145   0.037143  0.037143
# 153   0.037143  0.037143
# 154   0.037143  0.037143
# 158   0.037143  0.037143
# 198   0.037143  0.037143
# 205   0.037143  0.037143
# 208   0.037143  0.037143
# 272   0.037143  0.037143
# 284   0.037143  0.037143
# 285   0.037143  0.037143
# 286   0.037143  0.037143
# 292   0.037143  0.037143
# 322   0.037143  0.037143
# 330   0.037143  0.037143
# 340   0.037143  0.037143
# 392   0.037143  0.037143
# 395   0.037143  0.037143
# 465   0.037143  0.037143
# 481   0.037143  0.037143
# 501   0.037143  0.037143
# 525   0.037143  0.037143
# 530   0.037143  0.037143
# 560   0.037143  0.037143
# 564   0.037143  0.037143
# 591   0.037143  0.037143
# 613   0.037143  0.037143
# 615   0.037143  0.037143
# 650   0.037143  0.037143
# 658   0.037143  0.037143
# 684   0.037143  0.037143
# 687   0.037143  0.037143
# 703   0.037143  0.037143
# 704   0.037143  0.037143
# 740   0.037143  0.037143
# 770   0.037143  0.037143
# 808   0.037143  0.037143
# 815   0.037143  0.037143
# 829   0.037143  0.037143
# 838   0.037143  0.037143
# 872   0.037143  0.037143
# 882   0.037143  0.037143
# 886   0.037143  0.037143
# 890   0.037143  0.037143
# 893   0.037143  0.037143
# 907   0.037143  0.037143
# 945   0.037143  0.037143
# 988   0.037143  0.037143
# 996   0.037143  0.037143
# 999   0.037143  0.037143
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 27.776997412932474
# [0, 2, 27.776997412932474, 'negative']
# Target positive rate for subset: 0.010852713178294573
# New threshold for subset: 0.7854472948248968
# 0      0.500000
# 2      0.500000
# 3      0.720030
# 5      0.500000
# 6      0.500000
#          ...
# 994    0.500000
# 995    0.500000
# 996    0.785447
# 997    0.500000
# 999    0.785447
# Name: threshold, Length: 700, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 13.01465689131343 :
# {'checking': ['Little', 'Rich'], 'purpose': ['Education'], 'under_25': [True]}
# Best score is now 13.01465689131343
# Subset found on iteration 2 of 10 with score 21.257761485522387 :
# {'sex': ['Female'], 'checking': ['Little', 'Moderate', 'Rich'], 'job': ['1 Job', 'Multiple Jobs'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'under_25': [True], 'housing': ['Rent']}
# Best score is now 21.257761485522387
# Subset found on iteration 3 of 10 with score 17.086209188417907 :
# {'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'housing': ['Rent'], 'credit_amt': ['Low', 'Very High']}
# Current score of 17.086209188417907 does not beat best score of 21.257761485522387
# Subset found on iteration 4 of 10 with score 17.086209188417907 :
# {'housing': ['Rent'], 'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'credit_amt': ['Low', 'Very High']}
# Current score of 17.086209188417907 does not beat best score of 21.257761485522387
# Subset found on iteration 5 of 10 with score 21.257761485522387 :
# {'job': ['1 Job', 'Multiple Jobs'], 'under_25': [True], 'sex': ['Female'], 'checking': ['Little', 'Moderate', 'Rich'], 'housing': ['Rent'], 'purpose': ['Business', 'Education', 'Radio/TV']}
# Current score of 21.257761485522387 does not beat best score of 21.257761485522387
# Subset found on iteration 6 of 10 with score 21.257761485522387 :
# {'sex': ['Female'], 'job': ['1 Job', 'Multiple Jobs'], 'housing': ['Rent'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'under_25': [True], 'checking': ['Little', 'Moderate', 'Rich']}
# Current score of 21.257761485522387 does not beat best score of 21.257761485522387
# Subset found on iteration 7 of 10 with score 17.086209188417907 :
# {'housing': ['Rent'], 'credit_amt': ['Low', 'Very High'], 'savings': ['Little', 'Moderate'], 'purpose': ['Business', 'Education', 'Radio/TV']}
# Current score of 17.086209188417907 does not beat best score of 21.257761485522387
# Subset found on iteration 8 of 10 with score 21.257761485522387 :
# {'under_25': [True], 'housing': ['Rent'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'checking': ['Little', 'Moderate', 'Rich'], 'sex': ['Female'], 'job': ['1 Job', 'Multiple Jobs']}
# Current score of 21.257761485522387 does not beat best score of 21.257761485522387
# Subset found on iteration 9 of 10 with score 12.714656891313432 :
# {'checking': ['Moderate', 'Rich'], 'credit_amt': ['Low'], 'housing': ['Rent'], 'savings': ['Little', 'Moderate'], 'duration': ['Moderate']}
# Current score of 12.714656891313432 does not beat best score of 21.257761485522387
# Subset found on iteration 10 of 10 with score 21.257761485522387 :
# {'housing': ['Rent'], 'sex': ['Female'], 'under_25': [True], 'job': ['1 Job', 'Multiple Jobs'], 'checking': ['Little', 'Moderate', 'Rich'], 'purpose': ['Business', 'Education', 'Radio/TV']}
# Current score of 21.257761485522387 does not beat best score of 21.257761485522387
# Required time =  34.80717468261719 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female'], 'checking': ['Little', 'Moderate', 'Rich'], 'job': ['1 Job', 'Multiple Jobs'], 'purpose': ['Business', 'Education', 'Radio/TV'], 'under_25': [True], 'housing': ['Rent']}
# Score: 21.257761485522387
# First Iteration
# Average p_delta: 0.07582953399774824
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 111  0.181667  0.181667  0.120261   0.120261  0.061406              0.011429
# 221  0.248786  0.248786  0.120261   0.120261  0.128525              0.011429
# 417  0.220000  0.220000  0.120261   0.120261  0.099739              0.011429
# 565  0.150000  0.150000  0.120261   0.120261  0.029739              0.011429
# 752  0.180000  0.180000  0.120261   0.120261  0.059739              0.011429
#
#      p_hat_raw     p_hat
# 111   0.011429  0.011429
# 221   0.011429  0.011429
# 417   0.011429  0.011429
# 565   0.011429  0.011429
# 752   0.011429  0.011429
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 21.257761485522387
# [0, 3, 21.257761485522387, 'negative']
# Target positive rate for subset: 0.004316546762589928
# New threshold for subset: 0.6284805275383634
# 0      0.500000
# 2      0.500000
# 3      0.720030
# 5      0.500000
# 6      0.500000
#          ...
# 994    0.500000
# 995    0.500000
# 996    0.785447
# 997    0.500000
# 999    0.785447
# Name: threshold, Length: 700, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 14.793835967179273 :
# {'purpose': ['Business', 'Education', 'Radio/TV'], 'housing': ['Rent'], 'checking': ['Moderate'], 'credit_amt': ['Low', 'Very High']}
# Best score is now 14.793835967179273
# Subset found on iteration 2 of 10 with score 4.764611989059757 :
# {'savings': ['Moderate'], 'job': ['1 Job'], 'credit_amt': ['Low'], 'duration': ['Moderate']}
# Current score of 4.764611989059757 does not beat best score of 14.793835967179273
# Subset found on iteration 3 of 10 with score 9.829223978119515 :
# {'checking': ['Moderate'], 'purpose': ['Business', 'Radio/TV'], 'credit_amt': ['Low'], 'housing': ['Rent']}
# Current score of 9.829223978119515 does not beat best score of 14.793835967179273
# Subset found on iteration 4 of 10 with score 10.029223978119514 :
# {'credit_amt': ['Very High'], 'purpose': ['Education', 'Furniture/Equipment']}
# Current score of 10.029223978119514 does not beat best score of 14.793835967179273
# Subset found on iteration 5 of 10 with score 9.829223978119515 :
# {'purpose': ['Business', 'Education'], 'savings': ['Moderate'], 'credit_amt': ['Low', 'Very High']}
# Current score of 9.829223978119515 does not beat best score of 14.793835967179273
# Subset found on iteration 6 of 10 with score 9.829223978119515 :
# {'purpose': ['Business', 'Radio/TV'], 'under_25': [True], 'housing': ['Rent'], 'credit_amt': ['Low']}
# Current score of 9.829223978119515 does not beat best score of 14.793835967179273
# Subset found on iteration 7 of 10 with score 10.029223978119514 :
# {'purpose': ['Education', 'Furniture/Equipment'], 'credit_amt': ['Very High']}
# Current score of 10.029223978119514 does not beat best score of 14.793835967179273
# Subset found on iteration 8 of 10 with score 9.829223978119515 :
# {'credit_amt': ['Low', 'Very High'], 'sex': ['Male'], 'job': ['Multiple Jobs'], 'housing': ['Rent']}
# Current score of 9.829223978119515 does not beat best score of 14.793835967179273
# Subset found on iteration 9 of 10 with score 9.729223978119515 :
# {'purpose': ['Business', 'Radio/TV'], 'checking': ['Moderate'], 'housing': ['Rent'], 'duration': ['Moderate'], 'under_25': [True]}
# Current score of 9.729223978119515 does not beat best score of 14.793835967179273
# Subset found on iteration 10 of 10 with score 10.029223978119514 :
# {'purpose': ['Education', 'Furniture/Equipment'], 'credit_amt': ['Very High']}
# Current score of 10.029223978119514 does not beat best score of 14.793835967179273
# Required time =  19.88836097717285 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Education', 'Radio/TV'], 'housing': ['Rent'], 'checking': ['Moderate'], 'credit_amt': ['Low', 'Very High']}
# Score: 14.793835967179273
# First Iteration
# Average p_delta: 0.11640572447393872
# Average p_censor: 0.0
#      proba_rf  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 395      0.29   0.29  0.120261   0.120261  0.169739              0.005714
# 513      0.24   0.24  0.120261   0.120261  0.119739              0.005714
# 752      0.18   0.18  0.120261   0.120261  0.059739              0.005714
#
#      p_hat_raw     p_hat
# 395   0.005714  0.005714
# 513   0.005714  0.005714
# 752   0.005714  0.005714
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 14.793835967179273
# [0, 4, 14.793835967179273, 'negative']
# Target positive rate for subset: 0.0014347202295552368
# New threshold for subset: 0.7863717466259079
# 0      0.500000
# 2      0.500000
# 3      0.720030
# 5      0.500000
# 6      0.500000
#          ...
# 994    0.500000
# 995    0.500000
# 996    0.785447
# 997    0.500000
# 999    0.785447
# Name: threshold, Length: 700, dtype: float64
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Iteration 1
# Subset found on iteration 1 of 10 with score 21.99855960511423 :
# {'credit_amt': ['High', 'Low'], 'savings': ['Little', 'Moderate'], 'housing': ['Free', 'Rent'], 'duration': ['Long', 'Moderate'], 'under_25': [True]}
# Best score is now 21.99855960511423
# Subset found on iteration 2 of 10 with score 38.34448276759563 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'purpose': ['Business', 'Car', 'Education', 'Repairs'], 'checking': ['Little']}
# Best score is now 38.34448276759563
# Subset found on iteration 3 of 10 with score 39.65567811549402 :
# {'purpose': ['Car', 'Education', 'Furniture/Equipment'], 'duration': ['Long', 'Moderate', 'Very Long'], 'housing': ['Free', 'Rent'], 'checking': ['Little']}
# Best score is now 39.65567811549402
# Subset found on iteration 4 of 10 with score 38.096865705206824 :
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Repairs', 'Vacation/Others'], 'checking': ['Little'], 'duration': ['Long', 'Moderate', 'Very Long'], 'savings': ['Little', 'Moderate']}
# Current score of 38.096865705206824 does not beat best score of 39.65567811549402
# Subset found on iteration 5 of 10 with score 39.65567811549402 :
# {'purpose': ['Car', 'Education', 'Furniture/Equipment'], 'duration': ['Long', 'Moderate', 'Very Long'], 'housing': ['Free', 'Rent'], 'checking': ['Little']}
# Current score of 39.65567811549402 does not beat best score of 39.65567811549402
# Subset found on iteration 6 of 10 with score 36.5260394247176 :
# {'savings': ['Little', 'Moderate'], 'purpose': ['Car', 'Furniture/Equipment'], 'housing': ['Free', 'Rent'], 'duration': ['Long', 'Moderate'], 'checking': ['Little']}
# Current score of 36.5260394247176 does not beat best score of 39.65567811549402
# Subset found on iteration 7 of 10 with score 38.096865705206824 :
# {'checking': ['Little'], 'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate', 'Very Long'], 'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Repairs', 'Vacation/Others']}
# Current score of 38.096865705206824 does not beat best score of 39.65567811549402
# Subset found on iteration 8 of 10 with score 39.65567811549402 :
# {'checking': ['Little'], 'purpose': ['Car', 'Education', 'Furniture/Equipment'], 'housing': ['Free', 'Rent'], 'duration': ['Long', 'Moderate', 'Very Long']}
# Current score of 39.65567811549402 does not beat best score of 39.65567811549402
# Subset found on iteration 9 of 10 with score 21.99855960511423 :
# {'housing': ['Free', 'Rent'], 'duration': ['Long', 'Moderate'], 'credit_amt': ['High', 'Low'], 'savings': ['Little', 'Moderate'], 'under_25': [True]}
# Current score of 21.99855960511423 does not beat best score of 39.65567811549402
# Subset found on iteration 10 of 10 with score 26.989880447809483 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment', 'Radio/TV'], 'duration': ['Long', 'Moderate'], 'checking': ['Little'], 'savings': ['Little'], 'sex': ['Female']}
# Current score of 26.989880447809483 does not beat best score of 39.65567811549402
# Required time =  41.77210211753845 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Car', 'Education', 'Furniture/Equipment'], 'duration': ['Long', 'Moderate', 'Very Long'], 'housing': ['Free', 'Rent'], 'checking': ['Little']}
# Score: 39.65567811549402
# First Iteration
# Average p_delta: 0.1444949876413269
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3    0.141350  0.141350  0.120261   0.120261  0.021089                   0.1
# 14   0.159667  0.159667  0.120261   0.120261  0.039406                   0.1
# 43   0.158000  0.158000  0.120261   0.120261  0.037739                   0.1
# 75   0.234841  0.234841  0.120261   0.120261  0.114580                   0.1
# 205  0.278167  0.278167  0.120261   0.120261  0.157906                   0.1
# 218  0.370000  0.370000  0.120261   0.120261  0.249739                   0.1
# 221  0.248786  0.248786  0.120261   0.120261  0.128525                   0.1
# 229  0.139778  0.139778  0.120261   0.120261  0.019517                   0.1
# 262  0.554881  0.554881  0.120261   0.120261  0.434620                   0.1
# 292  0.160567  0.160567  0.120261   0.120261  0.040307                   0.1
# 322  0.511667  0.511667  0.120261   0.120261  0.391406                   0.1
# 330  0.213719  0.213719  0.120261   0.120261  0.093458                   0.1
# 341  0.190000  0.190000  0.120261   0.120261  0.069739                   0.1
# 367  0.164000  0.164000  0.120261   0.120261  0.043739                   0.1
# 392  0.213719  0.213719  0.120261   0.120261  0.093458                   0.1
# 396  0.091833  0.091833  0.120261   0.120261 -0.028428                   0.1
# 417  0.220000  0.220000  0.120261   0.120261  0.099739                   0.1
# 482  0.140000  0.140000  0.120261   0.120261  0.019739                   0.1
# 494  0.181778  0.181778  0.120261   0.120261  0.061517                   0.1
# 501  0.213719  0.213719  0.120261   0.120261  0.093458                   0.1
# 560  0.228810  0.228810  0.120261   0.120261  0.108549                   0.1
# 613  0.320000  0.320000  0.120261   0.120261  0.199739                   0.1
# 623  0.597956  0.597956  0.120261   0.120261  0.477695                   0.1
# 650  0.350000  0.350000  0.120261   0.120261  0.229739                   0.1
# 655  0.246667  0.246667  0.120261   0.120261  0.126406                   0.1
# 746  0.516429  0.516429  0.120261   0.120261  0.396168                   0.1
# 770  0.649794  0.649794  0.120261   0.120261  0.529533                   0.1
# 869  0.114389  0.114389  0.120261   0.120261 -0.005872                   0.1
# 926  0.597956  0.597956  0.120261   0.120261  0.477695                   0.1
# 944  0.025000  0.025000  0.120261   0.120261 -0.095261                   0.1
# 985  0.025000  0.025000  0.120261   0.120261 -0.095261                   0.1
# 988  0.213719  0.213719  0.120261   0.120261  0.093458                   0.1
#
#      p_hat_raw     p_hat
# 3     0.106327  0.106327
# 14    0.111822  0.111822
# 43    0.111322  0.111322
# 75    0.134374  0.134374
# 205   0.147372  0.147372
# 218   0.174922  0.174922
# 221   0.138557  0.138557
# 229   0.105855  0.105855
# 262   0.230386  0.230386
# 292   0.112092  0.112092
# 322   0.217422  0.217422
# 330   0.128037  0.128037
# 341   0.120922  0.120922
# 367   0.113122  0.113122
# 392   0.128037  0.128037
# 396   0.091472  0.091472
# 417   0.129922  0.129922
# 482   0.105922  0.105922
# 494   0.118455  0.118455
# 501   0.128037  0.128037
# 560   0.132565  0.132565
# 613   0.159922  0.159922
# 623   0.243309  0.243309
# 650   0.168922  0.168922
# 655   0.137922  0.137922
# 746   0.218850  0.218850
# 770   0.258860  0.258860
# 869   0.098238  0.098238
# 926   0.243309  0.243309
# 944   0.071422  0.071422
# 985   0.071422  0.071422
# 988   0.128037  0.128037
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 39.65567811549402
# [0.3, 1, 39.65567811549402, 'negative']
# Target positive rate for subset: 0.10979632845011772
# New threshold for subset: 0.6926310869957226
# 0      0.500000
# 2      0.500000
# 3      0.692631
# 5      0.500000
# 6      0.500000
#          ...
# 994    0.500000
# 995    0.500000
# 996    0.500000
# 997    0.500000
# 999    0.500000
# Name: threshold, Length: 700, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 27.904550620455183 :
# {'purpose': ['Business', 'Car', 'Education', 'Repairs', 'Vacation/Others'], 'duration': ['Long', 'Very Long'], 'housing': ['Own', 'Rent'], 'checking': ['Little', 'Moderate'], 'savings': ['Little', 'Moderate', 'Quite rich']}
# Best score is now 27.904550620455183
# Subset found on iteration 2 of 10 with score 10.193564846573858 :
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment'], 'credit_amt': ['Low'], 'duration': ['Moderate'], 'checking': ['Little', 'Rich']}
# Current score of 10.193564846573858 does not beat best score of 27.904550620455183
# Subset found on iteration 3 of 10 with score 15.213262473665576 :
# {'checking': ['Little', 'Moderate'], 'credit_amt': ['Very High']}
# Current score of 15.213262473665576 does not beat best score of 27.904550620455183
# Subset found on iteration 4 of 10 with score 24.865922217242186 :
# {'purpose': ['Business', 'Education', 'Repairs'], 'checking': ['Little', 'Moderate'], 'duration': ['Long', 'Very Long'], 'savings': ['Little', 'Moderate']}
# Current score of 24.865922217242186 does not beat best score of 27.904550620455183
# Subset found on iteration 5 of 10 with score 27.904550620455183 :
# {'savings': ['Little', 'Moderate', 'Quite rich'], 'duration': ['Long', 'Very Long'], 'housing': ['Own', 'Rent'], 'purpose': ['Business', 'Car', 'Education', 'Repairs', 'Vacation/Others'], 'checking': ['Little', 'Moderate']}
# Current score of 27.904550620455183 does not beat best score of 27.904550620455183
# Subset found on iteration 6 of 10 with score 27.904550620455183 :
# {'savings': ['Little', 'Moderate', 'Quite rich'], 'housing': ['Own', 'Rent'], 'duration': ['Long', 'Very Long'], 'checking': ['Little', 'Moderate'], 'purpose': ['Business', 'Car', 'Education', 'Repairs', 'Vacation/Others']}
# Current score of 27.904550620455183 does not beat best score of 27.904550620455183
# Subset found on iteration 7 of 10 with score 15.213262473665576 :
# {'credit_amt': ['Very High'], 'checking': ['Little', 'Moderate']}
# Current score of 15.213262473665576 does not beat best score of 27.904550620455183
# Subset found on iteration 8 of 10 with score 12.904586998978242 :
# {'credit_amt': ['High', 'Low'], 'under_25': [True], 'checking': ['Little', 'Moderate', 'Rich'], 'savings': ['Little', 'Moderate'], 'sex': ['Female'], 'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment']}
# Current score of 12.904586998978242 does not beat best score of 27.904550620455183
# Subset found on iteration 9 of 10 with score 17.395320615487954 :
# {'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate'], 'checking': ['Little', 'Moderate', 'Rich'], 'credit_amt': ['Low', 'Very High']}
# Current score of 17.395320615487954 does not beat best score of 27.904550620455183
# Subset found on iteration 10 of 10 with score 15.213262473665576 :
# {'credit_amt': ['Very High'], 'checking': ['Little', 'Moderate']}
# Current score of 15.213262473665576 does not beat best score of 27.904550620455183
# Required time =  41.922118186950684 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Car', 'Education', 'Repairs', 'Vacation/Others'], 'duration': ['Long', 'Very Long'], 'housing': ['Own', 'Rent'], 'checking': ['Little', 'Moderate'], 'savings': ['Little', 'Moderate', 'Quite rich']}
# Score: 27.904550620455183
# First Iteration
# Average p_delta: 0.14790939756852087
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 7    0.435833  0.435833  0.120261   0.120261  0.315572              0.067143
# 43   0.158000  0.158000  0.120261   0.120261  0.037739              0.067143
# 51   0.454715  0.454715  0.120261   0.120261  0.334454              0.067143
# 73   0.240000  0.240000  0.120261   0.120261  0.119739              0.067143
# 83   0.232500  0.232500  0.120261   0.120261  0.112239              0.067143
# 145  0.130833  0.130833  0.120261   0.120261  0.010572              0.067143
# 154  0.216667  0.216667  0.120261   0.120261  0.096406              0.067143
# 158  0.248544  0.248544  0.120261   0.120261  0.128283              0.067143
# 208  0.250000  0.250000  0.120261   0.120261  0.129739              0.067143
# 284  0.248544  0.248544  0.120261   0.120261  0.128283              0.067143
# 285  0.303333  0.303333  0.120261   0.120261  0.183072              0.067143
# 286  0.270000  0.270000  0.120261   0.120261  0.149739              0.067143
# 395  0.290000  0.290000  0.120261   0.120261  0.169739              0.067143
# 438  0.212391  0.212391  0.120261   0.120261  0.092130              0.067143
# 465  0.306680  0.306680  0.120261   0.120261  0.186419              0.067143
# 481  0.479000  0.479000  0.120261   0.120261  0.358739              0.067143
# 525  0.454715  0.454715  0.120261   0.120261  0.334454              0.067143
# 530  0.193333  0.193333  0.120261   0.120261  0.073072              0.067143
# 613  0.320000  0.320000  0.120261   0.120261  0.199739              0.067143
# 658  0.211000  0.211000  0.120261   0.120261  0.090739              0.067143
# 684  0.109000  0.109000  0.120261   0.120261 -0.011261              0.067143
# 703  0.081667  0.081667  0.120261   0.120261 -0.038594              0.067143
# 704  0.230000  0.230000  0.120261   0.120261  0.109739              0.067143
# 740  0.127500  0.127500  0.120261   0.120261  0.007239              0.067143
# 815  0.220833  0.220833  0.120261   0.120261  0.100572              0.067143
# 818  0.322500  0.322500  0.120261   0.120261  0.202239              0.067143
# 838  0.306680  0.306680  0.120261   0.120261  0.186419              0.067143
# 872  0.090000  0.090000  0.120261   0.120261 -0.030261              0.067143
# 890  0.214167  0.214167  0.120261   0.120261  0.093906              0.067143
# 893  0.454715  0.454715  0.120261   0.120261  0.334454              0.067143
# 945  0.100000  0.100000  0.120261   0.120261 -0.020261              0.067143
# 996  0.687929  0.687929  0.120261   0.120261  0.567668              0.067143
# 999  0.248544  0.248544  0.120261   0.120261  0.128283              0.067143
#
#      p_hat_raw     p_hat
# 7     0.161815  0.161815
# 43    0.078465  0.078465
# 51    0.167479  0.167479
# 73    0.103065  0.103065
# 83    0.100815  0.100815
# 145   0.070315  0.070315
# 154   0.096065  0.096065
# 158   0.105628  0.105628
# 208   0.106065  0.106065
# 284   0.105628  0.105628
# 285   0.122065  0.122065
# 286   0.112065  0.112065
# 395   0.118065  0.118065
# 438   0.094782  0.094782
# 465   0.123068  0.123068
# 481   0.174765  0.174765
# 525   0.167479  0.167479
# 530   0.089065  0.089065
# 613   0.127065  0.127065
# 658   0.094365  0.094365
# 684   0.063765  0.063765
# 703   0.055565  0.055565
# 704   0.100065  0.100065
# 740   0.069315  0.069315
# 815   0.097315  0.097315
# 818   0.127815  0.127815
# 838   0.123068  0.123068
# 872   0.058065  0.058065
# 890   0.095315  0.095315
# 893   0.167479  0.167479
# 945   0.061065  0.061065
# 996   0.237443  0.237443
# 999   0.105628  0.105628
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 27.904550620455183
# [0.3, 2, 27.904550620455183, 'negative']
# Target positive rate for subset: 0.0840494355163259
# New threshold for subset: 0.6760403391387458
# 0      0.500000
# 2      0.500000
# 3      0.692631
# 5      0.500000
# 6      0.500000
#          ...
# 994    0.500000
# 995    0.500000
# 996    0.676040
# 997    0.500000
# 999    0.676040
# Name: threshold, Length: 700, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 24.014359902562173 :
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'checking': ['Little', 'Moderate', 'Rich'], 'duration': ['Long', 'Moderate', 'Very Long'], 'credit_amt': ['Low', 'Very High']}
# Best score is now 24.014359902562173
# Subset found on iteration 2 of 10 with score 24.014359902562173 :
# {'duration': ['Long', 'Moderate', 'Very Long'], 'credit_amt': ['Low', 'Very High'], 'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'checking': ['Little', 'Moderate', 'Rich']}
# Current score of 24.014359902562173 does not beat best score of 24.014359902562173
# Subset found on iteration 3 of 10 with score 2.5486466165501875 :
# {'duration': ['Very Long'], 'under_25': [True], 'credit_amt': ['High']}
# Current score of 2.5486466165501875 does not beat best score of 24.014359902562173
# Subset found on iteration 4 of 10 with score 19.309368354600117 :
# {'checking': ['Little', 'Rich'], 'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment'], 'duration': ['Long', 'Moderate'], 'credit_amt': ['Low', 'Very High']}
# Current score of 19.309368354600117 does not beat best score of 24.014359902562173
# Subset found on iteration 5 of 10 with score 5.265207793841194 :
# {'checking': ['Little', 'Moderate'], 'duration': ['Very Long'], 'purpose': ['Business', 'Car', 'Education']}
# Current score of 5.265207793841194 does not beat best score of 24.014359902562173
# Subset found on iteration 6 of 10 with score 4.557169132609015 :
# {'housing': ['Free'], 'purpose': ['Education'], 'savings': ['Little'], 'checking': ['Little', 'Moderate']}
# Current score of 4.557169132609015 does not beat best score of 24.014359902562173
# Subset found on iteration 7 of 10 with score 4.921375350123377 :
# {'savings': ['Little'], 'duration': ['Long'], 'checking': ['Little'], 'purpose': ['Furniture/Equipment', 'Radio/TV'], 'credit_amt': ['Moderate']}
# Current score of 4.921375350123377 does not beat best score of 24.014359902562173
# Subset found on iteration 8 of 10 with score 13.705813876963216 :
# {'checking': ['Little', 'Moderate', 'Rich'], 'purpose': ['Business', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'credit_amt': ['Low'], 'savings': ['Little', 'Moderate'], 'duration': ['Moderate']}
# Current score of 13.705813876963216 does not beat best score of 24.014359902562173
# Subset found on iteration 9 of 10 with score 24.014359902562173 :
# {'checking': ['Little', 'Moderate', 'Rich'], 'duration': ['Long', 'Moderate', 'Very Long'], 'credit_amt': ['Low', 'Very High'], 'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV']}
# Current score of 24.014359902562173 does not beat best score of 24.014359902562173
# Subset found on iteration 10 of 10 with score 24.014359902562173 :
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'credit_amt': ['Low', 'Very High'], 'duration': ['Long', 'Moderate', 'Very Long'], 'checking': ['Little', 'Moderate', 'Rich']}
# Current score of 24.014359902562173 does not beat best score of 24.014359902562173
# Required time =  40.35098099708557 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Car', 'Education', 'Furniture/Equipment', 'Radio/TV'], 'checking': ['Little', 'Moderate', 'Rich'], 'duration': ['Long', 'Moderate', 'Very Long'], 'credit_amt': ['Low', 'Very High']}
# Score: 24.014359902562173
# First Iteration
# Average p_delta: 0.11991845595542017
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 27   0.120000  0.120000  0.120261   0.120261 -0.000261                  0.04
# 111  0.181667  0.181667  0.120261   0.120261  0.061406                  0.04
# 126  0.462000  0.462000  0.120261   0.120261  0.341739                  0.04
# 157  0.313000  0.313000  0.120261   0.120261  0.192739                  0.04
# 179  0.765298  0.765298  0.120261   0.120261  0.645037                  0.04
# 205  0.278167  0.278167  0.120261   0.120261  0.157906                  0.04
# 220  0.020000  0.020000  0.120261   0.120261 -0.100261                  0.04
# 233  0.020000  0.020000  0.120261   0.120261 -0.100261                  0.04
# 272  0.280000  0.280000  0.120261   0.120261  0.159739                  0.04
# 285  0.303333  0.303333  0.120261   0.120261  0.183072                  0.04
# 316  0.086333  0.086333  0.120261   0.120261 -0.033928                  0.04
# 346  0.220000  0.220000  0.120261   0.120261  0.099739                  0.04
# 391  0.100000  0.100000  0.120261   0.120261 -0.020261                  0.04
# 395  0.290000  0.290000  0.120261   0.120261  0.169739                  0.04
# 422  0.642190  0.642190  0.120261   0.120261  0.521930                  0.04
# 463  0.120000  0.120000  0.120261   0.120261 -0.000261                  0.04
# 513  0.240000  0.240000  0.120261   0.120261  0.119739                  0.04
# 573  0.200000  0.200000  0.120261   0.120261  0.079739                  0.04
# 590  0.218333  0.218333  0.120261   0.120261  0.098072                  0.04
# 615  0.163333  0.163333  0.120261   0.120261  0.043072                  0.04
# 690  0.235762  0.235762  0.120261   0.120261  0.115501                  0.04
# 744  0.210500  0.210500  0.120261   0.120261  0.090239                  0.04
# 752  0.180000  0.180000  0.120261   0.120261  0.059739                  0.04
# 869  0.114389  0.114389  0.120261   0.120261 -0.005872                  0.04
#
#      p_hat_raw     p_hat
# 27    0.039922  0.039922
# 111   0.058422  0.058422
# 126   0.142522  0.142522
# 157   0.097822  0.097822
# 179   0.233511  0.233511
# 205   0.087372  0.087372
# 220   0.009922  0.009922
# 233   0.009922  0.009922
# 272   0.087922  0.087922
# 285   0.094922  0.094922
# 316   0.029822  0.029822
# 346   0.069922  0.069922
# 391   0.033922  0.033922
# 395   0.090922  0.090922
# 422   0.196579  0.196579
# 463   0.039922  0.039922
# 513   0.075922  0.075922
# 573   0.063922  0.063922
# 590   0.069422  0.069422
# 615   0.052922  0.052922
# 690   0.074650  0.074650
# 744   0.067072  0.067072
# 752   0.057922  0.057922
# 869   0.038238  0.038238
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 24.014359902562173
# [0.3, 3, 24.014359902562173, 'negative']
# Target positive rate for subset: 0.056483544009819885
# New threshold for subset: 0.7832452286747221
# 0      0.500000
# 2      0.500000
# 3      0.692631
# 5      0.500000
# 6      0.500000
#          ...
# 994    0.500000
# 995    0.500000
# 996    0.676040
# 997    0.500000
# 999    0.676040
# Name: threshold, Length: 700, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 6.8806977299163545 :
# {'duration': ['Long', 'Moderate'], 'checking': ['Little', 'Moderate'], 'savings': ['Little', 'Moderate'], 'purpose': ['Car', 'Education', 'Radio/TV'], 'job': ['Multiple Jobs'], 'sex': ['Female']}
# Best score is now 6.8806977299163545
# Subset found on iteration 2 of 10 with score 5.126652531530322 :
# {'checking': ['Little', 'Moderate'], 'credit_amt': ['High'], 'savings': ['Little'], 'purpose': ['Education']}
# Current score of 5.126652531530322 does not beat best score of 6.8806977299163545
# Subset found on iteration 3 of 10 with score 5.126652531530322 :
# {'checking': ['Little', 'Moderate'], 'credit_amt': ['High'], 'purpose': ['Education'], 'savings': ['Little']}
# Current score of 5.126652531530322 does not beat best score of 6.8806977299163545
# Subset found on iteration 4 of 10 with score 2.9226015336983915 :
# {'under_25': [True], 'housing': ['Free'], 'purpose': ['Education']}
# Current score of 2.9226015336983915 does not beat best score of 6.8806977299163545
# Subset found on iteration 5 of 10 with score 10.294700303801065 :
# {'checking': ['Little', 'Moderate'], 'housing': ['Free', 'Rent'], 'savings': ['Little', 'Moderate'], 'purpose': ['Education', 'Radio/TV'], 'duration': ['Long', 'Very Long']}
# Best score is now 10.294700303801065
# Subset found on iteration 6 of 10 with score 2.104050997831931 :
# {'purpose': ['Education'], 'duration': ['Very Long'], 'checking': ['Little']}
# Current score of 2.104050997831931 does not beat best score of 10.294700303801065
# Subset found on iteration 7 of 10 with score 5.721140311776656 :
# {'purpose': ['Education', 'Radio/TV'], 'housing': ['Rent'], 'savings': ['Moderate']}
# Current score of 5.721140311776656 does not beat best score of 10.294700303801065
# Subset found on iteration 8 of 10 with score 1.5087880952115427 :
# {'duration': ['Moderate'], 'purpose': ['Radio/TV'], 'housing': ['Rent'], 'checking': ['Little'], 'sex': ['Female']}
# Current score of 1.5087880952115427 does not beat best score of 10.294700303801065
# Subset found on iteration 9 of 10 with score 2.7609681462124325 :
# {'duration': ['Long'], 'job': ['1 Job'], 'housing': ['Own'], 'purpose': ['Furniture/Equipment'], 'under_25': [True]}
# Current score of 2.7609681462124325 does not beat best score of 10.294700303801065
# Subset found on iteration 10 of 10 with score 2.326223013047165 :
# {'under_25': [False], 'savings': ['Moderate'], 'credit_amt': ['Very High']}
# Current score of 2.326223013047165 does not beat best score of 10.294700303801065
# Required time =  23.172335386276245 seconds
# Found positive subset for ijdi scan:
# {'checking': ['Little', 'Moderate'], 'housing': ['Free', 'Rent'], 'savings': ['Little', 'Moderate'], 'purpose': ['Education', 'Radio/TV'], 'duration': ['Long', 'Very Long']}
# Score: 10.294700303801065
# First Iteration
# Average p_delta: 0.14723905780727206
# Average p_censor: 0.0
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 101  0.273333  0.273333  0.120261   0.120261  0.153072              0.021429
# 340  0.181667  0.181667  0.120261   0.120261  0.061406              0.021429
# 395  0.290000  0.290000  0.120261   0.120261  0.169739              0.021429
# 565  0.150000  0.150000  0.120261   0.120261  0.029739              0.021429
# 650  0.350000  0.350000  0.120261   0.120261  0.229739              0.021429
# 678  0.360000  0.360000  0.120261   0.120261  0.239739              0.021429
#
#      p_hat_raw    p_hat
# 101    0.06735  0.06735
# 340    0.03985  0.03985
# 395    0.07235  0.07235
# 565    0.03035  0.03035
# 650    0.09035  0.09035
# 678    0.09335  0.09335
# Subset does not violate p_delta or p_censor conditions!
# ...
# Required time =  21.43021535873413 seconds
# Found positive subset for ijdi scan:
# {'savings': ['Moderate'], 'checking': ['Little']}
# Score: 16.14711001643168
# First Iteration
# Average p_delta: -0.020856180287966042
# Average p_censor: 0.2044489068188051
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 43   0.158000  0.158000  0.120261   0.120261  0.037739              0.095714
# 88   0.077000  0.077000  0.120261   0.120261 -0.043261              0.095714
# 156  0.110000  0.110000  0.120261   0.120261 -0.010261              0.095714
# 518  0.033333  0.033333  0.120261   0.120261 -0.086928              0.095714
# 737  0.100000  0.100000  0.120261   0.120261 -0.020261              0.095714
# 740  0.127500  0.127500  0.120261   0.120261  0.007239              0.095714
# 872  0.090000  0.090000  0.120261   0.120261 -0.030261              0.095714
#
#      p_hat_raw     p_hat
# 43    0.473105  0.473105
# 88   -0.336895  0.000000
# 156  -0.006895  0.000000
# 518  -0.773562  0.000000
# 737  -0.106895  0.000000
# 740   0.168105  0.168105
# 872  -0.206895  0.000000
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.7679633193945155
# p(S): 0.12047161068048517 p(~S): 0.12047161068048519
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.2796246865183846 :
# {'under_25': [True], 'purpose': ['Business']}
# Best score is now 0.2796246865183846
# Subset found on iteration 3 of 10 with score 0.42243642643948787 :
# {'purpose': ['Business', 'Education'], 'sex': ['Female'], 'credit_amt': ['Low']}
# Best score is now 0.42243642643948787
# Subset found on iteration 4 of 10 with score 5.839207562109405 :
# {'checking': ['Little'], 'savings': ['Moderate'], 'duration': ['Long']}
# Best score is now 5.839207562109405
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.839207562109405
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.839207562109405
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.839207562109405
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.839207562109405
# Subset found on iteration 9 of 10 with score 46.7565648791955 :
# {'housing': ['Free', 'Rent'], 'savings': ['Little'], 'sex': ['Female'], 'checking': ['Little', 'Rich']}
# Best score is now 46.7565648791955
# Subset found on iteration 10 of 10 with score 4.513647991609412 :
# {'credit_amt': ['High', 'Low'], 'sex': ['Female'], 'purpose': ['Business', 'Education', 'Furniture/Equipment'], 'savings': ['Little', 'Moderate'], 'duration': ['Long', 'Moderate'], 'under_25': [True]}
# Current score of 4.513647991609412 does not beat best score of 46.7565648791955
# Required time =  20.371004819869995 seconds
# Found positive subset for ijdi scan:
# {'housing': ['Free', 'Rent'], 'savings': ['Little'], 'sex': ['Female'], 'checking': ['Little', 'Rich']}
# Score: 46.7565648791955
# Average p_delta: 0.128436628754843
# Average p_censor: -0.8426455060547915
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 14   0.159667  0.159667  0.120472   0.120261  0.039406              0.095714
# 111  0.181667  0.181667  0.120472   0.120261  0.061406              0.095714
# 139  0.090000  0.090000  0.120472   0.120261 -0.030261              0.095714
# 292  0.160567  0.160567  0.120472   0.120261  0.040307              0.095714
# 341  0.190000  0.190000  0.120472   0.120261  0.069739              0.095714
# 367  0.164000  0.164000  0.120472   0.120261  0.043739              0.095714
# 396  0.091833  0.091833  0.120472   0.120261 -0.028428              0.095714
# 613  0.320000  0.320000  0.120472   0.120261  0.199739              0.095714
# 623  0.597956  0.597956  0.120472   0.120261  0.477695              0.095714
# 746  0.516429  0.516429  0.120472   0.120261  0.396168              0.095714
# 869  0.114389  0.114389  0.120472   0.120261 -0.005872              0.095714
# 896  0.496000  0.496000  0.120472   0.120261  0.375739              0.095714
# 926  0.597956  0.597956  0.120472   0.120261  0.477695              0.095714
# 944  0.025000  0.025000  0.120472   0.120261 -0.095261              0.095714
# 985  0.025000  0.025000  0.120472   0.120261 -0.095261              0.095714
#
#      p_hat_raw     p_hat
# 14    0.489772  0.489772
# 111   0.709772  0.709772
# 139  -0.206895  0.000000
# 292   0.498779  0.498779
# 341   0.793105  0.793105
# 367   0.533105  0.533105
# 396  -0.188562  0.000000
# 613   2.093105  1.000000
# 623   4.872665  1.000000
# 746   4.057391  1.000000
# 869   0.036994  0.036994
# 896   3.853105  1.000000
# 926   4.872665  1.000000
# 944  -0.856895  0.000000
# 985  -0.856895  0.000000
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 1.6486879617701846 :
# {'duration': ['Long', 'Moderate'], 'savings': ['Moderate'], 'housing': ['Rent']}
# Best score is now 1.6486879617701846
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 1.6486879617701846
# Subset found on iteration 4 of 10 with score 13.61551055796382 :
# {'savings': ['Quite rich'], 'duration': ['Very Long']}
# Best score is now 13.61551055796382
# Subset found on iteration 5 of 10 with score 5.839207562109405 :
# {'checking': ['Little'], 'duration': ['Long'], 'savings': ['Moderate']}
# Current score of 5.839207562109405 does not beat best score of 13.61551055796382
# Subset found on iteration 6 of 10 with score 0.23344167105016989 :
# {'purpose': ['Education'], 'duration': ['Long'], 'checking': ['Moderate']}
# Current score of 0.23344167105016989 does not beat best score of 13.61551055796382
# Subset found on iteration 7 of 10 with score 13.61551055796382 :
# {'duration': ['Very Long'], 'savings': ['Quite rich']}
# Current score of 13.61551055796382 does not beat best score of 13.61551055796382
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 13.61551055796382
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 13.61551055796382
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 13.61551055796382
# Required time =  17.937098503112793 seconds
# Found positive subset for ijdi scan:
# {'savings': ['Quite rich'], 'duration': ['Very Long']}
# Score: 13.61551055796382
# Average p_delta: -0.035260942192727934
# Average p_censor: 0.25689513621299365
#      proba_rf  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 921      0.07   0.07  0.120472   0.120261 -0.050261              0.095714
# 945      0.10   0.10  0.120472   0.120261 -0.020261              0.095714
#
#      p_hat_raw  p_hat
# 921  -0.406895    0.0
# 945  -0.106895    0.0
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.12036197641104524 p(~S): 0.12036197641104524
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 5.37645032789312 :
# {'purpose': ['Business'], 'savings': ['Moderate']}
# Best score is now 5.37645032789312
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.37645032789312
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.37645032789312
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.37645032789312
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.37645032789312
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 5.37645032789312
# Subset found on iteration 8 of 10 with score 3.4381465812240037 :
# {'purpose': ['Business', 'Car'], 'duration': ['Very Long'], 'savings': ['Moderate', 'Quite rich']}
# Current score of 3.4381465812240037 does not beat best score of 5.37645032789312
# Subset found on iteration 9 of 10 with score 0.44162043912720533 :
# {'purpose': ['Business'], 'credit_amt': ['Very High']}
# Current score of 0.44162043912720533 does not beat best score of 5.37645032789312
# Subset found on iteration 10 of 10 with score 3.4381465812240037 :
# {'purpose': ['Business', 'Car'], 'duration': ['Very Long'], 'savings': ['Moderate', 'Quite rich']}
# Current score of 3.4381465812240037 does not beat best score of 5.37645032789312
# Required time =  17.87319827079773 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business'], 'savings': ['Moderate']}
# Score: 5.37645032789312
# Average p_delta: -0.035268007958050615
# Average p_censor: 0.394227130834019
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 82   0.060000  0.060000  0.120573   0.120261 -0.060261              0.095714
# 97   0.010000  0.010000  0.120573   0.120261 -0.110261              0.095714
# 110  0.065000  0.065000  0.120573   0.120261 -0.055261              0.095714
# 145  0.130833  0.130833  0.120573   0.120261  0.010572              0.095714
# 154  0.216667  0.216667  0.120573   0.120261  0.096406              0.095714
# 348  0.063333  0.063333  0.120573   0.120261 -0.056928              0.095714
# 384  0.030000  0.030000  0.120573   0.120261 -0.090261              0.095714
# 478  0.080000  0.080000  0.120573   0.120261 -0.040261              0.095714
# 670  0.030000  0.030000  0.120573   0.120261 -0.090261              0.095714
# 671  0.020000  0.020000  0.120573   0.120261 -0.100261              0.095714
# 684  0.109000  0.109000  0.120573   0.120261 -0.011261              0.095714
# 703  0.081667  0.081667  0.120573   0.120261 -0.038594              0.095714
# 752  0.180000  0.180000  0.120573   0.120261  0.059739              0.095714
# 872  0.113401  0.090000  0.120573   0.120261 -0.006860              0.095714
#
#      p_hat_raw     p_hat
# 82   -0.506895  0.000000
# 97   -1.006895  0.000000
# 110  -0.456895  0.000000
# 145   0.201438  0.201438
# 154   1.059772  1.000000
# 348  -0.473562  0.000000
# 384  -0.806895  0.000000
# 478  -0.306895  0.000000
# 670  -0.806895  0.000000
# 671  -0.906895  0.000000
# 684  -0.016895  0.000000
# 703  -0.290228  0.000000
# 752   0.693105  0.693105
# 872   0.027116  0.027116
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.7540894777673119
# p(S): 0.12101480981765246 p(~S): 0.12101480981765245
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 2.035877886833169 :
# {'purpose': ['Car'], 'savings': ['Quite rich'], 'duration': ['Very Long']}
# Best score is now 2.035877886833169
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 2.035877886833169
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 2.035877886833169
# Subset found on iteration 5 of 10 with score 44.9239006189163 :
# {'purpose': ['Business', 'Car', 'Furniture/Equipment'], 'credit_amt': ['Low', 'Moderate'], 'sex': ['Female'], 'duration': ['Moderate'], 'housing': ['Free', 'Rent']}
# Best score is now 44.9239006189163
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 44.9239006189163
# Subset found on iteration 7 of 10 with score 3.406365465720975 :
# {'purpose': ['Business', 'Education', 'Furniture/Equipment'], 'housing': ['Rent'], 'duration': ['Moderate'], 'credit_amt': ['Low']}
# Current score of 3.406365465720975 does not beat best score of 44.9239006189163
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 44.9239006189163
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 44.9239006189163
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 44.9239006189163
# Required time =  18.82980179786682 seconds
# Found positive subset for ijdi scan:
# {'purpose': ['Business', 'Car', 'Furniture/Equipment'], 'credit_amt': ['Low', 'Moderate'], 'sex': ['Female'], 'duration': ['Moderate'], 'housing': ['Free', 'Rent']}
# Score: 44.9239006189163
# Average p_delta: 0.05170415957007024
# Average p_censor: -0.36452822571401317
#      proba_rf     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 14   0.159667  0.159667  0.121293   0.120261  0.039406              0.095714
# 82   0.106011  0.060000  0.121293   0.120261 -0.014250              0.095714
# 271  0.085000  0.085000  0.121293   0.120261 -0.035261              0.095714
# 382  0.020000  0.020000  0.121293   0.120261 -0.100261              0.095714
# 391  0.100000  0.100000  0.121293   0.120261 -0.020261              0.095714
# 396  0.091833  0.091833  0.121293   0.120261 -0.028428              0.095714
# 584  0.051667  0.051667  0.121293   0.120261 -0.068594              0.095714
# 623  0.597956  0.597956  0.121293   0.120261  0.477695              0.095714
# 746  0.516429  0.516429  0.121293   0.120261  0.396168              0.095714
# 752  0.180000  0.180000  0.121293   0.120261  0.059739              0.095714
# 797  0.077500  0.077500  0.121293   0.120261 -0.042761              0.095714
# 865  0.085000  0.085000  0.121293   0.120261 -0.035261              0.095714
# 869  0.114389  0.114389  0.121293   0.120261 -0.005872              0.095714
# 898  0.090000  0.090000  0.121293   0.120261 -0.030261              0.095714
# 926  0.597956  0.597956  0.121293   0.120261  0.477695              0.095714
# 944  0.025000  0.025000  0.121293   0.120261 -0.095261              0.095714
# 985  0.025000  0.025000  0.121293   0.120261 -0.095261              0.095714
#
#      p_hat_raw     p_hat
# 14    0.489772  0.489772
# 82   -0.046789  0.000000
# 271  -0.256895  0.000000
# 382  -0.906895  0.000000
# 391  -0.106895  0.000000
# 396  -0.188562  0.000000
# 584  -0.590228  0.000000
# 623   4.872665  1.000000
# 746   4.057391  1.000000
# 752   0.693105  0.693105
# 797  -0.331895  0.000000
# 865  -0.256895  0.000000
# 869   0.036994  0.036994
# 898  -0.206895  0.000000
# 926   4.872665  1.000000
# 944  -0.856895  0.000000
# 985  -0.856895  0.000000
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.4848917740568259
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  23.787041187286377 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Score for Negative IJDI-Scan: 0.0
# [10, 3, 0.0, 'negative']
#
# ----------------------------------------------------

# %%
columns = ['lambda', 'iteration', 'score', 'scan_type']
mit_result_df = pd.DataFrame(sim_data, columns=columns)
mit_result_df
# Out:
#     lambda  iteration      score scan_type
# 0      0.0          1  53.505692  negative
# 1      0.0          2  27.776997  negative
# 2      0.0          3  21.257761  negative
# 3      0.0          4  14.793836  negative
# 4      0.3          1  39.655678  negative
# 5      0.3          2  27.904551  negative
# 6      0.3          3  24.014360  negative
# 7      0.3          4  10.294700  negative
# 8      1.0          1  30.733451  negative
# 9      1.0          2  20.912831  negative
# 10     1.0          3  17.491102  negative
# 11     1.0          4  11.815044  negative
# 12     3.0          1  11.825935  negative
# 13     3.0          2   8.995093  negative
# 14     3.0          3  17.510474  negative
# 15     3.0          4  10.325089  negative
# 16    10.0          1  13.875920  negative
# 17    10.0          2   0.540049  negative
# 18    10.0          3   0.000000  negative

# %%
# Write recipe outputs
mit_result_df.to_csv(home_dir + "datasets/german_credit_mit_2_neg.csv")
