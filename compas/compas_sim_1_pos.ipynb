# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
import pandas as pd, numpy as np

os.chdir('../') # cd back to parent dir
home_dir = "compas/" # set home dir for reading and storing data

# Read recipe inputs
compas_prep_df = pd.read_csv(home_dir + "datasets/compas_prep.csv")
compas_prep_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
# [7214 rows x 10 columns]

# %% [markdown]
# ### Prepare Base Dataset for Simulations

# %% [markdown]
# Select only covariates to prepare for simulating probabilities and outcomes.

# %%
# Exclude decile score from covariates
FEATURES = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
compas_sim_df = compas_prep_df[FEATURES]
compas_sim_df
# Out:
#          sex              race  under_25 charge_degree prior_offenses
# 0       Male             Other     False             F           None
# 1       Male  African-American     False             F           None
# 2       Male  African-American      True             F         1 to 5
# 3       Male  African-American      True             F         1 to 5
# 4       Male             Other     False             F         1 to 5
# ...      ...               ...       ...           ...            ...
# 7209    Male  African-American      True             F           None
# 7210    Male  African-American      True             F           None
# 7211    Male             Other     False             F           None
# 7212  Female  African-American     False             M         1 to 5
# 7213  Female          Hispanic      True             F         1 to 5
#
# [7214 rows x 5 columns]

# %% [markdown]
# Define subgroup for which to simulate altered probabilities and outcomes.

# %%
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment
subgroup = {'race':['African-American'], 'sex':['Male'], 'under_25':[False]}
compas_sim_df['in_subgroup'] = compas_sim_df[list(subgroup.keys())].isin(subgroup).all(axis=1)

# %% [markdown]
# ### Example of one Iteration for Base Case of the Simulation

# %% [markdown]
# Define mean for altered group and remaining population.

# %%
subgroup_mu = 0.51
non_subgroup_mu = 0.49
k = 1

# %%
compas_sim_df['proba'] = compas_sim_df['in_subgroup'].apply(lambda x : generate_proba(x, subgroup_mu, non_subgroup_mu, k))
compas_sim_df['outcomes'] = compas_sim_df['proba'].apply(lambda x : generate_outcomes(x))
compas_sim_df
# Out:
#          sex              race  under_25 charge_degree prior_offenses  \
# 0       Male             Other     False             F           None
# 1       Male  African-American     False             F           None
# 2       Male  African-American      True             F         1 to 5
# 3       Male  African-American      True             F         1 to 5
# 4       Male             Other     False             F         1 to 5
# ...      ...               ...       ...           ...            ...
# 7209    Male  African-American      True             F           None
# 7210    Male  African-American      True             F           None
# 7211    Male             Other     False             F           None
# 7212  Female  African-American     False             M         1 to 5
# 7213  Female          Hispanic      True             F         1 to 5
#
#       in_subgroup     proba  outcomes
# 0           False  0.481817         0
# 1            True  0.505544         0
# 2           False  0.489042         1
# 3           False  0.498622         0
# 4           False  0.498873         1
# ...           ...       ...       ...
# 7209        False  0.499351         1
# 7210        False  0.480711         1
# 7211        False  0.485923         1
# 7212        False  0.496388         0
# 7213        False  0.483248         0
#
# [7214 rows x 8 columns]

# %% [markdown]
# Generate variant metrics for only "truly positive-outcome" people (those who DID reoffend). Additionally, generate metrics required for IJDI scan (i.e. $\hat{p}$ calculation).

# %%
# specify probability and outcomes columns
PROBA_COL = 'proba'
OUTCOMES_COL = 'outcomes'
FEATURES = ['sex', 'race', 'under_25', 'charge_degree']
THRESHOLD = 0.5
LAMBDA_PARAM = 49
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# %%
# metrics_df = generate_metrics(positives_df, PROBA_COL, OUTCOMES_COL, THRESHOLD)

# print("Number of people in subgroup:", len(metrics_df[metrics_df['in_subgroup'] == True]))
# print("Number of people not in subgroup:", len(metrics_df[metrics_df['in_subgroup'] == False]))
# print("Total population:", len(metrics_df))

# # display preview of treatments, probabilities, and outcomes
# metrics_df.head(10)

# %%
# filter for only positive outcomes
positives_df = compas_sim_df.loc[compas_sim_df[OUTCOMES_COL] == 1]

# scan with positive direction
current_subset, current_score = run_ijdi_scan(positives_df, FEATURES, PROBA_COL, PROBA_COL, OUTCOMES_COL,
                                              THRESHOLD, LAMBDA_PARAM)
# summarize_scan(positives_df, FEATURES, PROBA_COL, OUTCOMES_COL, current_subset, include='all')\
current_subset, current_score
# Out:
# Required time =  19.47016406059265 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Score: 171.61280480648492
# First Iteration
# Average p_delta: 0.013779277056850897
# Average p_censor: -0.11843352671541436
# p(S): 0.5101343821490414 p(~S): 0.48987308688216347 E[censored] 0.8766722646020748 E[uncensored] 0.9951057913174901
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.9603154256686912
# E[censored]: 0.995105791317489 E[uncensored]: 0.9951057913174901
# Required time =  10.784598112106323 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Score: 5.301648396010205
# Average p_delta: 0.013779277056850897
# Average p_censor: -5.834285463619446e-17
# p(S): 0.5101343821490414 p(~S): 0.48987308688216347 E[censored] 0.995105791317489 E[uncensored] 0.9951057913174901
# Subset does not violate p_delta or p_censor conditions!
# ({'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]},
#  5.301648396010205)

# %% [markdown]
# ### Simulations for Positives

# %% [markdown]
# Set mean values as well as ranges of standard deviation and lambda to iterate over for each simulation. Also define threshold and number of iterations to run for each set of parameters.

# %%
subgroup_mu = 0.51
non_subgroup_mu = 0.49
k_vals = [0, 1, 3, 10]
lambda_vals = [0, 4, 8, 12, 16, 20, 42, 46, 50, 54, 80]
n_iters = 50

# specify parameters for generating metrics and IJDI scan
proba_col = 'proba'
outcomes_col = 'outcomes'
features = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
threshold = 0.5
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(300)

# %%
sim_data = []

for k in k_vals:

    print("Parameter k =", k)

    for i in range(n_iters): # run n iterations for each k value

        print("Simulation", i+1, "of", n_iters)

        # generate probabilities from normal distribution (with edge boundary of 0 and 1) and outcomes from bernoulli random variable
        compas_sim_df[proba_col] = compas_sim_df['in_subgroup'].apply(lambda x : generate_proba(x, subgroup_mu, non_subgroup_mu, k))
        compas_sim_df[outcomes_col] = compas_sim_df[proba_col].apply(lambda x : generate_outcomes(x))

        # filter for only positives outcomes
        positives_df = compas_sim_df.loc[compas_sim_df[outcomes_col] == 0]

        for lambda_param in lambda_vals: # run IJDI scan for various lambda values

            print("Lambda =", lambda_param)
            
            positives_df_copy = positives_df.copy(deep=True)
            
            # Run IJDI Scan. Make sure to pass in copy because data may be modified by the function!
            current_subset, current_score = run_ijdi_scan(positives_df_copy, features, proba_col, proba_col, outcomes_col,
                                                          threshold, lambda_param, verbose=False)

            # save iou and score
            if current_subset:
                in_subgroup = positives_df[list(subgroup.keys())].isin(subgroup).all(axis=1)
                in_current_subset = positives_df[list(current_subset.keys())].isin(current_subset).all(axis=1)
                iou = (in_subgroup & in_current_subset).sum() / (in_subgroup | in_current_subset).sum()
            else:
                iou = 0.0

            print("Detected subset intersection over union with expected subset:", iou)
            print("Detected subset score:", current_score)

            # append data
            sim_row = [k, lambda_param, iou, current_score]
            sim_data.append(sim_row)
            print(sim_row)
            
            # release memory from kernel
            release_df(positives_df_copy)
            
            print("\n----------------------------------------------------\n")
# Out:
# Parameter k = 0
# Simulation 1 of 40
# Lambda = 0
# Required time =  21.549988508224487 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Score: 1299.2153879535374
# First Iteration
# Average p_delta: 0.01384314819982902
# Average p_censor: 0.0
# p(S): 0.5099999999999935 p(~S): 0.49000000000000793 E[censored] 0.30784259000836733 E[uncensored] 0.30784259000836733
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 1299.2153879535374
# [0, 0, 1.0, 1299.2153879535374]
#
# ----------------------------------------------------
#
# Lambda = 4
# Required time =  21.936479330062866 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Score: 1116.7721589936184
# First Iteration
# Average p_delta: 0.01384314819982902
# Average p_censor: 0.0
# p(S): 0.5099999999999935 p(~S): 0.49000000000000793 E[censored] 0.36321518280768234 E[uncensored] 0.36321518280768234
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 
# First Iteration
# Average p_delta: 0.013785249457697546
# Average p_censor: 0.0
# p(S): 0.5099999999999933 p(~S): 0.49000000000000793 E[censored] 0.5313015184381219 E[uncensored] 0.5313015184381219
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 724.4587123790054
# [0, 16, 1.0, 724.4587123790054]
#
# ----------------------------------------------------
#
# Lambda = 20
# Required time =  22.34986972808838 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Score: 611.2971905799379
# First Iteration
# Average p_delta: 0.013785249457697546
# Average p_censor: 0.0
# p(S): 0.5099999999999933 p(~S): 0.49000000000000793 E[censored] 0.5864425162689112 E[uncensored] 0.5864425162689112
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 611.2971905799379
# [0, 20, 1.0, 611.2971905799379]
#
# ----------------------------------------------------
#
# Lambda = 42
# Required time =  22.362088203430176 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Score: 133.6107779389087
# First Iteration
# Average p_delta: 0.013785249457697546
# Average p_censor: 0.0
# p(S): 0.5099999999999933 p(~S): 0.49000000000000793 E[censored] 0.8897180043382827 E[uncensored] 0.8897180043382827
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 133.6107779389087
# [0, 42, 1.0, 133.6107779389087]
#
# ...
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 80, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Simulation 39 of 40
# Lambda = 0
# Required time =  22.050841093063354 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'charge_degree': ['F'], 'sex': ['Male'], 'under_25': [False]}
# Score: 7.735173975871012
# First Iteration
# Average p_delta: 0.013797159824895053
# Average p_censor: 0.0
# p(S): 0.5018734784528147 p(~S): 0.4847048322045438 E[censored] 0.42982697061247094 E[uncensored] 0.42982697061247094
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.6608133086876156
# Detected subset score: 7.735173975871012
# [10, 0, 0.6608133086876156, 7.735173975871012]
#
# ----------------------------------------------------
#
# Lambda = 4
# Required time =  15.28626298904419 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Native American'], 'prior_offenses': ['1 to 5', 'None'], 'charge_degree': ['M']}
# Score: 2.1032490389494747
# First Iteration
# Average p_delta: 0.047181027171811225
# Average p_censor: 0.0
# p(S): 0.5352573457997309 p(~S): 0.4879333458183082 E[censored] 0.618551079299714 E[uncensored] 0.618551079299714
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 2.1032490389494747
# [10, 4, 0.0, 2.1032490389494747]
#
# ----------------------------------------------------
#
# Lambda = 8
# Required time =  18.90832281112671 seconds
# Found positive subset for ijdi scan:
# {'race': ['Native American'], 'charge_degree': ['M']}
# Score: 0.8993178430954487
# First Iteration
# Average p_delta: 0.03460514636090621
# Average p_censor: 0.016793775852620398
# p(S): 0.522681464988826 p(~S): 0.4880096603933225 E[censored] 0.7234619173523392 E[uncensored] 0.7066681414997189
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.8993178430954487
# [10, 8, 0.0, 0.8993178430954487]
#
# ----------------------------------------------------
#
# Lambda = 12
# Required time =  13.070387363433838 seconds
# Found positive subset for ijdi scan:
# {'under_25': [True], 'race': ['Asian']}
# Score: 0.44466924495901344
# First Iteration
# Average p_delta: 0.026469462646392883
# Average p_censor: -0.03628088899559397
# p(S): 0.5145457812743125 p(~S): 0.4880326276304292 E[censored] 0.7111796333735897 E[uncensored] 0.7474605223691837
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.12561748819647256
# E[censored]: 0.7474605223691837 E[uncensored]: 0.7474605223691837
# Required time =  10.849576473236084 seconds
# Found positive subset for ijdi scan:
# {'race': ['Native American'], 'charge_degree': ['M']}
# Score: 0.2815511620780626
# Average p_delta: 0.03460514636090621
# Average p_censor: -0.0490835762694753
# p(S): 0.522681464988826 p(~S): 0.4880096603933225 E[censored] 0.7960051506738682 E[uncensored] 0.8450887269433436
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.2406118410911651
# E[censored]: 0.8450887269433437 E[uncensored]: 0.8450887269433436
# Required time =  13.241257667541504 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian'], 'sex': ['Female']}
# Score: 0.11604890237067095
# Average p_delta: 0.03724376865066681
# Average p_censor: -0.01224043075676362
# p(S): 0.5253200872785866 p(~S): 0.48805584939535546 E[censored] 0.8645117636637072 E[uncensored] 0.8767521944204708
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.09034312563034533
# E[censored]: 0.8767521944204708 E[uncensored]: 0.8767521944204708
# Required time =  14.196643114089966 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Native American'], 'prior_offenses': ['None']}
# Score: 0.041924782709725106
# Average p_delta: 0.01461990185787985
# Average p_censor: 0.035213089578349115
# p(S): 0.5026962204857995 p(~S): 0.48802797505605566 E[censored] 0.6404788824853764 E[uncensored] 0.6052657929070273
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.041924782709725106
# [10, 12, 0.0, 0.041924782709725106]
#
# ----------------------------------------------------
#
# Lambda = 16
# Required time =  13.009395360946655 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Native American'], 'charge_degree': ['M']}
# Score: 0.1218371404821823
# First Iteration
# Average p_delta: 0.03063192204299517
# Average p_censor: -0.16203054286151053
# p(S): 0.5187082406709148 p(~S): 0.4879580812668495 E[censored] 0.7579071804388813 E[uncensored] 0.9199377233003919
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.6692909899403456
# E[censored]: 0.9199377233003919 E[uncensored]: 0.9199377233003919
# Required time =  17.350483655929565 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 16, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 20
# Required time =  16.253771781921387 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Other'], 'prior_offenses': ['1 to 5'], 'under_25': [True]}
# Score: 0.06248054964519267
# First Iteration
# Average p_delta: 0.004950567311142293
# Average p_censor: 0.036482138441119305
# p(S): 0.4930268859390621 p(~S): 0.48804346996453374 E[censored] 0.5653204552764343 E[uncensored] 0.5288383168353149
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.06248054964519267
# [10, 20, 0.0, 0.06248054964519267]
#
# ----------------------------------------------------
#
# Lambda = 42
# Required time =  17.417057275772095 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 42, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 46
# Required time =  16.84149408340454 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 46, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 50
# Required time =  16.642781019210815 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 50, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 54
# Required time =  15.612487554550171 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 54, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 80
# Required time =  15.032267093658447 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 80, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Simulation 40 of 40
# Lambda = 0
# Required time =  26.418766021728516 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian', 'Hispanic'], 'prior_offenses': ['Over 5'], 'under_25': [True]}
# Score: 5.128630539718374
# First Iteration
# Average p_delta: 0.04913013716428325
# Average p_censor: 0.0
# p(S): 0.5392254331430588 p(~S): 0.48994446385239904 E[censored] 0.43572621035058423 E[uncensored] 0.43572621035058423
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 5.128630539718374
# [10, 0, 0.0, 5.128630539718374]
#
# ----------------------------------------------------
#
# Lambda = 4
# Required time =  17.316319942474365 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female'], 'charge_degree': ['F'], 'race': ['Caucasian', 'Native American']}
# Score: 1.1523202641477597
# First Iteration
# Average p_delta: 0.0008078425854853695
# Average p_censor: 0.0
# p(S): 0.49090313856426093 p(~S): 0.49005765625434966 E[censored] 0.4389575806925257 E[uncensored] 0.4389575806925257
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 1.1523202641477597
# [10, 4, 0.0, 1.1523202641477597]
#
# ----------------------------------------------------
#
# Lambda = 8
# Required time =  11.79655122756958 seconds
# Found positive subset for ijdi scan:
# {'race': ['Other'], 'prior_offenses': ['None'], 'charge_degree': ['M'], 'sex': ['Male']}
# Score: 0.2033225445729142
# First Iteration
# Average p_delta: -0.008455849695168037
# Average p_censor: 0.04481586275135304
# p(S): 0.4816394462836075 p(~S): 0.49015930156940346 E[censored] 0.41289527554059297 E[uncensored] 0.36807941278923983
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.2930071664955753
# p(S): 0.49015930156940335 p(~S): 0.49015930156940346
# Required time =  12.648212432861328 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian'], 'under_25': [True], 'prior_offenses': ['Over 5']}
# Score: 0.8846716187367576
# Average p_delta: 0.052654570210805586
# Average p_censor: -0.020694455568259773
# p(S): 0.5427498661895811 p(~S): 0.4900072448580216 E[censored] 0.8362683164687693 E[uncensored] 0.8569627720370289
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.12639249241160033
# E[censored]: 0.8569627720370289 E[uncensored]: 0.8569627720370289
# Required time =  14.073968648910522 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'sex': ['Female'], 'under_25': [False], 'race': ['Caucasian']}
# Score: 0.16564644555638564
# Average p_delta: -0.0002480715481512163
# Average p_censor: 0.03518758442244531
# p(S): 0.4898472244306242 p(~S): 0.4901043089588986 E[censored] 0.46892922238782003 E[uncensored] 0.4337416379653746
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.0100634309437024
# p(S): 0.49010430895889845 p(~S): 0.4901043089588986
# Required time =  11.008641481399536 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian'], 'prior_offenses': ['Over 5'], 'under_25': [True]}
# Score: 0.8846716187367576
# Average p_delta: 0.052654570210805586
# Average p_censor: -0.020694455568259773
# p(S): 0.5427498661895811 p(~S): 0.4900072448580216 E[censored] 0.8362683164687693 E[uncensored] 0.8569627720370289
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.12639249241160033
# E[censored]: 0.8569627720370289 E[uncensored]: 0.8569627720370289
# Required time =  12.291841745376587 seconds
# Found positive subset for ijdi scan:
# {'race': ['Native American'], 'sex': ['Female']}
# Score: 0.047908789473251445
# Average p_delta: -0.004891463524335615
# Average p_censor: 0.022738864366526182
# p(S): 0.48520383245443993 p(~S): 0.49010074607740994 E[censored] 0.4193333665224256 E[uncensored] 0.3965945021558994
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.15360785508130897
# p(S): 0.49010074607740994 p(~S): 0.49010074607740994
# Required time =  15.952333211898804 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'race': ['Caucasian'], 'sex': ['Female']}
# Score: 0.14443500231908568
# Average p_delta: 0.0006743760353960073
# Average p_censor: 0.03077860408471036
# p(S): 0.4907696720141715 p(~S): 0.49007391559268443 E[censored] 0.4718998227184628 E[uncensored] 0.4411212186337525
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.14443500231908568
# [10, 8, 0.0, 0.14443500231908568]
#
# ----------------------------------------------------
#
# Lambda = 12
# Required time =  15.578418254852295 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian', 'Hispanic'], 'prior_offenses': ['Over 5'], 'charge_degree': ['F'], 'under_25': [True]}
# Score: 0.2655797764701333
# First Iteration
# Average p_delta: 0.05400940067351541
# Average p_censor: -0.20973285173529232
# p(S): 0.544104696652291 p(~S): 0.49002005301322316 E[censored] 0.8741061666974769 E[uncensored] 1.0838390184327693
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  14.310549020767212 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 12, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 16
# Required time =  15.428802251815796 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian'], 'under_25': [True], 'prior_offenses': ['Over 5']}
# Score: 0.08749428136961224
# First Iteration
# Average p_delta: 0.052654570210805586
# Average p_censor: -0.331740134632236
# p(S): 0.5427498661895811 p(~S): 0.4900072448580216 E[censored] 0.9464591990912377 E[uncensored] 1.2781993337234736
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  16.359077215194702 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 16, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 20
# Required time =  16.87208843231201 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 20, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 42
# Required time =  14.913547277450562 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 42, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 46
# Required time =  15.076879501342773 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 46, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 50
# Required time =  14.550669431686401 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 50, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 54
# Required time =  13.327515602111816 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 54, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 80
# Required time =  13.90898060798645 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 80, 0.0, 0.0]
#
# ----------------------------------------------------

# %%
columns = ['k', 'lambda', 'iou', 'score']
sim_result_df = pd.DataFrame(sim_data, columns=columns)
sim_result_df
# Out:
#        k  lambda  iou        score
# 0      0       0  1.0  1299.215388
# 1      0       4  1.0  1116.772159
# 2      0       8  1.0   960.266614
# 3      0      12  1.0   823.233399
# 4      0      16  1.0   701.358824
# ...   ..     ...  ...          ...
# 1755  10      42  0.0     0.000000
# 1756  10      46  0.0     0.000000
# 1757  10      50  0.0     0.000000
# 1758  10      54  0.0     0.000000
# 1759  10      80  0.0     0.000000
#
# [1760 rows x 4 columns]

# %%
# Write recipe outputs
sim_result_df.to_csv(home_dir + "datasets/compas_sim_1_pos_3.csv")
