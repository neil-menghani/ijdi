# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
import pandas as pd, numpy as np

os.chdir('../') # cd back to parent dir
home_dir = "compas/" # set home dir for reading and storing data

# Read recipe inputs
compas_prep_df = pd.read_csv(home_dir + "datasets/compas_prep.csv")
compas_prep_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
# [7214 rows x 10 columns]

# %% [markdown]
# ### Prepare Base Dataset for Simulations

# %% [markdown]
# Select only covariates to prepare for simulating probabilities and outcomes.

# %%
# Exclude decile score from covariates
FEATURES = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
compas_sim_df = compas_prep_df[FEATURES]
compas_sim_df
# Out:
#          sex              race  under_25 charge_degree prior_offenses
# 0       Male             Other     False             F           None
# 1       Male  African-American     False             F           None
# 2       Male  African-American      True             F         1 to 5
# 3       Male  African-American      True             F         1 to 5
# 4       Male             Other     False             F         1 to 5
# ...      ...               ...       ...           ...            ...
# 7209    Male  African-American      True             F           None
# 7210    Male  African-American      True             F           None
# 7211    Male             Other     False             F           None
# 7212  Female  African-American     False             M         1 to 5
# 7213  Female          Hispanic      True             F         1 to 5
#
# [7214 rows x 5 columns]

# %% [markdown]
# Define subgroup for which to simulate altered probabilities and outcomes.

# %%
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment
subgroup = {'race':['African-American'], 'sex':['Male'], 'under_25':[False]}
compas_sim_df['in_subgroup'] = compas_sim_df[list(subgroup.keys())].isin(subgroup).all(axis=1)

# %% [markdown]
# ### Example of one Iteration for Base Case of the Simulation

# %% [markdown]
# Define mean for altered group and remaining population.

# %%
subgroup_mu = 0.51
non_subgroup_mu = 0.49
k = 1

# %%
compas_sim_df['proba'] = compas_sim_df['in_subgroup'].apply(lambda x : generate_proba(x, subgroup_mu, non_subgroup_mu, k))
compas_sim_df['outcomes'] = compas_sim_df['proba'].apply(lambda x : generate_outcomes(x))
compas_sim_df
# Out:
#          sex              race  under_25 charge_degree prior_offenses  \
# 0       Male             Other     False             F           None
# 1       Male  African-American     False             F           None
# 2       Male  African-American      True             F         1 to 5
# 3       Male  African-American      True             F         1 to 5
# 4       Male             Other     False             F         1 to 5
# ...      ...               ...       ...           ...            ...
# 7209    Male  African-American      True             F           None
# 7210    Male  African-American      True             F           None
# 7211    Male             Other     False             F           None
# 7212  Female  African-American     False             M         1 to 5
# 7213  Female          Hispanic      True             F         1 to 5
#
#       in_subgroup     proba  outcomes
# 0           False  0.483062         1
# 1            True  0.507191         0
# 2           False  0.484595         0
# 3           False  0.496930         0
# 4           False  0.495524         0
# ...           ...       ...       ...
# 7209        False  0.493436         0
# 7210        False  0.486162         0
# 7211        False  0.481772         1
# 7212        False  0.496011         0
# 7213        False  0.481458         0
#
# [7214 rows x 8 columns]

# %% [markdown]
# Generate variant metrics for only "truly negative-outcome" people (those who did NOT reoffend). Additionally, generate metrics required for IJDI scan (i.e. $\hat{p}$ calculation).

# %%
# specify probability and outcomes columns
PROBA_COL = 'proba'
OUTCOMES_COL = 'outcomes'
FEATURES = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
THRESHOLD = 0.5
LAMBDA_PARAM = 49
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# %%
# metrics_df = generate_metrics(negatives_df, PROBA_COL, OUTCOMES_COL, THRESHOLD)

# print("Number of people in subgroup:", len(metrics_df[metrics_df['in_subgroup'] == True]))
# print("Number of people not in subgroup:", len(metrics_df[metrics_df['in_subgroup'] == False]))
# print("Total population:", len(metrics_df))

# # display preview of treatments, probabilities, and outcomes
# metrics_df.head(10)

# %%
# filter for only negative outcomes
negatives_df = compas_sim_df.loc[compas_sim_df[OUTCOMES_COL] == 0]

# scan with positive direction
current_subset, current_score = run_ijdi_scan(negatives_df, FEATURES, PROBA_COL, PROBA_COL, OUTCOMES_COL,
                                              THRESHOLD, LAMBDA_PARAM)
# summarize_scan(negatives_df, FEATURES, PROBA_COL, OUTCOMES_COL, current_subset, include='all')\
current_subset, current_score
# Out:
# Subset found on iteration 1 of 10 with score 182.990026548304 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Best score is now 182.990026548304
# Subset found on iteration 2 of 10 with score 182.990026548304 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 3 of 10 with score 182.990026548304 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 4 of 10 with score 182.990026548304 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 5 of 10 with score 182.990026548304 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 6 of 10 with score 182.990026548304 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 7 of 10 with score 182.990026548304 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 8 of 10 with score 182.990026548304 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 9 of 10 with score 182.990026548304 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Subset found on iteration 10 of 10 with score 182.990026548304 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 182.990026548304 does not beat best score of 182.990026548304
# Required time =  16.18166494369507 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Score: 182.990026548304
# First Iteration
# Average p_delta: 0.013552779871865159
# Average p_censor: -0.11404660194879107
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.8823879095470601
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  11.568322896957397 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# ({}, 0.0)

# %% [markdown]
# ### Simulations for Negatives

# %% [markdown]
# Set mean values as well as ranges of standard deviation and lambda to iterate over for each simulation. Also define threshold and number of iterations to run for each set of parameters.

# %%
subgroup_mu = 0.51
non_subgroup_mu = 0.49
k_vals = [0, 1, 3, 10]
lambda_vals = [0, 4, 8, 12, 16, 20, 42, 46, 50, 54, 80]
n_iters = 1

# specify parameters for generating metrics and IJDI scan
proba_col = 'proba'
outcomes_col = 'outcomes'
features = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
threshold = 0.5
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(100)

# %%
sim_data = []

for k in k_vals:

    print("Parameter k =", k)

    for i in range(n_iters): # run n iterations for each k value

        print("Simulation", i+1, "of", n_iters)

        # generate probabilities from normal distribution (with edge boundary of 0 and 1) and outcomes from bernoulli random variable
        compas_sim_df[proba_col] = compas_sim_df['in_subgroup'].apply(lambda x : generate_proba(x, subgroup_mu, non_subgroup_mu, k))
        compas_sim_df[outcomes_col] = compas_sim_df[proba_col].apply(lambda x : generate_outcomes(x))

        # filter for only negative outcomes
        negatives_df = compas_sim_df.loc[compas_sim_df[outcomes_col] == 0]

        for lambda_param in lambda_vals: # run IJDI scan for various lambda values

            print("Lambda =", lambda_param)

            # Run IJDI Scan. Make sure to pass in copy because data may be modified by the function!
            current_subset, current_score = run_ijdi_scan(negatives_df.copy(deep=True), features, proba_col, proba_col, outcomes_col,
                                                          threshold, lambda_param, verbose=True)

            # save iou and score
            if current_subset:
                in_subgroup = negatives_df[list(subgroup.keys())].isin(subgroup).all(axis=1)
                in_current_subset = negatives_df[list(current_subset.keys())].isin(current_subset).all(axis=1)
                iou = (in_subgroup & in_current_subset).sum() / (in_subgroup | in_current_subset).sum()
            else:
                iou = 0.0

            print("Detected subset intersection over union with expected subset:", iou)
            print("Detected subset score:", current_score)

            # append data
            sim_row = [k, lambda_param, iou, current_score]
            sim_data.append(sim_row)

            print(sim_row)
            print("\n----------------------------------------------------\n")
# Out:
# Parameter k = 0
# Simulation 1 of 1
# Lambda = 0
# Subset found on iteration 1 of 10 with score 1307.008241398987 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Best score is now 1307.008241398987
# Subset found on iteration 2 of 10 with score 1307.008241398987 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 3 of 10 with score 1307.008241398987 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 4 of 10 with score 1307.008241398987 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 5 of 10 with score 1307.008241398987 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 6 of 10 with score 1307.008241398987 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 7 of 10 with score 1307.008241398987 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 8 of 10 with score 1307.008241398987 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 9 of 10 with score 1307.008241398987 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Subset found on iteration 10 of 10 with score 1307.008241398987 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 1307.008241398987 does not beat best score of 1307.008241398987
# Required time =  22.47612190246582 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Score: 1307.008241398987
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw     p_hat
# 13     0.319576  0.319576
# 17     0.319576  0.319576
# 20     0.319576  0.319576
# 29     0.319576  0.319576
# 32     0.319576  0.319576
# ...         ...       ...
# 7195   0.319576  0.319576
# 7196   0.319576  0.319576
# 7197   0.319576  0.319576
# 7204   0.319576  0.319576
# 7207   0.319576  0.319576
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 1307.008241398987
# [0, 0, 1.0, 1307.008241398987]
#
# ----------------------------------------------------
#
# Lambda = 4
# Subset found on iteration 1 of 10 with score 1126.7577268634316 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Best score is now 1126.7577268634316
# Subset found on iteration 2 of 10 with score 1126.7577268634316 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 3 of 10 with score 1126.7577268634316 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 4 of 10 with score 1126.7577268634316 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 5 of 10 with score 1126.7577268634316 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 6 of 10 with score 1126.7577268634316 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 7 of 10 with score 1126.7577268634316 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 8 of 10 with score 1126.7577268634316 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 9 of 10 with score 1126.7577268634316 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Subset found on iteration 10 of 10 with score 1126.7577268634316 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 1126.7577268634316 does not beat best score of 1126.7577268634316
# Required time =  21.3095760345459 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Score: 1126.7577268634316
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw    p_hat
# 13      0.37401  0.37401
# 17      0.37401  0.37401
# 20      0.37401  0.37401
# 29      0.37401  0.37401
# 32      0.37401  0.37401
# ...         ...      ...
# 7195    0.37401  0.37401
# 7196    0.37401  0.37401
# 7197    0.37401  0.37401
# 7204    0.37401  0.37401
# 7207    0.37401  0.37401
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 1126.7577268634316
# [0, 4, 1.0, 1126.7577268634316]
#
# ----------------------------------------------------
#
# Lambda = 8
# Subset found on iteration 1 of 10 with score 971.0427511220089 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Best score is now 971.0427511220089
# Subset found on iteration 2 of 10 with score 971.0427511220089 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 3 of 10 with score 971.0427511220089 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 4 of 10 with score 971.0427511220089 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 5 of 10 with score 971.0427511220089 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 6 of 10 with score 971.0427511220089 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 7 of 10 with score 971.0427511220089 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 8 of 10 with score 971.0427511220089 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 9 of 10 with score 971.0427511220089 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Subset found on iteration 10 of 10 with score 971.0427511220089 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 971.0427511220089 does not beat best score of 971.0427511220089
# Required time =  20.932138681411743 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Score: 971.0427511220089
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw     p_hat
# 13     0.428444  0.428444
# 17     0.428444  0.428444
# 20     0.428444  0.428444
# 29     0.428444  0.428444
# 32     0.428444  0.428444
# ...         ...       ...
# 7195   0.428444  0.428444
# 7196   0.428444  0.428444
# 7197   0.428444  0.428444
# 7204   0.428444  0.428444
# 7207   0.428444  0.428444
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 971.0427511220089
# [0, 8, 1.0, 971.0427511220089]
#
# ----------------------------------------------------
#
# Lambda = 12
# Subset found on iteration 1 of 10 with score 833.9770759622272 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Best score is now 833.9770759622272
# Subset found on iteration 2 of 10 with score 833.9770759622272 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 3 of 10 with score 833.9770759622272 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 4 of 10 with score 833.9770759622272 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 5 of 10 with score 833.9770759622272 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 6 of 10 with score 833.9770759622272 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 7 of 10 with score 833.9770759622272 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 8 of 10 with score 833.9770759622272 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 9 of 10 with score 833.9770759622272 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Subset found on iteration 10 of 10 with score 833.9770759622272 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 833.9770759622272 does not beat best score of 833.9770759622272
# Required time =  20.86997127532959 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Score: 833.9770759622272
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw     p_hat
# 13     0.482878  0.482878
# 17     0.482878  0.482878
# 20     0.482878  0.482878
# 29     0.482878  0.482878
# 32     0.482878  0.482878
# ...         ...       ...
# 7195   0.482878  0.482878
# 7196   0.482878  0.482878
# 7197   0.482878  0.482878
# 7204   0.482878  0.482878
# 7207   0.482878  0.482878
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 833.9770759622272
# [0, 12, 1.0, 833.9770759622272]
#
# ----------------------------------------------------
#
# Lambda = 16
# Subset found on iteration 1 of 10 with score 711.5676023633143 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Best score is now 711.5676023633143
# Subset found on iteration 2 of 10 with score 711.5676023633143 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 3 of 10 with score 711.5676023633143 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 4 of 10 with score 711.5676023633143 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 5 of 10 with score 711.5676023633143 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 6 of 10 with score 711.5676023633143 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 7 of 10 with score 711.5676023633143 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 8 of 10 with score 711.5676023633143 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 9 of 10 with score 711.5676023633143 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Subset found on iteration 10 of 10 with score 711.5676023633143 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 711.5676023633143 does not beat best score of 711.5676023633143
# Required time =  22.418663501739502 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Score: 711.5676023633143
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw     p_hat
# 13     0.537312  0.537312
# 17     0.537312  0.537312
# 20     0.537312  0.537312
# 29     0.537312  0.537312
# 32     0.537312  0.537312
# ...         ...       ...
# 7195   0.537312  0.537312
# 7196   0.537312  0.537312
# 7197   0.537312  0.537312
# 7204   0.537312  0.537312
# 7207   0.537312  0.537312
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 711.5676023633143
# [0, 16, 1.0, 711.5676023633143]
#
# ----------------------------------------------------
#
# Lambda = 20
# Subset found on iteration 1 of 10 with score 600.9805812574534 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Best score is now 600.9805812574534
# Subset found on iteration 2 of 10 with score 600.9805812574534 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 3 of 10 with score 600.9805812574534 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 4 of 10 with score 600.9805812574534 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 5 of 10 with score 600.9805812574534 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 6 of 10 with score 600.9805812574534 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 7 of 10 with score 600.9805812574534 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 8 of 10 with score 600.9805812574534 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 9 of 10 with score 600.9805812574534 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Subset found on iteration 10 of 10 with score 600.9805812574534 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 600.9805812574534 does not beat best score of 600.9805812574534
# Required time =  21.92770028114319 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Score: 600.9805812574534
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw     p_hat
# 13     0.591746  0.591746
# 17     0.591746  0.591746
# 20     0.591746  0.591746
# 29     0.591746  0.591746
# 32     0.591746  0.591746
# ...         ...       ...
# 7195   0.591746  0.591746
# 7196   0.591746  0.591746
# 7197   0.591746  0.591746
# 7204   0.591746  0.591746
# 7207   0.591746  0.591746
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 600.9805812574534
# [0, 20, 1.0, 600.9805812574534]
#
# ----------------------------------------------------
#
# Lambda = 42
# Subset found on iteration 1 of 10 with score 131.7906982402048 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Best score is now 131.7906982402048
# Subset found on iteration 2 of 10 with score 131.7906982402048 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 3 of 10 with score 131.7906982402048 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 4 of 10 with score 131.7906982402048 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 5 of 10 with score 131.7906982402048 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 6 of 10 with score 131.7906982402048 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 7 of 10 with score 131.7906982402048 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 8 of 10 with score 131.7906982402048 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 9 of 10 with score 131.7906982402048 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Subset found on iteration 10 of 10 with score 131.7906982402048 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 131.7906982402048 does not beat best score of 131.7906982402048
# Required time =  21.224622011184692 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Score: 131.7906982402048
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw     p_hat
# 13     0.891132  0.891132
# 17     0.891132  0.891132
# 20     0.891132  0.891132
# 29     0.891132  0.891132
# 32     0.891132  0.891132
# ...         ...       ...
# 7195   0.891132  0.891132
# 7196   0.891132  0.891132
# 7197   0.891132  0.891132
# 7204   0.891132  0.891132
# 7207   0.891132  0.891132
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 131.7906982402048
# [0, 42, 1.0, 131.7906982402048]
#
# ----------------------------------------------------
#
# Lambda = 46
# Subset found on iteration 1 of 10 with score 63.84326549950238 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Best score is now 63.84326549950238
# Subset found on iteration 2 of 10 with score 63.84326549950238 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 3 of 10 with score 63.84326549950238 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 4 of 10 with score 63.84326549950238 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 5 of 10 with score 63.84326549950238 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 6 of 10 with score 63.84326549950238 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 7 of 10 with score 63.84326549950238 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 8 of 10 with score 63.84326549950238 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 9 of 10 with score 63.84326549950238 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Subset found on iteration 10 of 10 with score 63.84326549950238 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 63.84326549950238 does not beat best score of 63.84326549950238
# Required time =  20.409987688064575 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Score: 63.84326549950238
# First Iteration
# Average p_delta: 0.013608477412155564
# Average p_censor: 0.0
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 17     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 20     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 29     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 32     0.51   0.51  0.496392   0.496392  0.013608              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7195   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7196   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7197   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7204   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
#
#       p_hat_raw     p_hat
# 13     0.945566  0.945566
# 17     0.945566  0.945566
# 20     0.945566  0.945566
# 29     0.945566  0.945566
# 32     0.945566  0.945566
# ...         ...       ...
# 7195   0.945566  0.945566
# 7196   0.945566  0.945566
# 7197   0.945566  0.945566
# 7204   0.945566  0.945566
# 7207   0.945566  0.945566
#
# [1146 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 63.84326549950238
# [0, 46, 1.0, 63.84326549950238]
#
# ----------------------------------------------------
#
# Lambda = 50
# Subset found on iteration 1 of 10 with score 1.7462298274040222e-10 :
# {}
# Best score is now 1.7462298274040222e-10
# Subset found on iteration 2 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 3 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 4 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 5 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 6 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 7 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 8 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 9 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Subset found on iteration 10 of 10 with score 1.7462298274040222e-10 :
# {}
# Current score of 1.7462298274040222e-10 does not beat best score of 1.7462298274040222e-10
# Required time =  11.963363647460938 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 1.7462298274040222e-10
# First Iteration
# Average p_delta: -3.0327416849750824e-15
# Average p_censor: 1.0337953459137883e-13
#       proba  p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 2      0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# 3      0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# 4      0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# 8      0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# 11     0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# ...     ...    ...       ...        ...       ...                   ...
# 7206   0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# 7207   0.51   0.51  0.496392   0.496392  0.013608              0.319576
# 7208   0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# 7210   0.49   0.49  0.496392   0.496392 -0.006392              0.319576
# 7211   0.49   0.49  0.496392   0.496392 -0.006392              0.319576
#
#          p_hat_raw  p_hat
# 2    -1.519340e-13    0.0
# 3    -1.519340e-13    0.0
# 4    -1.519340e-13    0.0
# 8    -1.519340e-13    0.0
# 11   -1.519340e-13    0.0
# ...            ...    ...
# 7206 -1.519340e-13    0.0
# 7207  1.000000e+00    1.0
# 7208 -1.519340e-13    0.0
# 7210 -1.519340e-13    0.0
# 7211 -1.519340e-13    0.0
#
# [3586 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 1.7462298274040222e-10
# [0, 50, 0.0, 1.7462298274040222e-10]
#
# ----------------------------------------------------
#
# Lambda = 54
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  13.18248987197876 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [0, 54, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 80
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  12.827081441879272 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [0, 80, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Parameter k = 1
# Simulation 1 of 1
# Lambda = 0
# Subset found on iteration 1 of 10 with score 1322.8688769544417 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Best score is now 1322.8688769544417
# Subset found on iteration 2 of 10 with score 1322.8688769544417 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 3 of 10 with score 1322.8688769544417 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 4 of 10 with score 1322.8688769544417 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 5 of 10 with score 1322.8688769544417 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 6 of 10 with score 1322.8688769544417 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 7 of 10 with score 1322.8688769544417 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 8 of 10 with score 1322.8688769544417 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 9 of 10 with score 1322.8688769544417 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Subset found on iteration 10 of 10 with score 1322.8688769544417 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 1322.8688769544417 does not beat best score of 1322.8688769544417
# Required time =  24.38616633415222 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Score: 1322.8688769544417
# First Iteration
# Average p_delta: 0.014057559237768084
# Average p_censor: 0.0
#          proba     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 15    0.516797  0.516797  0.495984   0.495984  0.020814              0.300655
# 32    0.516072  0.516072  0.495984   0.495984  0.020089              0.300655
# 41    0.518857  0.518857  0.495984   0.495984  0.022874              0.300655
# 57    0.516108  0.516108  0.495984   0.495984  0.020124              0.300655
# 61    0.503639  0.503639  0.495984   0.495984  0.007656              0.300655
# ...        ...       ...       ...        ...       ...                   ...
# 7197  0.513731  0.513731  0.495984   0.495984  0.017748              0.300655
# 7198  0.515285  0.515285  0.495984   0.495984  0.019301              0.300655
# 7201  0.519235  0.519235  0.495984   0.495984  0.023252              0.300655
# 7204  0.516565  0.516565  0.495984   0.495984  0.020581              0.300655
# 7207  0.501358  0.501358  0.495984   0.495984  0.005374              0.300655
#
#       p_hat_raw     p_hat
# 15     0.300655  0.300655
# 32     0.300655  0.300655
# 41     0.300655  0.300655
# 57     0.300655  0.300655
# 61     0.300655  0.300655
# ...         ...       ...
# 7197   0.300655  0.300655
# 7198   0.300655  0.300655
# 7201   0.300655  0.300655
# 7204   0.300655  0.300655
# 7207   0.300655  0.300655
#
# [1101 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 1322.8688769544417
# [1, 0, 1.0, 1322.8688769544417]
#
# ----------------------------------------------------
#
# Lambda = 4
# Subset found on iteration 1 of 10 with score 1136.4802837720683 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Best score is now 1136.4802837720683
# Subset found on iteration 2 of 10 with score 1136.4802837720683 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 3 of 10 with score 1136.4802837720683 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 4 of 10 with score 1136.4802837720683 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 5 of 10 with score 1136.4802837720683 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 6 of 10 with score 1136.4802837720683 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 7 of 10 with score 1136.4802837720683 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 8 of 10 with score 1136.4802837720683 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 9 of 10 with score 1136.4802837720683 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Subset found on iteration 10 of 10 with score 1136.4802837720683 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 1136.4802837720683 does not beat best score of 1136.4802837720683
# Required time =  22.71933650970459 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Score: 1136.4802837720683
# First Iteration
# Average p_delta: 0.014057559237768084
# Average p_censor: 0.0
#          proba     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 15    0.516797  0.516797  0.495984   0.495984  0.020814              0.300655
# 32    0.516072  0.516072  0.495984   0.495984  0.020089              0.300655
# 41    0.518857  0.518857  0.495984   0.495984  0.022874              0.300655
# 57    0.516108  0.516108  0.495984   0.495984  0.020124              0.300655
# 61    0.503639  0.503639  0.495984   0.495984  0.007656              0.300655
# ...        ...       ...       ...        ...       ...                   ...
# 7197  0.513731  0.513731  0.495984   0.495984  0.017748              0.300655
# 7198  0.515285  0.515285  0.495984   0.495984  0.019301              0.300655
# 7201  0.519235  0.519235  0.495984   0.495984  0.023252              0.300655
# 7204  0.516565  0.516565  0.495984   0.495984  0.020581              0.300655
# 7207  0.501358  0.501358  0.495984   0.495984  0.005374              0.300655
#
#       p_hat_raw     p_hat
# 15     0.383910  0.383910
# 32     0.381009  0.381009
# 41     0.392150  0.392150
# 57     0.381152  0.381152
# 61     0.331279  0.331279
# ...         ...       ...
# 7197   0.371646  0.371646
# 7198   0.377861  0.377861
# 7201   0.393663  0.393663
# 7204   0.382979  0.382979
# 7207   0.322153  0.322153
#
# [1101 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 1.0
# Detected subset score: 1136.4802837720683
# [1, 4, 1.0, 1136.4802837720683]
#
# ----------------------------------------------------
#
# Lambda = 8
# Subset found on iteration 1 of 10 with score 980.1615595606975 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Best score is now 980.1615595606975
# Subset found on iteration 2 of 10 with score 980.1615595606975 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 3 of 10 with score 980.1615595606975 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 4 of 10 with score 980.1615595606975 :
# {'sex': ['Male'], 'under_25': [False], 'race': ['African-American']}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 5 of 10 with score 980.1615595606975 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 6 of 10 with score 980.1615595606975 :
# {'sex': ['Male'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 7 of 10 with score 980.1615595606975 :
# {'race': ['African-American'], 'under_25': [False], 'sex': ['Male']}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 8 of 10 with score 980.1615595606975 :
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 9 of 10 with score 980.1615595606975 :
# {'under_25': [False], 'race': ['African-American'], 'sex': ['Male']}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Subset found on iteration 10 of 10 with score 980.1615595606975 :
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American']}
# Current score of 980.1615595606975 does not beat best score of 980.1615595606975
# Required time =  23.271502256393433 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'sex': ['Male'], 'under_25': [False]}
# Score: 980.1615595606975
# First Iteration
# Average p_delta: 0.014057559237768084
# Average p_censor: 0.0
#          proba     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 15    0.516797  0.516797  0.495984   0.495984  0.020814              0.300655
# 32    0.516072  0.516072  0.495984   0.495984  0.020089              0.300655
# 41    0.518857  0.518857  0.495984   0.495984  0.022874              0.300655
# 57    0.516108  0.516108  0.495984   0.495984  0.020124              0.300655
# 61    0.503639  0.503639  0.495984   0.495984  0.007656              0.300655
# ...
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.5049920655707723
# [10, 16, 0.0, 0.5049920655707723]
#
# ----------------------------------------------------
#
# Lambda = 20
# Subset found on iteration 1 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Best score is now 0.18944193072012325
# Subset found on iteration 2 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.18944193072012325
# Subset found on iteration 3 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.18944193072012325
# Subset found on iteration 4 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.18944193072012325
# Subset found on iteration 5 of 10 with score 0.3264127406517161 :
# {'race': ['Asian', 'Native American'], 'under_25': [False]}
# Best score is now 0.3264127406517161
# Subset found on iteration 6 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 7 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 8 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 9 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 10 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Required time =  17.06068706512451 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Native American'], 'under_25': [False]}
# Score: 0.3264127406517161
# First Iteration
# Average p_delta: -0.016738817072392304
# Average p_censor: 0.3891620002867171
#          proba     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 483   0.518087  0.518087  0.488184   0.488184  0.029903              0.418745
# 1294  0.438770  0.438770  0.488184   0.488184 -0.049414              0.418745
# 1592  0.400456  0.400456  0.488184   0.488184 -0.087728              0.418745
# 1864  0.393429  0.393429  0.488184   0.488184 -0.094755              0.418745
# 1866  0.550046  0.550046  0.488184   0.488184  0.061862              0.418745
# 2040  0.444581  0.444581  0.488184   0.488184 -0.043603              0.418745
# 3007  0.560231  0.560231  0.488184   0.488184  0.072047              0.418745
# 3339  0.504681  0.504681  0.488184   0.488184  0.016497              0.418745
# 3766  0.409513  0.409513  0.488184   0.488184 -0.078671              0.418745
# 4255  0.527125  0.527125  0.488184   0.488184  0.038940              0.418745
# 4611  0.397152  0.397152  0.488184   0.488184 -0.091032              0.418745
# 4848  0.502943  0.502943  0.488184   0.488184  0.014759              0.418745
# 5356  0.529452  0.529452  0.488184   0.488184  0.041268              0.418745
# 5384  0.534728  0.534728  0.488184   0.488184  0.046544              0.418745
# 5416  0.442441  0.442441  0.488184   0.488184 -0.045743              0.418745
# 5497  0.522072  0.522072  0.488184   0.488184  0.033888              0.418745
# 5696  0.416577  0.416577  0.488184   0.488184 -0.071607              0.418745
# 5770  0.545889  0.545889  0.488184   0.488184  0.057704              0.418745
# 6143  0.390943  0.390943  0.488184   0.488184 -0.097241              0.418745
# 7123  0.399790  0.399790  0.488184   0.488184 -0.088395              0.418745
#
#       p_hat_raw     p_hat
# 483    1.016801  1.000000
# 1294  -0.569536  0.000000
# 1592  -1.335813  0.000000
# 1864  -1.476350  0.000000
# 1866   1.655983  1.000000
# 2040  -0.453322  0.000000
# 3007   1.859677  1.000000
# 3339   0.748681  0.748681
# 3766  -1.154677  0.000000
# 4255   1.197553  1.000000
# 4611  -1.401895  0.000000
# 4848   0.713929  0.713929
# 5356   1.244107  1.000000
# 5384   1.349624  1.000000
# 5416  -0.496112  0.000000
# 5497   1.096505  1.000000
# 5696  -1.013391  0.000000
# 5770   1.572833  1.000000
# 6143  -1.526081  0.000000
# 7123  -1.349147  0.000000
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.4493610370042516
# p(S): 0.4882763865921228 p(~S): 0.4882763865921228
# Subset found on iteration 1 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Best score is now 0.18944193072012325
# Subset found on iteration 2 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.18944193072012325
# Subset found on iteration 3 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.18944193072012325
# Subset found on iteration 4 of 10 with score 0.3264127406517161 :
# {'race': ['Asian', 'Native American'], 'under_25': [False]}
# Best score is now 0.3264127406517161
# Subset found on iteration 5 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 6 of 10 with score 0.3264127406517161 :
# {'race': ['Asian', 'Native American'], 'under_25': [False]}
# Current score of 0.3264127406517161 does not beat best score of 0.3264127406517161
# Subset found on iteration 7 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 8 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 9 of 10 with score 0.18944193072012325 :
# {'race': ['Native American']}
# Current score of 0.18944193072012325 does not beat best score of 0.3264127406517161
# Subset found on iteration 10 of 10 with score 0.3264127406517161 :
# {'race': ['Asian', 'Native American'], 'under_25': [False]}
# Current score of 0.3264127406517161 does not beat best score of 0.3264127406517161
# Required time =  13.225733995437622 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Native American'], 'under_25': [False]}
# Score: 0.3264127406517161
# Average p_delta: 9.225030075726837e-05
# Average p_censor: 0.052540652823725734
#          proba     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 483   0.518087  0.518087  0.488276   0.488184  0.029903              0.418745
# 1294  0.461016  0.438770  0.488276   0.488184 -0.027168              0.418745
# 1592  0.439919  0.400456  0.488276   0.488184 -0.048265              0.418745
# 1864  0.436050  0.393429  0.488276   0.488184 -0.052134              0.418745
# 1866  0.550046  0.550046  0.488276   0.488184  0.061862              0.418745
# 2040  0.464216  0.444581  0.488276   0.488184 -0.023968              0.418745
# 3007  0.560231  0.560231  0.488276   0.488184  0.072047              0.418745
# 3339  0.504681  0.504681  0.488276   0.488184  0.016497              0.418745
# 3766  0.444906  0.409513  0.488276   0.488184 -0.043278              0.418745
# 4255  0.527125  0.527125  0.488276   0.488184  0.038940              0.418745
# 4611  0.438100  0.397152  0.488276   0.488184 -0.050084              0.418745
# 4848  0.502943  0.502943  0.488276   0.488184  0.014759              0.418745
# 5356  0.529452  0.529452  0.488276   0.488184  0.041268              0.418745
# 5384  0.534728  0.534728  0.488276   0.488184  0.046544              0.418745
# 5416  0.463038  0.442441  0.488276   0.488184 -0.025146              0.418745
# 5497  0.522072  0.522072  0.488276   0.488184  0.033888              0.418745
# 5696  0.448796  0.416577  0.488276   0.488184 -0.039388              0.418745
# 5770  0.545889  0.545889  0.488276   0.488184  0.057704              0.418745
# 6143  0.434681  0.390943  0.488276   0.488184 -0.053503              0.418745
# 7123  0.439552  0.399790  0.488276   0.488184 -0.048632              0.418745
#
#       p_hat_raw     p_hat
# 483    1.016801  1.000000
# 1294  -0.124612  0.000000
# 1592  -0.546554  0.000000
# 1864  -0.623939  0.000000
# 1866   1.655983  1.000000
# 2040  -0.060620  0.000000
# 3007   1.859677  1.000000
# 3339   0.748681  0.748681
# 3766  -0.446813  0.000000
# 4255   1.197553  1.000000
# 4611  -0.582941  0.000000
# 4848   0.713929  0.713929
# 5356   1.244107  1.000000
# 5384   1.349624  1.000000
# 5416  -0.084182  0.000000
# 5497   1.096505  1.000000
# 5696  -0.369016  0.000000
# 5770   1.572833  1.000000
# 6143  -0.651323  0.000000
# 7123  -0.553896  0.000000
# Subset does not violate p_delta or p_censor conditions!
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.3264127406517161
# [10, 20, 0.0, 0.3264127406517161]
#
# ----------------------------------------------------
#
# Lambda = 42
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  17.798858165740967 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 42, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 46
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  16.56043291091919 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 46, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 50
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  14.976828813552856 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 50, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 54
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  15.414225816726685 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 54, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Lambda = 80
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  15.46817135810852 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected subset intersection over union with expected subset: 0.0
# Detected subset score: 0.0
# [10, 80, 0.0, 0.0]
#
# ----------------------------------------------------

# %%
columns = ['k', 'lambda', 'iou', 'score']
sim_result_df = pd.DataFrame(sim_data, columns=columns)
sim_result_df
# Out:
#      k  lambda       iou         score
# 0    0       0  1.000000  1.307008e+03
# 1    0       4  1.000000  1.126758e+03
# 2    0       8  1.000000  9.710428e+02
# 3    0      12  1.000000  8.339771e+02
# 4    0      16  1.000000  7.115676e+02
# 5    0      20  1.000000  6.009806e+02
# 6    0      42  1.000000  1.317907e+02
# 7    0      46  1.000000  6.384327e+01
# 8    0      50  0.000000  1.746230e-10
# 9    0      54  0.000000  0.000000e+00
# 10   0      80  0.000000  0.000000e+00
# 11   1       0  1.000000  1.322869e+03
# 12   1       4  1.000000  1.136480e+03
# 13   1       8  1.000000  9.801616e+02
# 14   1      12  1.000000  8.450771e+02
# 15   1      16  1.000000  7.258918e+02
# 16   1      20  1.000000  6.191083e+02
# 17   1      42  1.000000  1.362881e+02
# 18   1      46  1.000000  6.170959e+01
# 19   1      50  0.000000  0.000000e+00
# 20   1      54  0.000000  0.000000e+00
# 21   1      80  0.000000  0.000000e+00
# 22   3       0  1.000000  1.232791e+02
# 23   3       4  1.000000  7.408375e+01
# 24   3       8  1.000000  3.850808e+01
# 25   3      12  1.000000  1.385142e+01
# 26   3      16  0.433092  2.424087e+00
# 27   3      20  0.000000  3.883659e-01
# 28   3      42  0.000000  2.482913e-01
# 29   3      46  0.000000  0.000000e+00
# 30   3      50  0.000000  8.393214e-02
# 31   3      54  0.000000  0.000000e+00
# 32   3      80  0.000000  0.000000e+00
# 33  10       0  0.987299  8.883641e+00
# 34  10       4  0.126851  2.770313e+00
# 35  10       8  0.000000  1.949860e+00
# 36  10      12  0.000000  5.620653e-01
# 37  10      16  0.000000  5.049921e-01
# 38  10      20  0.000000  3.264127e-01
# 39  10      42  0.000000  0.000000e+00
# 40  10      46  0.000000  0.000000e+00
# 41  10      50  0.000000  0.000000e+00
# 42  10      54  0.000000  0.000000e+00
# 43  10      80  0.000000  0.000000e+00

# %%
# Write recipe outputs
sim_result_df.to_csv(home_dir + "datasets/compas_sim_1_neg.csv")
