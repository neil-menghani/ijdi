# %% [markdown]
# ### Import Libraries

# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
from subset import *
import pandas as pd, numpy as np
from sklearn.linear_model import LogisticRegression

os.chdir('../') # cd back to parent dir
home_dir = "compas/" # set home dir for reading and storing data

# Read recipe inputs
compas_prep_df = pd.read_csv(home_dir + "datasets/compas_prep.csv")
compas_prep_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
# [7214 rows x 10 columns]

# %% [markdown]
# ### Prepare Base Dataset for Mitigation

# %% [markdown]
# ### Mitigation Thresholds

# %% [markdown]
# a) 0.45 threshold for everyone (base case)
# b) 0.5 threshold for Black individuals, 0.45 for everyone else (increased threshold for Black defendants)
# c) 0.45 threshold for Black individuals, 0.4 for everyone else (decreased threshold for non-Black defendants)
# d) 0.5 threshold for Black individuals, 0.4 for everyone else (increased threshold for Black defendants and decreased threshold for non-Black defendants)

# %%
threshold_labels = ['a', 'b', 'c', 'd']
threshold_settings = {'a' : (0.45, 0.45),
                      'b' : (0.5, 0.45),
                      'c' : (0.45, 0.4),
                      'd' : (0.5, 0.4)}
for label in threshold_labels:
    setting = threshold_settings[label]
    compas_prep_df['threshold_' + label] = compas_prep_df['race'].apply(lambda x : setting[0] if x == 'African-American'
                                                                                    else setting[1])
compas_prep_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr  \
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
#       threshold_a  threshold_b  threshold_c  threshold_d
# 0            0.45         0.45         0.40          0.4
# 1            0.45         0.50         0.45          0.5
# 2            0.45         0.50         0.45          0.5
# 3            0.45         0.50         0.45          0.5
# 4            0.45         0.45         0.40          0.4
# ...           ...          ...          ...          ...
# 7209         0.45         0.50         0.45          0.5
# 7210         0.45         0.50         0.45          0.5
# 7211         0.45         0.45         0.40          0.4
# 7212         0.45         0.50         0.45          0.5
# 7213         0.45         0.45         0.40          0.4
#
# [7214 rows x 14 columns]

# %%
# specify probability and outcomes columns
PROBA_COL = 'proba_compas'
OUTCOMES_COL = 'outcomes'
FEATURES = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# filter for negative and positive outcomes
negatives_df = compas_prep_df.loc[compas_prep_df[OUTCOMES_COL] == 0]
positives_df = compas_prep_df.loc[compas_prep_df[OUTCOMES_COL] == 1]

# %%
# report FPR and TPR of African-Americans and non African-Americans
for label in threshold_labels:
    negative_metrics_df = generate_metrics(negatives_df, PROBA_COL, OUTCOMES_COL,
                                           'threshold_' + label, constant_threshold=False)
    positive_metrics_df = generate_metrics(positives_df, PROBA_COL, OUTCOMES_COL,
                                           'threshold_' + label, constant_threshold=False)
    negative_metrics_aa_df = negative_metrics_df.loc[negative_metrics_df['race'] == 'African-American']
    negative_metrics_other_df = negative_metrics_df.loc[negative_metrics_df['race'] != 'African-American']
    positive_metrics_aa_df = positive_metrics_df.loc[positive_metrics_df['race'] == 'African-American']
    positive_metrics_other_df = positive_metrics_df.loc[positive_metrics_df['race'] != 'African-American']
    print("FPR of African-Americans", negative_metrics_aa_df['positives'].sum() / len(negative_metrics_aa_df))
    print("FPR of non African-Americans", negative_metrics_other_df['positives'].sum() / len(negative_metrics_other_df))
    print("TPR of African-Americans", positive_metrics_aa_df['positives'].sum() / len(positive_metrics_aa_df))
    print("TPR of non African-Americans", positive_metrics_other_df['positives'].sum() / len(positive_metrics_other_df))
# Out:
# FPR of African-Americans 0.44846796657381616
# FPR of non African-Americans 0.22001845018450183
# TPR of African-Americans 0.7201472908995266
# TPR of non African-Americans 0.49333333333333335
# FPR of African-Americans 0.34317548746518106
# FPR of non African-Americans 0.22001845018450183
# TPR of African-Americans 0.6275644397685429
# TPR of non African-Americans 0.49333333333333335
# FPR of African-Americans 0.44846796657381616
# FPR of non African-Americans 0.3247232472324723
# TPR of African-Americans 0.7201472908995266
# TPR of non African-Americans 0.6096296296296296
# FPR of African-Americans 0.34317548746518106
# FPR of non African-Americans 0.3247232472324723
# TPR of African-Americans 0.6275644397685429
# TPR of non African-Americans 0.6096296296296296

# %% [markdown]
# ### Mitigation Results

# %% [markdown]
# Set lambda vales to test for each threshold case. Only need to score subgroup S in each case, no need to run the full IJDI-Scan.

# %%
lambda_vals = [0, 0.3, 1, 3, 10]
race_subset = {'race': ['African-American']}
n_iters = 1

# specify parameters for generating metrics and IJDI scan
proba_confusion_col = 'proba_compas'
proba_ijdi_col = 'proba_lr'
outcomes_col = 'outcomes'
features = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']

pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(100)

# %%
sim_data = []

for label in threshold_labels:

    setting = threshold_settings[label]
    threshold = 'threshold_' + label
    print("Thresholds: African-Americans {}, All Other Races {}".format(setting[0], setting[1]))

    for i in range(n_iters): # run n iterations for each k value

        print("Iteration", i+1, "of", n_iters)

        # filter for negative and positive outcomes
        negatives_df = compas_prep_df.loc[compas_prep_df[OUTCOMES_COL] == 0]
        positives_df = compas_prep_df.loc[compas_prep_df[OUTCOMES_COL] == 1]

        for lambda_param in lambda_vals: # run IJDI scan for various lambda values

            print("Lambda =", lambda_param)

            # Run Negative and Positive IJDI Scan. Make sure to pass in copy because data may be modified by the function!
            negative_score = score_current_subset_ijdi(negatives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                       threshold, lambda_param, race_subset, constant_threshold=False, verbose=True)

            print("Score for Negative IJDI-Scan:", negative_score)

            positive_score = score_current_subset_ijdi(positives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                       threshold, lambda_param, race_subset, constant_threshold=False, verbose=True)

            print("Score Positive IJDI-Scan:", positive_score)

            # append data
            negative_row = [setting[0], setting[1], lambda_param, negative_score, 'negative']
            positive_row = [setting[0], setting[1], lambda_param, positive_score, 'positive']
            sim_data.append(negative_row)
            sim_data.append(positive_row)

            print(negative_row)
            print(positive_row)

            print("\n----------------------------------------------------\n")
# Out:
# Thresholds: African-Americans 0.45, All Other Races 0.45
# Iteration 1 of 1
# Lambda = 0
# Current Score: 60.66139161495723
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.323492
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.323492
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.323492
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.323492
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.323492
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.323492
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.323492
#
#       p_hat_raw     p_hat
# 3      0.323492  0.323492
# 13     0.323492  0.323492
# 17     0.323492  0.323492
# 40     0.323492  0.323492
# 41     0.323492  0.323492
# ...         ...       ...
# 7204   0.323492  0.323492
# 7208   0.323492  0.323492
# 7209   0.323492  0.323492
# 7210   0.323492  0.323492
# 7212   0.323492  0.323492
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 60.66139161495723
# Current Score: 37.45797131977374
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.625961
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.625961
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.625961
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.625961
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.625961
#
#       p_hat_raw     p_hat
# 1      0.625961  0.625961
# 2      0.625961  0.625961
# 11     0.625961  0.625961
# 15     0.625961  0.625961
# 20     0.625961  0.625961
# ...         ...       ...
# 7190   0.625961  0.625961
# 7195   0.625961  0.625961
# 7200   0.625961  0.625961
# 7201   0.625961  0.625961
# 7207   0.625961  0.625961
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 37.45797131977374
# [0.45, 0.45, 0, 60.66139161495723, 'negative']
# [0.45, 0.45, 0, 37.45797131977374, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Current Score: 44.188756468849554
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.323492
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.323492
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.323492
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.323492
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.323492
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.323492
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.323492
#
#       p_hat_raw     p_hat
# 3      0.404927  0.404927
# 13     0.291267  0.291267
# 17     0.338141  0.338141
# 40     0.384099  0.384099
# 41     0.325764  0.325764
# ...         ...       ...
# 7204   0.325764  0.325764
# 7208   0.356009  0.356009
# 7209   0.356009  0.356009
# 7210   0.356009  0.356009
# 7212   0.304845  0.304845
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 44.188756468849554
# Current Score: 26.598115349728708
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.625961
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.625961
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.625961
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.625961
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.625961
#
#       p_hat_raw     p_hat
# 1      0.558148  0.558148
# 2      0.671809  0.671809
# 11     0.660282  0.660282
# 15     0.684513  0.684513
# 20     0.684513  0.684513
# ...         ...       ...
# 7190   0.660282  0.660282
# 7195   0.673744  0.673744
# 7200   0.588280  0.588280
# 7201   0.684513  0.684513
# 7207   0.548102  0.548102
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 26.598115349728708
# [0.45, 0.45, 0.3, 44.188756468849554, 'negative']
# [0.45, 0.45, 0.3, 26.598115349728708, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 1
# Current Score: 17.38048646861656
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.323492
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.323492
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.323492
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.323492
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.323492
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.323492
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.323492
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.323492
#
#       p_hat_raw     p_hat
# 3      0.594942  0.594942
# 13     0.216074  0.216074
# 17     0.372322  0.372322
# 40     0.525515  0.525515
# 41     0.331066  0.331066
# ...         ...       ...
# 7204   0.331066  0.331066
# 7208   0.431881  0.431881
# 7209   0.431881  0.431881
# 7210   0.431881  0.431881
# 7212   0.261335  0.261335
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 17.38048646861656
# Current Score: 8.649652844922878
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.625961
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.625961
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.625961
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.625961
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.625961
#
#       p_hat_raw     p_hat
# 1      0.399919  0.399919
# 2      0.778786  0.778786
# 11     0.740364  0.740364
# 15     0.821135  0.821135
# 20     0.821135  0.821135
# ...         ...       ...
# 7190   0.740364  0.740364
# 7195   0.785238  0.785238
# 7200   0.500358  0.500358
# 7201   0.821135  0.821135
# 7207   0.366429  0.366429
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 8.649652844922878
# [0.45, 0.45, 1, 17.38048646861656, 'negative']
# [0.45, 0.45, 1, 8.649652844922878, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 3
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: 2.7417908137348603
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: -0.07848883527119738
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.625961
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.625961
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.625961
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.625961
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.625961
#
#       p_hat_raw     p_hat
# 1     -0.052167  0.000000
# 2      1.084436  1.000000
# 11     0.969170  0.969170
# 15     1.211484  1.000000
# 20     1.211484  1.000000
# ...         ...       ...
# 7190   0.969170  0.969170
# 7195   1.103791  1.000000
# 7200   0.249151  0.249151
# 7201   1.211484  1.000000
# 7207  -0.152635  0.000000
#
# [1901 rows x 8 columns]
# Subset violates p_censor condition. Adjusting and Re-scoring...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.2655357416576395
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.45, 0.45, 3, 0, 'negative']
# [0.45, 0.45, 3, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 10
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: 2157.020930374218
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: -0.545590685726682
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.625961
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.625961
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.625961
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.625961
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.625961
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.625961
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.625961
#
#       p_hat_raw  p_hat
# 1     -1.634465    0.0
# 2      2.154209    1.0
# 11     1.769990    1.0
# 15     2.577703    1.0
# 20     2.577703    1.0
# ...         ...    ...
# 7190   1.769990    1.0
# 7195   2.218727    1.0
# 7200  -0.630073    0.0
# 7201   2.577703    1.0
# 7207  -1.969360    0.0
#
# [1901 rows x 8 columns]
# Subset violates p_censor condition. Adjusting and Re-scoring...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.45, 0.45, 10, 0, 'negative']
# [0.45, 0.45, 10, 0, 'positive']
#
# ----------------------------------------------------
#
# Thresholds: African-Americans 0.5, All Other Races 0.45
# Iteration 1 of 1
# Lambda = 0
# Current Score: 19.405741154046716
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.275801
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.275801
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.275801
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.275801
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.275801
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.275801
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.275801
#
#       p_hat_raw     p_hat
# 3      0.275801  0.275801
# 13     0.275801  0.275801
# 17     0.275801  0.275801
# 40     0.275801  0.275801
# 41     0.275801  0.275801
# ...         ...       ...
# 7204   0.275801  0.275801
# 7208   0.275801  0.275801
# 7209   0.275801  0.275801
# 7210   0.275801  0.275801
# 7212   0.275801  0.275801
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 19.405741154046716
# Current Score: 12.122029620292972
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.571824
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.571824
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.571824
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.571824
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.571824
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.571824
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.571824
#
#       p_hat_raw     p_hat
# 1      0.571824  0.571824
# 2      0.571824  0.571824
# 11     0.571824  0.571824
# 15     0.571824  0.571824
# 20     0.571824  0.571824
# ...         ...       ...
# 7190   0.571824  0.571824
# 7195   0.571824  0.571824
# 7200   0.571824  0.571824
# 7201   0.571824  0.571824
# 7207   0.571824  0.571824
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 12.122029620292972
# [0.5, 0.45, 0, 19.405741154046716, 'negative']
# [0.5, 0.45, 0, 12.122029620292972, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Current Score: 10.236598560579546
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.275801
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.275801
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.275801
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.275801
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.275801
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.275801
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.275801
#
#       p_hat_raw     p_hat
# 3      0.357236  0.357236
# 13     0.243576  0.243576
# 17     0.290450  0.290450
# 40     0.336408  0.336408
# 41     0.278073  0.278073
# ...         ...       ...
# 7204   0.278073  0.278073
# 7208   0.308318  0.308318
# 7209   0.308318  0.308318
# 7210   0.308318  0.308318
# 7212   0.257154  0.257154
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 10.236598560579546
# Current Score: 6.31408792326439
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.571824
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.571824
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.571824
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.571824
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.571824
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.571824
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.571824
#
#       p_hat_raw     p_hat
# 1      0.504011  0.504011
# 2      0.617672  0.617672
# 11     0.606145  0.606145
# 15     0.630376  0.630376
# 20     0.630376  0.630376
# ...         ...       ...
# 7190   0.606145  0.606145
# 7195   0.619607  0.619607
# 7200   0.534143  0.534143
# 7201   0.630376  0.630376
# 7207   0.493964  0.493964
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 6.31408792326439
# [0.5, 0.45, 0.3, 10.236598560579546, 'negative']
# [0.5, 0.45, 0.3, 6.31408792326439, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 1
# Current Score: 0.14027915975977265
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.275801
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.275801
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.275801
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.275801
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.275801
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.275801
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.275801
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.275801
#
#       p_hat_raw     p_hat
# 3      0.547250  0.547250
# 13     0.168383  0.168383
# 17     0.324630  0.324630
# 40     0.477824  0.477824
# 41     0.283375  0.283375
# ...         ...       ...
# 7204   0.283375  0.283375
# 7208   0.384190  0.384190
# 7209   0.384190  0.384190
# 7210   0.384190  0.384190
# 7212   0.213644  0.213644
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 0.14027915975977265
# Current Score: -0.04708068196830553
# Score Positive IJDI-Scan: 0
# [0.5, 0.45, 1, 0.14027915975977265, 'negative']
# [0.5, 0.45, 1, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 3
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.5, 0.45, 3, 0, 'negative']
# [0.5, 0.45, 3, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 10
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: 59.532507654266645
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: -0.49513774024587637
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.571824
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.571824
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.571824
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.571824
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.571824
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.571824
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.571824
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.571824
#
#       p_hat_raw  p_hat
# 1     -1.688602    0.0
# 2      2.100072    1.0
# 11     1.715853    1.0
# 15     2.523565    1.0
# 20     2.523565    1.0
# ...         ...    ...
# 7190   1.715853    1.0
# 7195   2.164590    1.0
# 7200  -0.684210    0.0
# 7201   2.523565    1.0
# 7207  -2.023497    0.0
#
# [1901 rows x 8 columns]
# Subset violates p_censor condition. Adjusting and Re-scoring...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.5, 0.45, 10, 0, 'negative']
# [0.5, 0.45, 10, 0, 'positive']
#
# ----------------------------------------------------
#
# Thresholds: African-Americans 0.45, All Other Races 0.4
# Iteration 1 of 1
# Lambda = 0
# Current Score: 17.01141331418159
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.380772
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.380772
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.380772
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.380772
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.380772
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.380772
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.380772
#
#       p_hat_raw     p_hat
# 3      0.380772  0.380772
# 13     0.380772  0.380772
# 17     0.380772  0.380772
# 40     0.380772  0.380772
# 41     0.380772  0.380772
# ...         ...       ...
# 7204   0.380772  0.380772
# 7208   0.380772  0.380772
# 7209   0.380772  0.380772
# 7210   0.380772  0.380772
# 7212   0.380772  0.380772
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 17.01141331418159
# Current Score: 9.260469511947486
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.674254
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.674254
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.674254
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.674254
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.674254
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.674254
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.674254
#
#       p_hat_raw     p_hat
# 1      0.674254  0.674254
# 2      0.674254  0.674254
# 11     0.674254  0.674254
# 15     0.674254  0.674254
# 20     0.674254  0.674254
# ...         ...       ...
# 7190   0.674254  0.674254
# 7195   0.674254  0.674254
# 7200   0.674254  0.674254
# 7201   0.674254  0.674254
# 7207   0.674254  0.674254
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 9.260469511947486
# [0.45, 0.4, 0, 17.01141331418159, 'negative']
# [0.45, 0.4, 0, 9.260469511947486, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Current Score: 9.109869843460354
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.380772
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.380772
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.380772
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.380772
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.380772
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.380772
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.380772
#
#       p_hat_raw     p_hat
# 3      0.462207  0.462207
# 13     0.348547  0.348547
# 17     0.395421  0.395421
# 40     0.441379  0.441379
# 41     0.383044  0.383044
# ...         ...       ...
# 7204   0.383044  0.383044
# 7208   0.413289  0.413289
# 7209   0.413289  0.413289
# 7210   0.413289  0.413289
# 7212   0.362125  0.362125
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 9.109869843460354
# Current Score: 4.070133870849924
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.674254
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.674254
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.674254
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.674254
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.674254
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.674254
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.674254
#
#       p_hat_raw     p_hat
# 1      0.606441  0.606441
# 2      0.720102  0.720102
# 11     0.708575  0.708575
# 15     0.732806  0.732806
# 20     0.732806  0.732806
# ...         ...       ...
# 7190   0.708575  0.708575
# 7195   0.722037  0.722037
# 7200   0.636573  0.636573
# 7201   0.732806  0.732806
# 7207   0.596394  0.596394
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 4.070133870849924
# [0.45, 0.4, 0.3, 9.109869843460354, 'negative']
# [0.45, 0.4, 0.3, 4.070133870849924, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 1
# Current Score: 0.13478307095761863
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.380772
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.380772
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.380772
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.380772
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.380772
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.380772
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.380772
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.380772
#
#       p_hat_raw     p_hat
# 3      0.652221  0.652221
# 13     0.273354  0.273354
# 17     0.429601  0.429601
# 40     0.582795  0.582795
# 41     0.388346  0.388346
# ...         ...       ...
# 7204   0.388346  0.388346
# 7208   0.489161  0.489161
# 7209   0.489161  0.489161
# 7210   0.489161  0.489161
# 7212   0.318615  0.318615
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 0.13478307095761863
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.45, 0.4, 1, 0.13478307095761863, 'negative']
# [0.45, 0.4, 1, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 3
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.45, 0.4, 3, 0, 'negative']
# [0.45, 0.4, 3, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 10
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: 2135.2542054170394
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: -0.5906318182168018
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.674254
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.674254
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.674254
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.674254
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.674254
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.674254
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.674254
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.674254
#
#       p_hat_raw  p_hat
# 1     -1.586172    0.0
# 2      2.202502    1.0
# 11     1.818283    1.0
# 15     2.625995    1.0
# 20     2.625995    1.0
# ...         ...    ...
# 7190   1.818283    1.0
# 7195   2.267020    1.0
# 7200  -0.581780    0.0
# 7201   2.625995    1.0
# 7207  -1.921067    0.0
#
# [1901 rows x 8 columns]
# Subset violates p_censor condition. Adjusting and Re-scoring...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.45, 0.4, 10, 0, 'negative']
# [0.45, 0.4, 10, 0, 'positive']
#
# ----------------------------------------------------
#
# Thresholds: African-Americans 0.5, All Other Races 0.4
# Iteration 1 of 1
# Lambda = 0
# Current Score: 0.30966397535409274
# First Iteration
# Average p_delta: 0.06005602252451366
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.333081
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.333081
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.333081
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.333081
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.333081
# ...        ...       ...       ...        ...       ...                   ...
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.333081
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.333081
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.333081
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.333081
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.333081
#
#       p_hat_raw     p_hat
# 3      0.333081  0.333081
# 13     0.333081  0.333081
# 17     0.333081  0.333081
# 40     0.333081  0.333081
# 41     0.333081  0.333081
# ...         ...       ...
# 7204   0.333081  0.333081
# 7208   0.333081  0.333081
# 7209   0.333081  0.333081
# 7210   0.333081  0.333081
# 7212   0.333081  0.333081
#
# [1795 rows x 8 columns]
# Score for Negative IJDI-Scan: 0.30966397535409274
# Current Score: 0.12437536406372515
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.620117
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.620117
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.620117
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.620117
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.620117
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.620117
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.620117
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.620117
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.620117
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.620117
#
#       p_hat_raw     p_hat
# 1      0.620117  0.620117
# 2      0.620117  0.620117
# 11     0.620117  0.620117
# 15     0.620117  0.620117
# 20     0.620117  0.620117
# ...         ...       ...
# 7190   0.620117  0.620117
# 7195   0.620117  0.620117
# 7200   0.620117  0.620117
# 7201   0.620117  0.620117
# 7207   0.620117  0.620117
#
# [1901 rows x 8 columns]
# Score Positive IJDI-Scan: 0.12437536406372515
# [0.5, 0.4, 0, 0.30966397535409274, 'negative']
# [0.5, 0.4, 0, 0.12437536406372515, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.5, 0.4, 0.3, 0, 'negative']
# [0.5, 0.4, 0.3, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 1
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.5, 0.4, 1, 0, 'negative']
# [0.5, 0.4, 1, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 3
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.5, 0.4, 3, 0, 'negative']
# [0.5, 0.4, 3, 0, 'positive']
#
# ----------------------------------------------------
#
# Lambda = 10
# Current Score: -0.1
# Score for Negative IJDI-Scan: 0
# Current Score: 43.3081452572932
# First Iteration
# Average p_delta: 0.052313628771825264
# Average p_censor: -0.5401398480367875
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.620117
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.620117
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.620117
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.620117
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.620117
# ...        ...       ...       ...        ...       ...                   ...
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.620117
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.620117
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.620117
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.620117
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.620117
#
#       p_hat_raw  p_hat
# 1     -1.640309    0.0
# 2      2.148365    1.0
# 11     1.764146    1.0
# 15     2.571858    1.0
# 20     2.571858    1.0
# ...         ...    ...
# 7190   1.764146    1.0
# 7195   2.212883    1.0
# 7200  -0.635917    0.0
# 7201   2.571858    1.0
# 7207  -1.975204    0.0
#
# [1901 rows x 8 columns]
# Subset violates p_censor condition. Adjusting and Re-scoring...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# Current Score: -0.1
# Score Positive IJDI-Scan: 0
# [0.5, 0.4, 10, 0, 'negative']
# [0.5, 0.4, 10, 0, 'positive']
#
# ----------------------------------------------------

# %%
columns = ['threshold_aa', 'threshold_other', 'lambda', 'score', 'scan_type']
mit_result_df = pd.DataFrame(sim_data, columns=columns)
mit_result_df
# Out:
#     threshold_aa  threshold_other  lambda      score scan_type
# 0           0.45             0.45     0.0  60.661392  negative
# 1           0.45             0.45     0.0  37.457971  positive
# 2           0.45             0.45     0.3  44.188756  negative
# 3           0.45             0.45     0.3  26.598115  positive
# 4           0.45             0.45     1.0  17.380486  negative
# 5           0.45             0.45     1.0   8.649653  positive
# 6           0.45             0.45     3.0   0.000000  negative
# 7           0.45             0.45     3.0   0.000000  positive
# 8           0.45             0.45    10.0   0.000000  negative
# 9           0.45             0.45    10.0   0.000000  positive
# 10          0.50             0.45     0.0  19.405741  negative
# 11          0.50             0.45     0.0  12.122030  positive
# 12          0.50             0.45     0.3  10.236599  negative
# 13          0.50             0.45     0.3   6.314088  positive
# 14          0.50             0.45     1.0   0.140279  negative
# 15          0.50             0.45     1.0   0.000000  positive
# 16          0.50             0.45     3.0   0.000000  negative
# 17          0.50             0.45     3.0   0.000000  positive
# 18          0.50             0.45    10.0   0.000000  negative
# 19          0.50             0.45    10.0   0.000000  positive
# 20          0.45             0.40     0.0  17.011413  negative
# 21          0.45             0.40     0.0   9.260470  positive
# 22          0.45             0.40     0.3   9.109870  negative
# 23          0.45             0.40     0.3   4.070134  positive
# 24          0.45             0.40     1.0   0.134783  negative
# 25          0.45             0.40     1.0   0.000000  positive
# 26          0.45             0.40     3.0   0.000000  negative
# 27          0.45             0.40     3.0   0.000000  positive
# 28          0.45             0.40    10.0   0.000000  negative
# 29          0.45             0.40    10.0   0.000000  positive
# 30          0.50             0.40     0.0   0.309664  negative
# 31          0.50             0.40     0.0   0.124375  positive
# 32          0.50             0.40     0.3   0.000000  negative
# 33          0.50             0.40     0.3   0.000000  positive
# 34          0.50             0.40     1.0   0.000000  negative
# 35          0.50             0.40     1.0   0.000000  positive
# 36          0.50             0.40     3.0   0.000000  negative
# 37          0.50             0.40     3.0   0.000000  positive
# 38          0.50             0.40    10.0   0.000000  negative
# 39          0.50             0.40    10.0   0.000000  positive

# %%
# Write recipe outputs
mit_result_df.to_csv(home_dir + "datasets/compas_mit_1.csv")
