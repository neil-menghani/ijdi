# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
import pandas as pd, numpy as np

os.chdir('../') # cd back to parent dir
home_dir = "compas/" # set home dir for reading and storing data

# Read recipe inputs
compas_mit_df = pd.read_csv(home_dir + "datasets/compas_prep.csv")
compas_mit_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
# [7214 rows x 10 columns]

# %% [markdown]
# Test running negative IJDI-Scan once.

# %%
PROBA_CONFUSION_COL = 'proba_compas'
PROBA_IJDI_COL = 'proba_lr'
OUTCOMES_COL = 'outcomes'
FEATURES = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
THRESHOLD = 0.5
LAMBDA_PARAM = 1
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# %%
# filter for only negative outcomes
negatives_df = compas_mit_df.loc[compas_mit_df[OUTCOMES_COL] == 0]

# scan with positive direction
current_subset, current_score = run_ijdi_scan(negatives_df, FEATURES, PROBA_CONFUSION_COL, PROBA_IJDI_COL, OUTCOMES_COL,
                                              THRESHOLD, LAMBDA_PARAM)
# summarize_scan(negatives_df, FEATURES, PROBA_COL, OUTCOMES_COL, current_subset, include='all')\
current_subset, current_score
# Out:
# Subset found on iteration 1 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Best score is now 11.453860833569696
# Subset found on iteration 2 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5']}
# Best score is now 25.454443717322924
# Subset found on iteration 3 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 25.454443717322924 does not beat best score of 25.454443717322924
# Subset found on iteration 4 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Current score of 11.453860833569696 does not beat best score of 25.454443717322924
# Subset found on iteration 5 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 25.454443717322924 does not beat best score of 25.454443717322924
# Subset found on iteration 6 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Current score of 11.453860833569696 does not beat best score of 25.454443717322924
# Subset found on iteration 7 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Current score of 11.453860833569696 does not beat best score of 25.454443717322924
# Subset found on iteration 8 of 10 with score 12.714378030702264 :
# {'race': ['African-American', 'Asian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 12.714378030702264 does not beat best score of 25.454443717322924
# Subset found on iteration 9 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5'], 'sex': ['Female']}
# Current score of 25.454443717322924 does not beat best score of 25.454443717322924
# Subset found on iteration 10 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Current score of 11.453860833569696 does not beat best score of 25.454443717322924
# Required time =  20.82157802581787 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5']}
# Score: 25.454443717322924
# First Iteration
# Average p_delta: -0.10574750275979283
# Average p_censor: 0.00040558934164654865
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.7982023761477275
# p(S): 0.41046743365119676 p(~S): 0.4104674336511966
# Subset found on iteration 1 of 10 with score 7.331940193559381 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Best score is now 7.331940193559381
# Subset found on iteration 2 of 10 with score 7.331940193559381 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 7.331940193559381 does not beat best score of 7.331940193559381
# Subset found on iteration 3 of 10 with score 6.788246662467389 :
# {'prior_offenses': ['Over 5'], 'sex': ['Female']}
# Current score of 6.788246662467389 does not beat best score of 7.331940193559381
# Subset found on iteration 4 of 10 with score 4.5266693633505115 :
# {'race': ['African-American', 'Other'], 'under_25': [True]}
# Current score of 4.5266693633505115 does not beat best score of 7.331940193559381
# Subset found on iteration 5 of 10 with score 6.788246662467389 :
# {'prior_offenses': ['Over 5'], 'sex': ['Female']}
# Current score of 6.788246662467389 does not beat best score of 7.331940193559381
# Subset found on iteration 6 of 10 with score 9.127420402640103 :
# {'race': ['African-American', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 9.127420402640103
# Subset found on iteration 7 of 10 with score 6.530838993594142 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F'], 'under_25': [True], 'sex': ['Female']}
# Current score of 6.530838993594142 does not beat best score of 9.127420402640103
# Subset found on iteration 8 of 10 with score 6.037509565305686 :
# {'prior_offenses': ['Over 5'], 'under_25': [True]}
# Current score of 6.037509565305686 does not beat best score of 9.127420402640103
# Subset found on iteration 9 of 10 with score 6.514773435408612 :
# {'under_25': [True], 'race': ['African-American', 'Caucasian'], 'sex': ['Female']}
# Current score of 6.514773435408612 does not beat best score of 9.127420402640103
# Subset found on iteration 10 of 10 with score 5.199915752803644 :
# {'race': ['Asian', 'Hispanic', 'Native American'], 'charge_degree': ['F'], 'prior_offenses': ['Over 5']}
# Current score of 5.199915752803644 does not beat best score of 9.127420402640103
# Required time =  16.088724613189697 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 9.127420402640103
# Average p_delta: 0.29647955126744024
# Average p_censor: 0.0
# Subset does not violate p_delta or p_censor conditions!
# ({'race': ['African-American', 'Hispanic', 'Native American'],
#   'prior_offenses': ['Over 5']},
#  9.127420402640103)

# %% [markdown]
# ### Implement Mitigation Approach 2

# %% [markdown]
# Set lambda vales to test.

# %%
lambda_vals = [0, 0.3, 1, 3, 10]

# specify parameters for generating metrics and IJDI scan
proba_confusion_col = 'proba_compas'
proba_ijdi_col = 'proba_lr'
outcomes_col = 'outcomes'
features = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
threshold = 'threshold'

# define stopping criteria
stop_limit = 0
max_iters = 3

pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(100)

# %%
sim_data = []

# %% [markdown]
# Implement approach for negatives

# %%
# filter for negative or positive outcomes
negatives_df = compas_mit_df.loc[compas_mit_df[outcomes_col] == 0]

for lambda_param in lambda_vals: # run IJDI scan for various lambda values

    print("Lambda =", lambda_param)

    i = 0
    ijdi_present = True
    # set initial threshold
    negatives_df['threshold'] = 0.5

    while ijdi_present and i <= max_iters:

        i += 1
        print("Iteration", i)

        # Run Negative or Positive IJDI Scan. Make sure to pass in copy because data may be modified by the function!
        current_subset, current_score = run_ijdi_scan(negatives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                      threshold, lambda_param, constant_threshold=False, verbose=True)

        print("Score for Negative IJDI-Scan:", current_score)

        # append data
        row = [lambda_param, i, current_score, 'negative']
        sim_data.append(row)

        print(row)

        if current_score > stop_limit:

            # correct IJDI by setting new threshold for subset
            negatives_df['threshold'] = correct_ijdi_subset(negatives_df.copy(deep=True), features,
                                                            proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                            threshold, lambda_param, current_subset)
            print(negatives_df['threshold'])

        else:
            ijdi_present = False

        print("\n----------------------------------------------------\n")
# Out:
# Lambda = 0
# Iteration 1
# Subset found on iteration 1 of 10 with score 63.09047814987018 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Best score is now 63.09047814987018
# Subset found on iteration 2 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 135.67766400191496
# Subset found on iteration 3 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 4 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 5 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 6 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 7 of 10 with score 63.09047814987018 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 63.09047814987018 does not beat best score of 135.67766400191496
# Subset found on iteration 8 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 9 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 10 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Required time =  23.01570153236389 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 135.67766400191496
# First Iteration
# Average p_delta: 0.28595028512231835
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 35    0.632297  0.632297  0.397193   0.397193  0.235104              0.233914
# 43    0.645737  0.645737  0.397193   0.397193  0.248544              0.233914
# 54    0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 58    0.670616  0.670616  0.397193   0.397193  0.273423              0.233914
# 93    0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7101  0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# 7131  0.670616  0.670616  0.397193   0.397193  0.273423              0.233914
# 7136  0.632297  0.632297  0.397193   0.397193  0.235104              0.233914
# 7173  0.670616  0.670616  0.397193   0.397193  0.273423              0.233914
# 7186  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
#
#       p_hat_raw     p_hat
# 35     0.233914  0.233914
# 43     0.233914  0.233914
# 54     0.233914  0.233914
# 58     0.233914  0.233914
# 93     0.233914  0.233914
# ...         ...       ...
# 7101   0.233914  0.233914
# 7131   0.233914  0.233914
# 7136   0.233914  0.233914
# 7173   0.233914  0.233914
# 7186   0.233914  0.233914
#
# [464 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 135.67766400191496
# [0, 1, 135.67766400191496, 'negative']
# Target positive rate for subset: 0.18633895398685338
# New threshold for subset: 0.6946329610766176
# 0       0.5
# 3       0.5
# 4       0.5
# 5       0.5
# 7       0.5
#        ...
# 7208    0.5
# 7209    0.5
# 7210    0.5
# 7211    0.5
# 7212    0.5
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Best score is now 83.33495229114686
# Subset found on iteration 2 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 3 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 4 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 5 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 6 of 10 with score 1.4794543095995156 :
# {'race': ['Native American'], 'prior_offenses': ['Over 5']}
# Current score of 1.4794543095995156 does not beat best score of 83.33495229114686
# Subset found on iteration 7 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 8 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 9 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 10 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Required time =  26.376027584075928 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Score: 83.33495229114686
# First Iteration
# Average p_delta: 0.13172521854970987
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.186475
# 23    0.385384  0.385384  0.397193   0.397193 -0.011808              0.186475
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.186475
# 71    0.589646  0.589646  0.397193   0.397193  0.192453              0.186475
# 77    0.458371  0.458371  0.397193   0.397193  0.061178              0.186475
# ...        ...       ...       ...        ...       ...                   ...
# 7178  0.553041  0.553041  0.397193   0.397193  0.155849              0.186475
# 7199  0.458371  0.458371  0.397193   0.397193  0.061178              0.186475
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.186475
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.186475
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.186475
#
#       p_hat_raw     p_hat
# 3      0.186475  0.186475
# 23     0.186475  0.186475
# 40     0.186475  0.186475
# 71     0.186475  0.186475
# 77     0.186475  0.186475
# ...         ...       ...
# 7178   0.186475  0.186475
# 7199   0.186475  0.186475
# 7208   0.186475  0.186475
# 7209   0.186475  0.186475
# 7210   0.186475  0.186475
#
# [661 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 83.33495229114686
# [0, 2, 83.33495229114686, 'negative']
# Target positive rate for subset: 0.14294367050272563
# New threshold for subset: 0.68359375
# 0       0.500000
# 3       0.683594
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.500000
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 47.90584659427634 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'race': ['African-American', 'Native American']}
# Best score is now 47.90584659427634
# Subset found on iteration 2 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 3 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 4 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 5 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 6 of 10 with score 8.940896647544173 :
# {'race': ['African-American', 'Caucasian'], 'sex': ['Male'], 'under_25': [True], 'prior_offenses': ['Over 5']}
# Current score of 8.940896647544173 does not beat best score of 47.90584659427634
# Subset found on iteration 7 of 10 with score 47.90584659427634 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False]}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 8 of 10 with score 8.940896647544173 :
# {'sex': ['Male'], 'race': ['African-American', 'Caucasian'], 'under_25': [True], 'prior_offenses': ['Over 5']}
# Current score of 8.940896647544173 does not beat best score of 47.90584659427634
# Subset found on iteration 9 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 10 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Required time =  23.560742378234863 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'race': ['African-American', 'Native American']}
# Score: 47.90584659427634
# First Iteration
# Average p_delta: 0.09762220417961803
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.137017
# 43    0.645737  0.645737  0.397193   0.397193  0.248544              0.137017
# 54    0.710991  0.710991  0.397193   0.397193  0.313799              0.137017
# 57    0.404766  0.404766  0.397193   0.397193  0.007573              0.137017
# ...        ...       ...       ...        ...       ...                   ...
# 7193  0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 7197  0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 7198  0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.137017
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.137017
#
#       p_hat_raw     p_hat
# 17     0.137017  0.137017
# 41     0.137017  0.137017
# 43     0.137017  0.137017
# 54     0.137017  0.137017
# 57     0.137017  0.137017
# ...         ...       ...
# 7193   0.137017  0.137017
# 7197   0.137017  0.137017
# 7198   0.137017  0.137017
# 7204   0.137017  0.137017
# 7212   0.137017  0.137017
#
# [1061 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 47.90584659427634
# [0, 3, 47.90584659427634, 'negative']
# Target positive rate for subset: 0.0954514128187457
# New threshold for subset: 0.6988188976377953
# 0       0.500000
# 3       0.683594
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 11.389877671168918 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'race': ['African-American', 'Hispanic', 'Other'], 'under_25': [True]}
# Best score is now 11.389877671168918
# Subset found on iteration 2 of 10 with score 8.419580624798622 :
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Other'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 8.419580624798622 does not beat best score of 11.389877671168918
# Subset found on iteration 3 of 10 with score 11.389877671168918 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'under_25': [True], 'race': ['African-American', 'Hispanic', 'Other']}
# Current score of 11.389877671168918 does not beat best score of 11.389877671168918
# Subset found on iteration 4 of 10 with score 6.523468353186145 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'sex': ['Female'], 'race': ['Caucasian']}
# Current score of 6.523468353186145 does not beat best score of 11.389877671168918
# Subset found on iteration 5 of 10 with score 6.938706150335794 :
# {'prior_offenses': ['None'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 6.938706150335794 does not beat best score of 11.389877671168918
# Subset found on iteration 6 of 10 with score 6.645528797240878 :
# {'prior_offenses': ['None'], 'under_25': [False], 'charge_degree': ['F'], 'race': ['African-American', 'Asian']}
# Current score of 6.645528797240878 does not beat best score of 11.389877671168918
# Subset found on iteration 7 of 10 with score 12.494789164709807 :
# {'race': ['African-American', 'Caucasian'], 'prior_offenses': ['Over 5'], 'under_25': [True], 'sex': ['Male']}
# Best score is now 12.494789164709807
# Subset found on iteration 8 of 10 with score 6.523468353186145 :
# {'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian'], 'sex': ['Female'], 'under_25': [False]}
# Current score of 6.523468353186145 does not beat best score of 12.494789164709807
# Subset found on iteration 9 of 10 with score 12.494789164709807 :
# {'sex': ['Male'], 'under_25': [True], 'race': ['African-American', 'Caucasian'], 'prior_offenses': ['Over 5']}
# Current score of 12.494789164709807 does not beat best score of 12.494789164709807
# Subset found on iteration 10 of 10 with score 6.523468353186145 :
# {'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'sex': ['Female'], 'under_25': [False], 'race': ['Caucasian']}
# Current score of 6.523468353186145 does not beat best score of 12.494789164709807
# Required time =  18.569750547409058 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian'], 'prior_offenses': ['Over 5'], 'under_25': [True], 'sex': ['Male']}
# Score: 12.494789164709807
# First Iteration
# Average p_delta: 0.44527102666057083
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 466   0.860447  0.860447  0.397193   0.397193  0.463254              0.080999
# 858   0.838907  0.838907  0.397193   0.397193  0.441715              0.080999
# 1335  0.860447  0.860447  0.397193   0.397193  0.463254              0.080999
# 2908  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 3407  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 5821  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 5860  0.838907  0.838907  0.397193   0.397193  0.441715              0.080999
# 5947  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 6940  0.838907  0.838907  0.397193   0.397193  0.441715              0.080999
#
#       p_hat_raw     p_hat
# 466    0.080999  0.080999
# 858    0.080999  0.080999
# 1335   0.080999  0.080999
# 2908   0.080999  0.080999
# 3407   0.080999  0.080999
# 5821   0.080999  0.080999
# 5860   0.080999  0.080999
# 5947   0.080999  0.080999
# 6940   0.080999  0.080999
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 12.494789164709807
# [0, 4, 12.494789164709807, 'negative']
# Target positive rate for subset: 0.07941325240263025
# New threshold for subset: 0.7728459530026109
# 0       0.500000
# 3       0.683594
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Iteration 1
# Subset found on iteration 1 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 74.48509339471337
# Subset found on iteration 2 of 10 with score 34.32714954393056 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 34.32714954393056 does not beat best score of 74.48509339471337
# Subset found on iteration 3 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 4 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 5 of 10 with score 34.32714954393056 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 34.32714954393056 does not beat best score of 74.48509339471337
# Subset found on iteration 6 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 7 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 8 of 10 with score 34.32714954393056 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 34.32714954393056 does not beat best score of 74.48509339471337
# Subset found on iteration 9 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 10 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Required time =  18.780827283859253 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 74.48509339471337
# First Iteration
# Average p_delta: 0.2956612316651005
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 43    0.645737  0.645737  0.397193   0.397193  0.248544              0.233914
# 54    0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 93    0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# 122   0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 172   0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7010  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 7028  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 7074  0.606223  0.606223  0.397193   0.397193  0.209030              0.233914
# 7101  0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# 7186  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
#
#       p_hat_raw     p_hat
# 43     0.308477  0.308477
# 54     0.328053  0.328053
# 93     0.317284  0.317284
# 122    0.328053  0.328053
# 172    0.328053  0.328053
# ...         ...       ...
# 7010   0.328053  0.328053
# 7028   0.328053  0.328053
# 7074   0.296623  0.296623
# 7101   0.317284  0.317284
# 7186   0.328053  0.328053
#
# [342 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 74.48509339471337
# [0.3, 1, 74.48509339471337, 'negative']
# Target positive rate for subset: 0.2920496101426776
# New threshold for subset: 0.68359375
# 0       0.5
# 3       0.5
# 4       0.5
# 5       0.5
# 7       0.5
#        ...
# 7208    0.5
# 7209    0.5
# 7210    0.5
# 7211    0.5
# 7212    0.5
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Best score is now 47.52372573962501
# Subset found on iteration 2 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 3 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 4 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 5 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 6 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 7 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 8 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 9 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 10 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Required time =  22.840296268463135 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Score: 47.52372573962501
# First Iteration
# Average p_delta: 0.13172521854970987
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.195811
# 23    0.385384  0.385384  0.397193   0.397193 -0.011808              0.195811
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.195811
# 71    0.589646  0.589646  0.397193   0.397193  0.192453              0.195811
# 77    0.458371  0.458371  0.397193   0.397193  0.061178              0.195811
# ...        ...       ...       ...        ...       ...                   ...
# 7178  0.553041  0.553041  0.397193   0.397193  0.155849              0.195811
# 7199  0.458371  0.458371  0.397193   0.397193  0.061178              0.195811
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.195811
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.195811
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.195811
#
#       p_hat_raw     p_hat
# 3      0.277246  0.277246
# 23     0.192269  0.192269
# 40     0.256418  0.256418
# 71     0.253547  0.253547
# 77     0.214165  0.214165
# ...         ...       ...
# 7178   0.242566  0.242566
# 7199   0.214165  0.214165
# 7208   0.228328  0.228328
# 7209   0.228328  0.228328
# 7210   0.228328  0.228328
#
# [661 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 47.52372573962501
# [0.3, 2, 47.52372573962501, 'negative']
# Target positive rate for subset: 0.20097156642451566
# New threshold for subset: 0.5912162162162162
# 0       0.500000
# 3       0.591216
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.591216
# 7209    0.591216
# 7210    0.591216
# 7211    0.500000
# 7212    0.500000
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 27.058076048611817 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5'], 'under_25': [False]}
# Best score is now 27.058076048611817
# Subset found on iteration 2 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 3 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Native American']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 4 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 5 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 6 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 7 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Native American']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 8 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 9 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Native American']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 10 of 10 with score 10.967654580459534 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 10.967654580459534 does not beat best score of 27.058076048611817
# Required time =  26.38931894302368 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5'], 'under_25': [False]}
# Score: 27.058076048611817
# First Iteration
# Average p_delta: 0.017282301579300614
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.158466
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.158466
# 57    0.404766  0.404766  0.397193   0.397193  0.007573              0.158466
# 59    0.446022  0.446022  0.397193   0.397193  0.048829              0.158466
# 72    0.404766  0.404766  0.397193   0.397193  0.007573              0.158466
# ...        ...       ...       ...        ...       ...                   ...
# 7193  0.446022  0.446022  0.397193   0.397193  0.048829              0.158466
# 7197  0.446022  0.446022  0.397193   0.397193  0.048829              0.158466
# 7198  0.446022  0.446022  0.397193   0.397193  0.048829              0.158466
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.158466
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.158466
#
#       p_hat_raw     p_hat
# 17     0.173115  0.173115
# 41     0.160738  0.160738
# 57     0.160738  0.160738
# 59     0.173115  0.173115
# 72     0.160738  0.160738
# ...         ...       ...
# 7193   0.173115  0.173115
# 7197   0.173115  0.173115
# 7198   0.173115  0.173115
# 7204   0.160738  0.160738
# 7212   0.139819  0.139819
#
# [758 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 27.058076048611817
# [0.3, 3, 27.058076048611817, 'negative']
# Target positive rate for subset: 0.13839217733155418
# New threshold for subset: 0.5912162162162162
# 0       0.500000
# 3       0.591216
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.591216
# 7209    0.591216
# 7210    0.591216
# 7211    0.500000
# 7212    0.591216
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 6.848719692394406 :
# {'race': ['African-American', 'Hispanic'], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Best score is now 6.848719692394406
# Subset found on iteration 2 of 10 with score 15.651135124270372 :
# {'prior_offenses': ['Over 5'], 'race': ['Caucasian', 'Native American']}
# Best score is now 15.651135124270372
# Subset found on iteration 3 of 10 with score 5.595667436621363 :
# {'prior_offenses': ['None'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 5.595667436621363 does not beat best score of 15.651135124270372
# Subset found on iteration 4 of 10 with score 15.651135124270372 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 15.651135124270372 does not beat best score of 15.651135124270372
# Subset found on iteration 5 of 10 with score 5.595667436621363 :
# {'prior_offenses': ['None'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 5.595667436621363 does not beat best score of 15.651135124270372
# Subset found on iteration 6 of 10 with score 15.651135124270372 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 15.651135124270372 does not beat best score of 15.651135124270372
# Subset found on iteration 7 of 10 with score 15.651135124270372 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 15.651135124270372 does not beat best score of 15.651135124270372
# Subset found on iteration 8 of 10 with score 7.251858571056338 :
# {'sex': ['Male'], 'prior_offenses': ['Over 5'], 'under_25': [True]}
# Current score of 7.251858571056338 does not beat best score of 15.651135124270372
# Subset found on iteration 9 of 10 with score 6.848719692394406 :
# {'race': ['African-American', 'Hispanic'], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'under_25': [True]}
# Current score of 6.848719692394406 does not beat best score of 15.651135124270372
# Subset found on iteration 10 of 10 with score 15.651135124270372 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 15.651135124270372 does not beat best score of 15.651135124270372
# Required time =  17.511223793029785 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['Over 5'], 'race': ['Caucasian', 'Native American']}
# Score: 15.651135124270372
# First Iteration
# Average p_delta: 0.2594116744051708
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 35    0.632297  0.632297  0.397193   0.397193  0.235104              0.127429
# 58    0.670616  0.670616  0.397193   0.397193  0.273423              0.127429
# 127   0.670616  0.670616  0.397193   0.397193  0.273423              0.127429
# 166   0.601357  0.601357  0.397193   0.397193  0.204164              0.127429
# 173   0.601357  0.601357  0.397193   0.397193  0.204164              0.127429
# ...        ...       ...       ...        ...       ...                   ...
# 6983  0.670616  0.670616  0.397193   0.397193  0.273423              0.127429
# 7082  0.670616  0.670616  0.397193   0.397193  0.273423              0.127429
# 7131  0.670616  0.670616  0.397193   0.397193  0.273423              0.127429
# 7136  0.632297  0.632297  0.397193   0.397193  0.235104              0.127429
# 7173  0.670616  0.670616  0.397193   0.397193  0.273423              0.127429
#
#       p_hat_raw     p_hat
# 35     0.197960  0.197960
# 58     0.209456  0.209456
# 127    0.209456  0.209456
# 166    0.188678  0.188678
# 173    0.188678  0.188678
# ...         ...       ...
# 6983   0.209456  0.209456
# 7082   0.209456  0.209456
# 7131   0.209456  0.209456
# 7136   0.197960  0.197960
# 7173   0.209456  0.209456
#
# [123 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 15.651135124270372
# [0.3, 4, 15.651135124270372, 'negative']
# Target positive rate for subset: 0.19802461971362179
# New threshold for subset: 0.68359375
# 0       0.500000
# 3       0.591216
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.591216
# 7209    0.591216
# 7210    0.591216
# 7211    0.500000
# 7212    0.591216
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Lambda = 1
# Iteration 1
# Subset found on iteration 1 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Best score is now 11.453860833569696
# Subset found on iteration 2 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5']}
# Best score is now 25.454443717322924
# Subset found on iteration 3 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Current score of 11.453860833569696 does not beat best score of 25.454443717322924
# Subset found on iteration 4 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5'], 'sex': ['Female']}
# Current score of 25.454443717322924 does not beat best score of 25.454443717322924
# Subset found on iteration 5 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5'], 'sex': ['Female']}
# Current score of 25.454443717322924 does not beat best score of 25.454443717322924
# Subset found on iteration 6 of 10 with score 12.714378030702264 :
# {'prior_offenses': ['None', 'Over 5'], 'race': ['African-American', 'Asian', 'Hispanic']}
# Current score of 12.714378030702264 does not beat best score of 25.454443717322924
# Subset found on iteration 7 of 10 with score 25.454443717322924 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 25.454443717322924 does not beat best score of 25.454443717322924
# Subset found on iteration 8 of 10 with score 11.453860833569696 :
# {'race': ['African-American', 'Native American']}
# Current score of 11.453860833569696 does not beat best score of 25.454443717322924
# Subset found on iteration 9 of 10 with score 25.454443717322924 :
# {'sex': ['Female'], 'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 25.454443717322924 does not beat best score of 25.454443717322924
# Subset found on iteration 10 of 10 with score 6.037509565305686 :
# {'prior_offenses': ['Over 5'], 'under_25': [True]}
# Current score of 6.037509565305686 does not beat best score of 25.454443717322924
# Required time =  19.938862085342407 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5']}
# Score: 25.454443717322924
# First Iteration
# Average p_delta: -0.10574750275979283
# Average p_censor: 0.00040558934164654865
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 8     0.174444  0.174444  0.397193   0.397193 -0.222748              0.233914
# 12    0.174444  0.174444  0.397193   0.397193 -0.222748              0.233914
# 23    0.385384  0.385384  0.397193   0.397193 -0.011808              0.233914
# 43    0.645737  0.645737  0.397193   0.397193  0.248544              0.233914
# 69    0.203393  0.203393  0.397193   0.397193 -0.193799              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7050  0.174444  0.174444  0.397193   0.397193 -0.222748              0.233914
# 7052  0.313037  0.313037  0.397193   0.397193 -0.084156              0.233914
# 7074  0.606223  0.606223  0.397193   0.397193  0.209030              0.233914
# 7120  0.174444  0.174444  0.397193   0.397193 -0.222748              0.233914
# 7122  0.431060  0.431060  0.397193   0.397193  0.033868              0.233914
#
#       p_hat_raw     p_hat
# 8      0.011165  0.011165
# 12     0.011165  0.011165
# 23     0.222105  0.222105
# 43     0.482458  0.482458
# 69     0.040114  0.040114
# ...         ...       ...
# 7050   0.011165  0.011165
# 7052   0.149758  0.149758
# 7074   0.442944  0.442944
# 7120   0.011165  0.011165
# 7122   0.267781  0.267781
#
# [442 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.7982023761477275
# p(S): 0.41046743365119676 p(~S): 0.4104674336511966
# Subset found on iteration 1 of 10 with score 6.037509565305686 :
# {'under_25': [True], 'prior_offenses': ['Over 5']}
# Best score is now 6.037509565305686
# Subset found on iteration 2 of 10 with score 5.199915752803644 :
# {'race': ['Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5'], 'charge_degree': ['F']}
# Current score of 5.199915752803644 does not beat best score of 6.037509565305686
# Subset found on iteration 3 of 10 with score 9.127420402640103 :
# {'race': ['African-American', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 9.127420402640103
# Subset found on iteration 4 of 10 with score 6.788246662467389 :
# {'sex': ['Female'], 'prior_offenses': ['Over 5']}
# Current score of 6.788246662467389 does not beat best score of 9.127420402640103
# Subset found on iteration 5 of 10 with score 4.5266693633505115 :
# {'race': ['African-American', 'Other'], 'under_25': [True]}
# Current score of 4.5266693633505115 does not beat best score of 9.127420402640103
# Subset found on iteration 6 of 10 with score 7.331940193559381 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 7.331940193559381 does not beat best score of 9.127420402640103
# Subset found on iteration 7 of 10 with score 7.331940193559381 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 7.331940193559381 does not beat best score of 9.127420402640103
# Subset found on iteration 8 of 10 with score 7.331940193559381 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 7.331940193559381 does not beat best score of 9.127420402640103
# Subset found on iteration 9 of 10 with score 7.331940193559381 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 7.331940193559381 does not beat best score of 9.127420402640103
# Subset found on iteration 10 of 10 with score 7.331940193559381 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 7.331940193559381 does not beat best score of 9.127420402640103
# Required time =  18.519996643066406 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 9.127420402640103
# Average p_delta: 0.29647955126744024
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 43    0.645737  0.645737  0.410467   0.397193  0.248544              0.233914
# 54    0.710991  0.710991  0.410467   0.397193  0.313799              0.233914
# 93    0.675094  0.675094  0.410467   0.397193  0.277901              0.233914
# 122   0.710991  0.710991  0.410467   0.397193  0.313799              0.233914
# 172   0.710991  0.710991  0.410467   0.397193  0.313799              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7010  0.710991  0.710991  0.410467   0.397193  0.313799              0.233914
# 7028  0.710991  0.710991  0.410467   0.397193  0.313799              0.233914
# 7074  0.606223  0.606223  0.410467   0.397193  0.209030              0.233914
# 7101  0.675094  0.675094  0.410467   0.397193  0.277901              0.233914
# 7186  0.710991  0.710991  0.410467   0.397193  0.313799              0.233914
#
#       p_hat_raw     p_hat
# 43     0.482458  0.482458
# 54     0.547712  0.547712
# 93     0.511815  0.511815
# 122    0.547712  0.547712
# 172    0.547712  0.547712
# ...         ...       ...
# 7010   0.547712  0.547712
# 7028   0.547712  0.547712
# 7074   0.442944  0.442944
# 7101   0.511815  0.511815
# 7186   0.547712  0.547712
#
# [340 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 9.127420402640103
# [1, 1, 9.127420402640103, 'negative']
# Target positive rate for subset: 0.5194447865506094
# New threshold for subset: 0.5585023400936038
# 0       0.5
# 3       0.5
# 4       0.5
# 5       0.5
# 7       0.5
#        ...
# 7208    0.5
# 7209    0.5
# 7210    0.5
# 7211    0.5
# 7212    0.5
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 28.755071878948662 :
# {'race': ['African-American', 'Caucasian'], 'prior_offenses': ['None'], 'sex': ['Female']}
# Best score is now 28.755071878948662
# Subset found on iteration 2 of 10 with score 28.755071878948662 :
# {'race': ['African-American', 'Caucasian'], 'sex': ['Female'], 'prior_offenses': ['None']}
# Current score of 28.755071878948662 does not beat best score of 28.755071878948662
# Subset found on iteration 3 of 10 with score 28.755071878948662 :
# {'prior_offenses': ['None'], 'sex': ['Female'], 'race': ['African-American', 'Caucasian']}
# Current score of 28.755071878948662 does not beat best score of 28.755071878948662
# Subset found on iteration 4 of 10 with score 28.755071878948662 :
# {'prior_offenses': ['None'], 'race': ['African-American', 'Caucasian'], 'sex': ['Female']}
# Current score of 28.755071878948662 does not beat best score of 28.755071878948662
# Subset found on iteration 5 of 10 with score 28.755071878948662 :
# {'prior_offenses': ['None'], 'race': ['African-American', 'Caucasian'], 'sex': ['Female']}
# Current score of 28.755071878948662 does not beat best score of 28.755071878948662
# Subset found on iteration 6 of 10 with score 123.83959502167437 :
# {'under_25': [False], 'sex': ['Female'], 'prior_offenses': ['None'], 'race': ['Caucasian'], 'charge_degree': ['M']}
# Best score is now 123.83959502167437
# Subset found on iteration 7 of 10 with score 28.755071878948662 :
# {'race': ['African-American', 'Caucasian'], 'sex': ['Female'], 'prior_offenses': ['None']}
# Current score of 28.755071878948662 does not beat best score of 123.83959502167437
# Subset found on iteration 8 of 10 with score 11.901950685694512 :
# {'prior_offenses': ['1 to 5', 'None'], 'race': ['African-American']}
# Current score of 11.901950685694512 does not beat best score of 123.83959502167437
# Subset found on iteration 9 of 10 with score 28.755071878948662 :
# {'prior_offenses': ['None'], 'race': ['African-American', 'Caucasian'], 'sex': ['Female']}
# Current score of 28.755071878948662 does not beat best score of 123.83959502167437
# Subset found on iteration 10 of 10 with score 28.755071878948662 :
# {'race': ['African-American', 'Caucasian'], 'prior_offenses': ['None'], 'sex': ['Female']}
# Current score of 28.755071878948662 does not beat best score of 123.83959502167437
# Required time =  17.959799766540527 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'sex': ['Female'], 'prior_offenses': ['None'], 'race': ['Caucasian'], 'charge_degree': ['M']}
# Score: 123.83959502167437
# First Iteration
# Average p_delta: -0.22274828309679054
# Average p_censor: 0.003722292685485795
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 8     0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 12    0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 97    0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 143   0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 151   0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# ...        ...       ...       ...        ...       ...                   ...
# 6820  0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 6906  0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 6931  0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 7050  0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
# 7120  0.174444  0.174444  0.397193   0.397193 -0.222748              0.219026
#
#       p_hat_raw  p_hat
# 8     -0.003722    0.0
# ...
#
#       p_hat_raw  p_hat
# 125   -0.074850    0.0
# 131   -0.142152    0.0
# 378   -0.074850    0.0
# 418   -0.074850    0.0
# 881   -0.074850    0.0
# 904   -0.074850    0.0
# 928   -0.074850    0.0
# 991   -0.142152    0.0
# 1094  -0.074850    0.0
# 1187  -0.074850    0.0
# 1198  -0.074850    0.0
# 1225  -0.074850    0.0
# 1227  -0.074850    0.0
# 1262  -0.074850    0.0
# 1266  -0.074850    0.0
# 1268  -0.074850    0.0
# 1350  -0.074850    0.0
# 1573  -0.074850    0.0
# 2022  -0.074850    0.0
# 2696  -0.074850    0.0
# 2713  -0.074850    0.0
# 2907  -0.074850    0.0
# 3039  -0.074850    0.0
# 3557  -0.074850    0.0
# 3615  -0.142152    0.0
# 3659  -0.074850    0.0
# 3689  -0.074850    0.0
# 3704  -0.074850    0.0
# 3986  -0.074850    0.0
# 4147  -0.074850    0.0
# 4394  -0.074850    0.0
# 4402  -0.074850    0.0
# 4450  -0.074850    0.0
# 4456  -0.074850    0.0
# 4505  -0.074850    0.0
# 4599  -0.074850    0.0
# 4826  -0.074850    0.0
# 4827  -0.074850    0.0
# 4968  -0.074850    0.0
# 4976  -0.074850    0.0
# 5083  -0.074850    0.0
# 5314  -0.074850    0.0
# 5447  -0.074850    0.0
# 5625  -0.074850    0.0
# 5688  -0.074850    0.0
# 5737  -0.074850    0.0
# 5887  -0.074850    0.0
# 5905  -0.074850    0.0
# 6089  -0.074850    0.0
# 6215  -0.074850    0.0
# 6544  -0.074850    0.0
# 6636  -0.074850    0.0
# 6673  -0.074850    0.0
# 6926  -0.074850    0.0
# 7073  -0.074850    0.0
# 7127  -0.142152    0.0
# 7166  -0.074850    0.0
# 7180  -0.074850    0.0
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.39874432572737695 p(~S): 0.3987443257273766
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 6.74152871639415 :
# {'sex': ['Male'], 'prior_offenses': ['1 to 5'], 'race': ['Hispanic', 'Native American'], 'charge_degree': ['M'], 'under_25': [False]}
# Best score is now 6.74152871639415
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 6.74152871639415
# Subset found on iteration 5 of 10 with score 13.39669878912345 :
# {'race': ['Caucasian'], 'under_25': [False], 'charge_degree': ['F'], 'sex': ['Female'], 'prior_offenses': ['1 to 5']}
# Best score is now 13.39669878912345
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 13.39669878912345
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 13.39669878912345
# Subset found on iteration 8 of 10 with score 9.18242195335683 :
# {'under_25': [True], 'sex': ['Female'], 'prior_offenses': ['None']}
# Current score of 9.18242195335683 does not beat best score of 13.39669878912345
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 13.39669878912345
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 13.39669878912345
# Required time =  15.623411893844604 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian'], 'under_25': [False], 'charge_degree': ['F'], 'sex': ['Female'], 'prior_offenses': ['1 to 5']}
# Score: 13.39669878912345
# Average p_delta: -0.06667383956695884
# Average p_censor: 0.0
#       proba_lr     p_old    p_bar  p_bar_old   p_delta  positives_constprobs  \
# 28    0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 106   0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 128   0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 141   0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 647   0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# ...        ...       ...      ...        ...       ...                   ...
# 6990  0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 7046  0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 7144  0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 7179  0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
# 7182  0.330519  0.330519  0.46879   0.397193 -0.066674              0.233914
#
#       p_hat_raw     p_hat
# 28     0.033892  0.033892
# 106    0.033892  0.033892
# 128    0.033892  0.033892
# 141    0.033892  0.033892
# 647    0.033892  0.033892
# ...         ...       ...
# 6990   0.033892  0.033892
# 7046   0.033892  0.033892
# 7144   0.033892  0.033892
# 7179   0.033892  0.033892
# 7182   0.033892  0.033892
#
# [83 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.3986189535131473 p(~S): 0.3986189535131476
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 9.18242195335683 :
# {'prior_offenses': ['None'], 'sex': ['Female'], 'under_25': [True]}
# Best score is now 9.18242195335683
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 9.18242195335683
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 9.18242195335683
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 9.18242195335683
# Subset found on iteration 7 of 10 with score 9.18242195335683 :
# {'prior_offenses': ['None'], 'sex': ['Female'], 'under_25': [True]}
# Current score of 9.18242195335683 does not beat best score of 9.18242195335683
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 9.18242195335683
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 9.18242195335683
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 9.18242195335683
# Required time =  15.925008296966553 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['None'], 'sex': ['Female'], 'under_25': [True]}
# Score: 9.18242195335683
# Average p_delta: -0.010490435632871432
# Average p_censor: 0.0007276352984717461
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 23    0.385384  0.385384  0.470216   0.397193 -0.011808              0.233914
# 94    0.385384  0.385384  0.470216   0.397193 -0.011808              0.233914
# 133   0.390214  0.390214  0.470216   0.397193 -0.006979              0.233914
# 150   0.431060  0.431060  0.470216   0.397193  0.033868              0.233914
# 305   0.390214  0.390214  0.470216   0.397193 -0.006979              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 6693  0.390214  0.390214  0.470216   0.397193 -0.006979              0.233914
# 6789  0.390214  0.390214  0.470216   0.397193 -0.006979              0.233914
# 6848  0.431060  0.431060  0.470216   0.397193  0.033868              0.233914
# 7052  0.313037  0.313037  0.470216   0.397193 -0.084156              0.233914
# 7122  0.431060  0.431060  0.470216   0.397193  0.033868              0.233914
#
#       p_hat_raw     p_hat
# 23     0.198488  0.198488
# 94     0.198488  0.198488
# 133    0.212977  0.212977
# 150    0.335517  0.335517
# 305    0.212977  0.212977
# ...         ...       ...
# 6693   0.212977  0.212977
# 6789   0.212977  0.212977
# 6848   0.335517  0.335517
# 7052  -0.018555  0.000000
# 7122   0.335517  0.335517
#
# [102 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.513316023730536
# p(S): 0.39746981983943697 p(~S): 0.3974698198394373
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  16.954151153564453 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Score for Negative IJDI-Scan: 0.0
# [3, 1, 0.0, 'negative']
#
# ----------------------------------------------------
#
# Lambda = 10
# Iteration 1
# Subset found on iteration 1 of 10 with score 1173.9183974269245 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False], 'sex': ['Female']}
# Best score is now 1173.9183974269245
# Subset found on iteration 2 of 10 with score 1229.3804396587798 :
# {'under_25': [False], 'prior_offenses': ['None']}
# Best score is now 1229.3804396587798
# Subset found on iteration 3 of 10 with score 13.61551055796382 :
# {'charge_degree': ['F'], 'race': ['Asian']}
# Current score of 13.61551055796382 does not beat best score of 1229.3804396587798
# Subset found on iteration 4 of 10 with score 1173.9183974269245 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False], 'sex': ['Female']}
# Current score of 1173.9183974269245 does not beat best score of 1229.3804396587798
# Subset found on iteration 5 of 10 with score 1173.9183974269245 :
# {'under_25': [False], 'sex': ['Female'], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 1173.9183974269245 does not beat best score of 1229.3804396587798
# Subset found on iteration 6 of 10 with score 1173.9183974269245 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False], 'sex': ['Female']}
# Current score of 1173.9183974269245 does not beat best score of 1229.3804396587798
# Subset found on iteration 7 of 10 with score 1173.9183974269245 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False], 'sex': ['Female']}
# Current score of 1173.9183974269245 does not beat best score of 1229.3804396587798
# Subset found on iteration 8 of 10 with score 1173.9183974269245 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'None'], 'sex': ['Female']}
# Current score of 1173.9183974269245 does not beat best score of 1229.3804396587798
# Subset found on iteration 9 of 10 with score 1173.9183974269245 :
# {'prior_offenses': ['1 to 5', 'None'], 'sex': ['Female'], 'under_25': [False]}
# Current score of 1173.9183974269245 does not beat best score of 1229.3804396587798
# Subset found on iteration 10 of 10 with score 1173.9183974269245 :
# {'sex': ['Female'], 'under_25': [False], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 1173.9183974269245 does not beat best score of 1229.3804396587798
# Required time =  17.82818031311035 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'prior_offenses': ['None']}
# Score: 1229.3804396587798
# First Iteration
# Average p_delta: -0.16871590130869848
# Average p_censor: 1.4532453113458812
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 0     0.232134  0.232134  0.397193   0.397193 -0.165059              0.233914
# 5     0.203398  0.203398  0.397193   0.397193 -0.193795              0.233914
# 8     0.174444  0.174444  0.397193   0.397193 -0.222748              0.233914
# 10    0.252427  0.252427  0.397193   0.397193 -0.144766              0.233914
# 12    0.174444  0.174444  0.397193   0.397193 -0.222748              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7192  0.252427  0.252427  0.397193   0.397193 -0.144766              0.233914
# 7196  0.256285  0.256285  0.397193   0.397193 -0.140908              0.233914
# 7202  0.225128  0.225128  0.397193   0.397193 -0.172064              0.233914
# 7203  0.225128  0.225128  0.397193   0.397193 -0.172064              0.233914
# 7211  0.232134  0.232134  0.397193   0.397193 -0.165059              0.233914
#
#       p_hat_raw  p_hat
# 0     -1.416675    0.0
# 5     -1.704033    0.0
# 8     -1.993569    0.0
# 10    -1.213744    0.0
# 12    -1.993569    0.0
# ...         ...    ...
# 7192  -1.213744    0.0
# 7196  -1.175164    0.0
# 7202  -1.486730    0.0
# 7203  -1.486730    0.0
# 7211  -1.416675    0.0
#
# [1164 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.46735535173081966 p(~S): 0.4673553517308285
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 800.9996123619015 :
# {'under_25': [False], 'sex': ['Female'], 'prior_offenses': ['1 to 5']}
# Best score is now 800.9996123619015
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 800.9996123619015
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 800.9996123619015
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 800.9996123619015
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 800.9996123619015
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 800.9996123619015
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 800.9996123619015
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 800.9996123619015
# Required time =  16.610482215881348 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'sex': ['Female'], 'prior_offenses': ['1 to 5']}
# Score: 800.9996123619015
# Average p_delta: -0.06194510549515089
# Average p_censor: 0.3855373532104041
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 28    0.330519  0.330519  0.467355   0.397193 -0.066674              0.233914
# 53    0.298143  0.298143  0.467355   0.397193 -0.099050              0.233914
# 88    0.335035  0.335035  0.467355   0.397193 -0.062157              0.233914
# 106   0.330519  0.330519  0.467355   0.397193 -0.066674              0.233914
# 119   0.306522  0.306522  0.467355   0.397193 -0.090671              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7166  0.294272  0.294272  0.467355   0.397193 -0.102921              0.233914
# 7179  0.330519  0.330519  0.467355   0.397193 -0.066674              0.233914
# 7180  0.294272  0.294272  0.467355   0.397193 -0.102921              0.233914
# 7182  0.330519  0.330519  0.467355   0.397193 -0.066674              0.233914
# 7212  0.335035  0.335035  0.467355   0.397193 -0.062157              0.233914
#
#       p_hat_raw  p_hat
# 28    -0.432825    0.0
# 53    -0.756582    0.0
# 88    -0.387658    0.0
# 106   -0.432825    0.0
# 119   -0.672795    0.0
# ...         ...    ...
# 7166  -0.795298    0.0
# 7179  -0.432825    0.0
# 7180  -0.795298    0.0
# 7182  -0.432825    0.0
# 7212  -0.387658    0.0
#
# [348 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.40315586351377747 p(~S): 0.40315586351378124
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0

# %%
columns = ['lambda', 'iteration', 'score', 'scan_type']
mit_result_df = pd.DataFrame(sim_data, columns=columns)
mit_result_df

# %%
# Write recipe outputs
mit_result_df.to_csv(home_dir + "datasets/compas_mit_2_neg.csv")
