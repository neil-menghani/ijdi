# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
import pandas as pd, numpy as np

os.chdir('../') # cd back to parent dir
home_dir = "compas/" # set home dir for reading and storing data

# Read recipe inputs
compas_mit_df = pd.read_csv(home_dir + "datasets/compas_prep.csv")
compas_mit_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
# [7214 rows x 10 columns]

# %% [markdown]
# Test running positive IJDI-Scan once.

# %%
PROBA_CONFUSION_COL = 'proba_compas'
PROBA_IJDI_COL = 'proba_lr'
OUTCOMES_COL = 'outcomes'
FEATURES = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
THRESHOLD = 0.5
LAMBDA_PARAM = 1
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# %%
# filter for only positive outcomes
positives_df = compas_mit_df.loc[compas_mit_df[OUTCOMES_COL] == 1]

# scan with positive direction
current_subset, current_score = run_ijdi_scan(positives_df, FEATURES, PROBA_CONFUSION_COL, PROBA_IJDI_COL, OUTCOMES_COL,
                                              THRESHOLD, LAMBDA_PARAM)
# summarize_scan(positives_df, FEATURES, PROBA_COL, OUTCOMES_COL, current_subset, include='all')\
current_subset, current_score
# Out:
# Subset found on iteration 1 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 23.79444568654959
# Subset found on iteration 2 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 3 of 10 with score 1.9769395249199533 :
# {'under_25': [True], 'charge_degree': ['M'], 'prior_offenses': ['Over 5']}
# Current score of 1.9769395249199533 does not beat best score of 23.79444568654959
# Subset found on iteration 4 of 10 with score 7.708451583477554 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'charge_degree': ['F'], 'sex': ['Female']}
# Current score of 7.708451583477554 does not beat best score of 23.79444568654959
# Subset found on iteration 5 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 6 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 7 of 10 with score 2.045040524664439 :
# {'race': ['Asian'], 'under_25': [True]}
# Current score of 2.045040524664439 does not beat best score of 23.79444568654959
# Subset found on iteration 8 of 10 with score 7.708451583477554 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'sex': ['Female'], 'charge_degree': ['F']}
# Current score of 7.708451583477554 does not beat best score of 23.79444568654959
# Subset found on iteration 9 of 10 with score 0.639896140180015 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['M'], 'under_25': [True], 'race': ['Hispanic', 'Other']}
# Current score of 0.639896140180015 does not beat best score of 23.79444568654959
# Subset found on iteration 10 of 10 with score 7.708451583477554 :
# {'charge_degree': ['F'], 'sex': ['Female'], 'race': ['African-American', 'Caucasian', 'Native American']}
# Current score of 7.708451583477554 does not beat best score of 23.79444568654959
# Required time =  19.660075902938843 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 23.79444568654959
# First Iteration
# Average p_delta: 0.19041533772898256
# Average p_censor: 0.0
# Subset does not violate p_delta or p_censor conditions!
# ({'race': ['African-American', 'Native American'],
#   'prior_offenses': ['Over 5']},
#  23.79444568654959)

# %% [markdown]
# ### Implement Mitigation Approach 2

# %% [markdown]
# Set lambda vales to test.

# %%
lambda_vals = [0, 0.3, 1, 3, 10]

# specify parameters for generating metrics and IJDI scan
proba_confusion_col = 'proba_compas'
proba_ijdi_col = 'proba_lr'
outcomes_col = 'outcomes'
features = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
threshold = 'threshold'

# define stopping criteria
stop_limit = 0
max_iters = 3

pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(100)

# %%
sim_data = []

# %% [markdown]
# Implement approach for Positives

# %%
# filter for negative or positive outcomes
positives_df = compas_mit_df.loc[compas_mit_df[outcomes_col] == 1]

for lambda_param in lambda_vals: # run IJDI scan for various lambda values

    print("Lambda =", lambda_param)

    i = 0
    ijdi_present = True
    # set initial threshold
    positives_df['threshold'] = 0.5

    while ijdi_present and i <= max_iters:

        i += 1
        print("Iteration", i)

        # Run Negative or Positive IJDI Scan. Make sure to pass in copy because data may be modified by the function!
        current_subset, current_score = run_ijdi_scan(positives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                      threshold, lambda_param, constant_threshold=False, verbose=True)

        print("Score for Positives IJDI-Scan:", current_score)

        # append data
        row = [lambda_param, i, current_score, 'positive']
        sim_data.append(row)

        print(row)

        if current_score > stop_limit:

            # correct IJDI by setting new threshold for subset
            positives_df['threshold'] = correct_ijdi_subset(positives_df.copy(deep=True), features,
                                                            proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                            threshold, lambda_param, current_subset)
            print(positives_df['threshold'])

        else:
            ijdi_present = False

        print("\n----------------------------------------------------\n")
# Out:
# Lambda = 0
# Iteration 1
# Subset found on iteration 1 of 10 with score 146.34697806274693 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Best score is now 146.34697806274693
# Subset found on iteration 2 of 10 with score 146.34697806274693 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 3 of 10 with score 146.34697806274693 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 4 of 10 with score 146.34697806274693 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 5 of 10 with score 146.34697806274693 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 6 of 10 with score 146.34697806274693 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 7 of 10 with score 146.34697806274693 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 8 of 10 with score 146.34697806274693 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 9 of 10 with score 146.34697806274693 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Subset found on iteration 10 of 10 with score 146.34697806274693 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 146.34697806274693 does not beat best score of 146.34697806274693
# Required time =  26.17819881439209 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Score: 146.34697806274693
# First Iteration
# Average p_delta: 0.19041533772898256
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 27    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 38    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 46    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# ...        ...       ...       ...        ...       ...                   ...
# 7152  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7160  0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 7181  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
#
#       p_hat_raw     p_hat
# 15     0.525684  0.525684
# 20     0.525684  0.525684
# 27     0.525684  0.525684
# 38     0.525684  0.525684
# 46     0.525684  0.525684
# ...         ...       ...
# 7152   0.525684  0.525684
# 7160   0.525684  0.525684
# 7181   0.525684  0.525684
# 7195   0.525684  0.525684
# 7201   0.525684  0.525684
#
# [743 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 146.34697806274693
# [0, 1, 146.34697806274693, 'positive']
# Target positive rate for subset: 0.4370015948963317
# New threshold for subset: 0.68359375
# 1       0.500000
# 2       0.500000
# 6       0.500000
# 9       0.500000
# 11      0.500000
#           ...
# 7201    0.683594
# 7205    0.500000
# 7206    0.500000
# 7207    0.500000
# 7213    0.500000
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Best score is now 72.24337368694513
# Subset found on iteration 2 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Subset found on iteration 3 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Subset found on iteration 4 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Subset found on iteration 5 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Subset found on iteration 6 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Subset found on iteration 7 of 10 with score 72.24337368694513 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True]}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Subset found on iteration 8 of 10 with score 26.727310390058932 :
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5']}
# Current score of 26.727310390058932 does not beat best score of 72.24337368694513
# Subset found on iteration 9 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Subset found on iteration 10 of 10 with score 72.24337368694513 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 72.24337368694513 does not beat best score of 72.24337368694513
# Required time =  23.356502294540405 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Score: 72.24337368694513
# First Iteration
# Average p_delta: 0.1426994125404181
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 9     0.625467  0.625467  0.515817   0.515817  0.109650              0.423562
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.423562
# 21    0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 24    0.589646  0.589646  0.515817   0.515817  0.073829              0.423562
# ...        ...       ...       ...        ...       ...                   ...
# 7143  0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 7174  0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.423562
# 7205  0.585145  0.585145  0.515817   0.515817  0.069328              0.423562
# 7213  0.515657  0.515657  0.515817   0.515817 -0.000160              0.423562
#
#       p_hat_raw     p_hat
# 2      0.423562  0.423562
# 9      0.423562  0.423562
# 11     0.423562  0.423562
# 21     0.423562  0.423562
# 24     0.423562  0.423562
# ...         ...       ...
# 7143   0.423562  0.423562
# 7174   0.423562  0.423562
# 7190   0.423562  0.423562
# 7205   0.423562  0.423562
# 7213   0.423562  0.423562
#
# [567 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 72.24337368694513
# [0, 2, 72.24337368694513, 'positive']
# Target positive rate for subset: 0.37034277198211624
# New threshold for subset: 0.68359375
# 1       0.500000
# 2       0.683594
# 6       0.500000
# 9       0.683594
# 11      0.683594
#           ...
# 7201    0.683594
# 7205    0.683594
# 7206    0.500000
# 7207    0.500000
# 7213    0.683594
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 2.8530781807560883 :
# {'sex': ['Female'], 'race': ['Native American']}
# Best score is now 2.8530781807560883
# Subset found on iteration 2 of 10 with score 42.16656120801439 :
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5'], 'charge_degree': ['F']}
# Best score is now 42.16656120801439
# Subset found on iteration 3 of 10 with score 42.16656120801439 :
# {'charge_degree': ['F'], 'prior_offenses': ['Over 5'], 'race': ['Caucasian', 'Hispanic', 'Native American', 'Other']}
# Current score of 42.16656120801439 does not beat best score of 42.16656120801439
# Subset found on iteration 4 of 10 with score 42.16656120801439 :
# {'charge_degree': ['F'], 'prior_offenses': ['Over 5'], 'race': ['Caucasian', 'Hispanic', 'Native American', 'Other']}
# Current score of 42.16656120801439 does not beat best score of 42.16656120801439
# Subset found on iteration 5 of 10 with score 2.8530781807560883 :
# {'prior_offenses': ['1 to 5'], 'race': ['Native American']}
# Current score of 2.8530781807560883 does not beat best score of 42.16656120801439
# Subset found on iteration 6 of 10 with score 42.16656120801439 :
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['Over 5']}
# Current score of 42.16656120801439 does not beat best score of 42.16656120801439
# Subset found on iteration 7 of 10 with score 42.16656120801439 :
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5']}
# Current score of 42.16656120801439 does not beat best score of 42.16656120801439
# Subset found on iteration 8 of 10 with score 42.16656120801439 :
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5']}
# Current score of 42.16656120801439 does not beat best score of 42.16656120801439
# Subset found on iteration 9 of 10 with score 42.16656120801439 :
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['Over 5']}
# Current score of 42.16656120801439 does not beat best score of 42.16656120801439
# Subset found on iteration 10 of 10 with score 42.16656120801439 :
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['Over 5']}
# Current score of 42.16656120801439 does not beat best score of 42.16656120801439
# Required time =  29.191069841384888 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5'], 'charge_degree': ['F']}
# Score: 42.16656120801439
# First Iteration
# Average p_delta: 0.14739324522845684
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 6     0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 18    0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 31    0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 34    0.645743  0.645743  0.515817   0.515817  0.129926              0.361427
# 52    0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# ...        ...       ...       ...        ...       ...                   ...
# 7076  0.601357  0.601357  0.515817   0.515817  0.085539              0.361427
# 7085  0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 7128  0.636604  0.636604  0.515817   0.515817  0.120787              0.361427
# 7145  0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 7187  0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
#
#       p_hat_raw     p_hat
# 6      0.361427  0.361427
# 18     0.361427  0.361427
# 31     0.361427  0.361427
# 34     0.361427  0.361427
# 52     0.361427  0.361427
# ...         ...       ...
# 7076   0.361427  0.361427
# 7085   0.361427  0.361427
# 7128   0.361427  0.361427
# 7145   0.361427  0.361427
# 7187   0.361427  0.361427
#
# [249 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 42.16656120801439
# [0, 3, 42.16656120801439, 'positive']
# Target positive rate for subset: 0.3374417055296469
# New threshold for subset: 0.68359375
# 1       0.500000
# 2       0.683594
# 6       0.683594
# 9       0.683594
# 11      0.683594
#           ...
# 7201    0.683594
# 7205    0.683594
# 7206    0.500000
# 7207    0.500000
# 7213    0.683594
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 22.5751049542522 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'under_25': [True], 'prior_offenses': ['None', 'Over 5']}
# Best score is now 22.5751049542522
# Subset found on iteration 2 of 10 with score 19.47170481238428 :
# {'race': ['African-American', 'Asian', 'Native American'], 'charge_degree': ['F']}
# Current score of 19.47170481238428 does not beat best score of 22.5751049542522
# Subset found on iteration 3 of 10 with score 22.5751049542522 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [True]}
# Current score of 22.5751049542522 does not beat best score of 22.5751049542522
# Subset found on iteration 4 of 10 with score 19.47170481238428 :
# {'charge_degree': ['F'], 'race': ['African-American', 'Asian', 'Native American']}
# Current score of 19.47170481238428 does not beat best score of 22.5751049542522
# Subset found on iteration 5 of 10 with score 19.47170481238428 :
# {'charge_degree': ['F'], 'race': ['African-American', 'Asian', 'Native American']}
# Current score of 19.47170481238428 does not beat best score of 22.5751049542522
# Subset found on iteration 6 of 10 with score 22.5751049542522 :
# {'prior_offenses': ['None', 'Over 5'], 'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'under_25': [True]}
# Current score of 22.5751049542522 does not beat best score of 22.5751049542522
# Subset found on iteration 7 of 10 with score 12.65605692225867 :
# {'race': ['African-American', 'Native American'], 'under_25': [False], 'prior_offenses': ['1 to 5'], 'charge_degree': ['F']}
# Current score of 12.65605692225867 does not beat best score of 22.5751049542522
# Subset found on iteration 8 of 10 with score 5.394206428139891 :
# {'race': ['Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F'], 'under_25': [True], 'sex': ['Female']}
# Current score of 5.394206428139891 does not beat best score of 22.5751049542522
# Subset found on iteration 9 of 10 with score 5.394206428139891 :
# {'race': ['Caucasian', 'Hispanic'], 'sex': ['Female'], 'under_25': [True], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F']}
# Current score of 5.394206428139891 does not beat best score of 22.5751049542522
# Subset found on iteration 10 of 10 with score 19.47170481238428 :
# {'charge_degree': ['F'], 'race': ['African-American', 'Asian', 'Native American']}
# Current score of 19.47170481238428 does not beat best score of 22.5751049542522
# Required time =  18.57972812652588 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'under_25': [True], 'prior_offenses': ['None', 'Over 5']}
# Score: 22.5751049542522
# First Iteration
# Average p_delta: 0.02663385352493651
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 103   0.836139  0.836139  0.515817   0.515817  0.320322               0.33159
# 116   0.505581  0.505581  0.515817   0.515817 -0.010236               0.33159
# 185   0.463425  0.463425  0.515817   0.515817 -0.052392               0.33159
# 196   0.505581  0.505581  0.515817   0.515817 -0.010236               0.33159
# 272   0.431060  0.431060  0.515817   0.515817 -0.084757               0.33159
# ...        ...       ...       ...        ...       ...                   ...
# 7165  0.505581  0.505581  0.515817   0.515817 -0.010236               0.33159
# 7170  0.505581  0.505581  0.515817   0.515817 -0.010236               0.33159
# 7183  0.431060  0.431060  0.515817   0.515817 -0.084757               0.33159
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603               0.33159
# 7206  0.416832  0.416832  0.515817   0.515817 -0.098985               0.33159
#
#       p_hat_raw    p_hat
# 103     0.33159  0.33159
# 116     0.33159  0.33159
# 185     0.33159  0.33159
# 196     0.33159  0.33159
# 272     0.33159  0.33159
# ...         ...      ...
# 7165    0.33159  0.33159
# 7170    0.33159  0.33159
# 7183    0.33159  0.33159
# 7200    0.33159  0.33159
# 7206    0.33159  0.33159
#
# [286 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 22.5751049542522
# [0, 4, 22.5751049542522, 'positive']
# Target positive rate for subset: 0.3126475548060708
# New threshold for subset: 0.68359375
# 1       0.500000
# 2       0.683594
# 6       0.683594
# 9       0.683594
# 11      0.683594
#           ...
# 7201    0.683594
# 7205    0.683594
# 7206    0.683594
# 7207    0.500000
# 7213    0.683594
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Iteration 1
# Subset found on iteration 1 of 10 with score 99.86067980663377 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Best score is now 99.86067980663377
# Subset found on iteration 2 of 10 with score 99.86067980663377 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 3 of 10 with score 99.86067980663377 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 4 of 10 with score 99.86067980663377 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 5 of 10 with score 99.86067980663377 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 6 of 10 with score 99.86067980663377 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 7 of 10 with score 99.86067980663377 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 8 of 10 with score 99.86067980663377 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 9 of 10 with score 99.86067980663377 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Subset found on iteration 10 of 10 with score 99.86067980663377 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 99.86067980663377 does not beat best score of 99.86067980663377
# Required time =  27.053888082504272 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Score: 99.86067980663377
# First Iteration
# Average p_delta: 0.19041533772898256
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 27    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 38    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 46    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# ...        ...       ...       ...        ...       ...                   ...
# 7152  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7160  0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 7181  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
#
#       p_hat_raw     p_hat
# 15     0.584237  0.584237
# 20     0.584237  0.584237
# 27     0.584237  0.584237
# 38     0.584237  0.584237
# 46     0.584237  0.584237
# ...         ...       ...
# 7152   0.573467  0.573467
# 7160   0.584237  0.584237
# 7181   0.573467  0.573467
# 7195   0.573467  0.573467
# 7201   0.584237  0.584237
#
# [743 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 99.86067980663377
# [0.3, 1, 99.86067980663377, 'positive']
# Target positive rate for subset: 0.5110494732404633
# New threshold for subset: 0.68359375
# 1       0.500000
# 2       0.500000
# 6       0.500000
# 9       0.500000
# 11      0.500000
#           ...
# 7201    0.683594
# 7205    0.500000
# 7206    0.500000
# 7207    0.500000
# 7213    0.500000
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 49.666885199825074 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True], 'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American']}
# Best score is now 49.666885199825074
# Subset found on iteration 2 of 10 with score 49.666885199825074 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 49.666885199825074 does not beat best score of 49.666885199825074
# Subset found on iteration 3 of 10 with score 49.666885199825074 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True], 'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American']}
# Current score of 49.666885199825074 does not beat best score of 49.666885199825074
# Subset found on iteration 4 of 10 with score 17.239541622559088 :
# {'race': ['Caucasian', 'Hispanic', 'Native American'], 'charge_degree': ['F'], 'prior_offenses': ['Over 5']}
# Current score of 17.239541622559088 does not beat best score of 49.666885199825074
# Subset found on iteration 5 of 10 with score 49.666885199825074 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 49.666885199825074 does not beat best score of 49.666885199825074
# Subset found on iteration 6 of 10 with score 49.666885199825074 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True]}
# Current score of 49.666885199825074 does not beat best score of 49.666885199825074
# Subset found on iteration 7 of 10 with score 17.239541622559088 :
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 17.239541622559088 does not beat best score of 49.666885199825074
# Subset found on iteration 8 of 10 with score 49.666885199825074 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True]}
# Current score of 49.666885199825074 does not beat best score of 49.666885199825074
# Subset found on iteration 9 of 10 with score 49.666885199825074 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True], 'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American']}
# Current score of 49.666885199825074 does not beat best score of 49.666885199825074
# Subset found on iteration 10 of 10 with score 17.239541622559088 :
# {'race': ['Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5'], 'charge_degree': ['F']}
# Current score of 17.239541622559088 does not beat best score of 49.666885199825074
# Required time =  32.72933101654053 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True], 'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American']}
# Score: 49.666885199825074
# First Iteration
# Average p_delta: 0.1426994125404181
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 9     0.625467  0.625467  0.515817   0.515817  0.109650              0.423562
# 11    0.630220  0.630220  0.515817   0.515817  0.114403              0.423562
# 21    0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 24    0.589646  0.589646  0.515817   0.515817  0.073829              0.423562
# ...        ...       ...       ...        ...       ...                   ...
# 7143  0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 7174  0.668642  0.668642  0.515817   0.515817  0.152825              0.423562
# 7190  0.630220  0.630220  0.515817   0.515817  0.114403              0.423562
# 7205  0.585145  0.585145  0.515817   0.515817  0.069328              0.423562
# 7213  0.515657  0.515657  0.515817   0.515817 -0.000160              0.423562
#
#       p_hat_raw     p_hat
# 2      0.469409  0.469409
# 9      0.456457  0.456457
# 11     0.457883  0.457883
# 21     0.469409  0.469409
# 24     0.445711  0.445711
# ...         ...       ...
# 7143   0.469409  0.469409
# 7174   0.469409  0.469409
# 7190   0.457883  0.457883
# 7205   0.444360  0.444360
# 7213   0.423514  0.423514
#
# [567 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 49.666885199825074
# [0.3, 2, 49.666885199825074, 'positive']
# Target positive rate for subset: 0.4221962507640352
# New threshold for subset: 0.68359375
# 1       0.500000
# 2       0.683594
# 6       0.500000
# 9       0.683594
# 11      0.683594
#           ...
# 7201    0.683594
# 7205    0.683594
# 7206    0.500000
# 7207    0.500000
# 7213    0.683594
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 8.822870167372436 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'charge_degree': ['F'], 'sex': ['Female']}
# Best score is now 8.822870167372436
# Subset found on iteration 2 of 10 with score 5.3619206926587735 :
# {'race': ['Caucasian', 'Hispanic'], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [True], 'charge_degree': ['F']}
# Current score of 5.3619206926587735 does not beat best score of 8.822870167372436
# Subset found on iteration 3 of 10 with score 29.740165240461486 :
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5']}
# Best score is now 29.740165240461486
# Subset found on iteration 4 of 10 with score 11.687209704488817 :
# {'race': ['African-American', 'Asian', 'Native American'], 'under_25': [False], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5']}
# Current score of 11.687209704488817 does not beat best score of 29.740165240461486
# Subset found on iteration 5 of 10 with score 14.291049349390997 :
# {'race': ['African-American', 'Asian', 'Caucasian'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [True]}
# Current score of 14.291049349390997 does not beat best score of 29.740165240461486
# Subset found on iteration 6 of 10 with score 29.740165240461486 :
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['Over 5']}
# Current score of 29.740165240461486 does not beat best score of 29.740165240461486
# Subset found on iteration 7 of 10 with score 29.740165240461486 :
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5']}
# Current score of 29.740165240461486 does not beat best score of 29.740165240461486
# Subset found on iteration 8 of 10 with score 14.291049349390997 :
# {'prior_offenses': ['None', 'Over 5'], 'under_25': [True], 'race': ['African-American', 'Asian', 'Caucasian']}
# Current score of 14.291049349390997 does not beat best score of 29.740165240461486
# Subset found on iteration 9 of 10 with score 29.740165240461486 :
# {'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5'], 'charge_degree': ['F']}
# Current score of 29.740165240461486 does not beat best score of 29.740165240461486
# Subset found on iteration 10 of 10 with score 11.687209704488817 :
# {'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Asian', 'Native American'], 'under_25': [False], 'charge_degree': ['F']}
# Current score of 11.687209704488817 does not beat best score of 29.740165240461486
# Required time =  20.922236919403076 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Native American', 'Other'], 'prior_offenses': ['Over 5']}
# Score: 29.740165240461486
# First Iteration
# Average p_delta: 0.14739324522845684
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 6     0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 18    0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 31    0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 34    0.645743  0.645743  0.515817   0.515817  0.129926              0.361427
# 52    0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# ...        ...       ...       ...        ...       ...                   ...
# 7076  0.601357  0.601357  0.515817   0.515817  0.085539              0.361427
# 7085  0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 7128  0.636604  0.636604  0.515817   0.515817  0.120787              0.361427
# 7145  0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
# 7187  0.670616  0.670616  0.515817   0.515817  0.154799              0.361427
#
#       p_hat_raw     p_hat
# 6      0.407867  0.407867
# 18     0.407867  0.407867
# 31     0.407867  0.407867
# 34     0.400405  0.400405
# 52     0.407867  0.407867
# ...         ...       ...
# 7076   0.387089  0.387089
# 7085   0.407867  0.407867
# 7128   0.397663  0.397663
# 7145   0.407867  0.407867
# 7187   0.407867  0.407867
#
# [249 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 29.740165240461486
# [0.3, 3, 29.740165240461486, 'positive']
# Target positive rate for subset: 0.3853273258065664
# New threshold for subset: 0.5912162162162162
# 1       0.500000
# 2       0.683594
# 6       0.591216
# 9       0.683594
# 11      0.683594
#           ...
# 7201    0.683594
# 7205    0.683594
# 7206    0.500000
# 7207    0.500000
# 7213    0.683594
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 16.530796102786844 :
# {'prior_offenses': ['1 to 5'], 'under_25': [False], 'race': ['African-American', 'Asian', 'Native American'], 'charge_degree': ['F']}
# Best score is now 16.530796102786844
# Subset found on iteration 2 of 10 with score 16.530796102786844 :
# {'charge_degree': ['F'], 'race': ['African-American', 'Asian', 'Native American'], 'under_25': [False], 'prior_offenses': ['1 to 5']}
# Current score of 16.530796102786844 does not beat best score of 16.530796102786844
# Subset found on iteration 3 of 10 with score 16.530796102786844 :
# {'prior_offenses': ['1 to 5'], 'charge_degree': ['F'], 'race': ['African-American', 'Asian', 'Native American'], 'under_25': [False]}
# Current score of 16.530796102786844 does not beat best score of 16.530796102786844
# Subset found on iteration 4 of 10 with score 16.530796102786844 :
# {'prior_offenses': ['1 to 5'], 'charge_degree': ['F'], 'under_25': [False], 'race': ['African-American', 'Asian', 'Native American']}
# Current score of 16.530796102786844 does not beat best score of 16.530796102786844
# Subset found on iteration 5 of 10 with score 16.530796102786844 :
# {'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Asian', 'Native American'], 'charge_degree': ['F'], 'under_25': [False]}
# Current score of 16.530796102786844 does not beat best score of 16.530796102786844
# Subset found on iteration 6 of 10 with score 18.863771206763094 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [True]}
# Best score is now 18.863771206763094
# Subset found on iteration 7 of 10 with score 16.530796102786844 :
# {'charge_degree': ['F'], 'under_25': [False], 'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Asian', 'Native American']}
# Current score of 16.530796102786844 does not beat best score of 18.863771206763094
# Subset found on iteration 8 of 10 with score 18.863771206763094 :
# {'prior_offenses': ['None', 'Over 5'], 'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'under_25': [True]}
# Current score of 18.863771206763094 does not beat best score of 18.863771206763094
# Subset found on iteration 9 of 10 with score 16.530796102786844 :
# {'prior_offenses': ['1 to 5'], 'under_25': [False], 'race': ['African-American', 'Asian', 'Native American'], 'charge_degree': ['F']}
# Current score of 16.530796102786844 does not beat best score of 18.863771206763094
# Subset found on iteration 10 of 10 with score 18.863771206763094 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [True]}
# Current score of 18.863771206763094 does not beat best score of 18.863771206763094
# Required time =  30.672065496444702 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Caucasian', 'Native American'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [True]}
# Score: 18.863771206763094
# First Iteration
# Average p_delta: 0.02663385352493651
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 103   0.836139  0.836139  0.515817   0.515817  0.320322              0.339895
# 116   0.505581  0.505581  0.515817   0.515817 -0.010236              0.339895
# 185   0.463425  0.463425  0.515817   0.515817 -0.052392              0.339895
# 196   0.505581  0.505581  0.515817   0.515817 -0.010236              0.339895
# 272   0.431060  0.431060  0.515817   0.515817 -0.084757              0.339895
# ...        ...       ...       ...        ...       ...                   ...
# 7165  0.505581  0.505581  0.515817   0.515817 -0.010236              0.339895
# 7170  0.505581  0.505581  0.515817   0.515817 -0.010236              0.339895
# 7183  0.431060  0.431060  0.515817   0.515817 -0.084757              0.339895
# 7200  0.390214  0.390214  0.515817   0.515817 -0.125603              0.339895
# 7206  0.416832  0.416832  0.515817   0.515817 -0.098985              0.339895
#
#       p_hat_raw     p_hat
# 103    0.435992  0.435992
# 116    0.336825  0.336825
# 185    0.324178  0.324178
# 196    0.336825  0.336825
# 272    0.314468  0.314468
# ...         ...       ...
# 7165   0.336825  0.336825
# 7170   0.336825  0.336825
# 7183   0.314468  0.314468
# 7200   0.302214  0.302214
# 7206   0.310200  0.310200
#
# [286 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 18.863771206763094
# [0.3, 4, 18.863771206763094, 'positive']
# Target positive rate for subset: 0.33051467026740916
# New threshold for subset: 0.68359375
# 1       0.500000
# 2       0.683594
# 6       0.591216
# 9       0.683594
# 11      0.683594
#           ...
# 7201    0.683594
# 7205    0.683594
# 7206    0.683594
# 7207    0.500000
# 7213    0.683594
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Lambda = 1
# Iteration 1
# Subset found on iteration 1 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 23.79444568654959
# Subset found on iteration 2 of 10 with score 4.30202036902124 :
# {'race': ['Caucasian'], 'under_25': [True], 'sex': ['Female']}
# Current score of 4.30202036902124 does not beat best score of 23.79444568654959
# Subset found on iteration 3 of 10 with score 23.79444568654959 :
# {'prior_offenses': ['Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 4 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 5 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 6 of 10 with score 7.708451583477554 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'charge_degree': ['F'], 'sex': ['Female']}
# Current score of 7.708451583477554 does not beat best score of 23.79444568654959
# Subset found on iteration 7 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 8 of 10 with score 7.708451583477554 :
# {'charge_degree': ['F'], 'race': ['African-American', 'Caucasian', 'Native American'], 'sex': ['Female']}
# Current score of 7.708451583477554 does not beat best score of 23.79444568654959
# Subset found on iteration 9 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 10 of 10 with score 1.7424737885021964 :
# {'race': ['Caucasian', 'Hispanic'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['M'], 'sex': ['Female']}
# Current score of 1.7424737885021964 does not beat best score of 23.79444568654959
# Required time =  22.351152420043945 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 23.79444568654959
# First Iteration
# Average p_delta: 0.19041533772898256
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 15    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 20    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 27    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 38    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 46    0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# ...        ...       ...       ...        ...       ...                   ...
# 7152  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7160  0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
# 7181  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7195  0.675094  0.675094  0.515817   0.515817  0.159277              0.525684
# 7201  0.710991  0.710991  0.515817   0.515817  0.195174              0.525684
#
#       p_hat_raw     p_hat
# 15     0.720859  0.720859
# 20     0.720859  0.720859
# 27     0.720859  0.720859
# 38     0.720859  0.720859
# 46     0.720859  0.720859
# ...         ...       ...
# 7152   0.684961  0.684961
# 7160   0.720859  0.720859
# 7181   0.684961  0.684961
# 7195   0.684961  0.684961
# 7201   0.720859  0.720859
#
# [743 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 23.79444568654959
# [1, 1, 23.79444568654959, 'positive']
# Target positive rate for subset: 0.6838278560434372
# New threshold for subset: 0.5912162162162162
# 1       0.500000
# 2       0.500000
# 6       0.500000
# 9       0.500000
# 11      0.500000
#           ...
# 7201    0.591216
# 7205    0.500000
# 7206    0.500000
# 7207    0.500000
# 7213    0.500000
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 10.258345536768275 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'under_25': [True]}
# Best score is now 10.258345536768275
# Subset found on iteration 2 of 10 with score 14.906305916421411 :
# {'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'None'], 'race': ['African-American', 'Asian', 'Native American']}
# Best score is now 14.906305916421411
# Subset found on iteration 3 of 10 with score 6.020578874343116 :
# {'race': ['Caucasian', 'Native American'], 'charge_degree': ['F'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 6.020578874343116 does not beat best score of 14.906305916421411
# Subset found on iteration 4 of 10 with score 14.906305916421411 :
# {'charge_degree': ['F'], 'race': ['African-American', 'Asian', 'Native American'], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 14.906305916421411 does not beat best score of 14.906305916421411
# Subset found on iteration 5 of 10 with score 14.329257814691298 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'prior_offenses': ['1 to 5', 'None'], 'sex': ['Female']}
# Current score of 14.329257814691298 does not beat best score of 14.906305916421411
# Subset found on iteration 6 of 10 with score 2.8390009110092196 :
# {'prior_offenses': ['Over 5'], 'charge_degree': ['M'], 'under_25': [True]}
# Current score of 2.8390009110092196 does not beat best score of 14.906305916421411
# Subset found on iteration 7 of 10 with score 14.906305916421411 :
# {'race': ['African-American', 'Asian', 'Native American'], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 14.906305916421411 does not beat best score of 14.906305916421411
# Subset found on iteration 8 of 10 with score 10.258345536768275 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'under_25': [True]}
# Current score of 10.258345536768275 does not beat best score of 14.906305916421411
# Subset found on iteration 9 of 10 with score 14.329257814691298 :
# {'sex': ['Female'], 'prior_offenses': ['1 to 5', 'None'], 'race': ['African-American', 'Caucasian', 'Native American']}
# Current score of 14.329257814691298 does not beat best score of 14.906305916421411
# Subset found on iteration 10 of 10 with score 14.329257814691298 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'sex': ['Female'], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 14.329257814691298 does not beat best score of 14.906305916421411
# Required time =  22.559383630752563 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'None'], 'race': ['African-American', 'Asian', 'Native American']}
# Score: 14.906305916421411
# First Iteration
# Average p_delta: -0.013183425065941133
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.464472
# 2     0.668642  0.668642  0.515817   0.515817  0.152825              0.464472
# 21    0.668642  0.668642  0.515817   0.515817  0.152825              0.464472
# 29    0.446022  0.446022  0.515817   0.515817 -0.069795              0.464472
# 30    0.289774  0.289774  0.515817   0.515817 -0.226043              0.464472
# ...        ...       ...       ...        ...       ...                   ...
# 7148  0.505581  0.505581  0.515817   0.515817 -0.010236              0.464472
# 7165  0.505581  0.505581  0.515817   0.515817 -0.010236              0.464472
# 7170  0.505581  0.505581  0.515817   0.515817 -0.010236              0.464472
# 7174  0.668642  0.668642  0.515817   0.515817  0.152825              0.464472
# 7183  0.431060  0.431060  0.515817   0.515817 -0.084757              0.464472
#
#       p_hat_raw     p_hat
# 1      0.238430  0.238430
# 2      0.617297  0.617297
# 21     0.617297  0.617297
# 29     0.394677  0.394677
# 30     0.238430  0.238430
# ...         ...       ...
# 7148   0.454237  0.454237
# 7165   0.454237  0.454237
# 7170   0.454237  0.454237
# 7174   0.617297  0.617297
# 7183   0.379716  0.379716
#
# [830 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.2723029133586542
# p(S): 0.5203367987752489 p(~S): 0.5203367987752509
# Subset found on iteration 1 of 10 with score 9.857258461219772 :
# {'race': ['African-American', 'Asian', 'Native American'], 'prior_offenses': ['1 to 5', 'None']}
# Best score is now 9.857258461219772
# Subset found on iteration 2 of 10 with score 6.020578874343116 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F']}
# Current score of 6.020578874343116 does not beat best score of 9.857258461219772
# Subset found on iteration 3 of 10 with score 9.857258461219772 :
# {'race': ['African-American', 'Asian', 'Native American'], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 9.857258461219772 does not beat best score of 9.857258461219772
# Subset found on iteration 4 of 10 with score 6.020578874343116 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F']}
# Current score of 6.020578874343116 does not beat best score of 9.857258461219772
# Subset found on iteration 5 of 10 with score 9.940904849539004 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'under_25': [True]}
# Best score is now 9.940904849539004
# Subset found on iteration 6 of 10 with score 1.8800395210596492 :
# {'race': ['Hispanic', 'Other'], 'under_25': [True], 'prior_offenses': ['Over 5']}
# Current score of 1.8800395210596492 does not beat best score of 9.940904849539004
# Subset found on iteration 7 of 10 with score 11.62753854727327 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'sex': ['Female'], 'prior_offenses': ['1 to 5', 'None']}
# ...
# 7000  0.380811  0.380811  0.639739   0.515817 -0.135007              0.525684
# 7056  0.421353  0.421353  0.639739   0.515817 -0.094464              0.525684
# 7206  0.416832  0.416832  0.639739   0.515817 -0.098985              0.525684
#
#       p_hat_raw  p_hat
# 85    -0.321808    0.0
# 298   -0.048781    0.0
# 453   -0.321808    0.0
# 533   -0.048781    0.0
# 541   -0.418954    0.0
# ...         ...    ...
# 6806  -0.464168    0.0
# 6967  -1.170169    0.0
# 7000  -0.824381    0.0
# 7056  -0.418954    0.0
# 7206  -0.464168    0.0
#
# [116 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.5193746609659778 p(~S): 0.5193746609659765
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 1.3225314316481545 :
# {'race': ['Asian'], 'under_25': [True]}
# Best score is now 1.3225314316481545
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 1.3225314316481545
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 1.3225314316481545
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 1.3225314316481545
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 1.3225314316481545
# Required time =  12.543374300003052 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian'], 'under_25': [True]}
# Score: 1.3225314316481545
# Average p_delta: 0.007703787697326529
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 682   0.519375  0.359564  0.643296   0.515817  0.003558              0.525684
# 5544  0.525594  0.525594  0.643296   0.515817  0.009777              0.525684
# 7091  0.525594  0.525594  0.643296   0.515817  0.009777              0.525684
#
#       p_hat_raw     p_hat
# 682    0.561260  0.561260
# 5544   0.623453  0.623453
# 7091   0.623453  0.623453
# Subset does not violate p_delta or p_censor conditions!
# Score for Positives IJDI-Scan: 1.3225314316481545
# [10, 1, 1.3225314316481545, 'positive']
# Target positive rate for subset: 0.06916084130317546
# New threshold for subset: 0.7431975838091127
# 1       0.5
# 2       0.5
# 6       0.5
# 9       0.5
# 11      0.5
#        ...
# 7201    0.5
# 7205    0.5
# 7206    0.5
# 7207    0.5
# 7213    0.5
# Name: threshold, Length: 3251, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 5926.554029366478 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False]}
# Best score is now 5926.554029366478
# Subset found on iteration 2 of 10 with score 5926.554029366478 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 3 of 10 with score 5926.554029366478 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False]}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 4 of 10 with score 5926.554029366478 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False]}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 5 of 10 with score 5926.554029366478 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False]}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 6 of 10 with score 5926.554029366478 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 7 of 10 with score 5926.554029366478 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False]}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 8 of 10 with score 5926.554029366478 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 9 of 10 with score 5926.554029366478 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Subset found on iteration 10 of 10 with score 5926.554029366478 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'None']}
# Current score of 5926.554029366478 does not beat best score of 5926.554029366478
# Required time =  20.905240297317505 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [False]}
# Score: 5926.554029366478
# First Iteration
# Average p_delta: -0.16343184040683592
# Average p_censor: 1.1092491945943344
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 1     0.289774  0.289774  0.515817   0.515817 -0.226043              0.525069
# 14    0.330519  0.330519  0.515817   0.515817 -0.185298              0.525069
# 19    0.399875  0.399875  0.515817   0.515817 -0.115942              0.525069
# 22    0.221905  0.221905  0.515817   0.515817 -0.293912              0.525069
# 29    0.446022  0.446022  0.515817   0.515817 -0.069795              0.525069
# ...        ...       ...       ...        ...       ...                   ...
# 7175  0.221905  0.221905  0.515817   0.515817 -0.293912              0.525069
# 7184  0.294272  0.294272  0.515817   0.515817 -0.221546              0.525069
# 7189  0.404766  0.404766  0.515817   0.515817 -0.111051              0.525069
# 7194  0.294272  0.294272  0.515817   0.515817 -0.221546              0.525069
# 7207  0.256285  0.256285  0.515817   0.515817 -0.259532              0.525069
#
#       p_hat_raw  p_hat
# 1     -1.735357    0.0
# 14    -1.327913    0.0
# 19    -0.634355    0.0
# 22    -2.414050    0.0
# 29    -0.172882    0.0
# ...         ...    ...
# 7175  -2.414050    0.0
# 7184  -1.690387    0.0
# 7189  -0.585441    0.0
# 7194  -1.690387    0.0
# 7207  -2.070252    0.0
#
# [1402 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.6397388958263263 p(~S): 0.6397388958263247
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 621.1979751083718 :
# {'race': ['Caucasian', 'Hispanic', 'Other'], 'under_25': [True], 'prior_offenses': ['None']}
# Best score is now 621.1979751083718
# Subset found on iteration 3 of 10 with score 621.1979751083718 :
# {'race': ['Caucasian', 'Hispanic', 'Other'], 'prior_offenses': ['None'], 'under_25': [True]}
# Current score of 621.1979751083718 does not beat best score of 621.1979751083718
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 621.1979751083718
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 621.1979751083718
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 621.1979751083718
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 621.1979751083718
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 621.1979751083718
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 621.1979751083718
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 621.1979751083718
# Required time =  11.834679365158081 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian', 'Hispanic', 'Other'], 'under_25': [True], 'prior_offenses': ['None']}
# Score: 621.1979751083718
# Average p_delta: -0.09562406866512115
# Average p_censor: 0.43117147717720283
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 85    0.431068  0.431068  0.639739   0.515817 -0.084749              0.525069
# 298   0.458371  0.458371  0.639739   0.515817 -0.057447              0.525069
# 453   0.431068  0.431068  0.639739   0.515817 -0.084749              0.525069
# 533   0.458371  0.458371  0.639739   0.515817 -0.057447              0.525069
# 541   0.421353  0.421353  0.639739   0.515817 -0.094464              0.525069
# ...        ...       ...       ...        ...       ...                   ...
# 6806  0.416832  0.416832  0.639739   0.515817 -0.098985              0.525069
# 6967  0.346232  0.346232  0.639739   0.515817 -0.169585              0.525069
# 7000  0.380811  0.380811  0.639739   0.515817 -0.135007              0.525069
# 7056  0.421353  0.421353  0.639739   0.515817 -0.094464              0.525069
# 7206  0.416832  0.416832  0.639739   0.515817 -0.098985              0.525069
#
#       p_hat_raw  p_hat
# 85    -0.322424    0.0
# 298   -0.049396    0.0
# 453   -0.322424    0.0
# 533   -0.049396    0.0
# 541   -0.419569    0.0
# ...         ...    ...
# 6806  -0.464783    0.0
# 6967  -1.170784    0.0
# 7000  -0.824996    0.0
# 7056  -0.419569    0.0
# 7206  -0.464783    0.0
#
# [115 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.5193237009083926 p(~S): 0.5193237009083916
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 111.12203070166082 :
# {'race': ['African-American'], 'charge_degree': ['M'], 'prior_offenses': ['None'], 'under_25': [True]}
# Best score is now 111.12203070166082
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 111.12203070166082
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 111.12203070166082
# Subset found on iteration 10 of 10 with score 193.01714781149346 :
# {'race': ['African-American'], 'sex': ['Female'], 'prior_offenses': ['None'], 'under_25': [True]}
# Best score is now 193.01714781149346
# Required time =  12.764464378356934 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'sex': ['Female'], 'prior_offenses': ['None'], 'under_25': [True]}
# Score: 193.01714781149346
# Average p_delta: -0.09973376457676496
# Average p_censor: 0.4722684362936413
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 272   0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 336   0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 359   0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 842   0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 1296  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 1514  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 1861  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 2551  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 2705  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 3580  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 3861  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 3932  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 3936  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 3969  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 4237  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 4426  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 4574  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 4679  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 4921  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 5072  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 5236  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 5359  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 5717  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 6282  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 6413  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 6550  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
# 6905  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 7079  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 7183  0.431060  0.431060  0.643246   0.515817 -0.084757              0.525069
# 7200  0.390214  0.390214  0.643246   0.515817 -0.125603              0.525069
#
#       p_hat_raw  p_hat
# 272   -0.322497    0.0
# 336   -0.322497    0.0
# 359   -0.322497    0.0
# 842   -0.730965    0.0
# 1296  -0.322497    0.0
# 1514  -0.322497    0.0
# 1861  -0.730965    0.0
# 2551  -0.322497    0.0
# 2705  -0.730965    0.0
# 3580  -0.322497    0.0
# 3861  -0.322497    0.0
# 3932  -0.322497    0.0
# 3936  -0.322497    0.0
# 3969  -0.322497    0.0
# 4237  -0.322497    0.0
# 4426  -0.730965    0.0
# 4574  -0.730965    0.0
# 4679  -0.730965    0.0
# 4921  -0.322497    0.0
# 5072  -0.322497    0.0
# 5236  -0.322497    0.0
# 5359  -0.730965    0.0
# 5717  -0.730965    0.0
# 6282  -0.730965    0.0
# 6413  -0.322497    0.0
# 6550  -0.730965    0.0
# 6905  -0.322497    0.0
# 7079  -0.322497    0.0
# 7183  -0.322497    0.0
# 7200  -0.730965    0.0
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.5167459865760268 p(~S): 0.516745986576027
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  13.111152172088623 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Score for Positives IJDI-Scan: 0.0
# [10, 2, 0.0, 'positive']
#
# ----------------------------------------------------

# %%
columns = ['lambda', 'iteration', 'score', 'scan_type']
mit_result_df = pd.DataFrame(sim_data, columns=columns)
mit_result_df
# Out:
#     lambda  iteration       score scan_type
# 0      0.0          1  146.346978  positive
# 1      0.0          2   72.243374  positive
# 2      0.0          3   42.166561  positive
# 3      0.0          4   22.575105  positive
# 4      0.3          1   99.860680  positive
# 5      0.3          2   49.666885  positive
# 6      0.3          3   29.740165  positive
# 7      0.3          4   18.863771  positive
# 8      1.0          1   23.794446  positive
# 9      1.0          2    9.018073  positive
# 10     1.0          3    4.435142  positive
# 11     1.0          4    3.313294  positive
# 12     3.0          1    1.632526  positive
# 13     3.0          2    1.476817  positive
# 14     3.0          3    1.967325  positive
# 15     3.0          4    0.218129  positive
# 16    10.0          1    1.322531  positive
# 17    10.0          2    0.000000  positive

# %%
# Write recipe outputs
mit_result_df.to_csv(home_dir + "datasets/compas_mit_2_pos.csv")
