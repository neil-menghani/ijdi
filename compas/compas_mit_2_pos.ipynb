# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
import pandas as pd, numpy as np

os.chdir('../') # cd back to parent dir
home_dir = "compas/" # set home dir for reading and storing data

# Read recipe inputs
compas_mit_df = pd.read_csv(home_dir + "datasets/compas_prep.csv")
compas_mit_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
# [7214 rows x 10 columns]

# %% [markdown]
# Test running positive IJDI-Scan once.

# %%
PROBA_CONFUSION_COL = 'proba_compas'
PROBA_IJDI_COL = 'proba_lr'
OUTCOMES_COL = 'outcomes'
FEATURES = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
THRESHOLD = 0.5
LAMBDA_PARAM = 1
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# %%
# filter for only positive outcomes
positives_df = compas_mit_df.loc[compas_mit_df[OUTCOMES_COL] == 1]

# scan with positive direction
current_subset, current_score = run_ijdi_scan(positives_df, FEATURES, PROBA_CONFUSION_COL, PROBA_IJDI_COL, OUTCOMES_COL,
                                              THRESHOLD, LAMBDA_PARAM)
# summarize_scan(positives_df, FEATURES, PROBA_COL, OUTCOMES_COL, current_subset, include='all')\
current_subset, current_score
# Out:
# Subset found on iteration 1 of 10 with score 7.708451583477554 :
# {'race': ['African-American', 'Caucasian', 'Native American'], 'sex': ['Female'], 'charge_degree': ['F']}
# Best score is now 7.708451583477554
# Subset found on iteration 2 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 23.79444568654959
# Subset found on iteration 3 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 4 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 5 of 10 with score 1.7424737885021964 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True], 'race': ['Caucasian', 'Hispanic'], 'sex': ['Female'], 'charge_degree': ['M']}
# Current score of 1.7424737885021964 does not beat best score of 23.79444568654959
# Subset found on iteration 6 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 7 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 8 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 9 of 10 with score 23.79444568654959 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 23.79444568654959 does not beat best score of 23.79444568654959
# Subset found on iteration 10 of 10 with score 7.708451583477554 :
# {'charge_degree': ['F'], 'race': ['African-American', 'Caucasian', 'Native American'], 'sex': ['Female']}
# Current score of 7.708451583477554 does not beat best score of 23.79444568654959
# Required time =  20.30499839782715 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 23.79444568654959
# First Iteration
# Average p_delta: 0.19041533772898256
# Average p_censor: 0.0
# Subset does not violate p_delta or p_censor conditions!
# ({'race': ['African-American', 'Native American'],
#   'prior_offenses': ['Over 5']},
#  23.79444568654959)

# %% [markdown]
# ### Implement Mitigation Approach 2

# %% [markdown]
# Set lambda vales to test.

# %%
lambda_vals = [0, 0.3, 1, 3, 10]

# specify parameters for generating metrics and IJDI scan
proba_confusion_col = 'proba_compas'
proba_ijdi_col = 'proba_lr'
outcomes_col = 'outcomes'
features = ['sex', 'race', 'under_25', 'charge_degree', 'prior_offenses']
threshold = 'threshold'

# define stopping criteria
stop_limit = 0
max_iters = 3

pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(100)

# %%
sim_data = []

# %% [markdown]
# Implement approach for negatives

# %%
# filter for negative or positive outcomes
negatives_df = compas_mit_df.loc[compas_mit_df[outcomes_col] == 0]

for lambda_param in lambda_vals: # run IJDI scan for various lambda values

    print("Lambda =", lambda_param)

    i = 0
    ijdi_present = True
    # set initial threshold
    negatives_df['threshold'] = 0.5

    while ijdi_present and i <= max_iters:

        i += 1
        print("Iteration", i)

        # Run Negative or Positive IJDI Scan. Make sure to pass in copy because data may be modified by the function!
        current_subset, current_score = run_ijdi_scan(negatives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                      threshold, lambda_param, constant_threshold=False, verbose=True)

        print("Score for Negative IJDI-Scan:", current_score)

        # append data
        row = [lambda_param, i, current_score, 'negative']
        sim_data.append(row)

        print(row)

        if current_score > stop_limit:

            # correct IJDI by setting new threshold for subset
            negatives_df['threshold'] = correct_ijdi_subset(negatives_df.copy(deep=True), features,
                                                            proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                            threshold, lambda_param, current_subset)
            print(negatives_df['threshold'])

        else:
            ijdi_present = False

        print("\n----------------------------------------------------\n")
# Out:
# Lambda = 0
# Iteration 1
# Subset found on iteration 1 of 10 with score 63.09047814987018 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Best score is now 63.09047814987018
# Subset found on iteration 2 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 135.67766400191496
# Subset found on iteration 3 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 4 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 5 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 6 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 7 of 10 with score 63.09047814987018 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 63.09047814987018 does not beat best score of 135.67766400191496
# Subset found on iteration 8 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 9 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Subset found on iteration 10 of 10 with score 135.67766400191496 :
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 135.67766400191496 does not beat best score of 135.67766400191496
# Required time =  22.118273735046387 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Caucasian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 135.67766400191496
# First Iteration
# Average p_delta: 0.28595028512231835
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 35    0.632297  0.632297  0.397193   0.397193  0.235104              0.233914
# 43    0.645737  0.645737  0.397193   0.397193  0.248544              0.233914
# 54    0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 58    0.670616  0.670616  0.397193   0.397193  0.273423              0.233914
# 93    0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7101  0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# 7131  0.670616  0.670616  0.397193   0.397193  0.273423              0.233914
# 7136  0.632297  0.632297  0.397193   0.397193  0.235104              0.233914
# 7173  0.670616  0.670616  0.397193   0.397193  0.273423              0.233914
# 7186  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
#
#       p_hat_raw     p_hat
# 35     0.233914  0.233914
# 43     0.233914  0.233914
# 54     0.233914  0.233914
# 58     0.233914  0.233914
# 93     0.233914  0.233914
# ...         ...       ...
# 7101   0.233914  0.233914
# 7131   0.233914  0.233914
# 7136   0.233914  0.233914
# 7173   0.233914  0.233914
# 7186   0.233914  0.233914
#
# [464 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 135.67766400191496
# [0, 1, 135.67766400191496, 'negative']
# Target positive rate for subset: 0.18633895398685338
# New threshold for subset: 0.6946329610766176
# 0       0.5
# 3       0.5
# 4       0.5
# 5       0.5
# 7       0.5
#        ...
# 7208    0.5
# 7209    0.5
# 7210    0.5
# 7211    0.5
# 7212    0.5
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Best score is now 83.33495229114686
# Subset found on iteration 2 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 3 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 4 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 5 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 6 of 10 with score 1.4794543095995156 :
# {'race': ['Native American'], 'prior_offenses': ['Over 5']}
# Current score of 1.4794543095995156 does not beat best score of 83.33495229114686
# Subset found on iteration 7 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 8 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 9 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Subset found on iteration 10 of 10 with score 83.33495229114686 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 83.33495229114686 does not beat best score of 83.33495229114686
# Required time =  26.70301866531372 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Score: 83.33495229114686
# First Iteration
# Average p_delta: 0.13172521854970987
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.186475
# 23    0.385384  0.385384  0.397193   0.397193 -0.011808              0.186475
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.186475
# 71    0.589646  0.589646  0.397193   0.397193  0.192453              0.186475
# 77    0.458371  0.458371  0.397193   0.397193  0.061178              0.186475
# ...        ...       ...       ...        ...       ...                   ...
# 7178  0.553041  0.553041  0.397193   0.397193  0.155849              0.186475
# 7199  0.458371  0.458371  0.397193   0.397193  0.061178              0.186475
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.186475
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.186475
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.186475
#
#       p_hat_raw     p_hat
# 3      0.186475  0.186475
# 23     0.186475  0.186475
# 40     0.186475  0.186475
# 71     0.186475  0.186475
# 77     0.186475  0.186475
# ...         ...       ...
# 7178   0.186475  0.186475
# 7199   0.186475  0.186475
# 7208   0.186475  0.186475
# 7209   0.186475  0.186475
# 7210   0.186475  0.186475
#
# [661 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 83.33495229114686
# [0, 2, 83.33495229114686, 'negative']
# Target positive rate for subset: 0.14294367050272563
# New threshold for subset: 0.68359375
# 0       0.500000
# 3       0.683594
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.500000
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 47.90584659427634 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'race': ['African-American', 'Native American']}
# Best score is now 47.90584659427634
# Subset found on iteration 2 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 3 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 4 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 5 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 6 of 10 with score 8.940896647544173 :
# {'race': ['African-American', 'Caucasian'], 'sex': ['Male'], 'under_25': [True], 'prior_offenses': ['Over 5']}
# Current score of 8.940896647544173 does not beat best score of 47.90584659427634
# Subset found on iteration 7 of 10 with score 47.90584659427634 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False]}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 8 of 10 with score 8.940896647544173 :
# {'sex': ['Male'], 'race': ['African-American', 'Caucasian'], 'under_25': [True], 'prior_offenses': ['Over 5']}
# Current score of 8.940896647544173 does not beat best score of 47.90584659427634
# Subset found on iteration 9 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Subset found on iteration 10 of 10 with score 47.90584659427634 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['African-American', 'Native American']}
# Current score of 47.90584659427634 does not beat best score of 47.90584659427634
# Required time =  22.689836025238037 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'race': ['African-American', 'Native American']}
# Score: 47.90584659427634
# First Iteration
# Average p_delta: 0.09762220417961803
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 17    0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 41    0.404766  0.404766  0.397193   0.397193  0.007573              0.137017
# 43    0.645737  0.645737  0.397193   0.397193  0.248544              0.137017
# 54    0.710991  0.710991  0.397193   0.397193  0.313799              0.137017
# 57    0.404766  0.404766  0.397193   0.397193  0.007573              0.137017
# ...        ...       ...       ...        ...       ...                   ...
# 7193  0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 7197  0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 7198  0.446022  0.446022  0.397193   0.397193  0.048829              0.137017
# 7204  0.404766  0.404766  0.397193   0.397193  0.007573              0.137017
# 7212  0.335035  0.335035  0.397193   0.397193 -0.062157              0.137017
#
#       p_hat_raw     p_hat
# 17     0.137017  0.137017
# 41     0.137017  0.137017
# 43     0.137017  0.137017
# 54     0.137017  0.137017
# 57     0.137017  0.137017
# ...         ...       ...
# 7193   0.137017  0.137017
# 7197   0.137017  0.137017
# 7198   0.137017  0.137017
# 7204   0.137017  0.137017
# 7212   0.137017  0.137017
#
# [1061 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 47.90584659427634
# [0, 3, 47.90584659427634, 'negative']
# Target positive rate for subset: 0.0954514128187457
# New threshold for subset: 0.6988188976377953
# 0       0.500000
# 3       0.683594
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 4
# Subset found on iteration 1 of 10 with score 11.389877671168918 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'race': ['African-American', 'Hispanic', 'Other'], 'under_25': [True]}
# Best score is now 11.389877671168918
# Subset found on iteration 2 of 10 with score 8.419580624798622 :
# {'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic', 'Other'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 8.419580624798622 does not beat best score of 11.389877671168918
# Subset found on iteration 3 of 10 with score 11.389877671168918 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'under_25': [True], 'race': ['African-American', 'Hispanic', 'Other']}
# Current score of 11.389877671168918 does not beat best score of 11.389877671168918
# Subset found on iteration 4 of 10 with score 6.523468353186145 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'sex': ['Female'], 'race': ['Caucasian']}
# Current score of 6.523468353186145 does not beat best score of 11.389877671168918
# Subset found on iteration 5 of 10 with score 6.938706150335794 :
# {'prior_offenses': ['None'], 'race': ['African-American'], 'under_25': [False]}
# Current score of 6.938706150335794 does not beat best score of 11.389877671168918
# Subset found on iteration 6 of 10 with score 6.645528797240878 :
# {'prior_offenses': ['None'], 'under_25': [False], 'charge_degree': ['F'], 'race': ['African-American', 'Asian']}
# Current score of 6.645528797240878 does not beat best score of 11.389877671168918
# Subset found on iteration 7 of 10 with score 12.494789164709807 :
# {'race': ['African-American', 'Caucasian'], 'prior_offenses': ['Over 5'], 'under_25': [True], 'sex': ['Male']}
# Best score is now 12.494789164709807
# Subset found on iteration 8 of 10 with score 6.523468353186145 :
# {'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian'], 'sex': ['Female'], 'under_25': [False]}
# Current score of 6.523468353186145 does not beat best score of 12.494789164709807
# Subset found on iteration 9 of 10 with score 12.494789164709807 :
# {'sex': ['Male'], 'under_25': [True], 'race': ['African-American', 'Caucasian'], 'prior_offenses': ['Over 5']}
# Current score of 12.494789164709807 does not beat best score of 12.494789164709807
# Subset found on iteration 10 of 10 with score 6.523468353186145 :
# {'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'sex': ['Female'], 'under_25': [False], 'race': ['Caucasian']}
# Current score of 6.523468353186145 does not beat best score of 12.494789164709807
# Required time =  18.8019757270813 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian'], 'prior_offenses': ['Over 5'], 'under_25': [True], 'sex': ['Male']}
# Score: 12.494789164709807
# First Iteration
# Average p_delta: 0.44527102666057083
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 466   0.860447  0.860447  0.397193   0.397193  0.463254              0.080999
# 858   0.838907  0.838907  0.397193   0.397193  0.441715              0.080999
# 1335  0.860447  0.860447  0.397193   0.397193  0.463254              0.080999
# 2908  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 3407  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 5821  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 5860  0.838907  0.838907  0.397193   0.397193  0.441715              0.080999
# 5947  0.836139  0.836139  0.397193   0.397193  0.438947              0.080999
# 6940  0.838907  0.838907  0.397193   0.397193  0.441715              0.080999
#
#       p_hat_raw     p_hat
# 466    0.080999  0.080999
# 858    0.080999  0.080999
# 1335   0.080999  0.080999
# 2908   0.080999  0.080999
# 3407   0.080999  0.080999
# 5821   0.080999  0.080999
# 5860   0.080999  0.080999
# 5947   0.080999  0.080999
# 6940   0.080999  0.080999
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 12.494789164709807
# [0, 4, 12.494789164709807, 'negative']
# Target positive rate for subset: 0.07941325240263025
# New threshold for subset: 0.7728459530026109
# 0       0.500000
# 3       0.683594
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 5
# Subset found on iteration 1 of 10 with score 6.812737181858715 :
# {'under_25': [False], 'race': ['Caucasian'], 'prior_offenses': ['1 to 5', 'Over 5'], 'sex': ['Female'], 'charge_degree': ['F']}
# Best score is now 6.812737181858715
# Subset found on iteration 2 of 10 with score 10.79359394404247 :
# {'race': ['African-American', 'Hispanic', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Best score is now 10.79359394404247
# Subset found on iteration 3 of 10 with score 6.812737181858715 :
# {'under_25': [False], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian'], 'sex': ['Female']}
# Current score of 6.812737181858715 does not beat best score of 10.79359394404247
# Subset found on iteration 4 of 10 with score 10.79359394404247 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'race': ['African-American', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 10.79359394404247 does not beat best score of 10.79359394404247
# Subset found on iteration 5 of 10 with score 6.812737181858715 :
# {'under_25': [False], 'charge_degree': ['F'], 'sex': ['Female'], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian']}
# Current score of 6.812737181858715 does not beat best score of 10.79359394404247
# Subset found on iteration 6 of 10 with score 6.812737181858715 :
# {'charge_degree': ['F'], 'race': ['Caucasian'], 'sex': ['Female'], 'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 6.812737181858715 does not beat best score of 10.79359394404247
# Subset found on iteration 7 of 10 with score 7.77470648463637 :
# {'race': ['Caucasian', 'Hispanic', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 7.77470648463637 does not beat best score of 10.79359394404247
# Subset found on iteration 8 of 10 with score 7.77470648463637 :
# {'race': ['Caucasian', 'Hispanic', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 7.77470648463637 does not beat best score of 10.79359394404247
# Subset found on iteration 9 of 10 with score 10.79359394404247 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True], 'race': ['African-American', 'Hispanic', 'Other'], 'charge_degree': ['F']}
# Current score of 10.79359394404247 does not beat best score of 10.79359394404247
# Subset found on iteration 10 of 10 with score 10.79359394404247 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'under_25': [True], 'race': ['African-American', 'Hispanic', 'Other']}
# Current score of 10.79359394404247 does not beat best score of 10.79359394404247
# Required time =  18.968518257141113 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Hispanic', 'Other'], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Score: 10.79359394404247
# First Iteration
# Average p_delta: 0.24847658972669295
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.079233
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.079233
# 71    0.589646  0.589646  0.397193   0.397193  0.192453              0.079233
# 100   0.668642  0.668642  0.397193   0.397193  0.271449              0.079233
# 142   0.599215  0.599215  0.397193   0.397193  0.202023              0.079233
# ...        ...       ...       ...        ...       ...                   ...
# 6947  0.668642  0.668642  0.397193   0.397193  0.271449              0.079233
# 6963  0.599223  0.599223  0.397193   0.397193  0.202030              0.079233
# 7097  0.599215  0.599215  0.397193   0.397193  0.202023              0.079233
# 7099  0.589646  0.589646  0.397193   0.397193  0.192453              0.079233
# 7158  0.668642  0.668642  0.397193   0.397193  0.271449              0.079233
#
#       p_hat_raw     p_hat
# 3      0.079233  0.079233
# 40     0.079233  0.079233
# 71     0.079233  0.079233
# 100    0.079233  0.079233
# 142    0.079233  0.079233
# ...         ...       ...
# 6947   0.079233  0.079233
# 6963   0.079233  0.079233
# 7097   0.079233  0.079233
# 7099   0.079233  0.079233
# 7158   0.079233  0.079233
#
# [161 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 10.79359394404247
# [0, 5, 10.79359394404247, 'negative']
# Target positive rate for subset: 0.07417148869016307
# New threshold for subset: 0.6988188976377953
# 0       0.500000
# 3       0.698819
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 6
# Subset found on iteration 1 of 10 with score 9.125788601959856 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic']}
# Best score is now 9.125788601959856
# Subset found on iteration 2 of 10 with score 5.052277486896624 :
# {'race': ['African-American', 'Asian', 'Caucasian'], 'under_25': [False], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F']}
# Current score of 5.052277486896624 does not beat best score of 9.125788601959856
# Subset found on iteration 3 of 10 with score 9.125788601959856 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F'], 'race': ['Caucasian', 'Hispanic'], 'under_25': [False]}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 4 of 10 with score 9.125788601959856 :
# {'race': ['Caucasian', 'Hispanic'], 'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F']}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 5 of 10 with score 9.729570583143342 :
# {'race': ['African-American'], 'under_25': [False], 'prior_offenses': ['None']}
# Best score is now 9.729570583143342
# Subset found on iteration 6 of 10 with score 5.052277486896624 :
# {'race': ['African-American', 'Asian', 'Caucasian'], 'under_25': [False], 'charge_degree': ['F'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 5.052277486896624 does not beat best score of 9.729570583143342
# Subset found on iteration 7 of 10 with score 9.125788601959856 :
# {'race': ['Caucasian', 'Hispanic'], 'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F']}
# Current score of 9.125788601959856 does not beat best score of 9.729570583143342
# Subset found on iteration 8 of 10 with score 5.052277486896624 :
# {'race': ['African-American', 'Asian', 'Caucasian'], 'charge_degree': ['F'], 'under_25': [False], 'prior_offenses': ['None', 'Over 5']}
# Current score of 5.052277486896624 does not beat best score of 9.729570583143342
# Subset found on iteration 9 of 10 with score 5.052277486896624 :
# {'race': ['African-American', 'Asian', 'Caucasian'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [False], 'charge_degree': ['F']}
# Current score of 5.052277486896624 does not beat best score of 9.729570583143342
# Subset found on iteration 10 of 10 with score 9.125788601959856 :
# {'race': ['Caucasian', 'Hispanic'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'charge_degree': ['F']}
# Current score of 9.125788601959856 does not beat best score of 9.729570583143342
# Required time =  20.44646954536438 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'under_25': [False], 'prior_offenses': ['None']}
# Score: 9.729570583143342
# First Iteration
# Average p_delta: -0.1385437443393067
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.072672
# 49    0.289774  0.289774  0.397193   0.397193 -0.107418              0.072672
# 69    0.203393  0.203393  0.397193   0.397193 -0.193799              0.072672
# 80    0.289774  0.289774  0.397193   0.397193 -0.107418              0.072672
# 206   0.256285  0.256285  0.397193   0.397193 -0.140908              0.072672
# ...        ...       ...       ...        ...       ...                   ...
# 7061  0.289774  0.289774  0.397193   0.397193 -0.107418              0.072672
# 7112  0.289774  0.289774  0.397193   0.397193 -0.107418              0.072672
# 7124  0.256285  0.256285  0.397193   0.397193 -0.140908              0.072672
# 7156  0.256285  0.256285  0.397193   0.397193 -0.140908              0.072672
# 7196  0.256285  0.256285  0.397193   0.397193 -0.140908              0.072672
#
#       p_hat_raw     p_hat
# 13     0.072672  0.072672
# 49     0.072672  0.072672
# 69     0.072672  0.072672
# 80     0.072672  0.072672
# 206    0.072672  0.072672
# ...         ...       ...
# 7061   0.072672  0.072672
# 7112   0.072672  0.072672
# 7124   0.072672  0.072672
# 7156   0.072672  0.072672
# 7196   0.072672  0.072672
#
# [381 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.41192891064672693 p(~S): 0.411928910646726
# Subset found on iteration 1 of 10 with score 5.052277486896624 :
# {'race': ['African-American', 'Asian', 'Caucasian'], 'charge_degree': ['F'], 'prior_offenses': ['None', 'Over 5'], 'under_25': [False]}
# Best score is now 5.052277486896624
# Subset found on iteration 2 of 10 with score 5.052277486896624 :
# {'race': ['African-American', 'Asian', 'Caucasian'], 'under_25': [False], 'charge_degree': ['F'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 5.052277486896624 does not beat best score of 5.052277486896624
# Subset found on iteration 3 of 10 with score 9.125788601959856 :
# {'under_25': [False], 'race': ['Caucasian', 'Hispanic'], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Best score is now 9.125788601959856
# Subset found on iteration 4 of 10 with score 9.125788601959856 :
# {'race': ['Caucasian', 'Hispanic'], 'under_25': [False], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 5 of 10 with score 9.125788601959856 :
# {'race': ['Caucasian', 'Hispanic'], 'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F']}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 6 of 10 with score 9.125788601959856 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian', 'Hispanic'], 'charge_degree': ['F'], 'under_25': [False]}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 7 of 10 with score 9.125788601959856 :
# {'under_25': [False], 'charge_degree': ['F'], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian', 'Hispanic']}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 8 of 10 with score 9.125788601959856 :
# {'race': ['Caucasian', 'Hispanic'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'charge_degree': ['F']}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 9 of 10 with score 9.125788601959856 :
# {'under_25': [False], 'race': ['Caucasian', 'Hispanic'], 'prior_offenses': ['1 to 5', 'Over 5'], 'charge_degree': ['F']}
# Current score of 9.125788601959856 does not beat best score of 9.125788601959856
# Subset found on iteration 10 of 10 with score 9.729570583143342 :
# {'race': ['African-American'], 'under_25': [False], 'prior_offenses': ['None']}
# Best score is now 9.729570583143342
# Required time =  22.48769736289978 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American'], 'under_25': [False], 'prior_offenses': ['None']}
# Score: 9.729570583143342
# Average p_delta: 0.01473622741297446
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13    0.411929  0.289774  0.411929   0.397193  0.014736              0.072672
# 49    0.411929  0.289774  0.411929   0.397193  0.014736              0.072672
# 69    0.411929  0.203393  0.411929   0.397193  0.014736              0.072672
# 80    0.411929  0.289774  0.411929   0.397193  0.014736              0.072672
# 206   0.411929  0.256285  0.411929   0.397193  0.014736              0.072672
# ...        ...       ...       ...        ...       ...                   ...
# 7061  0.411929  0.289774  0.411929   0.397193  0.014736              0.072672
# 7112  0.411929  0.289774  0.411929   0.397193  0.014736              0.072672
# 7124  0.411929  0.256285  0.411929   0.397193  0.014736              0.072672
# 7156  0.411929  0.256285  0.411929   0.397193  0.014736              0.072672
# 7196  0.411929  0.256285  0.411929   0.397193  0.014736              0.072672
#
#       p_hat_raw     p_hat
# 13     0.072672  0.072672
# 49     0.072672  0.072672
# 69     0.072672  0.072672
# 80     0.072672  0.072672
# 206    0.072672  0.072672
# ...         ...       ...
# 7061   0.072672  0.072672
# 7112   0.072672  0.072672
# 7124   0.072672  0.072672
# 7156   0.072672  0.072672
# 7196   0.072672  0.072672
#
# [381 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 9.729570583143342
# [0, 6, 9.729570583143342, 'negative']
# Target positive rate for subset: 0.06560580681183696
# New threshold for subset: 0.68359375
# 0       0.500000
# 3       0.698819
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 7
# Subset found on iteration 1 of 10 with score 15.651041673308159 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'race': ['Caucasian', 'Hispanic', 'Other']}
# Best score is now 15.651041673308159
# Subset found on iteration 2 of 10 with score 15.651041673308159 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian', 'Hispanic', 'Other']}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 3 of 10 with score 15.651041673308159 :
# {'race': ['Caucasian', 'Hispanic', 'Other'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False]}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 4 of 10 with score 15.651041673308159 :
# {'race': ['Caucasian', 'Hispanic', 'Other'], 'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False]}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 5 of 10 with score 15.651041673308159 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian', 'Hispanic', 'Other']}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 6 of 10 with score 15.651041673308159 :
# {'under_25': [False], 'race': ['Caucasian', 'Hispanic', 'Other'], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 7 of 10 with score 15.651041673308159 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian', 'Hispanic', 'Other']}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 8 of 10 with score 15.651041673308159 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian', 'Hispanic', 'Other'], 'under_25': [False]}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 9 of 10 with score 15.651041673308159 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'race': ['Caucasian', 'Hispanic', 'Other']}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Subset found on iteration 10 of 10 with score 15.651041673308159 :
# {'under_25': [False], 'prior_offenses': ['1 to 5', 'Over 5'], 'race': ['Caucasian', 'Hispanic', 'Other']}
# Current score of 15.651041673308159 does not beat best score of 15.651041673308159
# Required time =  28.56207299232483 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [False], 'race': ['Caucasian', 'Hispanic', 'Other']}
# Score: 15.651041673308159
# First Iteration
# Average p_delta: 0.005608514721268252
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 4     0.373653  0.373653  0.397193   0.397193 -0.023540              0.063084
# 7     0.373653  0.373653  0.397193   0.397193 -0.023540              0.063084
# 25    0.360113  0.360113  0.397193   0.397193 -0.037080              0.063084
# 28    0.330519  0.330519  0.397193   0.397193 -0.066674              0.063084
# 35    0.632297  0.632297  0.397193   0.397193  0.235104              0.063084
# ...        ...       ...       ...        ...       ...                   ...
# 7179  0.330519  0.330519  0.397193   0.397193 -0.066674              0.063084
# 7180  0.294272  0.294272  0.397193   0.397193 -0.102921              0.063084
# 7182  0.330519  0.330519  0.397193   0.397193 -0.066674              0.063084
# 7185  0.399875  0.399875  0.397193   0.397193  0.002682              0.063084
# 7191  0.399875  0.399875  0.397193   0.397193  0.002682              0.063084
#
#       p_hat_raw     p_hat
# 4      0.063084  0.063084
# 7      0.063084  0.063084
# 25     0.063084  0.063084
# 28     0.063084  0.063084
# 35     0.063084  0.063084
# ...         ...       ...
# 7179   0.063084  0.063084
# 7180   0.063084  0.063084
# 7182   0.063084  0.063084
# 7185   0.063084  0.063084
# 7191   0.063084  0.063084
#
# [1067 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 15.651041673308159
# [0, 7, 15.651041673308159, 'negative']
# Target positive rate for subset: 0.045925414364640885
# New threshold for subset: 0.68359375
# 0       0.500000
# 3       0.698819
# 4       0.683594
# 5       0.500000
# 7       0.683594
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 8
# Subset found on iteration 1 of 10 with score 2.2481168090466417 :
# {'sex': ['Male'], 'under_25': [True], 'prior_offenses': ['None']}
# Best score is now 2.2481168090466417
# Subset found on iteration 2 of 10 with score 8.523768134525486 :
# {'under_25': [False], 'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['Over 5']}
# Best score is now 8.523768134525486
# Subset found on iteration 3 of 10 with score 6.272854239868501 :
# {'sex': ['Female'], 'under_25': [False], 'race': ['Caucasian'], 'prior_offenses': ['None', 'Over 5']}
# Current score of 6.272854239868501 does not beat best score of 8.523768134525486
# Subset found on iteration 4 of 10 with score 2.2481168090466417 :
# {'sex': ['Male'], 'prior_offenses': ['None'], 'under_25': [True]}
# Current score of 2.2481168090466417 does not beat best score of 8.523768134525486
# Subset found on iteration 5 of 10 with score 8.523768134525486 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'under_25': [False], 'prior_offenses': ['Over 5']}
# Current score of 8.523768134525486 does not beat best score of 8.523768134525486
# Subset found on iteration 6 of 10 with score 1.9837732211353731 :
# {'prior_offenses': ['1 to 5', 'None'], 'under_25': [True], 'sex': ['Male'], 'race': ['Caucasian', 'Hispanic', 'Other'], 'charge_degree': ['F']}
# Current score of 1.9837732211353731 does not beat best score of 8.523768134525486
# Subset found on iteration 7 of 10 with score 2.2481168090466417 :
# {'sex': ['Male'], 'prior_offenses': ['None'], 'under_25': [True]}
# Current score of 2.2481168090466417 does not beat best score of 8.523768134525486
# Subset found on iteration 8 of 10 with score 2.2481168090466417 :
# {'sex': ['Male'], 'under_25': [True], 'prior_offenses': ['None']}
# Current score of 2.2481168090466417 does not beat best score of 8.523768134525486
# Subset found on iteration 9 of 10 with score 2.2481168090466417 :
# {'sex': ['Male'], 'under_25': [True], 'prior_offenses': ['None']}
# Current score of 2.2481168090466417 does not beat best score of 8.523768134525486
# Subset found on iteration 10 of 10 with score 9.023517035608668 :
# {'race': ['Asian', 'Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F']}
# Best score is now 9.023517035608668
# Required time =  18.001922607421875 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Caucasian', 'Hispanic'], 'prior_offenses': ['None', 'Over 5'], 'charge_degree': ['F']}
# Score: 9.023517035608668
# First Iteration
# Average p_delta: -0.02612932545433599
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 10    0.252427  0.252427  0.397193   0.397193 -0.144766              0.043149
# 23    0.385384  0.385384  0.397193   0.397193 -0.011808              0.043149
# 33    0.252427  0.252427  0.397193   0.397193 -0.144766              0.043149
# 58    0.670616  0.670616  0.397193   0.397193  0.273423              0.043149
# 77    0.458371  0.458371  0.397193   0.397193  0.061178              0.043149
# ...        ...       ...       ...        ...       ...                   ...
# 7173  0.670616  0.670616  0.397193   0.397193  0.273423              0.043149
# 7192  0.252427  0.252427  0.397193   0.397193 -0.144766              0.043149
# 7199  0.458371  0.458371  0.397193   0.397193  0.061178              0.043149
# 7202  0.225128  0.225128  0.397193   0.397193 -0.172064              0.043149
# 7203  0.225128  0.225128  0.397193   0.397193 -0.172064              0.043149
#
#       p_hat_raw     p_hat
# 10     0.043149  0.043149
# 23     0.043149  0.043149
# 33     0.043149  0.043149
# 58     0.043149  0.043149
# 77     0.043149  0.043149
# ...         ...       ...
# 7173   0.043149  0.043149
# 7192   0.043149  0.043149
# 7199   0.043149  0.043149
# 7202   0.043149  0.043149
# 7203   0.043149  0.043149
#
# [481 rows x 8 columns]
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.3035676367929136
# p(S): 0.4008021621376971 p(~S): 0.40080216213769565
# Subset found on iteration 1 of 10 with score 2.2481168090466417 :
# {'prior_offenses': ['None'], 'sex': ['Male'], 'under_25': [True]}
# Best score is now 2.2481168090466417
# Subset found on iteration 2 of 10 with score 8.427760715960602 :
# {'race': ['Caucasian', 'Hispanic'], 'prior_offenses': ['Over 5'], 'charge_degree': ['F'], 'under_25': [False]}
# Best score is now 8.427760715960602
# Subset found on iteration 3 of 10 with score 2.2481168090466417 :
# {'sex': ['Male'], 'prior_offenses': ['None'], 'under_25': [True]}
# Current score of 2.2481168090466417 does not beat best score of 8.427760715960602
# Subset found on iteration 4 of 10 with score 2.2481168090466417 :
# {'prior_offenses': ['None'], 'sex': ['Male'], 'under_25': [True]}
# Current score of 2.2481168090466417 does not beat best score of 8.427760715960602
# Subset found on iteration 5 of 10 with score 8.523768134525486 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'under_25': [False], 'prior_offenses': ['Over 5']}
# Best score is now 8.523768134525486
# Subset found on iteration 6 of 10 with score 2.2481168090466417 :
# {'prior_offenses': ['None'], 'sex': ['Male'], 'under_25': [True]}
# Current score of 2.2481168090466417 does not beat best score of 8.523768134525486
# Subset found on iteration 7 of 10 with score 9.023517035608668 :
# {'race': ['Asian', 'Caucasian', 'Hispanic'], 'charge_degree': ['F'], 'prior_offenses': ['None', 'Over 5']}
# Best score is now 9.023517035608668
# Subset found on iteration 8 of 10 with score 6.272854239868501 :
# {'sex': ['Female'], 'under_25': [False], 'prior_offenses': ['None', 'Over 5'], 'race': ['Caucasian']}
# Current score of 6.272854239868501 does not beat best score of 9.023517035608668
# Subset found on iteration 9 of 10 with score 1.9837732211353731 :
# {'prior_offenses': ['1 to 5', 'None'], 'sex': ['Male'], 'race': ['Caucasian', 'Hispanic', 'Other'], 'under_25': [True], 'charge_degree': ['F']}
# Current score of 1.9837732211353731 does not beat best score of 9.023517035608668
# Subset found on iteration 10 of 10 with score 6.272854239868501 :
# {'under_25': [False], 'sex': ['Female'], 'prior_offenses': ['None', 'Over 5'], 'race': ['Caucasian']}
# Current score of 6.272854239868501 does not beat best score of 9.023517035608668
# Required time =  17.141950368881226 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Caucasian', 'Hispanic'], 'charge_degree': ['F'], 'prior_offenses': ['None', 'Over 5']}
# Score: 9.023517035608668
# Average p_delta: 0.0036094789039440986
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 10    0.297469  0.252427  0.400802   0.397193 -0.099724              0.043149
# 23    0.390065  0.385384  0.400802   0.397193 -0.007128              0.043149
# 33    0.297469  0.252427  0.400802   0.397193 -0.099724              0.043149
# 58    0.670616  0.670616  0.400802   0.397193  0.273423              0.043149
# 77    0.458371  0.458371  0.400802   0.397193  0.061178              0.043149
# ...        ...       ...       ...        ...       ...                   ...
# 7173  0.670616  0.670616  0.400802   0.397193  0.273423              0.043149
# 7192  0.297469  0.252427  0.400802   0.397193 -0.099724              0.043149
# 7199  0.458371  0.458371  0.400802   0.397193  0.061178              0.043149
# 7202  0.278457  0.225128  0.400802   0.397193 -0.118735              0.043149
# 7203  0.278457  0.225128  0.400802   0.397193 -0.118735              0.043149
#
#       p_hat_raw     p_hat
# 10     0.043149  0.043149
# 23     0.043149  0.043149
# 33     0.043149  0.043149
# 58     0.043149  0.043149
# 77     0.043149  0.043149
# ...         ...       ...
# 7173   0.043149  0.043149
# 7192   0.043149  0.043149
# 7199   0.043149  0.043149
# 7202   0.043149  0.043149
# 7203   0.043149  0.043149
#
# [481 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 9.023517035608668
# [0, 8, 9.023517035608668, 'negative']
# Target positive rate for subset: 0.03676048248133257
# New threshold for subset: 0.6988188976377953
# 0       0.500000
# 3       0.698819
# 4       0.683594
# 5       0.500000
# 7       0.683594
#           ...
# 7208    0.683594
# 7209    0.683594
# 7210    0.683594
# 7211    0.500000
# 7212    0.698819
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 9
# Subset found on iteration 1 of 10 with score 5.781076469786983 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['Over 5']}
# Best score is now 5.781076469786983
# Subset found on iteration 2 of 10 with score 2.881495975514665 :
# {'under_25': [True]}
# Current score of 2.881495975514665 does not beat best score of 5.781076469786983
# Subset found on iteration 3 of 10 with score 3.410599169222684 :
# {'race': ['Caucasian'], 'sex': ['Female'], 'prior_offenses': ['None'], 'charge_degree': ['M']}
# Current score of 3.410599169222684 does not beat best score of 5.781076469786983
# Subset found on iteration 4 of 10 with score 5.781076469786983 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['Over 5']}
# Current score of 5.781076469786983 does not beat best score of 5.781076469786983
# Subset found on iteration 5 of 10 with score 5.781076469786983 :
# {'race': ['African-American', 'Caucasian', 'Hispanic'], 'prior_offenses': ['Over 5']}
# Current score of 5.781076469786983 does not beat best score of 5.781076469786983
# Subset found on iteration 6 of 10 with score 2.881495975514665 :
# {'under_25': [True]}
# Current score of 2.881495975514665 does not beat best score of 5.781076469786983
# Subset found on iteration 7 of 10 with score 3.061132207390968 :
# {'race': ['African-American', 'Hispanic'], 'prior_offenses': ['None'], 'sex': ['Male'], 'under_25': [True]}
# Current score of 3.061132207390968 does not beat best score of 5.781076469786983
# Subset found on iteration 8 of 10 with score 5.8764182244954615 :
# {'prior_offenses': ['None', 'Over 5'], 'race': ['African-American'], 'sex': ['Male']}
# Best score is now 5.8764182244954615
# Subset found on iteration 9 of 10 with score 2.881495975514665 :
# {'under_25': [True]}
# Current score of 2.881495975514665 does not beat best score of 5.8764182244954615
# Subset found on iteration 10 of 10 with score 2.2889904037951654 :
# {'sex': ['Male'], 'under_25': [True], 'charge_degree': ['F'], 'race': ['Hispanic', 'Other']}
# Current score of 2.2889904037951654 does not beat best score of 5.8764182244954615
# Required time =  15.561719179153442 seconds
# Found positive subset for ijdi scan:
# {'prior_offenses': ['None', 'Over 5'], 'race': ['African-American'], 'sex': ['Male']}
# Score: 5.8764182244954615
# First Iteration
# Average p_delta: 0.09527774623213872
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 13    0.289774  0.289774  0.397193   0.397193 -0.107418              0.035327
# 49    0.289774  0.289774  0.397193   0.397193 -0.107418              0.035327
# 54    0.710991  0.710991  0.397193   0.397193  0.313799              0.035327
# 80    0.289774  0.289774  0.397193   0.397193 -0.107418              0.035327
# 93    0.675094  0.675094  0.397193   0.397193  0.277901              0.035327
# ...        ...       ...       ...        ...       ...                   ...
# ...
# 1557  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 1594  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 2409  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 2761  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 3519  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 3611  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 3939  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 3950  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 4403  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 4461  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 4637  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 4829  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 4983  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 4993  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 5002  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 5022  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 5185  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 5450  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 5864  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 5906  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 6108  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 6150  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 6429  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 6703  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 6929  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
# 7211  0.398791  0.232134  0.398791   0.397193  0.001598              0.000252
#
#       p_hat_raw     p_hat
# 0      0.000252  0.000252
# 265    0.000252  0.000252
# 670    0.000252  0.000252
# 742    0.000252  0.000252
# 785    0.000252  0.000252
# 794    0.000252  0.000252
# 829    0.000252  0.000252
# 869    0.000252  0.000252
# 1052   0.000252  0.000252
# 1246   0.000252  0.000252
# 1287   0.000252  0.000252
# 1553   0.000252  0.000252
# 1557   0.000252  0.000252
# 1594   0.000252  0.000252
# 2409   0.000252  0.000252
# 2761   0.000252  0.000252
# 3519   0.000252  0.000252
# 3611   0.000252  0.000252
# 3939   0.000252  0.000252
# 3950   0.000252  0.000252
# 4403   0.000252  0.000252
# 4461   0.000252  0.000252
# 4637   0.000252  0.000252
# 4829   0.000252  0.000252
# 4983   0.000252  0.000252
# 4993   0.000252  0.000252
# 5002   0.000252  0.000252
# 5022   0.000252  0.000252
# 5185   0.000252  0.000252
# 5450   0.000252  0.000252
# 5864   0.000252  0.000252
# 5906   0.000252  0.000252
# 6108   0.000252  0.000252
# 6150   0.000252  0.000252
# 6429   0.000252  0.000252
# 6703   0.000252  0.000252
# 6929   0.000252  0.000252
# 7211   0.000252  0.000252
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 3.1697828309058167
# [0, 17, 3.1697828309058167, 'negative']
# Target positive rate for subset: 0.0
# New threshold for subset: 0.5912162162162162
# 0       0.591216
# 3       0.772846
# 4       0.683594
# 5       0.500000
# 7       0.683594
#           ...
# 7208    0.772846
# 7209    0.772846
# 7210    0.772846
# 7211    0.591216
# 7212    0.772846
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 18
# Subset found on iteration 1 of 10 with score 0.0 :
# {}
# Best score is now 0.0
# Subset found on iteration 2 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 3 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 4 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 5 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 6 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 7 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 8 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 9 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Subset found on iteration 10 of 10 with score 0.0 :
# {}
# Current score of 0.0 does not beat best score of 0.0
# Required time =  12.02164340019226 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Score for Negative IJDI-Scan: 0.0
# [0, 18, 0.0, 'negative']
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Iteration 1
# Subset found on iteration 1 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Best score is now 74.48509339471337
# Subset found on iteration 2 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 3 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 4 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 5 of 10 with score 34.32714954393056 :
# {'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 34.32714954393056 does not beat best score of 74.48509339471337
# Subset found on iteration 6 of 10 with score 34.32714954393056 :
# {'prior_offenses': ['1 to 5', 'Over 5'], 'under_25': [True]}
# Current score of 34.32714954393056 does not beat best score of 74.48509339471337
# Subset found on iteration 7 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 8 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 9 of 10 with score 74.48509339471337 :
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 74.48509339471337 does not beat best score of 74.48509339471337
# Subset found on iteration 10 of 10 with score 34.32714954393056 :
# {'under_25': [True], 'prior_offenses': ['1 to 5', 'Over 5']}
# Current score of 34.32714954393056 does not beat best score of 74.48509339471337
# Required time =  23.699944496154785 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'prior_offenses': ['Over 5']}
# Score: 74.48509339471337
# First Iteration
# Average p_delta: 0.2956612316651005
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 43    0.645737  0.645737  0.397193   0.397193  0.248544              0.233914
# 54    0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 93    0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# 122   0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 172   0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# ...        ...       ...       ...        ...       ...                   ...
# 7010  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 7028  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
# 7074  0.606223  0.606223  0.397193   0.397193  0.209030              0.233914
# 7101  0.675094  0.675094  0.397193   0.397193  0.277901              0.233914
# 7186  0.710991  0.710991  0.397193   0.397193  0.313799              0.233914
#
#       p_hat_raw     p_hat
# 43     0.308477  0.308477
# 54     0.328053  0.328053
# 93     0.317284  0.317284
# 122    0.328053  0.328053
# 172    0.328053  0.328053
# ...         ...       ...
# 7010   0.328053  0.328053
# 7028   0.328053  0.328053
# 7074   0.296623  0.296623
# 7101   0.317284  0.317284
# 7186   0.328053  0.328053
#
# [342 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 74.48509339471337
# [0.3, 1, 74.48509339471337, 'negative']
# Target positive rate for subset: 0.2920496101426776
# New threshold for subset: 0.68359375
# 0       0.5
# 3       0.5
# 4       0.5
# 5       0.5
# 7       0.5
#        ...
# 7208    0.5
# 7209    0.5
# 7210    0.5
# 7211    0.5
# 7212    0.5
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 2
# Subset found on iteration 1 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Best score is now 47.52372573962501
# Subset found on iteration 2 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 3 of 10 with score 8.157685625271487 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 8.157685625271487 does not beat best score of 47.52372573962501
# Subset found on iteration 4 of 10 with score 8.157685625271487 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 8.157685625271487 does not beat best score of 47.52372573962501
# Subset found on iteration 5 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 6 of 10 with score 47.52372573962501 :
# {'under_25': [True], 'race': ['African-American', 'Caucasian', 'Hispanic', 'Other']}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 7 of 10 with score 8.157685625271487 :
# {'prior_offenses': ['Over 5'], 'race': ['Caucasian', 'Native American']}
# Current score of 8.157685625271487 does not beat best score of 47.52372573962501
# Subset found on iteration 8 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 9 of 10 with score 47.52372573962501 :
# {'under_25': [True], 'race': ['African-American', 'Caucasian', 'Hispanic', 'Other']}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Subset found on iteration 10 of 10 with score 47.52372573962501 :
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Current score of 47.52372573962501 does not beat best score of 47.52372573962501
# Required time =  23.62429642677307 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Other'], 'under_25': [True]}
# Score: 47.52372573962501
# First Iteration
# Average p_delta: 0.13172521854970987
# Average p_censor: 0.0
#       proba_lr     p_old     p_bar  p_bar_old   p_delta  positives_constprobs  \
# 3     0.668642  0.668642  0.397193   0.397193  0.271449              0.195811
# 23    0.385384  0.385384  0.397193   0.397193 -0.011808              0.195811
# 40    0.599215  0.599215  0.397193   0.397193  0.202023              0.195811
# 71    0.589646  0.589646  0.397193   0.397193  0.192453              0.195811
# 77    0.458371  0.458371  0.397193   0.397193  0.061178              0.195811
# ...        ...       ...       ...        ...       ...                   ...
# 7178  0.553041  0.553041  0.397193   0.397193  0.155849              0.195811
# 7199  0.458371  0.458371  0.397193   0.397193  0.061178              0.195811
# 7208  0.505581  0.505581  0.397193   0.397193  0.108389              0.195811
# 7209  0.505581  0.505581  0.397193   0.397193  0.108389              0.195811
# 7210  0.505581  0.505581  0.397193   0.397193  0.108389              0.195811
#
#       p_hat_raw     p_hat
# 3      0.277246  0.277246
# 23     0.192269  0.192269
# 40     0.256418  0.256418
# 71     0.253547  0.253547
# 77     0.214165  0.214165
# ...         ...       ...
# 7178   0.242566  0.242566
# 7199   0.214165  0.214165
# 7208   0.228328  0.228328
# 7209   0.228328  0.228328
# 7210   0.228328  0.228328
#
# [661 rows x 8 columns]
# Subset does not violate p_delta or p_censor conditions!
# Score for Negative IJDI-Scan: 47.52372573962501
# [0.3, 2, 47.52372573962501, 'negative']
# Target positive rate for subset: 0.20097156642451566
# New threshold for subset: 0.5912162162162162
# 0       0.500000
# 3       0.591216
# 4       0.500000
# 5       0.500000
# 7       0.500000
#           ...
# 7208    0.591216
# 7209    0.591216
# 7210    0.591216
# 7211    0.500000
# 7212    0.500000
# Name: threshold, Length: 3963, dtype: float64
#
# ----------------------------------------------------
#
# Iteration 3
# Subset found on iteration 1 of 10 with score 27.058076048611817 :
# {'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Native American'], 'under_25': [False]}
# Best score is now 27.058076048611817
# Subset found on iteration 2 of 10 with score 27.058076048611817 :
# {'race': ['African-American', 'Native American'], 'under_25': [False], 'prior_offenses': ['1 to 5']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 3 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Native American']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 4 of 10 with score 27.058076048611817 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5'], 'under_25': [False]}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 5 of 10 with score 10.967654580459534 :
# {'race': ['Caucasian', 'Native American'], 'prior_offenses': ['Over 5']}
# Current score of 10.967654580459534 does not beat best score of 27.058076048611817
# Subset found on iteration 6 of 10 with score 27.058076048611817 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5'], 'under_25': [False]}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 7 of 10 with score 27.058076048611817 :
# {'race': ['African-American', 'Native American'], 'under_25': [False], 'prior_offenses': ['1 to 5']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 8 of 10 with score 27.058076048611817 :
# {'under_25': [False], 'prior_offenses': ['1 to 5'], 'race': ['African-American', 'Native American']}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817
# Subset found on iteration 9 of 10 with score 27.058076048611817 :
# {'race': ['African-American', 'Native American'], 'prior_offenses': ['1 to 5'], 'under_25': [False]}
# Current score of 27.058076048611817 does not beat best score of 27.058076048611817

# %% [markdown]
# Implement approach for Positives

# %%
# filter for negative or positive outcomes
positives_df = compas_mit_df.loc[compas_mit_df[outcomes_col] == 1]

for lambda_param in lambda_vals: # run IJDI scan for various lambda values

    print("Lambda =", lambda_param)

    i = 0
    ijdi_present = True
    # set initial threshold
    positives_df['threshold'] = 0.5

    while ijdi_present and i <= 20:

        i += 1
        print("Iteration", i)

        # Run Negative or Positive IJDI Scan. Make sure to pass in copy because data may be modified by the function!
        current_subset, current_score = run_ijdi_scan(positives_df.copy(deep=True), features, proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                      threshold, lambda_param, constant_threshold=False, verbose=True)

        print("Score for Positives IJDI-Scan:", current_score)

        # append data
        row = [lambda_param, i, current_score, 'positive']
        sim_data.append(row)

        print(row)

        if current_score > stop_limit:

            # correct IJDI by setting new threshold for subset
            positives_df['threshold'] = correct_ijdi_subset(positives_df.copy(deep=True), features,
                                                            proba_confusion_col, proba_ijdi_col, outcomes_col,
                                                            threshold, lambda_param, current_subset)
            print(positives_df['threshold'])

        else:
            ijdi_present = False

        print("\n----------------------------------------------------\n")

# %%
columns = ['lambda', 'iteration', 'score', 'scan_type']
mit_result_df = pd.DataFrame(sim_data, columns=columns)
mit_result_df

# %%
# Write recipe outputs
mit_result_df.to_csv(home_dir + "datasets/compas_mit_2_pos.csv")
