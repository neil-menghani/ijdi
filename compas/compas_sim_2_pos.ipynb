# %%
import os

os.chdir('../scripts') # cd into scripts dir

from scan import *
from prep import *
import pandas as pd, numpy as np
from sklearn.linear_model import LogisticRegression

os.chdir('../') # cd back to parent dir
home_dir = "compas/" # set home dir for reading and storing data

# Read recipe inputs
compas_prep_df = pd.read_csv(home_dir + "datasets/compas_prep.csv")
compas_prep_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  compas_risk_score  proba_compas  proba_lr
# 0                F         0                  1      0.213889  0.232134
# 1                F         1                  3      0.376171  0.289774
# 2                F         1                  4      0.434330  0.668642
# 3                F         0                  8      0.683594  0.668642
# 4                F         0                  1      0.213889  0.373653
# ...            ...       ...                ...           ...       ...
# 7209             F         0                  7      0.591216  0.505581
# 7210             F         0                  3      0.376171  0.505581
# 7211             F         0                  1      0.213889  0.232134
# 7212             M         0                  2      0.311371  0.335035
# 7213             F         1                  4      0.434330  0.515657
#
# [7214 rows x 10 columns]

# %% [markdown]
# ### Prepare Base Dataset for Simulations

# %% [markdown]
# Select only covariates and outcomes to prepare for simulation.

# %%
# Exclude risk score
prob_cols = ['compas_risk_score', 'proba_lr']
compas_sim_df = compas_prep_df.drop(columns=prob_cols)

# %% [markdown]
# ### Build Logistic Regression Model to Predict Outcomes

# %% [markdown]
# One-Hot encode categorical features.

# %%
### Columns to exclude from model
exclude = ['race', 'under_25', 'Unnamed: 0']

# %%
compas_df = compas_sim_df.copy(deep=True)
compas_df = compas_df.drop(columns=exclude)
compas_df
# Out:
#          sex prior_offenses charge_degree  outcomes  proba_compas
# 0       Male           None             F         0      0.213889
# 1       Male           None             F         1      0.376171
# 2       Male         1 to 5             F         1      0.434330
# 3       Male         1 to 5             F         0      0.683594
# 4       Male         1 to 5             F         0      0.213889
# ...      ...            ...           ...       ...           ...
# 7209    Male           None             F         0      0.591216
# 7210    Male           None             F         0      0.376171
# 7211    Male           None             F         0      0.213889
# 7212  Female         1 to 5             M         0      0.311371
# 7213  Female         1 to 5             F         1      0.434330
#
# [7214 rows x 5 columns]

# %%
for cat_col in compas_df.select_dtypes(include=['object', 'bool']).columns:
    compas_df[cat_col] = compas_df[cat_col].astype('category')

# %%
X_num = compas_df.select_dtypes(exclude=['category'])
X_cat = compas_df.select_dtypes(include=['category'])

# %%
X_cat
# Out:
#          sex prior_offenses charge_degree
# 0       Male           None             F
# 1       Male           None             F
# 2       Male         1 to 5             F
# 3       Male         1 to 5             F
# 4       Male         1 to 5             F
# ...      ...            ...           ...
# 7209    Male           None             F
# 7210    Male           None             F
# 7211    Male           None             F
# 7212  Female         1 to 5             M
# 7213  Female         1 to 5             F
#
# [7214 rows x 3 columns]

# %%
# one-hot encoding of categorical features
X_encoded = pd.get_dummies(X_cat)
frames = [X_encoded, X_num]
compas_df = pd.concat(frames, axis=1)

# %%
extra_cols = ['sex_Female', 'prior_offenses_None', 'charge_degree_M']
compas_df = compas_df.drop(columns=extra_cols)
compas_df
# Out:
#       sex_Male  prior_offenses_1 to 5  prior_offenses_Over 5  charge_degree_F  \
# 0            1                      0                      0                1
# 1            1                      0                      0                1
# 2            1                      1                      0                1
# 3            1                      1                      0                1
# 4            1                      1                      0                1
# ...        ...                    ...                    ...              ...
# 7209         1                      0                      0                1
# 7210         1                      0                      0                1
# 7211         1                      0                      0                1
# 7212         0                      1                      0                0
# 7213         0                      1                      0                1
#
#       outcomes  proba_compas
# 0            0      0.213889
# 1            1      0.376171
# 2            1      0.434330
# 3            0      0.683594
# 4            0      0.213889
# ...        ...           ...
# 7209         0      0.591216
# 7210         0      0.376171
# 7211         0      0.213889
# 7212         0      0.311371
# 7213         1      0.434330
#
# [7214 rows x 6 columns]

# %%
X = compas_df.drop(columns=['outcomes'])
y = compas_df['outcomes']

# %%
lr = LogisticRegression(random_state=0)
lr.fit(X, y)
proba = lr.predict_proba(X)[:,1]
compas_sim_df['proba'] = proba
compas_sim_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  proba_compas     proba
# 0                F         0      0.213889  0.206231
# 1                F         1      0.376171  0.313529
# 2                F         1      0.434330  0.460612
# 3                F         0      0.683594  0.670093
# 4                F         0      0.213889  0.284108
# ...            ...       ...           ...       ...
# 7209             F         0      0.591216  0.490967
# 7210             F         0      0.376171  0.313529
# 7211             F         0      0.213889  0.206231
# 7212             M         0      0.311371  0.259957
# 7213             F         1      0.434330  0.379047
#
# [7214 rows x 9 columns]

# %%
compas_sim_df.loc[compas_sim_df['prior_offenses'] == 'Over 5']['proba'].mean()
# Out:
# 0.6889936745293317

# %%
compas_sim_df.loc[compas_sim_df['prior_offenses'] != 'Over 5']['proba'].mean()
# Out:
# 0.3868154624406128

# %%
# Check accuracy
# Note: model results can vary environment to environment, which can impact IJDI scores.
compas_sim_df['test_outcomes'] = compas_sim_df['proba'].apply(lambda x : 1 if x > 0.5 else 0)
compas_sim_df['check'] = compas_sim_df.apply(lambda x : 1 if x['outcomes'] == x['test_outcomes'] else 0, axis=1)
print(np.sum(compas_sim_df['check']) / len(compas_sim_df))
compas_sim_df = compas_sim_df.drop(columns=['test_outcomes', 'check'])
# Out:
# 0.6639866925422789

# %% [markdown]
# ### Example of one Iteration for Base Case of the Simulation 2

# %% [markdown]
# Define subgroup for which to simulate altered probabilities.

# %%
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment
subgroup = {'race':['African-American', 'Asian'], 'under_25':[True]}
compas_sim_df['in_subgroup'] = compas_sim_df[list(subgroup.keys())].isin(subgroup).all(axis=1)
compas_sim_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  proba_compas     proba  in_subgroup
# 0                F         0      0.213889  0.206231        False
# 1                F         1      0.376171  0.313529        False
# 2                F         1      0.434330  0.460612         True
# 3                F         0      0.683594  0.670093         True
# 4                F         0      0.213889  0.284108        False
# ...            ...       ...           ...       ...          ...
# 7209             F         0      0.591216  0.490967         True
# 7210             F         0      0.376171  0.313529         True
# 7211             F         0      0.213889  0.206231        False
# 7212             M         0      0.311371  0.259957        False
# 7213             F         1      0.434330  0.379047        False
#
# [7214 rows x 10 columns]

# %%
THRESHOLD = 0.5
proba_epsilon = 0.3
threshold_epsilon = 0.3
compas_sim_df['proba_shifted'] = compas_sim_df.apply(lambda x : calculate_proba_shift(x['proba'], proba_epsilon) if x['in_subgroup']
                                                                                                                 else x['proba'], axis=1)
compas_sim_df['threshold'] = THRESHOLD
compas_sim_df['threshold_shifted'] = compas_sim_df.apply(lambda x : calculate_proba_shift(x['threshold'], -threshold_epsilon) if x['in_subgroup']
                                                                                                                              else x['threshold'], axis=1)
compas_sim_df['outcomes'] = compas_sim_df['proba'].apply(lambda x : generate_outcomes(x))
compas_sim_df
# Out:
#       Unnamed: 0     sex              race prior_offenses  under_25  \
# 0              0    Male             Other           None     False
# 1              1    Male  African-American           None     False
# 2              2    Male  African-American         1 to 5      True
# 3              3    Male  African-American         1 to 5      True
# 4              4    Male             Other         1 to 5     False
# ...          ...     ...               ...            ...       ...
# 7209        7209    Male  African-American           None      True
# 7210        7210    Male  African-American           None      True
# 7211        7211    Male             Other           None     False
# 7212        7212  Female  African-American         1 to 5     False
# 7213        7213  Female          Hispanic         1 to 5      True
#
#      charge_degree  outcomes  proba_compas     proba  in_subgroup  \
# 0                F         0      0.213889  0.206231        False
# 1                F         0      0.376171  0.313529        False
# 2                F         0      0.434330  0.460612         True
# 3                F         0      0.683594  0.670093         True
# 4                F         0      0.213889  0.284108        False
# ...            ...       ...           ...       ...          ...
# 7209             F         0      0.591216  0.490967         True
# 7210             F         0      0.376171  0.313529         True
# 7211             F         1      0.213889  0.206231        False
# 7212             M         0      0.311371  0.259957        False
# 7213             F         0      0.434330  0.379047        False
#
#       proba_shifted  threshold  threshold_shifted
# 0          0.206231        0.5           0.500000
# 1          0.313529        0.5           0.500000
# 2          0.535470        0.5           0.425557
# 3          0.732747        0.5           0.425557
# 4          0.284108        0.5           0.500000
# ...             ...        ...                ...
# 7209       0.565585        0.5           0.425557
# 7210       0.381385        0.5           0.425557
# 7211       0.206231        0.5           0.500000
# 7212       0.259957        0.5           0.500000
# 7213       0.379047        0.5           0.500000
#
# [7214 rows x 13 columns]

# %% [markdown]
# Generate variant metrics for only "truly positive-outcome" people (those who DID reoffend). Additionally, generate metrics required for IJDI scan (i.e. $\hat{p}$ calculation).

# %%
# specify probability and outcomes columns
OUTCOMES_COL = 'outcomes'
FEATURES = ['sex', 'race', 'under_25', 'charge_degree']
LAMBDA_PARAM = 3
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# filter for only positive outcomes
positives_df = compas_sim_df.loc[compas_sim_df[OUTCOMES_COL] == 1]

# %%
# # define new columns
# metrics_df = generate_metrics(positives_df, 'proba_shifted', OUTCOMES_COL, THRESHOLD, constant_threshold=False)

# print("Number of people in subgroup:", len(positives_df[positives_df['in_subgroup'] == True]))
# print("Number of people not in subgroup:", len(positives_df[positives_df['in_subgroup'] == False]))
# print("Total population:", len(positives_df))

# # display preview of treatments, probabilities, and outcomes
# metrics_df.head(10)

# %%
# # scan with shifted probabilities
# current_subset, current_score = run_ijdi_scan(positives_df, FEATURES, 'proba', 'proba', OUTCOMES_COL,
#                                               'threshold_shifted', LAMBDA_PARAM, constant_threshold=False)
# summarize_scan(positives_df, FEATURES, 'proba', OUTCOMES_COL, current_subset, include='all')

# %%
# # scan with shifted thresholds
# current_subset, current_score = run_ijdi_scan(positives_df, FEATURES, 'proba_shifted', 'proba', OUTCOMES_COL,
#                                               'threshold', LAMBDA_PARAM, constant_threshold=False)
# summarize_scan(positives_df, FEATURES, 'proba', OUTCOMES_COL, current_subset, include='all')

# %% [markdown]
# ### Simulations for Positives

# %% [markdown]
# Set mean values as well as ranges of standard deviation and lambda to iterate over for each simulation. Also define threshold and number of iterations to run for each set of parameters.

# %%
epsilon_vals = [0, 0.3, 3]
lambda_vals = [0, 0.3, 1, 3, 10]
n_iters = 10

# specify parameters for generating metrics and IJDI scan
outcomes_col = 'outcomes'
features = ['sex', 'race', 'under_25', 'charge_degree']
threshold = 0.5
pd.options.mode.chained_assignment = None  # suppress warnings on chained assignment

# set random seed
np.random.seed(200)

# %%
sim_data = []

for e in epsilon_vals:

    print("Parameter Epsilon =", e)

    for i in range(n_iters): # run n iterations for each k value

        print("Simulation", i+1, "of", n_iters)

        compas_sim_df['proba_shifted'] = compas_sim_df.apply(lambda x : calculate_proba_shift(x['proba'], e) if x['in_subgroup']
                                                                                                             else x['proba'], axis=1)
        compas_sim_df['threshold'] = threshold
        compas_sim_df['threshold_shifted'] = compas_sim_df.apply(lambda x : calculate_proba_shift(x['threshold'], -e) if x['in_subgroup']
                                                                                                                      else x['threshold'], axis=1)
        compas_sim_df['outcomes'] = compas_sim_df['proba'].apply(lambda x : generate_outcomes(x))

        # filter for only positive outcomes
        positives_df = compas_sim_df.loc[compas_sim_df[outcomes_col] == 1]

        for lambda_param in lambda_vals: # run IJDI scan for various lambda values

            print("Lambda =", lambda_param)
            
            positives_df_copy_1 = positives_df.copy(deep=True)
            positives_df_copy_2 = positives_df.copy(deep=True)

            # Run IJDI Scan. Make sure to pass in copy because data may be modified by the function!
            proba_shift_subset, proba_shift_score = run_ijdi_scan(positives_df_copy_1, features, 'proba_shifted', 'proba', outcomes_col,
                                                                  'threshold', lambda_param, constant_threshold=False, verbose=False)
            threshold_shift_subset, threshold_shift_score = run_ijdi_scan(positives_df_copy_2, features, 'proba', 'proba', outcomes_col,
                                                                          'threshold_shifted', lambda_param, constant_threshold=False, verbose=False)

            # save iou and score
            if proba_shift_subset:
                in_subgroup = positives_df[list(subgroup.keys())].isin(subgroup).all(axis=1)
                in_proba_shift_subset = positives_df[list(proba_shift_subset.keys())].isin(proba_shift_subset).all(axis=1)
                proba_shift_iou = (in_subgroup & in_proba_shift_subset).sum() / (in_subgroup | in_proba_shift_subset).sum()
            else:
                proba_shift_iou = 0.0

            print("Detected proba shift subset intersection over union with expected subset:", proba_shift_iou)
            print("Detected proba shift subset score:", proba_shift_score)

            if threshold_shift_subset:
                in_subgroup = positives_df[list(subgroup.keys())].isin(subgroup).all(axis=1)
                in_threshold_shift_subset = positives_df[list(threshold_shift_subset.keys())].isin(threshold_shift_subset).all(axis=1)
                threshold_shift_iou = (in_subgroup & in_threshold_shift_subset).sum() / (in_subgroup | in_threshold_shift_subset).sum()
            else:
                threshold_shift_iou = 0.0

            print("Detected threshold shift subset intersection over union with expected subset:", threshold_shift_iou)
            print("Detected threshold shift subset score:", threshold_shift_score)

            # append data
            sim_row = [e, lambda_param, proba_shift_iou, proba_shift_score, threshold_shift_iou, threshold_shift_score]
            sim_data.append(sim_row)
            print(sim_row)
            
            # release memory from kernel
            release_df(positives_df_copy_1)
            release_df(positives_df_copy_2)
            
            print("\n----------------------------------------------------\n")
# Out:
# Parameter Epsilon = 0
# Simulation 1 of 10
# Lambda = 0
# Required time =  22.27760601043701 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 80.58566855550767
# First Iteration
# Average p_delta: 0.06518179537564787
# Average p_censor: 0.0
# p(S): 0.5965504420070348 p(~S): 0.46466634283078406 E[censored] 0.5370145631068146 E[uncensored] 0.5370145631068146
# Subset does not violate p_delta or p_censor conditions!
# Required time =  21.353509187698364 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Native American']}
# Score: 80.58566855550767
# First Iteration
# Average p_delta: 0.06518179537564787
# Average p_censor: 0.0
# p(S): 0.5965504420070348 p(~S): 0.46466634283078406 E[censored] 0.5370145631068146 E[uncensored] 0.5370145631068146
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.2564991334488735
# Detected proba shift subset score: 80.58566855550767
# Detected threshold shift subset intersection over union with expected subset: 0.2564991334488735
# Detected threshold shift subset score: 80.58566855550767
# [0, 0, 0.2564991334488735, 80.58566855550767, 0.2564991334488735, 80.58566855550767]
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Required time =  18.614444255828857 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 62.38691486870523
# First Iteration
# Average p_delta: 0.06518179537564787
# Average p_censor: 0.0
# p(S): 0.5965504420070348 p(~S): 0.46466634283078406 E[censored] 0.556569101719489 E[uncensored] 0.556569101719489
# Subset does not violate p_delta or p_censor conditions!
# Required time =  22.683708667755127 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Native American']}
# Score: 62.38691486870523
# First Iteration
# Average p_delta: 0.06518179537564787
# Average p_censor: 0.0
# p(S): 0.5965504420070348 p(~S): 0.46466634283078406 E[censored] 0.556569101719489 E[uncensored] 0.556569101719489
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.2564991334488735
# Detected proba shift subset score: 62.38691486870523
# Detected threshold shift subset intersection over union with expected subset: 0.2564991334488735
# Detected threshold shift subset score: 62.38691486870523
# [0, 0.3, 0.2564991334488735, 62.38691486870523, 0.2564991334488735, 62.38691486870523]
#
# ----------------------------------------------------
#
# Lambda = 1
# Required time =  18.827024936676025 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Native American']}
# Score: 30.87885201514349
# First Iteration
# Average p_delta: 0.06518179537564787
# Average p_censor: 0.0
# p(S): 0.5965504420070348 p(~S): 0.46466634283078406 E[censored] 0.6021963584824462 E[uncensored] 0.6021963584824462
# Subset does not violate p_delta or p_censor conditions!
# Required time =  17.052728176116943 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 30.87885201514349
# First Iteration
# Average p_delta: 0.06518179537564787
# Average p_censor: 0.0
# p(S): 0.5965504420070348 p(~S): 0.46466634283078406 E[censored] 0.6021963584824462 E[uncensored] 0.6021963584824462
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.2564991334488735
# Detected proba shift subset score: 30.87885201514349
# Detected threshold shift subset intersection over union with expected subset: 0.2564991334488735
# Detected threshold shift subset score: 30.87885201514349
# [0, 1, 0.2564991334488735, 30.87885201514349, 0.2564991334488735, 30.87885201514349]
#
# ----------------------------------------------------
#
# Lambda = 3
# Required time =  18.47468376159668 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'sex': ['Male'], 'charge_degree': ['M']}
# Score: 6.112762240673613
# First Iteration
# Average p_delta: -0.00017813949697673508
# Average p_censor: 0.007499461626856576
# p(S): 0.5311905071344151 p(~S): 0.5314016354271289 E[censored] 0.5439796062427221 E[uncensored] 0.5364801446158655
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.002751406074774802
# p(S): 0.5314016354271289 p(~S): 0.5314016354271289
# Required time =  19.739691972732544 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'sex': ['Male'], 'charge_degree': ['M']}
# Score: 6.064566741302707
# Average p_delta: 3.298879573653969e-05
# Average p_censor: 0.007013853718542924
# p(S): 0.5314016354271289 p(~S): 0.5314016354271289 E[censored] 0.5441273832125495 E[uncensored] 0.5371135294940064
# Subset does not violate p_delta or p_censor conditions!
# Required time =  20.386168003082275 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M'], 'race': ['African-American', 'Asian', 'Hispanic', 'Native American']}
# Score: 6.112762240673613
# First Iteration
# Average p_delta: -0.00017813949697673508
# Average p_censor: 0.007499461626856576
# p(S): 0.5311905071344151 p(~S): 0.5314016354271289 E[censored] 0.5439796062427221 E[uncensored] 0.5364801446158655
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.002751406074774802
# p(S): 0.5314016354271289 p(~S): 0.5314016354271289
# Required time =  14.79784107208252 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Asian', 'Hispanic', 'Native American'], 'charge_degree': ['M']}
# Score: 6.064566741302707
# Average p_delta: 3.298879573653969e-05
# Average p_censor: 0.007013853718542924
# p(S): 0.5314016354271289 p(~S): 0.5314016354271289 E[censored] 0.5441273832125495 E[uncensored] 0.5371135294940064
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.09881847475832438
# Detected proba shift subset score: 6.064566741302707
# Detected threshold shift subset intersection over union with expected subset: 0.09881847475832438
# Detected threshold shift subset score: 6.064566741302707
# [0, 3, 0.09881847475832438, 6.064566741302707, 0.09881847475832438, 6.064566741302707]
#
# ----------------------------------------------------
#
# Lambda = 10
# Required time =  15.491320848464966 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M']}
# Score: 41.4377183565437
# First Iteration
# Average p_delta: -0.041571771844339224
# Average p_censor: 0.3235831464659731
# p(S): 0.4897968747870532 p(~S): 0.5445612872566551 E[censored] 0.44487999112937543 E[uncensored] 0.12129684466340233
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.5038045309231752
# p(S): 0.5445612872566558 p(~S): 0.5445612872566551
# Required time =  13.06255841255188 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female']}
# Score: 13.742622686026602
# Average p_delta: -0.10275736468187327
# Average p_censor: 0.7917816091170091
# p(S): 0.42861128194951953 p(~S): 0.5507491376983323 E[censored] 0.30122252540507055 E[uncensored] -0.49055908371193746
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.8107022870388931
# p(S): 0.5507491376983316 p(~S): 0.5507491376983323
# Required time =  10.435791730880737 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['Asian', 'Native American']}
# Score: 0.9429409705758303
# Average p_delta: 0.030921103754262453
# Average p_censor: -0.28906506600002957
# p(S): 0.5622897503856548 p(~S): 0.5313476845756386 E[censored] 0.557160534649391 E[uncensored] 0.8462256006494205
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.6527536243211028
# E[censored]: 0.8462256006494203 E[uncensored]: 0.8462256006494205
# Required time =  11.00475788116455 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'race': ['Native American']}
# Score: 0.6333171474289998
# Average p_delta: 0.1734837784786524
# Average p_censor: -1.3692107408445935
# p(S): 0.7048524251100449 p(~S): 0.5310180595795116 E[censored] 0.9026416070487261 E[uncensored] 2.27185234789332
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  11.83676266670227 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Hispanic', 'Other'], 'charge_degree': ['M'], 'sex': ['Male'], 'under_25': [True]}
# Score: 0.9020713452485665
# Average p_delta: 0.025636956352322517
# Average p_censor: -0.22682247256434904
# p(S): 0.557005602983715 p(~S): 0.5317766827449242 E[censored] 0.5665616540656722 E[uncensored] 0.7933841266300207
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.5233096579754759
# E[censored]: 0.793384126630021 E[uncensored]: 0.7933841266300207
# Required time =  12.678414583206177 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Required time =  13.634500980377197 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M']}
# Score: 41.4377183565437
# First Iteration
# Average p_delta: -0.041571771844339224
# Average p_censor: 0.3235831464659731
# p(S): 0.4897968747870532 p(~S): 0.5445612872566551 E[censored] 0.44487999112937543 E[uncensored] 0.12129684466340233
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.5038045309231752
# p(S): 0.5445612872566558 p(~S): 0.5445612872566551
# Required time =  18.546821117401123 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['M']}
# Score: 53.7379763112207
# Average p_delta: -0.01757596127229301
# Average p_censor: 0.05377653786122347
# p(S): 0.5137926853590997 p(~S): 0.5572803834098471 E[censored] 0.43002514332304054 E[uncensored] 0.37624860546181726
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.5050600354640029
# p(S): 0.5572803834098471 p(~S): 0.5572803834098471
# Required time =  18.153302431106567 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Native American'], 'charge_degree': ['M']}
# Score: 46.370303561693596
# Average p_delta: 0.03409411594448111
# Average p_censor: -0.3593802353676103
# p(S): 0.5654627625758742 p(~S): 0.5473398493497389 E[censored] 0.5777381085432196 E[uncensored] 0.9371183439108306
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.8510837530892698
# E[censored]: 0.937118343910832 E[uncensored]: 0.9371183439108306
# Required time =  14.518001556396484 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female'], 'charge_degree': ['F']}
# Score: 11.66988910343257
# Average p_delta: -0.07457200681493109
# Average p_censor: 0.5659580872896645
# p(S): 0.45679663981646124 p(~S): 0.5403132332456207 E[censored] 0.3572525822471486 E[uncensored] -0.20870550504251498
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.6858661397205096
# p(S): 0.5403132332456199 p(~S): 0.5403132332456207
# Required time =  12.99758768081665 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Caucasian', 'Hispanic', 'Native American'], 'sex': ['Female'], 'charge_degree': ['F']}
# Score: 24.034950160250894
# Average p_delta: 0.010382388611390632
# Average p_censor: -0.23841306325804787
# p(S): 0.5417510352427821 p(~S): 0.5397764012229622 E[censored] 0.4807020849917806 E[uncensored] 0.7191151482498286
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.4591065289647354
# E[censored]: 0.7191151482498275 E[uncensored]: 0.7191151482498286
# Required time =  11.877616167068481 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female'], 'race': ['Other'], 'under_25': [False]}
# Score: 1.9879840178886325
# Average p_delta: -0.10155523365917007
# Average p_censor: 0.5433966382577033
# p(S): 0.4298134129722223 p(~S): 0.5322387060909092 E[censored] 0.1309720598301684 E[uncensored] -0.4124245784275349
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.5322387060909091 p(~S): 0.5322387060909092
# Required time =  13.074870109558105 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'sex': ['Female'], 'race': ['Other']}
# Score: 4.84508654624791
# Average p_delta: 0.0008700594595167921
# Average p_censor: 0.0
# p(S): 0.5322387060909091 p(~S): 0.5322387060909092 E[censored] 0.6264190411971098 E[uncensored] 0.6264190411971098
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.0
# Detected proba shift subset score: 0.0
# Detected threshold shift subset intersection over union with expected subset: 0.0
# Detected threshold shift subset score: 4.84508654624791
# [0, 10, 0.0, 0.0, 0.0, 4.84508654624791]
#
# ----------------------------------------------------
#
# Simulation 2 of 10
# Lambda = 0
# Required time =  25.621917963027954 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Native American']}
# Score: 94.96854536047381
# First Iteration
# Average p_delta: 0.0702007180810925
# Average p_censor: 0.0
# p(S): 0.6000354616911259 p(~S): 0.46128478498878256 E[censored] 0.5372573575453997 E[uncensored] 0.5372573575453997
# Subset does not violate p_delta or p_censor conditions!
# Required time =  22.334706783294678 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Native American']}
# Score: 94.96854536047381
# First Iteration
# Average p_delta: 0.0702007180810925
# Average p_censor: 0.0
# p(S): 0.6000354616911259 p(~S): 0.46128478498878256 E[censored] 0.5372573575453997 E[uncensored] 0.5372573575453997
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.24711596842744385
# Detected proba shift subset score: 94.96854536047381
# Detected threshold shift subset intersection over union with expected subset: 0.24711596842744385
# Detected threshold shift subset score: 94.96854536047381
# [0, 0, 0.24711596842744385, 94.96854536047381, 0.24711596842744385, 94.96854536047381]
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Required time =  20.258736610412598 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 74.3095095935342
# First Iteration
# Average p_delta: 0.0702007180810925
# Average p_censor: 0.0
# p(S): 0.6000354616911259 p(~S): 0.46128478498878256 E[censored] 0.558317572969724 E[uncensored] 0.558317572969724
# Subset does not violate p_delta or p_censor conditions!
# Required time =  19.342369318008423 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 74.3095095935342
# First Iteration
# Average p_delta: 0.0702007180810925
# Average p_censor: 0.0
# p(S): 0.6000354616911259 p(~S): 0.46128478498878256 E[censored] 0.558317572969724 E[uncensored] 0.558317572969724
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.24711596842744385
# Detected proba shift subset score: 74.3095095935342
# Detected threshold shift subset intersection over union with expected subset: 0.24711596842744385
# Detected threshold shift subset score: 74.3095095935342
# [0, 0.3, 0.24711596842744385, 74.3095095935342, 0.24711596842744385, 74.3095095935342]
#
# ----------------------------------------------------
#
# Lambda = 1
# Required time =  17.909176111221313 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 38.35045314127963
# First Iteration
# Average p_delta: 0.0702007180810925
# Average p_censor: 0.0
# p(S): 0.6000354616911259 p(~S): 0.46128478498878256 E[censored] 0.6074580756264899 E[uncensored] 0.6074580756264899
# Subset does not violate p_delta or p_censor conditions!
# Required time =  18.377923727035522 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Native American']}
# Score: 38.35045314127963
# First Iteration
# Average p_delta: 0.0702007180810925
# Average p_censor: 0.0
# p(S): 0.6000354616911259 p(~S): 0.46128478498878256 E[censored] 0.6074580756264899 E[uncensored] 0.6074580756264899
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.24711596842744385
# Detected proba shift subset score: 38.35045314127963
# Detected threshold shift subset intersection over union with expected subset: 0.24711596842744385
# Detected threshold shift subset score: 38.35045314127963
# [0, 1, 0.24711596842744385, 38.35045314127963, 0.24711596842744385, 38.35045314127963]
#
# ----------------------------------------------------
#
# Lambda = 3
# Required time =  15.56269907951355 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Native American'], 'charge_degree': ['M'], 'sex': ['Male']}
# Score: 6.686502818606755
# First Iteration
# Average p_delta: 0.02248516026091588
# Average p_censor: -0.010499628559958906
# p(S): 0.5523199038709531 p(~S): 0.5265880508170798 E[censored] 0.5942132097681864 E[uncensored] 0.6047128383281453
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.025874742137270815
# E[censored]: 0.6047128383281449 E[uncensored]: 0.6047128383281453
# Required time =  20.673279285430908 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American']}
# Score: 4.876499784000361
# Average p_delta: 0.05112569753318138
# Average p_censor: -0.046967650272453185
# p(S): 0.5809604411432149 p(~S): 0.4618536009382849 E[censored] 0.6436667998724863 E[uncensored] 0.6906344501449367
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.13180823525746724
# E[censored]: 0.6906344501449421 E[uncensored]: 0.6906344501449367
# Required time =  11.4926917552948 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'race': ['Native American']}
# Score: 1.2158814791749848
# Average p_delta: 0.15803503179667572
# Average p_censor: -0.1714099680569498
# p(S): 0.687869775406714 p(~S): 0.5294876318364027 E[censored] 0.8399524848784748 E[uncensored] 1.0113624529354248
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  10.585180521011353 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian'], 'charge_degree': ['M']}
# Score: 0.0008119304326595356
# Average p_delta: -0.2490641104870301
# Average p_censor: 0.3317408731570796
# p(S): 0.2807706331230081 p(~S): 0.5302252486437276 E[censored] 0.12180589924138674 E[uncensored] -0.20993497391569288
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.5302252486437276 p(~S): 0.5302252486437276
# Required time =  11.194146394729614 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Required time =  15.19040298461914 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M'], 'race': ['African-American', 'Asian', 'Native American']}
# Score: 6.686502818606755
# First Iteration
# Average p_delta: 0.02248516026091588
# Average p_censor: -0.010499628559958906
# p(S): 0.5523199038709531 p(~S): 0.5265880508170798 E[censored] 0.5942132097681864 E[uncensored] 0.6047128383281453
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.025874742137270815
# E[censored]: 0.6047128383281449 E[uncensored]: 0.6047128383281453
# Required time =  19.367003202438354 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American']}
# Score: 4.876499784000361
# Average p_delta: 0.05112569753318138
# Average p_censor: -0.046967650272453185
# p(S): 0.5809604411432149 p(~S): 0.4618536009382849 E[censored] 0.6436667998724863 E[uncensored] 0.6906344501449367
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.13180823525746724
# E[censored]: 0.6906344501449421 E[uncensored]: 0.6906344501449367
# Required time =  12.934149026870728 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'race': ['Native American']}
# Score: 1.2158814791749848
# Average p_delta: 0.15803503179667572
# Average p_censor: -0.1714099680569498
# p(S): 0.687869775406714 p(~S): 0.5294876318364027 E[censored] 0.8399524848784748 E[uncensored] 1.0113624529354248
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  11.44369912147522 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian'], 'charge_degree': ['M']}
# Score: 0.0008119304326595356
# Average p_delta: -0.2490641104870301
# Average p_censor: 0.3317408731570796
# p(S): 0.2807706331230081 p(~S): 0.5302252486437276 E[censored] 0.12180589924138674 E[uncensored] -0.20993497391569288
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.5302252486437276 p(~S): 0.5302252486437276
# Required time =  12.615664958953857 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian'], 'charge_degree': ['M']}
# Score: 2.8838789632308304
# Average p_delta: 0.00039050503368931455
# Average p_censor: 0.0
# p(S): 0.5302252486437276 p(~S): 0.5302252486437276 E[censored] 0.5396812207992521 E[uncensored] 0.5396812207992521
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.0
# Detected proba shift subset score: 0.0
# Detected threshold shift subset intersection over union with expected subset: 0.0020833333333333333
# Detected threshold shift subset score: 2.8838789632308304
# [0, 3, 0.0, 0.0, 0.0020833333333333333, 2.8838789632308304]
#
# ----------------------------------------------------
#
# Lambda = 10
# Required time =  17.77483630180359 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M']}
# Score: 32.38955118489848
# First Iteration
# Average p_delta: -0.05183029742562463
# Average p_censor: 0.4058605115535754
# p(S): 0.4780044461844124 p(~S): 0.546102335932438 E[censored] 0.4248148948427253 E[uncensored] 0.018954383289150323
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.5712781557789582
# p(S): 0.5461023359324397 p(~S): 0.546102335932438
# Required time =  15.665008783340454 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'sex': ['Female']}
# Score: 10.291153007377847
# Average p_delta: -0.06610118444817677
# Average p_censor: 0.4805853526438833
# p(S): 0.46373355916186143 p(~S): 0.5376317681669298 E[censored] 0.35683086570751377 E[uncensored] -0.12375448693636933
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.6518534672334877
# p(S): 0.5376317681669303 p(~S): 0.5376317681669298
# Required time =  9.250631332397461 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'race': ['Native American']}
# Score: 0.9653208819941341
# Average p_delta: 0.16107065116651872
# Average p_censor: -1.2791789017824529
# p(S): 0.690905394776557 p(~S): 0.5294876318364027 E[censored] 0.8687849674281318 E[uncensored] 2.1479638692105847
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  10.28401255607605 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian'], 'charge_degree': ['M']}
# Score: 0.3690173231010487
# Average p_delta: -0.09748590463636844
# Average p_censor: 0.5508178901593477
# p(S): 0.4323488389736698 p(~S): 0.5302252486437276 E[censored] 0.11321620134106092 E[uncensored] -0.43760168881828676
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.9949339457926216
# p(S): 0.5302252486437276 p(~S): 0.5302252486437276
# Required time =  11.361195087432861 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female'], 'race': ['African-American'], 'charge_degree': ['M']}
# Score: 0.14498792775605973
# Average p_delta: -0.13023257862445775
# Average p_censor: 1.0261883716240021
# p(S): 0.39960216498558065 p(~S): 0.5325826177114497 E[censored] 0.26111994292482227 E[uncensored] -0.76506842869918
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.8537966976760833
# p(S): 0.5325826177114495 p(~S): 0.5325826177114497
# Required time =  11.63546872138977 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Required time =  14.61797046661377 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M']}
# Score: 32.38955118489848
# First Iteration
# Average p_delta: -0.05183029742562463
# Average p_censor: 0.4058605115535754
# p(S): 0.4780044461844124 p(~S): 0.546102335932438 E[censored] 0.4248148948427253 E[uncensored] 0.018954383289150323
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.5712781557789582
# p(S): 0.5461023359324397 p(~S): 0.546102335932438
# Required time =  17.201280117034912 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Hispanic', 'Other'], 'charge_degree': ['M']}
# Score: 28.001089950323035
# Average p_delta: 0.010464854768576635
# Average p_censor: -0.14311736831142327
# p(S): 0.5402995983786155 p(~S): 0.5380346048875085 E[censored] 0.514550594994482 E[uncensored] 0.6576679633059047
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.29481418008905913
# E[censored]: 0.6576679633059067 E[uncensored]: 0.6576679633059047
# Required time =  15.507650375366211 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'sex': ['Female']}
# Score: 10.291153007377847
# Average p_delta: -0.06610118444817677
# Average p_censor: 0.4805853526438833
# p(S): 0.46373355916186143 p(~S): 0.5376317681669298 E[censored] 0.35683086570751377 E[uncensored] -0.12375448693636933
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.6518534672334877
# p(S): 0.5376317681669303 p(~S): 0.5376317681669298
# Required time =  13.740118980407715 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'under_25': [False], 'sex': ['Female']}
# Score: 5.42336194140415
# Average p_delta: 0.011784608415091186
# Average p_censor: -0.23204377334417828
# p(S): 0.5416193520251299 p(~S): 0.5354245254949371 E[censored] 0.4512375017898274 E[uncensored] 0.6832812751340052
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.42284918175167746
# E[censored]: 0.6832812751340043 E[uncensored]: 0.6832812751340052
# Required time =  11.777325630187988 seconds
# Found positive subset for ijdi scan:
# {'race': ['Caucasian'], 'charge_degree': ['M']}
# Score: 2.17804847875401
# Average p_delta: -0.06629341110059783
# Average p_censor: 0.3708205764635511
# p(S): 0.4635413325094403 p(~S): 0.5460346321275429 E[censored] 0.25922048028959954 E[uncensored] -0.11160009617395122
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.7918573028859852
# p(S): 0.5460346321275422 p(~S): 0.5460346321275429
# Required time =  13.486784934997559 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['M'], 'sex': ['Male'], 'race': ['Caucasian']}
# Score: 103.45486574347497
# Average p_delta: 0.025052798333940248
# Average p_censor: -0.19189746470574945
# p(S): 0.5548875419439782 p(~S): 0.5408782012315648 E[censored] 0.6863700302178738 E[uncensored] 0.8782674949236238
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.6118594624074267
# E[censored]: 0.878267494923622 E[uncensored]: 0.8782674949236238
# Required time =  14.451852321624756 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M'], 'race': ['Caucasian']}
# Score: 33.35454461514628
# Average p_delta: 0.025052798333940248
# Average p_censor: -5.441409290652941e-17
# p(S): 0.5548875419439782 p(~S): 0.5408782012315648 E[censored] 0.878267494923622 E[uncensored] 0.8782674949236238
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.0
# Detected proba shift subset score: 0.0
# Detected threshold shift subset intersection over union with expected subset: 0.0
# Detected threshold shift subset score: 33.35454461514628
# [0, 10, 0.0, 0.0, 0.0, 33.35454461514628]
#
# ----------------------------------------------------
#
# Simulation 3 of 10
# Lambda = 0
# Required time =  20.96042513847351 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'charge_degree': ['F'], 'sex': ['Male']}
# Score: 68.96609281983771
# First Iteration
# Average p_delta: 0.08248877776061499
# Average p_censor: 0.0
# p(S): 0.6124208705199295 p(~S): 0.48246025876587684 E[censored] 0.5318432333129206 E[uncensored] 0.5318432333129206
# Subset does not violate p_delta or p_censor conditions!
# Required time =  22.156225204467773 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'sex': ['Male'], 'charge_degree': ['F']}
# Score: 68.96609281983771
# First Iteration
# Average p_delta: 0.08248877776061499
# Average p_censor: 0.0
# p(S): 0.6124208705199295 p(~S): 0.48246025876587684 E[censored] 0.5318432333129206 E[uncensored] 0.5318432333129206
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.2315160567587752
# Detected proba shift subset score: 68.96609281983771
# Detected threshold shift subset intersection over union with expected subset: 0.2315160567587752
# Detected threshold shift subset score: 68.96609281983771
# [0, 0, 0.2315160567587752, 68.96609281983771, 0.2315160567587752, 68.96609281983771]
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Required time =  20.629224061965942 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'sex': ['Male']}
# Score: 52.58451553637356
# First Iteration
# Average p_delta: 0.06367216283879923
# Average p_censor: 0.0
# p(S): 0.5936042555981113 p(~S): 0.4665710950413029 E[censored] 0.5509448821645606 E[uncensored] 0.5509448821645606
# Subset does not violate p_delta or p_censor conditions!
# Required time =  25.674257516860962 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'sex': ['Male']}
# Score: 52.58451553637356
# First Iteration
# Average p_delta: 0.06367216283879923
# Average p_censor: 0.0
# p(S): 0.5936042555981113 p(~S): 0.4665710950413029 E[censored] 0.5509448821645606 E[uncensored] 0.5509448821645606
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.23008849557522124
# Detected proba shift subset score: 52.58451553637356
# Detected threshold shift subset intersection over union with expected subset: 0.23008849557522124
# Detected threshold shift subset score: 52.58451553637356
# [0, 0.3, 0.23008849557522124, 52.58451553637356, 0.23008849557522124, 52.58451553637356]
#
# ----------------------------------------------------
#
# Lambda = 1
# Required time =  19.350756883621216 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'sex': ['Male']}
# Score: 24.69158536129562
# First Iteration
# Average p_delta: 0.06367216283879923
# Average p_censor: 0.0
# p(S): 0.5936042555981113 p(~S): 0.4665710950413029 E[censored] 0.5955153961517137 E[uncensored] 0.5955153961517137
# Subset does not violate p_delta or p_censor conditions!
# Required time =  18.68242907524109 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'sex': ['Male']}
# Score: 24.69158536129562
# First Iteration
# Average p_delta: 0.06367216283879923
# Average p_censor: 0.0
# p(S): 0.5936042555981113 p(~S): 0.4665710950413029 E[censored] 0.5955153961517137 E[uncensored] 0.5955153961517137
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.23008849557522124
# Detected proba shift subset score: 24.69158536129562
# Detected threshold shift subset intersection over union with expected subset: 0.23008849557522124
# Detected threshold shift subset score: 24.69158536129562
# [0, 1, 0.23008849557522124, 24.69158536129562, 0.23008849557522124, 24.69158536129562]
#
# ----------------------------------------------------
#
# Lambda = 3
# Required time =  13.379818201065063 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Native American', 'Other'], 'charge_degree': ['M'], 'sex': ['Male']}
# Score: 4.758589568726103
# First Iteration
# Average p_delta: 0.0007142071069340579
# Average p_censor: 0.0072150406413487725
# p(S): 0.5306462998662511 p(~S): 0.5298129306589479 E[censored] 0.5412008952750719 E[uncensored] 0.5339858546337235
# Subset does not violate p_delta or p_censor conditions!
# Required time =  14.942317724227905 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian', 'Native American', 'Other'], 'charge_degree': ['M'], 'sex': ['Male']}
# Score: 4.758589568726103
# First Iteration
# Average p_delta: 0.0007142071069340579
# Average p_censor: 0.0072150406413487725
# p(S): 0.5306462998662511 p(~S): 0.5298129306589479 E[censored] 0.5412008952750719 E[uncensored] 0.5339858546337235
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.09489916963226572
# Detected proba shift subset score: 4.758589568726103
# Detected threshold shift subset intersection over union with expected subset: 0.09489916963226572
# Detected threshold shift subset score: 4.758589568726103
# [0, 3, 0.09489916963226572, 4.758589568726103, 0.09489916963226572, 4.758589568726103]
#
# ----------------------------------------------------
#
# Lambda = 10
# Required time =  15.764167308807373 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M']}
# Score: 39.365395618734325
# First Iteration
# Average p_delta: -0.04290610911590639
# Average p_censor: 0.3332188720887771
# p(S): 0.4870259836434108 p(~S): 0.5440595010925584 E[censored] 0.4360010142426311 E[uncensored] 0.1027821421538567
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.519030723434717
# p(S): 0.5440595010925573 p(~S): 0.5440595010925584
# Required time =  10.68711543083191 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female']}
# Score: 9.682421524522676
# Average p_delta: -0.10648631110470076
# Average p_censor: 0.8245462211701214
# p(S): 0.4234457816546172 p(~S): 0.5504206966118858 E[censored] 0.29152634343603445 E[uncensored] -0.5330198777340872
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.8175213419181403
# p(S): 0.5504206966118852 p(~S): 0.5504206966118858
# Required time =  9.64622688293457 seconds
# Found positive subset for ijdi scan:
# {'race': ['Asian', 'Native American']}
# Score: 1.7739207593942468
# Average p_delta: 0.06303914478314736
# Average p_censor: -0.5341217606701032
# p(S): 0.5929712375424653 p(~S): 0.5297409795690134 E[censored] 0.6281129204742913 E[uncensored] 1.1622346811443944
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  12.360808372497559 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Required time =  17.948609352111816 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M']}
# Score: 39.365395618734325
# First Iteration
# Average p_delta: -0.04290610911590639
# Average p_censor: 0.3332188720887771
# p(S): 0.4870259836434108 p(~S): 0.5440595010925584 E[censored] 0.4360010142426311 E[uncensored] 0.1027821421538567
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.519030723434717
# p(S): 0.5440595010925573 p(~S): 0.5440595010925584
# Required time =  18.76706027984619 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['M']}
# Score: 48.716613154094055
# Average p_delta: -0.01823771817252287
# Average p_censor: 0.05863704194222796
# p(S): 0.5116943745867935 p(~S): 0.5580356736520398 E[censored] 0.4249519687276968 E[uncensored] 0.36631492678546873
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.5324548942399304
# p(S): 0.5580356736520382 p(~S): 0.5580356736520398
# Required time =  15.747698783874512 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['M']}
# Score: 90.50475024457549
# Average p_delta: 0.028103580892721684
# Average p_censor: -0.3183960807197615
# p(S): 0.5580356736520382 p(~S): 0.5580356736520398 E[censored] 0.5845013326165212 E[uncensored] 0.9028974133362847
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.7662986808713423
# E[censored]: 0.9028974133362807 E[uncensored]: 0.9028974133362847
# Required time =  11.480967283248901 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['F'], 'sex': ['Female']}
# Score: 9.248716520039654
# Average p_delta: -0.0761397726799168
# Average p_censor: 0.5801202188887736
# p(S): 0.4537923200794012 p(~S): 0.5391002094696628 E[censored] 0.3505657254025267 E[uncensored] -0.2295544934862474
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.6800874355833868
# p(S): 0.5391002094696625 p(~S): 0.5391002094696628
# Required time =  9.724668741226196 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'sex': ['Female'], 'charge_degree': ['F']}
# Score: 1.609797425624049
# Average p_delta: 0.011940143347365427
# Average p_censor: -0.2788859064258401
# p(S): 0.5418722361066836 p(~S): 0.5371912666019727 E[censored] 0.47401215901352173 E[uncensored] 0.7528980654393629
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.5302135994299711
# E[censored]: 0.7528980654393614 E[uncensored]: 0.7528980654393629
# Required time =  10.035545587539673 seconds
# Found positive subset for ijdi scan:
# {'race': ['Native American']}
# Score: 0.47424389310922666
# Average p_delta: 0.08384974914438324
# Average p_censor: -0.6525026823382626
# p(S): 0.6137818419037012 p(~S): 0.5297167905756592 E[censored] 0.7701121614409258 E[uncensored] 1.4226148437791883
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] >= 1. Pushing all p_hat values below 1 to 1.
# E[censored]: 1.0
# Required time =  13.398527145385742 seconds
# Found positive subset for ijdi scan:
# {}
# Score: 0.0
# No subset was detected.
# Detected proba shift subset intersection over union with expected subset: 0.0
# Detected proba shift subset score: 0.0
# Detected threshold shift subset intersection over union with expected subset: 0.0
# Detected threshold shift subset score: 0.0
# [0, 10, 0.0, 0.0, 0.0, 0.0]
#
# ----------------------------------------------------
#
# Simulation 4 of 10
# Lambda = 0
# Required time =  19.401456594467163 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 73.12355529013855
# First Iteration
# Average p_delta: 0.06303999228743742
# Average p_censor: 0.0
# p(S): 0.5970677872840111 p(~S): 0.4692925433793416 E[censored] 0.5402653502005643 E[uncensored] 0.5402653502005643
# Subset does not violate p_delta or p_censor conditions!
# Required time =  19.410143613815308 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 73.12355529013855
# First Iteration
# Average p_delta: 0.06303999228743742
# Average p_censor: 0.0
# p(S): 0.5970677872840111 p(~S): 0.4692925433793416 E[censored] 0.5402653502005643 E[uncensored] 0.5402653502005643
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.23327515997673065
# Detected proba shift subset score: 73.12355529013855
# Detected threshold shift subset intersection over union with expected subset: 0.23327515997673065
# Detected threshold shift subset score: 73.12355529013855
# [0, 0, 0.23327515997673065, 73.12355529013855, 0.23327515997673065, 73.12355529013855]
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Required time =  23.534883499145508 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 56.47956205124042
# First Iteration
# Average p_delta: 0.06303999228743742
# Average p_censor: 0.0
# p(S): 0.5970677872840111 p(~S): 0.4692925433793416 E[censored] 0.559177347886787 E[uncensored] 0.559177347886787
# Subset does not violate p_delta or p_censor conditions!
# Required time =  21.579339265823364 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Native American']}
# Score: 56.47956205124042
# First Iteration
# Average p_delta: 0.06303999228743742
# Average p_censor: 0.0
# p(S): 0.5970677872840111 p(~S): 0.4692925433793416 E[censored] 0.559177347886787 E[uncensored] 0.559177347886787
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.23327515997673065
# Detected proba shift subset score: 56.47956205124042
# Detected threshold shift subset intersection over union with expected subset: 0.23327515997673065
# Detected threshold shift subset score: 56.47956205124042
# [0, 0.3, 0.23327515997673065, 56.47956205124042, 0.23327515997673065, 56.47956205124042]
#
# ----------------------------------------------------
#
# Lambda = 1
# Required time =  17.797637701034546 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 27.72844995801837
# First Iteration
# Average p_delta: 0.06303999228743742
# Average p_censor: 0.0
# p(S): 0.5970677872840111 p(~S): 0.4692925433793416 E[censored] 0.6033053424879932 E[uncensored] 0.6033053424879932
# Subset does not violate p_delta or p_censor conditions!
# Required time =  20.23135733604431 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Native American'], 'sex': ['Male']}
# Score: 27.72844995801837
# First Iteration
# Average p_delta: 0.06303999228743742
# Average p_censor: 0.0
# p(S): 0.5970677872840111 p(~S): 0.4692925433793416 E[censored] 0.6033053424879932 E[uncensored] 0.6033053424879932
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 0.23327515997673065
# Detected proba shift subset score: 27.72844995801837
# Detected threshold shift subset intersection over union with expected subset: 0.23327515997673065
# Detected threshold shift subset score: 27.72844995801837
# [0, 1, 0.23327515997673065, 27.72844995801837, 0.23327515997673065, 27.72844995801837]
#
# ----------------------------------------------------
#
# Lambda = 3
# Required time =  17.55249810218811 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'race': ['African-American', 'Hispanic', 'Native American', 'Other'], 'charge_degree': ['M']}
# Score: 9.804782924676795
# First Iteration
# Average p_delta: -0.01685810027073197
# Average p_censor: 0.023013820221131076
# p(S): 0.517169694725847 p(~S): 0.537488438860263 E[censored] 0.5127048696094897 E[uncensored] 0.48969104938835917
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.23293983399664414
# p(S): 0.5374884388602624 p(~S): 0.537488438860263
# Required time =  21.19746232032776 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['M'], 'sex': ['Male']}
# Score: 3.1882899850510027
# Average p_delta: -0.02962536098845888
# Average p_censor: 0.01626701891813241
# p(S): 0.5044024340081203 p(~S): 0.5484039693900624 E[censored] 0.46765628615331173 E[uncensored] 0.45138926723518014
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.4589008227413321
# p(S): 0.548403969390062 p(~S): 0.5484039693900624
# Required time =  13.217979669570923 seconds
# Found positive subset for ijdi scan:
# {'charge_degree': ['M'], 'race': ['Native American']}
# Score: 0.82665010385806
# Average p_delta: 0.10455578113657393
# Average p_censor: -0.12094282154185294
# p(S): 0.6385835761331539 p(~S): 0.5339325447355971 E[censored] 0.7329898720684244 E[uncensored] 0.8539326936102772
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.45295218753966476
# E[censored]: 0.8539326936102772 E[uncensored]: 0.8539326936102772
# Required time =  11.213584899902344 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female'], 'race': ['Native American']}
# Score: 0.5402402702683855
# Average p_delta: -0.02108886006618038
# Average p_censor: 0.0
# p(S): 0.5129389349303995 p(~S): 0.5340343039040077 E[censored] 0.4769987700020143 E[uncensored] 0.4769987700020143
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 1.0
# p(S): 0.5340343039040077 p(~S): 0.5340343039040077
# Required time =  10.459025859832764 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Female'], 'race': ['Native American']}
# Score: 0.4156578777971511
# Average p_delta: 6.5089074278157355e-06
# Average p_censor: 0.0
# p(S): 0.5340343039040077 p(~S): 0.5340343039040077 E[censored] 0.5402848769228389 E[uncensored] 0.5402848769228389
# Subset does not violate p_delta or p_censor conditions!
# Required time =  17.287984132766724 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Hispanic', 'Native American', 'Other'], 'sex': ['Male'], 'charge_degree': ['M']}
# Score: 9.804782924676795
# First Iteration
# Average p_delta: -0.01685810027073197
# Average p_censor: 0.023013820221131076
# p(S): 0.517169694725847 p(~S): 0.537488438860263 E[censored] 0.5127048696094897 E[uncensored] 0.48969104938835917
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.23293983399664414
# p(S): 0.5374884388602624 p(~S): 0.537488438860263
# Required time =  20.805697917938232 seconds
# Found positive subset for ijdi scan:
# {'sex': ['Male'], 'charge_degree': ['M']}
# Score: 3.1882899850510027
# Average p_delta: -0.02962536098845888
# Average p_censor: 0.01626701891813241
# p(S): 0.5044024340081203 p(~S): 0.5484039693900624 E[censored] 0.46765628615331173 E[uncensored] 0.45138926723518014
# Subset violates p_delta condition. Adjusting and Re-running...
# Alpha Ratio: 0.4589008227413321
# p(S): 0.548403969390062 p(~S): 0.5484039693900624
# Required time =  11.461693525314331 seconds
# Found positive subset for ijdi scan:
# {'under_25': [False], 'sex': ['Male'], 'race': ['African-American', 'Native American'], 'charge_degree': ['M']}
# Score: 1.3227420827072507
# Average p_delta: 0.05852503226649113
# Average p_censor: -0.05825209755896529
# p(S): 0.5925528272630719 p(~S): 0.532059946655139 E[censored] 0.6720900464481591 E[uncensored] 0.7303421440071239
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.1776466280696665
# E[censored]: 0.7303421440071247 E[uncensored]: 0.7303421440071239
# ...
# Score: 251.08234181460938
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: 0.0
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.603330834402492 E[uncensored] 0.603330834402492
# Subset does not violate p_delta or p_censor conditions!
# Required time =  15.379698514938354 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 251.08234181460938
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: 0.0
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.603330834402492 E[uncensored] 0.603330834402492
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 251.08234181460938
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 251.08234181460938
# [3, 0.3, 1.0, 251.08234181460938, 1.0, 251.08234181460938]
#
# ----------------------------------------------------
#
# Lambda = 1
# Required time =  16.837745904922485 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 251.35430724822908
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: 0.0
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6194799607494551 E[uncensored] 0.6194799607494551
# Subset does not violate p_delta or p_censor conditions!
# Required time =  13.81466817855835 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 251.35430724822908
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: 0.0
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6194799607494551 E[uncensored] 0.6194799607494551
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 251.35430724822908
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 251.35430724822908
# [3, 1, 1.0, 251.35430724822908, 1.0, 251.35430724822908]
#
# ----------------------------------------------------
#
# Lambda = 3
# Required time =  12.659210681915283 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 904.223592385438
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: -0.03386881379986338
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6317515079409227 E[uncensored] 0.6656203217407867
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.0919727155174066
# E[censored]: 0.6656203217407877 E[uncensored]: 0.6656203217407867
# Required time =  13.924997091293335 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 302.27275979556833
# Average p_delta: 0.023070180495665213
# Average p_censor: -5.551115123125783e-18
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6656203217407877 E[uncensored] 0.6656203217407867
# Subset does not violate p_delta or p_censor conditions!
# Required time =  12.363860130310059 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 904.223592385438
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: -0.03386881379986338
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6317515079409227 E[uncensored] 0.6656203217407867
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.0919727155174066
# E[censored]: 0.6656203217407877 E[uncensored]: 0.6656203217407867
# Required time =  11.567525148391724 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 302.27275979556833
# Average p_delta: 0.023070180495665213
# Average p_censor: -5.551115123125783e-18
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6656203217407877 E[uncensored] 0.6656203217407867
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 302.27275979556833
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 302.27275979556833
# [3, 3, 1.0, 302.27275979556833, 1.0, 302.27275979556833]
#
# ----------------------------------------------------
#
# Lambda = 10
# Required time =  14.795515537261963 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 2057.248791316065
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: -0.2035105736159061
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6236010115945364 E[uncensored] 0.8271115852104423
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.5406777910802498
# E[censored]: 0.8271115852104451 E[uncensored]: 0.8271115852104423
# Required time =  13.513766527175903 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 111.72928954289382
# Average p_delta: 0.023070180495665213
# Average p_censor: -4.194175870806147e-17
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.8271115852104451 E[uncensored] 0.8271115852104423
# Subset does not violate p_delta or p_censor conditions!
# Required time =  13.6909761428833 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 2057.248791316065
# First Iteration
# Average p_delta: 0.023070180495665213
# Average p_censor: -0.2035105736159061
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.6236010115945364 E[uncensored] 0.8271115852104423
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.5406777910802498
# E[censored]: 0.8271115852104451 E[uncensored]: 0.8271115852104423
# Required time =  12.889019012451172 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 111.72928954289382
# Average p_delta: 0.023070180495665213
# Average p_censor: -4.194175870806147e-17
# p(S): 0.5565378974223668 p(~S): 0.5292938355870258 E[censored] 0.8271115852104451 E[uncensored] 0.8271115852104423
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 111.72928954289382
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 111.72928954289382
# [3, 10, 1.0, 111.72928954289382, 1.0, 111.72928954289382]
#
# ----------------------------------------------------
#
# Simulation 10 of 10
# Lambda = 0
# Required time =  17.54741621017456 seconds
# Found positive subset for ijdi scan:
# {'under_25': [True], 'race': ['African-American', 'Asian']}
# Score: 241.5438875598822
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: 0.0
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.5971068020929498 E[uncensored] 0.5971068020929498
# Subset does not violate p_delta or p_censor conditions!
# Required time =  14.655545949935913 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 241.5438875598822
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: 0.0
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.5971068020929498 E[uncensored] 0.5971068020929498
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 241.5438875598822
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 241.5438875598822
# [3, 0, 1.0, 241.5438875598822, 1.0, 241.5438875598822]
#
# ----------------------------------------------------
#
# Lambda = 0.3
# Required time =  13.296642780303955 seconds
# Found positive subset for ijdi scan:
# {'under_25': [True], 'race': ['African-American', 'Asian']}
# Score: 237.59120847706907
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: 0.0
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6037879305196115 E[uncensored] 0.6037879305196115
# Subset does not violate p_delta or p_censor conditions!
# Required time =  14.07757306098938 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 237.59120847706907
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: 0.0
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6037879305196115 E[uncensored] 0.6037879305196115
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 237.59120847706907
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 237.59120847706907
# [3, 0.3, 1.0, 237.59120847706907, 1.0, 237.59120847706907]
#
# ----------------------------------------------------
#
# Lambda = 1
# Required time =  15.453245639801025 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 238.94507205586268
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: 0.0
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6193772301818191 E[uncensored] 0.6193772301818191
# Subset does not violate p_delta or p_censor conditions!
# Required time =  16.289594173431396 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 238.94507205586268
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: 0.0
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6193772301818191 E[uncensored] 0.6193772301818191
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 238.94507205586268
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 238.94507205586268
# [3, 1, 1.0, 238.94507205586268, 1.0, 238.94507205586268]
#
# ----------------------------------------------------
#
# Lambda = 3
# Required time =  12.365609169006348 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 842.7309084808142
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: -0.0385576910444566
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.625360395315095 E[uncensored] 0.6639180863595516
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.10291942059058609
# E[censored]: 0.6639180863595516 E[uncensored]: 0.6639180863595516
# Required time =  13.441029071807861 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 284.63393312007355
# Average p_delta: 0.022270428088866607
# Average p_censor: 5.42091839315908e-17
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6639180863595516 E[uncensored] 0.6639180863595516
# Subset does not violate p_delta or p_censor conditions!
# Required time =  11.236442565917969 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 842.7309084808142
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: -0.0385576910444566
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.625360395315095 E[uncensored] 0.6639180863595516
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.10291942059058609
# E[censored]: 0.6639180863595516 E[uncensored]: 0.6639180863595516
# Required time =  9.941474437713623 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 284.63393312007355
# Average p_delta: 0.022270428088866607
# Average p_censor: 5.42091839315908e-17
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6639180863595516 E[uncensored] 0.6639180863595516
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 284.63393312007355
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 284.63393312007355
# [3, 3, 1.0, 284.63393312007355, 1.0, 284.63393312007355]
#
# ----------------------------------------------------
#
# Lambda = 10
# Required time =  12.91725492477417 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 2101.245368324031
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: -0.21176423676082137
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6080468462207962 E[uncensored] 0.8198110829816196
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.5402794561518274
# E[censored]: 0.8198110829816201 E[uncensored]: 0.8198110829816196
# Required time =  12.578883171081543 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 110.80173333572857
# Average p_delta: 0.022270428088866607
# Average p_censor: 1.5623607596004334e-17
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.8198110829816201 E[uncensored] 0.8198110829816196
# Subset does not violate p_delta or p_censor conditions!
# Required time =  16.3612117767334 seconds
# Found positive subset for ijdi scan:
# {'race': ['African-American', 'Asian'], 'under_25': [True]}
# Score: 2101.245368324031
# First Iteration
# Average p_delta: 0.022270428088866607
# Average p_censor: -0.21176423676082137
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.6080468462207962 E[uncensored] 0.8198110829816196
# Subset violates p_censor condition. Adjusting and Re-running...
# E[uncensored] < 1. Pushing all p_hat values below 1 toward 1 so that E[censored] = E[uncensored].
# Beta Ratio: 0.5402794561518274
# E[censored]: 0.8198110829816201 E[uncensored]: 0.8198110829816196
# Required time =  13.176127910614014 seconds
# Found positive subset for ijdi scan:
# {'under_25': [True], 'race': ['African-American', 'Asian']}
# Score: 110.80173333572857
# Average p_delta: 0.022270428088866607
# Average p_censor: 1.5623607596004334e-17
# p(S): 0.5559927187137993 p(~S): 0.5299651572531063 E[censored] 0.8198110829816201 E[uncensored] 0.8198110829816196
# Subset does not violate p_delta or p_censor conditions!
# Detected proba shift subset intersection over union with expected subset: 1.0
# Detected proba shift subset score: 110.80173333572857
# Detected threshold shift subset intersection over union with expected subset: 1.0
# Detected threshold shift subset score: 110.80173333572857
# [3, 10, 1.0, 110.80173333572857, 1.0, 110.80173333572857]
#
# ----------------------------------------------------

# %%
columns = ['e', 'lambda', 'proba_shift_iou', 'proba_shift_score', 'threshold_shift_iou', 'threshold_shift_score']
sim_result_df = pd.DataFrame(sim_data, columns=columns)
sim_result_df
# Out:
#        e  lambda  proba_shift_iou  proba_shift_score  threshold_shift_iou  \
# 0    0.0     0.0         0.256499          80.585669             0.256499
# 1    0.0     0.3         0.256499          62.386915             0.256499
# 2    0.0     1.0         0.256499          30.878852             0.256499
# 3    0.0     3.0         0.098818           6.064567             0.098818
# 4    0.0    10.0         0.000000           0.000000             0.000000
# ..   ...     ...              ...                ...                  ...
# 145  3.0     0.0         1.000000         241.543888             1.000000
# 146  3.0     0.3         1.000000         237.591208             1.000000
# 147  3.0     1.0         1.000000         238.945072             1.000000
# 148  3.0     3.0         1.000000         284.633933             1.000000
# 149  3.0    10.0         1.000000         110.801733             1.000000
#
#      threshold_shift_score
# 0                80.585669
# 1                62.386915
# 2                30.878852
# 3                 6.064567
# 4                 4.845087
# ..                     ...
# 145             241.543888
# 146             237.591208
# 147             238.945072
# 148             284.633933
# 149             110.801733
#
# [150 rows x 6 columns]

# %%
# Write recipe outputs
sim_result_df.to_csv(home_dir + "datasets/compas_sim_2_pos.csv")
